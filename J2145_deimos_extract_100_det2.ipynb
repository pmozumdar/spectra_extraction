# %%
from specim_test.specim.specfuncs import spec2d, spec1d
from astropy.io import fits as pf
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
#infile = 'J2145_deimos_det2_101_clean.fits'
infile = 'J2145_DEIMOS_spectra/J2145_deimos_det2_100_clean.fits'

# %%
spec = spec2d.Spec2d(infile, hext=1, varext=2, xtrim=[0, -10])
# Out:
# Loading file J2145_DEIMOS_spectra/J2145_deimos_det2_100_clean.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from J2145_DEIMOS_spectra/J2145_deimos_det2_100_clean.fits (HDU=1)
# The input dataset was trimmed
#  xrange: 0:-9.  yrange: 0:4096
# Final data dimensions (x y): 82 x 4096
#
# Dispersion axis:              x
# N_pixels along dispersion axis: 82

# %%
wavim  = pf.open(infile)[4].data
diff = []
spec_pix = np.arange(4096)
for i in range(wavim.shape[0]):
    diff.append(np.max(wavim[i:i+1, :]) - np.min(wavim[i:i+1, :]))
    
plt.figure(facecolor='white') #'#94F008'
plt.plot(spec_pix[280:], diff[280:] , '.')
plt.xlabel('dispersion axis')
plt.ylabel('Angstrom')
# Out:
# Text(0, 0.5, 'Angstrom')

# %%
spec.set_dispaxis('y')
spec.do_waverect(doplot=True)
# Out:
# Old value of dispaxis: x
#
# Dispersion axis:              y
# N_pixels along dispersion axis: 4096
#
#
# Dispersion : 0.630000
# Found 990 NaNs in the two-dimensional spectrum
#
# sky subtracted and cosmic ray rejected data has been resampled along with vardata in place of the coordinateds whcih rectify the tilted wave image

# %%
#%matplotlib notebook
profile = spec.spatial_profile(pixrange=[2100, 2500])
# Out:
# Profile max value (before normalization) 3237.756348

# %%
spec.initial_model()
# Out:
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 3
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 2
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 300, 49.35, 2
#
# amplitude=300.000000, mu=49.350000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3100, 62.5, 3, 4
#
# amplitude=3100.000000, x_0=62.500000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 2800, 60, 3, 4
#
# amplitude=2800.000000, x_0=60.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 3 :  50, 53.5, 2, 3
#
# amplitude=50.000000, x_0=53.500000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3] + [4]
# Components:
#     [0]: <Polynomial1D(0, c0=15.98165146)>
#
#     [1]: <Gaussian1D(amplitude=198.59466675, mean=49.78996264, stddev=2.24793311)>
#
#     [2]: <Moffat1D(amplitude=2874.03594876, x_0=62.63561172, gamma=3.21828532, alpha=3.41691098)>
#
#     [3]: <Moffat1D(amplitude=2660.25366287, x_0=59.79579211, gamma=3.34460613, alpha=3.16302678)>
#
#     [4]: <Moffat1D(amplitude=197.83567673, x_0=56.76565028, gamma=4.38927456, alpha=0.69193751)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_4           alpha_4
#     ------------------ ------------------ ... ----------------- -----------------
#     15.981651463475318 198.59466675176105 ... 4.389274555670273 0.691937513525162
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# <CompoundModel(c0_0=15.98165146, amplitude_1=198.59466675, mean_1=49.78996264, stddev_1=2.24793311, amplitude_2=2874.03594876, x_0_2=62.63561172, gamma_2=3.21828532, alpha_2=3.41691098, amplitude_3=2660.25366287, x_0_3=59.79579211, gamma_3=3.34460613, alpha_3=3.16302678, amplitude_4=197.83567673, x_0_4=56.76565028, gamma_4=4.38927456, alpha_4=0.69193751)>

# %%
spec.initial_model()
# Out:
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 3
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 3
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 50, 49.35, 2
#
# amplitude=50.000000, mu=49.350000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3100, 62.5, 3, 4
#
# amplitude=3100.000000, x_0=62.500000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 2800, 60, 3, 4
#
# amplitude=2800.000000, x_0=60.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 3 : 50, 53.5, 2, 3
#
# amplitude=50.000000, x_0=53.500000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3] + [4]
# Components:
#     [0]: <Polynomial1D(0, c0=13.25519853)>
#
#     [1]: <Gaussian1D(amplitude=140.83510218, mean=57.91490075, stddev=6.95518286)>
#
#     [2]: <Moffat1D(amplitude=2850.62830685, x_0=62.63865966, gamma=3.20128472, alpha=3.45544916)>
#
#     [3]: <Moffat1D(amplitude=2616.69789427, x_0=59.8049708, gamma=3.29873243, alpha=3.25868361)>
#
#     [4]: <Moffat1D(amplitude=170.353059, x_0=56.84166721, gamma=4.82184152, alpha=0.64824547)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_4           alpha_4
#     ------------------ ------------------ ... ----------------- ------------------
#     13.255198534181211 140.83510217874618 ... 4.821841515876407 0.6482454660701464
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# <CompoundModel(c0_0=13.25519853, amplitude_1=140.83510218, mean_1=57.91490075, stddev_1=6.95518286, amplitude_2=2850.62830685, x_0_2=62.63865966, gamma_2=3.20128472, alpha_2=3.45544916, amplitude_3=2616.69789427, x_0_3=59.8049708, gamma_3=3.29873243, alpha_3=3.25868361, amplitude_4=170.353059, x_0_4=56.84166721, gamma_4=4.82184152, alpha_4=0.64824547)>

# %%
spec.initial_model()
# Out:
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 4
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3100, 62.5, 3, 4
#
# amplitude=3100.000000, x_0=62.500000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 2800, 60, 3, 4
#
# amplitude=2800.000000, x_0=60.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 3 : 50, 53.5, 2, 3
#
# amplitude=50.000000, x_0=53.500000, gamma=2.000000, alpha=3.000000
#
# Parameters of Moffat profile 4 : 50, 50.35, 3, 4
#
# amplitude=50.000000, x_0=50.350000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3] + [4]
# Components:
#     [0]: <Polynomial1D(0, c0=11.10677212)>
#
#     [1]: <Moffat1D(amplitude=2830.15421761, x_0=62.63782594, gamma=3.208407, alpha=3.42736163)>
#
#     [2]: <Moffat1D(amplitude=2625.72331247, x_0=59.78971093, gamma=3.32977981, alpha=3.18681328)>
#
#     [3]: <Moffat1D(amplitude=195.20879882, x_0=56.45319719, gamma=4.16306533, alpha=0.79765034)>
#
#     [4]: <Moffat1D(amplitude=101.82634882, x_0=55.22432661, gamma=4.98301654, alpha=0.52953332)>
# Parameters:
#            c0_0           amplitude_1     ...     gamma_4           alpha_4
#     ------------------ ------------------ ... ---------------- -----------------
#     11.106772122305996 2830.1542176136654 ... 4.98301654449185 0.529533322792052
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# <CompoundModel(c0_0=11.10677212, amplitude_1=2830.15421761, x_0_1=62.63782594, gamma_1=3.208407, alpha_1=3.42736163, amplitude_2=2625.72331247, x_0_2=59.78971093, gamma_2=3.32977981, alpha_2=3.18681328, amplitude_3=195.20879882, x_0_3=56.45319719, gamma_3=4.16306533, alpha_3=0.79765034, amplitude_4=101.82634882, x_0_4=55.22432661, gamma_4=4.98301654, alpha_4=0.52953332)>

# %%
def tie_pos1_moffat(model):
     return model.x_0_2 - 2.7
            
def tie_pos2_moffat(model):
    return model.x_0_2 - 9.1

def tie_pos3_moffat(model):
    return model.x_0_2 - 12.3

def tie_gamma_moffat(model):
    return model.gamma_2

def tie_alpha_moffat(model):
    return model.alpha_2 

spec.mod0[1].mean.tied = tie_pos3_moffat
spec.mod0[3].x_0.tied = tie_pos1_moffat
spec.mod0[4].x_0.tied = tie_pos2_moffat
#spec.mod0[4].x_0.tied = tie_pos3_moffat
#spec.mod0[2].gamma.tied = tie_gamma_moffat
#spec.mod0[2].alpha.tied = tie_alpha_moffat
spec.mod0[3].gamma.tied = tie_gamma_moffat
spec.mod0[3].alpha.tied = tie_alpha_moffat
spec.mod0[4].gamma.tied = tie_gamma_moffat
spec.mod0[4].alpha.tied = tie_alpha_moffat
spec.refined_model(spec.mod0)
# Out:
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3] + [4]
# Components:
#     [0]: <Polynomial1D(0, c0=15.98165146)>
#
#     [1]: <Gaussian1D(amplitude=198.59466675, mean=49.78996264, stddev=2.24793311)>
#
#     [2]: <Moffat1D(amplitude=2874.03594876, x_0=62.63561172, gamma=3.21828532, alpha=3.41691098)>
#
#     [3]: <Moffat1D(amplitude=2660.25366287, x_0=59.79579211, gamma=3.34460613, alpha=3.16302678)>
#
#     [4]: <Moffat1D(amplitude=197.83567673, x_0=56.76565028, gamma=4.38927456, alpha=0.69193751)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_4           alpha_4
#     ------------------ ------------------ ... ----------------- -----------------
#     15.981651463475318 198.59466675176105 ... 4.389274555670273 0.691937513525162
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3] + [4]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.71271935)>
#
#     [1]: <Gaussian1D(amplitude=138.55550277, mean=49.67195515, stddev=4.92681133)>
#
#     [2]: <Moffat1D(amplitude=2522.09728678, x_0=61.97195515, gamma=6.04215303, alpha=3.33542491)>
#
#     [3]: <Moffat1D(amplitude=1231.17059618, x_0=59.27195515, gamma=6.04215303, alpha=3.33542491)>
#
#     [4]: <Moffat1D(amplitude=46.46788576, x_0=52.87195515, gamma=6.04215303, alpha=3.33542491)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_4            alpha_4
#     ------------------- ------------------ ... ------------------ ------------------
#     -1.7127193544529886 138.55550277499736 ... 6.0421530321461585 3.3354249075844384
#
# -------------------------------------------
# <CompoundModel(c0_0=-1.71271935, amplitude_1=138.55550277, mean_1=49.67195515, stddev_1=4.92681133, amplitude_2=2522.09728678, x_0_2=61.97195515, gamma_2=6.04215303, alpha_2=3.33542491, amplitude_3=1231.17059618, x_0_3=59.27195515, gamma_3=6.04215303, alpha_3=3.33542491, amplitude_4=46.46788576, x_0_4=52.87195515, gamma_4=6.04215303, alpha_4=3.33542491)>

# %%
spec.find_and_trace(spec.mod0, stepsize=25, fitorder={'x_0_1':4, 'x_0_2':4, 'x_0_3':4, 'x_0_4':4, 'mean_1':4},
                    fitrange=[1200, 3800], polyorder=3)
# Out:
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Fitting polynomial of degree 4 to parameter: x_0_4
# Fitting polynomial of degree 3 to parameter: gamma_4
# Fitting polynomial of degree 3 to parameter: alpha_4

# %%
spec.extract(method='modelfit', extrange=[1000, -1])#[1000, -1]
# Out:
# Fitting to 4 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1000 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  5355.16
#  Spectrum End:     7304.91
#  Dispersion (1st pixel):   0.63
#  Dispersion (average):      0.63
#
#  Spectrum Start:  5355.16
#  Spectrum End:     7304.91
#  Dispersion (1st pixel):   0.63
#  Dispersion (average):      0.63
#
#  Spectrum Start:  5355.16
#  Spectrum End:     7304.91
#  Dispersion (1st pixel):   0.63
#  Dispersion (average):      0.63
#
#  Spectrum Start:  5355.16
#  Spectrum End:     7304.91
#  Dispersion (1st pixel):   0.63
#  Dispersion (average):      0.63
#
#
# Plotting the spectrum

# %%
sp_d = spec1d.Spec1d(flux=spec.spectra[3][1]['flux'], wav=spec.spectra[3][1]['wav'], 
                    var=spec.spectra[3][1]['var'], trimsec=[0, -1])
# Out:
#  Spectrum Start:  5355.16
#  Spectrum End:     7304.28
#  Dispersion (1st pixel):   0.63
#  Dispersion (average):      0.63

# %%
# %matplotlib notebook
sp_d.smooth(13)
sp_d.mark_lines('abs', z=0.794, usesmooth=True)
#sp_d.mark_lines('strongem', z=0.794, usesmooth=True)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-kappa       3750.00       6727.50
# [Fe VII]      3761.40       6747.95
# H-iota        3770.00       6763.38
# H-theta       3797.00       6811.82
# H-eta         3835.00       6879.99
# CN bandhd     3883.00       6966.10
# CaII K        3933.67       7057.00
# CaII H        3968.47       7119.44

# %%
sp_im = spec1d.Spec1d(flux=spec.spectra[1][1]['flux'], wav=spec.spectra[1][1]['wav'], 
                    var=spec.spectra[1][1]['var'], trimsec=[0, -10])
# Out:
#  Spectrum Start:  5355.16
#  Spectrum End:     7298.61
#  Dispersion (1st pixel):   0.63
#  Dispersion (average):      0.63

# %%
sp_im.smooth(3)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
sp_im.save('spec1d_J2145_deimos_100_det2_primary_new.fits', outformat='fits')
sp_d.save('spec1d_J2145_deimos_100_det2_deflector_new.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J2145_deimos_100_det2_primary_new.fits in format fits
# Saved spectrum to file spec1d_J2145_deimos_100_det2_deflector_new.fits in format fits

# %%
sp_d = spec1d.Spec1d('J2145_DEIMOS_spectra/spec1d_J2145_deimos_100_det2_deflector.fits', informat='fits', trimsec=[400, -10])
# Out:
# Reading spectrum from J2145_DEIMOS_spectra/spec1d_J2145_deimos_100_det2_deflector.fits
# Expected file format: fits
#  Spectrum Start:  5607.20
#  Spectrum End:     7292.30
#  Dispersion (1st pixel):   0.63
#  Dispersion (average):      0.63

# %%
fg = plt.figure(figsize=(16, 6))
sp_d.smooth(11, fig=fg)
sp_d.mark_lines('abs', z=0.707, usesmooth=True, markatm=False, labloc='topright')
plt.savefig('J2145_DEIMOS_spectra/spec1d_J2145_z_0.707.pdf', dpi=200, format='pdf')
# Out:
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-kappa       3750.00       6401.25
# [Fe VII]      3761.40       6420.71
# H-iota        3770.00       6435.39
# H-theta       3797.00       6481.48
# H-eta         3835.00       6546.34
# CN bandhd     3883.00       6628.28
# CaII K        3933.67       6714.77
# CaII H        3968.47       6774.18
# H-delta       4101.00       7000.41

# %%
import os
import specim_test.specim.imfuncs as im
from specim_test.specim.imfuncs import finding_chart as fc

# %%
2103-08 21:03:28 -08:50:49

# %%
im1 = im.Image('../Target_image_file/J2145+6345/idxo18020_drc.fits', hext=1)
# Out:
# Loading file ../Target_image_file/J2145+6345/idxo18020_drc.fits
# -----------------------------------------------
# Pixel scale (x, y): (  0.040,   0.040) arcsec/pix
# Instrument FOV (arcsec):   163.5 x   173.9
# Image position angle (E of N): -107.04

# %%
im1.display(imcent=(326.27130, 63.76145), fixnans=True, fmax=100, imsize=10)

# %%
im1.poststamp_radec((326.27130, 63.76145), 10, fixnans=True, 
                       outfile='../Target_image_file/J2145_short.fits')
# Out:
# ------------------
#  Requested center (RA, dec): 326.2713000    +63.761450
#  Requested center (RA, dec):  21 45 05.112 +63 45 41.22
#  Requested center (x, y):      2050.31  1132.74
#  Requested image size (arcsec):  10.00  10.00
#  Requested size in input pixels: 252 252
#
# Input file:  ../Target_image_file/J2145+6345/idxo18020_drc.fits
# Wrote postage stamp cutout to ../Target_image_file/J2145_short.fits

# %%
lens = '2145+6345'
root = lens[:4]
srcname = 'J%s' % lens
rstar = 3.5
#datadir = os.getenv('lensdat')  
#lensdir = os.path.join(datadir, lens)
infile = '../Target_image_file/J2145_long_panstarss.fits'#'%s/%s_panstarrs_3amin_r.fits' % (lensdir, root)
# zoomim = infile
zoomim = '../Target_image_file/J2145_short.fits'  #'%s/%s_blk2gsmo3.fits' % (lensdir, root)
posfile = '../Target_image_file/2145.pos'#'%s/%s.pos'  % (lensdir, root)
# slitfile = '../%s_pointings.txt' % root
outfile = '../Target_image_file/%s_fc_LRIS.pdf' % root
# outfile = None

imcent = posfile
imsize = 500.
zimsize = 50.
slitx = 1.
slity = 12.
slitpa = 95.0

fc.make_fc(srcname, infile, imcent, imsize, zimsize, outfile=outfile,
           zoomim=zoomim, slitsize=(slitx, slity), slitpa=slitpa,
            slitcent='default', #starpos='file', slitfile=slitfile,
           rstar=rstar, verbose=True, fmax=200.)
# Out:
# Reading central position from ../Target_image_file/2145.pos
#
# Loading file ../Target_image_file/J2145_long_panstarss.fits
# -----------------------------------------------
# Pixel scale (x, y): (  0.250,   0.250) arcsec/pix
# Instrument FOV (arcsec):   125.0 x   125.0
# Image position angle (E of N):   -0.00
#
#
# Loading file ../Target_image_file/J2145_short.fits
# -----------------------------------------------
# Pixel scale (x, y): (  0.040,   0.040) arcsec/pix
# Instrument FOV (arcsec):    10.0 x    10.0
# Image position angle (E of N):   -0.00
# ------------------
#  Requested center (RA, dec): 326.2713000    +63.761450
#  Requested center (RA, dec):  21 45 05.112 +63 45 41.22
#  Requested center (x, y):       126.00   126.00
#  Requested image size (arcsec):  50.00  50.00
#  Requested size in input pixels: 1262 1262
#  ------------------
#  Image PA is effectively zero, so doing pixel-based cutout
#    Cutout data in section [xrange,yrange]:  [-504:758,-505:757]
# ...

# %%
lens = '2017+62'
root = lens[:4]
srcname = 'J%s' % lens
rstar = 3.5
#datadir = os.getenv('lensdat')  
#lensdir = os.path.join(datadir, lens)
infile = '../Target_image_file/J2017+62_long_panstarrs.fits'#'%s/%s_panstarrs_3amin_r.fits' % (lensdir, root)
# zoomim = infile
zoomim = '../Target_image_file/J2017+62_short_panstarrs.fits'  #'%s/%s_blk2gsmo3.fits' % (lensdir, root)
posfile = '../Target_image_file/2017.pos'#'%s/%s.pos'  % (lensdir, root)
# slitfile = '../%s_pointings.txt' % root
outfile = '../Target_image_file/%s_fc_LRIS.pdf' % root
# outfile = None

imcent = posfile
imsize = 500.
zimsize = 50.
slitx = 1.
slity = 20.
slitpa = 44.0

fc.make_fc(srcname, infile, imcent, imsize, zimsize, outfile=outfile,
           zoomim=zoomim, slitsize=(slitx, slity), slitpa=slitpa,
            slitcent='default', #starpos='file', slitfile=slitfile,
           rstar=rstar, verbose=True, fmax=200.)
# Out:
# Reading central position from ../Target_image_file/2017.pos
#
# Loading file ../Target_image_file/J2017+62_long_panstarrs.fits
# -----------------------------------------------
# Pixel scale (x, y): (  0.250,   0.250) arcsec/pix
# Instrument FOV (arcsec):   125.0 x   125.0
# Image position angle (E of N):   -0.00
#
#
# Loading file ../Target_image_file/J2017+62_short_panstarrs.fits
# -----------------------------------------------
# Pixel scale (x, y): (  0.250,   0.250) arcsec/pix
# Instrument FOV (arcsec):    12.5 x    12.5
# Image position angle (E of N):   -0.00
# ------------------
#  Requested center (RA, dec): 304.4541667    +62.078750
#  Requested center (RA, dec):  20 17 49.000 +62 04 43.50
#  Requested center (x, y):        25.60    27.73
#  Requested image size (arcsec):  50.00  50.00
#  Requested size in input pixels: 200 200
#  ------------------
#  Image PA is effectively zero, so doing pixel-based cutout
#    Cutout data in section [xrange,yrange]:  [-74:126,-72:128]
# ...

# %%
lens = '2103-08'
root = lens[:4]
srcname = '%s' % lens
rstar = 3.5
#datadir = os.getenv('lensdat')  
#lensdir = os.path.join(datadir, lens)
infile = '../Target_image_file/2103-08_panstarrs_image.fits'#'%s/%s_panstarrs_3amin_r.fits' % (lensdir, root)
# zoomim = infile
zoomim = '../Target_image_file/2103-08_short_panstarrs.fits'  #'%s/%s_blk2gsmo3.fits' % (lensdir, root)
posfile = '../Target_image_file/2103.pos'#'%s/%s.pos'  % (lensdir, root)
# slitfile = '../%s_pointings.txt' % root
outfile = '../Target_image_file/%s_fc_LRIS.pdf' % root
# outfile = None

imcent = posfile
imsize = 500.
zimsize = 50.
slitx = 1.
slity = 20.
slitpa = 34.0

fc.make_fc(srcname, infile, imcent, imsize, zimsize, outfile=outfile,
           zoomim=zoomim, slitsize=(slitx, slity), slitpa=slitpa,
            slitcent='default', #starpos='file', slitfile=slitfile,
           rstar=rstar, verbose=True, fmax=200.)
# Out:
# Reading central position from ../Target_image_file/2103.pos
#
# Loading file ../Target_image_file/2103-08_panstarrs_image.fits
# -----------------------------------------------
# Pixel scale (x, y): (  0.250,   0.250) arcsec/pix
# Instrument FOV (arcsec):   125.0 x   125.0
# Image position angle (E of N):   -0.00
#
#
# Loading file ../Target_image_file/2103-08_short_panstarrs.fits
# -----------------------------------------------
# Pixel scale (x, y): (  0.250,   0.250) arcsec/pix
# Instrument FOV (arcsec):    12.5 x    12.5
# Image position angle (E of N):   -0.00
# ------------------
#  Requested center (RA, dec): 315.8706333     -8.847072
#  Requested center (RA, dec):  21 03 28.952 -08 -50 -49.46
#  Requested center (x, y):        28.16    26.86
#  Requested image size (arcsec):  50.00  50.00
#  Requested size in input pixels: 200 200
#  ------------------
#  Image PA is effectively zero, so doing pixel-based cutout
#    Cutout data in section [xrange,yrange]:  [-71:129,-73:127]
# ...

# %%
lens = '1817+2729'
root = lens[:4]
srcname = 'J%s' % lens
rstar = 3.5
#datadir = os.getenv('lensdat')  
#lensdir = os.path.join(datadir, lens)
infile = '../../Target_image_file/J1817_long.fits'#'%s/%s_panstarrs_3amin_r.fits' % (lensdir, root)
# zoomim = infile
zoomim = '../../Target_image_file/J1817_short.fits'  #'%s/%s_blk2gsmo3.fits' % (lensdir, root)
posfile = '../../Target_image_file/J1817.pos'#'%s/%s.pos'  % (lensdir, root)
# slitfile = '../%s_pointings.txt' % root
outfile = '../../Target_image_file/%s_fc_for_esi.pdf' % root
# outfile = None

imcent = posfile
imsize = 500.
zimsize = 50.
slitx = 1.
slity = 20.
slitpa = 130.

fc.make_fc(srcname, infile, imcent, imsize, zimsize, outfile=outfile,
           zoomim=zoomim, slitsize=(slitx, slity), slitpa=slitpa,
           # slitcent='file', starpos='file', slitfile=slitfile,
           rstar=rstar, verbose=True, fmax=200.)
# Out:
# Reading central position from ../../Target_image_file/J1817.pos
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [45], in <cell line: 22>()
#      19 slity = 20.
#      20 slitpa = 130.
# ---> 22 fc.make_fc(srcname, infile, imcent, imsize, zimsize, outfile=outfile,
#      23            zoomim=zoomim, slitsize=(slitx, slity), slitpa=slitpa,
#      24            # slitcent='file', starpos='file', slitfile=slitfile,
#      25            rstar=rstar, verbose=True, fmax=200.)
#
# File ~/Project/new_project/spectra_extraction/specim_test/specim/imfuncs/finding_chart.py:51, in make_fc(srcname, infile, imcent, imsize, zoomsize, outfile, fcfmax, zoomim, slitsize, slitpa, slitfile, slitcent, starpos, rstar, crosshair, **kwargs)
#      49     cent = imcent
#      50 elif isinstance(imcent, str):
# ---> 51     imtab, impos = read_posfile(imcent)
# ...

# %%
lens = '1206+4332'
root = lens[:4]
srcname = 'SDSSJ%s' % lens
rstar = 3.5
#datadir = os.getenv('lensdat')  
#lensdir = os.path.join(datadir, lens)
infile = '../../Target_image_file/J1206_long.fits'#'%s/%s_panstarrs_3amin_r.fits' % (lensdir, root)
# zoomim = infile
zoomim = '../../Target_image_file/J1206_short.fits'  #'%s/%s_blk2gsmo3.fits' % (lensdir, root)
posfile = '../../Target_image_file/J1206.pos'#'%s/%s.pos'  % (lensdir, root)
# slitfile = '../%s_pointings.txt' % root
outfile = '../../Target_image_file/%s_fc_for_esi.pdf' % root
# outfile = None

imcent = posfile
imsize = 500.
zimsize = 50.
slitx = 1.
slity = 20.
slitpa = 175.

fc.make_fc(srcname, infile, imcent, imsize, zimsize, outfile=outfile,
           zoomim=zoomim, slitsize=(slitx, slity), slitpa=slitpa,
           # slitcent='file', starpos='file', slitfile=slitfile,
           rstar=rstar, verbose=True, fmax=200.)
# Out:
# Reading central position from ../../Target_image_file/J1206.pos
#
# Loading file ../../Target_image_file/J1206_long.fits
# -----------------------------------------------
# Pixel scale (x, y): (  0.250,   0.250) arcsec/pix
# Instrument FOV (arcsec):   100.0 x   100.0
# Image position angle (E of N):   -0.00
#
# Calculating display limits
# --------------------------
#  Clipped mean: 9.609406
#  Clipped rms:  148.778336
#  fmin (mean -   1 sigma):  -139.168930
#  fmax (mean +  15 sigma):  2241.284439
#
# Loading file ../../Target_image_file/J1206_short.fits
# -----------------------------------------------
# Pixel scale (x, y): (  0.128,   0.128) arcsec/pix
# Instrument FOV (arcsec):    10.0 x    10.0
# Image position angle (E of N):   -0.00
# ------------------
#  Requested center (RA, dec): 181.6236100    +43.539949
#  Requested center (RA, dec):  12 06 29.666 +43 32 23.82
#  Requested center (x, y):        39.00    77.99
#  Requested image size (arcsec):  50.00  50.00
# ...

# %%
im1 = im.Image('../../Target_image_file/B1608+656/j93502030_drc.fits', hext=1)
# Out:
# Loading file ../../Target_image_file/B1608+656/j93502030_drc.fits
# -----------------------------------------------
# Pixel scale (x, y): (  0.050,   0.050) arcsec/pix
# Instrument FOV (arcsec):   210.8 x   212.2
# Image position angle (E of N):  -92.72

# %%
im1.display(imcent=(242.3081, 65.5411), fixnans=True, fmax=100, imsize=10)
# Out:
# Calculating display limits
# --------------------------
#  Clipped mean: 0.004376
#  Clipped rms:  0.006144
#  fmin (mean -   1 sigma):  -0.001768
#  fmax (mean + 100 sigma):  0.618821

# %%
im1.poststamp_radec((242.3081, 65.5411), 10, fixnans=True, 
                       outfile='../../Target_image_file/B1608_short.fits')
# Out:
# ------------------
#  Requested center (RA, dec): 242.3081000    +65.541100
#  Requested center (RA, dec):  16 09 13.944 +65 32 27.96
#  Requested center (x, y):      2091.88  2359.02
#  Requested image size (arcsec):  10.00  10.00
#  Requested size in input pixels: 200 200
#
# Input file:  ../../Target_image_file/B1608+656/j93502030_drc.fits
# Wrote postage stamp cutout to ../../Target_image_file/B1608_short.fits

# %%
myim = sp.Image('../Target_image_file/PSJ0630-1201_F814W_drc_sci.fits')
# Out:
# Loading file ../Target_image_file/PSJ0630-1201_F814W_drc_sci.fits
# -----------------------------------------------
# Pixel scale (x, y): (  0.040,   0.040) arcsec/pix
# Instrument FOV (arcsec):   233.7 x   236.2
# Image position angle (E of N):   -0.00

# %%
myim.display()
# Out:
# Calculating display limits
# --------------------------
#  Clipped mean: 0.000599
#  Clipped rms:  0.005924
#  fmin (mean -   1 sigma):  -0.005325
#  fmax (mean +  10 sigma):  0.059842

# %%
plt.figure(figsize=(10, 10))
myim.display(imcent=(97.53756, -12.02199), imsize=7, fmax=50)
# Out:
# 3467 3730 3642 3905
#
# Calculating display limits
# --------------------------
#  Clipped mean: 0.002562
#  Clipped rms:  0.006653
#  fmin (mean -   1 sigma):  -0.004091
#  fmax (mean +  50 sigma):  0.335188

# %%
myim.display(imcent=(97.53756, -12.02199), imsize=7, fmax=50)
myim.mark_fov(ra=97.5375303, dec=-12.0219680,  size=[0.6, 5.0], pa=0.01)
# Out:
# 3467 3730 3642 3905
#
# Calculating display limits
# --------------------------
#  Clipped mean: 0.002562
#  Clipped rms:  0.006653
#  fmin (mean -   1 sigma):  -0.004091
#  fmax (mean +  50 sigma):  0.335188

# %%
myim.display(imcent=(97.53756, -12.02199), imsize=7, fmax=50)
myim.mark_fov(ra=97.5376019, dec=-12.0220453,  size=[0.7, 7.0], pa=38.34557)
# Out:
# 3467 3730 3642 3905
#
# Calculating display limits
# --------------------------
#  Clipped mean: 0.002562
#  Clipped rms:  0.006653
#  fmin (mean -   1 sigma):  -0.004091
#  fmax (mean +  50 sigma):  0.335188

# %%
 myim_1 = sp.Image('../Target_image_file/SDSSJ0248+1913_F814W_drc_sci.fits')
# Out:
# Loading file ../Target_image_file/SDSSJ0248+1913_F814W_drc_sci.fits
# -----------------------------------------------
# Pixel scale (x, y): (  0.040,   0.040) arcsec/pix
# Instrument FOV (arcsec):   220.0 x   213.9
# Image position angle (E of N):   -0.00

# %%
myim_1.display()
# Out:
# Calculating display limits
# --------------------------
#  Clipped mean: 0.000711
#  Clipped rms:  0.005880
#  fmin (mean -   1 sigma):  -0.005168
#  fmax (mean +  10 sigma):  0.059507

# %%
myim_1.display(imcent=(42.2031840, 19.2251949), imsize=5, fmax=50)
# Out:
# 3641 2961 3766 3086
#
# Calculating display limits
# --------------------------
#  Clipped mean: 0.004010
#  Clipped rms:  0.007123
#  fmin (mean -   1 sigma):  -0.003112
#  fmax (mean +  50 sigma):  0.360136

# %%
myim_1.display(imcent=(42.2031960, 19.2251949), imsize=10, fmax=50)
myim_1.mark_fov(ra=42.2031530, dec=19.2251949,  size=[0.55, 4.0],pa=14.82172)
# Out:
# 3577 2898 3827 3148
#
# Calculating display limits
# --------------------------
#  Clipped mean: 0.001897
#  Clipped rms:  0.006464
#  fmin (mean -   1 sigma):  -0.004568
#  fmax (mean +  50 sigma):  0.325100

# %%
myim_1.display(imcent=(42.2031960, 19.2251949), imsize=5, fmax=50)
myim_1.mark_fov(ra=42.2031530, dec=19.2251949,  size=[0.5, 4.0],pa=0.381064)
# Out:
# 3640 2961 3765 3086
#
# Calculating display limits
# --------------------------
#  Clipped mean: 0.003994
#  Clipped rms:  0.007123
#  fmin (mean -   1 sigma):  -0.003130
#  fmax (mean +  50 sigma):  0.360163

# %%
myim_2 = sp.Image('../Target_image_file/W2MJ1042+1641_F814W_drc_sci.fits')
# Out:
# Loading file ../Target_image_file/W2MJ1042+1641_F814W_drc_sci.fits
# -----------------------------------------------
# Pixel scale (x, y): (  0.040,   0.040) arcsec/pix
# Instrument FOV (arcsec):   219.9 x   225.2
# Image position angle (E of N):   +0.00

# %%
myim_2.display()
# Out:
# Calculating display limits
# --------------------------
#  Clipped mean: 0.000968
#  Clipped rms:  0.005718
#  fmin (mean -   1 sigma):  -0.004749
#  fmax (mean +  10 sigma):  0.058145

# %%
myim_2.display(imcent=(160.5920077, 16.6876104), imsize=5, fmax=75)
# Out:
# 2254 1824 2379 1949
#
# Calculating display limits
# --------------------------
#  Clipped mean: 0.003911
#  Clipped rms:  0.006834
#  fmin (mean -   1 sigma):  -0.002923
#  fmax (mean +  75 sigma):  0.516485

# %%
myim_2.display(imcent=(160.5920077, 16.6876104), imsize=15, fmax=75)
myim_2.mark_fov(ra=160.59199, dec=16.6876104,  size=[0.58, 6.0], pa=18.73335)#28.27607
# Out:
# 2129 1699 2504 2074
#
# Calculating display limits
# --------------------------
#  Clipped mean: 0.001618
#  Clipped rms:  0.005795
#  fmin (mean -   1 sigma):  -0.004177
#  fmax (mean +  75 sigma):  0.436246

# %%
myim_3 = sp.Image('../Target_image_file/WISEJ0259-1635_F814W_drc_sci.fits')
# Out:
# Loading file ../Target_image_file/WISEJ0259-1635_F814W_drc_sci.fits
# -----------------------------------------------
# Pixel scale (x, y): (  0.040,   0.040) arcsec/pix
# Instrument FOV (arcsec):   232.7 x   235.6
# Image position angle (E of N):   -0.00

# %%
myim_3.display()
# Out:
# Calculating display limits
# --------------------------
#  Clipped mean: 0.000500
#  Clipped rms:  0.005507
#  fmin (mean -   1 sigma):  -0.005007
#  fmax (mean +  10 sigma):  0.055574

# %%
myim_3.display(imcent=(44.9285690, -16.5953837), imsize=5, fmax=50)
# Out:
# 3429 3728 3554 3853
#
# Calculating display limits
# --------------------------
#  Clipped mean: 0.004425
#  Clipped rms:  0.006828
#  fmin (mean -   1 sigma):  -0.002403
#  fmax (mean +  50 sigma):  0.345820

# %%
myim_3.display(imcent=(44.9285690, -16.5953837), imsize=5, fmax=40)
myim_3.mark_fov(ra=44.9285600, dec=-16.5953837,  size=[0.5, 6.0], pa=1.218876)
# Out:
# 3429 3728 3554 3853
#
# Calculating display limits
# --------------------------
#  Clipped mean: 0.004425
#  Clipped rms:  0.006828
#  fmin (mean -   1 sigma):  -0.002403
#  fmax (mean +  40 sigma):  0.277541

# %%
myim_3.display(imcent=(44.9285690, -16.5953837), imsize=5, fmax=40)
myim_3.mark_fov(ra=44.9285500, dec=-16.5953837,  size=[0.6, 6.0], pa=27.00131)
# Out:
# 3429 3728 3554 3853
#
# Calculating display limits
# --------------------------
#  Clipped mean: 0.004425
#  Clipped rms:  0.006828
#  fmin (mean -   1 sigma):  -0.002403
#  fmax (mean +  40 sigma):  0.277541

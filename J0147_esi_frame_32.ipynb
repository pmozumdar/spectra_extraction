# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, echelle1d, spec1d, echelle2d

# %%
file_loc = '../galaxy_spectra/ESI_data/*'

# %%
spec2d_file_list = []
var2d_file_list = []
#out_file = []
for i,p in enumerate(glob.glob(file_loc)):
    if 'J0147' in p:
        if 'bgsub.fits' in p:
            spec2d_file_list.append(p)
        elif 'var.fits' in p:
            var2d_file_list.append(p)
            #frame = p.split('_')[-3][:4]
            #out_file.append('0053m1_r'+ frame + '_cleaned.fits')
        #print(p)

# %%
print(spec2d_file_list, var2d_file_list)
# Out:
# ['../galaxy_spectra/ESI_data/J0147+4630_0031_bgsub.fits', '../galaxy_spectra/ESI_data/J0147+4630_0033_bgsub.fits', '../galaxy_spectra/ESI_data/J0147+4630_0032_bgsub.fits'] ['../galaxy_spectra/ESI_data/J0147+4630_0032_var.fits', '../galaxy_spectra/ESI_data/J0147+4630_0031_var.fits', '../galaxy_spectra/ESI_data/J0147+4630_0033_var.fits']

# %%
spec = esi2d.Esi2d(spec2d_file_list[2], varfile=var2d_file_list[0])
print(spec2d_file_list[2])
print(var2d_file_list[0])
# Out:
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3461x165     x
#   2   4093x145     x
#   3   4096x146     x
#   4   4096x141     x
#   5   4096x130     x
#   6   4096x127     x
#   7   4096x124     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x111     x
# ../galaxy_spectra/ESI_data/J0147+4630_0032_bgsub.fits
# ../galaxy_spectra/ESI_data/J0147+4630_0032_var.fits

# %%
pixrange = np.array([[2600, 3000], [2600, 3000], [2600, 3000], [1800, 2200], [1500, 1800]]) #(1900, 2400)
i = 0
for sp, info in zip(spec[5:], spec.ordinfo[5:]):
    print(info['pixscale'])
    title = 'Spatial profile for ' + str(info['name'])
    sp.spatial_profile(pixrange=pixrange[i], title=title)
    plt.show()
    sp.initial_model()
    i +=1
# Out:
# 0.149
# Profile max value (before normalization) 3117.042348
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 100, 91, 2
#
# amplitude=100.000000, mu=91.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3100, 78, 3, 4.765
#
# amplitude=3100.000000, x_0=78.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 300, 99, 3, 4.765
#
# amplitude=300.000000, x_0=99.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-2.01057524)>
#
#     [1]: <Gaussian1D(amplitude=342.39704415, mean=82.31272029, stddev=2.74734767)>
#
#     [2]: <Moffat1D(amplitude=2990.83306342, x_0=78.78018284, gamma=5.31051416, alpha=2.50330919)>
#
#     [3]: <Moffat1D(amplitude=333.081277, x_0=100.04959253, gamma=4.53341798, alpha=1.67186576)>
# Parameters:
#             c0_0           amplitude_1     ...     gamma_3           alpha_3
#     ------------------- ------------------ ... ---------------- ------------------
#     -2.0105752390049556 342.39704414605035 ... 4.53341798240028 1.6718657576722853
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# 0.153
# Profile max value (before normalization) 2960.740824
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 100, 91, 2
#
# amplitude=100.000000, mu=91.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 2900, 78, 3, 4.765
#
# amplitude=2900.000000, x_0=78.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 280, 98.6, 3, 4.765
#
# amplitude=280.000000, x_0=98.600000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.36212161)>
#
#     [1]: <Gaussian1D(amplitude=84.46794912, mean=81.96129278, stddev=5.18516886)>
#
#     [2]: <Moffat1D(amplitude=2967.45315666, x_0=77.81144388, gamma=7.31187926, alpha=3.89391229)>
#
#     [3]: <Moffat1D(amplitude=332.26832689, x_0=98.70140968, gamma=8.68753051, alpha=4.8027822)>
# Parameters:
#             c0_0           amplitude_1    ...     gamma_3           alpha_3
#     ------------------- ----------------- ... ---------------- ------------------
#     0.36212161322593994 84.46794911824439 ... 8.68753050979816 4.8027821986173445
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# 0.158
# Profile max value (before normalization) 3603.707911
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 100, 88.3, 2
#
# amplitude=100.000000, mu=88.300000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3500, 76, 3, 4.765
#
# amplitude=3500.000000, x_0=76.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 300, 96, 3, 4.765
#
# amplitude=300.000000, x_0=96.000000, gamma=3.000000, alpha=4.765000
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-4.65476231)>
#
#     [1]: <Gaussian1D(amplitude=155.36575212, mean=78.47196078, stddev=0.)>
#
#     [2]: <Moffat1D(amplitude=3620.58844483, x_0=76.31227408, gamma=7.67556892, alpha=4.14464089)>
#
#     [3]: <Moffat1D(amplitude=385.69993052, x_0=95.76697243, gamma=3.14772136, alpha=0.96676359)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_3            alpha_3
#     ------------------ ------------------ ... ------------------ ------------------
#     -4.654762313481972 155.36575212096716 ... 3.1477213622953863 0.9667635856101316
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# yes
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 100, 88, 2
#
# amplitude=100.000000, mu=88.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3500, 75.5, 3, 4.765
#
# amplitude=3500.000000, x_0=75.500000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 270, 96, 3, 4.765
#
# amplitude=270.000000, x_0=96.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.23230708)>
#
#     [1]: <Gaussian1D(amplitude=190.75365868, mean=81.57410968, stddev=3.95845834)>
#
#     [2]: <Moffat1D(amplitude=3574.18888825, x_0=76.19828214, gamma=7.71733575, alpha=4.48196458)>
#
#     [3]: <Moffat1D(amplitude=370.42907855, x_0=95.92975845, gamma=15.92548688, alpha=16.18006755)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_3            alpha_3
#     ------------------- ------------------ ... ------------------ ------------------
#     0.23230707588909483 190.75365868168961 ... 15.925486884262618 16.180067552876977
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# 0.163
# Profile max value (before normalization) 3270.689288
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 100, 83, 2
#
# amplitude=100.000000, mu=83.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3200, 71, 3, 4.765
#
# amplitude=3200.000000, x_0=71.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 300, 90.3, 3, 4.765
#
# amplitude=300.000000, x_0=90.300000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.52647732)>
#
#     [1]: <Gaussian1D(amplitude=101.39961859, mean=75.90356275, stddev=6.4584924)>
#
#     [2]: <Moffat1D(amplitude=3263.61595063, x_0=72.80644846, gamma=6.92811487, alpha=3.98289378)>
#
#     [3]: <Moffat1D(amplitude=395.27155709, x_0=91.87782529, gamma=14.48224271, alpha=10.74230019)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_3            alpha_3
#     ------------------- ------------------ ... ------------------ ------------------
#     -1.5264773207466251 101.39961858854727 ... 14.482242714006928 10.742300186456529
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# 0.168
# Profile max value (before normalization) 885.557369
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 70, 81.6, 2
#
# amplitude=70.000000, mu=81.600000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 900, 70, 3, 4.765
#
# amplitude=900.000000, x_0=70.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 100, 89, 3, 4.765
#
# amplitude=100.000000, x_0=89.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.32954119)>
#
#     [1]: <Gaussian1D(amplitude=44.99479253, mean=75.98915625, stddev=5.26148861)>
#
#     [2]: <Moffat1D(amplitude=880.68392018, x_0=70.76412141, gamma=4.94107456, alpha=2.55556589)>
#
#     [3]: <Moffat1D(amplitude=90.8779331, x_0=89.47323818, gamma=6.08527372, alpha=3.1817565)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_3           alpha_3
#     -------------------- ----------------- ... ----------------- -----------------
#     -0.32954119062058174 44.99479253412716 ... 6.085273724939881 3.181756500964736
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no

# %%
def tie_pos1_moffat_6(model):
    return model.x_0_2 + (1.95 / spec.ordinfo[5]['pixscale']) #(0.886 / pixscale)

def tie_pos2_moffat_6(model):
    return model.x_0_2 + (3.15 / spec.ordinfo[5]['pixscale'])  #(1.87 / pixscale) 

def tie_pos1_moffat_7(model):
    return model.x_0_2 + (1.95 / spec.ordinfo[6]['pixscale']) #(0.886 / pixscale)

def tie_pos2_moffat_7(model):
    return model.x_0_2 + (3.15 / spec.ordinfo[6]['pixscale'])  #(1.87 / pixscale) 

def tie_pos1_moffat_8(model):
    return model.x_0_2 + (1.95 / spec.ordinfo[7]['pixscale']) #(0.886 / pixscale)

def tie_pos2_moffat_8(model):
    return model.x_0_2 + (3.15 / spec.ordinfo[7]['pixscale'])  #(1.87 / pixscale) 

def tie_pos1_moffat_9(model):
    return model.x_0_2 + (1.95 / spec.ordinfo[8]['pixscale']) #(0.886 / pixscale)

def tie_pos2_moffat_9(model):
    return model.x_0_2 + (3.15 / spec.ordinfo[8]['pixscale'])  #(1.87 / pixscale) 

def tie_pos1_moffat_10(model):
    return model.x_0_2 + (1.95 / spec.ordinfo[9]['pixscale']) #(0.886 / pixscale)

def tie_pos2_moffat_10(model):
    return model.x_0_2 + (3.15 / spec.ordinfo[9]['pixscale'])  #(1.87 / pixscale) 

def tie_gamma_moffat(model):
    return model.gamma_3

def tie_alpha_moffat(model):
    return model.alpha_3

func_dict = {
             '6_1' : tie_pos1_moffat_6, '6_2' : tie_pos2_moffat_6,
             '7_1' : tie_pos1_moffat_7, '7_2' : tie_pos2_moffat_7,
             '8_1' : tie_pos1_moffat_8, '8_2' : tie_pos2_moffat_8,
             '9_1' : tie_pos1_moffat_9, '9_2' : tie_pos2_moffat_9,
             '10_1' : tie_pos1_moffat_10, '10_2' : tie_pos2_moffat_10
            }

for sp, info in zip(spec, spec.ordinfo):
    if sp.mod0 is not None:
        print(info['pixscale'])
        sp.mod0[1].mean.tied = func_dict['%d_%d' %(info['order'], 1)] #tie_pos1_moffat
        sp.mod0[3].x_0.tied = func_dict['%d_%d' %(info['order'], 2)] #tie_pos2_moffat
        sp.mod0[2].gamma.tied = tie_gamma_moffat
        sp.mod0[2].alpha.tied = tie_alpha_moffat
        sp.refined_model(sp.mod0)
# Out:
# 0.149
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-2.01057524)>
#
#     [1]: <Gaussian1D(amplitude=342.39704415, mean=82.31272029, stddev=2.74734767)>
#
#     [2]: <Moffat1D(amplitude=2990.83306342, x_0=78.78018284, gamma=5.31051416, alpha=2.50330919)>
#
#     [3]: <Moffat1D(amplitude=333.081277, x_0=100.04959253, gamma=4.53341798, alpha=1.67186576)>
# Parameters:
#             c0_0           amplitude_1     ...     gamma_3           alpha_3
#     ------------------- ------------------ ... ---------------- ------------------
#     -2.0105752390049556 342.39704414605035 ... 4.53341798240028 1.6718657576722853
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.77292125)>
#
#     [1]: <Gaussian1D(amplitude=59.2217198, mean=92.11398804, stddev=8.87383415)>
#
#     [2]: <Moffat1D(amplitude=3121.92665145, x_0=79.02673971, gamma=6.87021677, alpha=3.47331163)>
#
#     [3]: <Moffat1D(amplitude=277.95086724, x_0=100.16767931, gamma=6.87021677, alpha=3.47331163)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_3            alpha_3
#     ------------------- ----------------- ... ------------------ -----------------
#     -1.7729212474145766 59.22171980172142 ... 6.8702167748134695 3.473311634620881
#
# -------------------------------------------
# 0.153
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.36212161)>
#
#     [1]: <Gaussian1D(amplitude=84.46794912, mean=81.96129278, stddev=5.18516886)>
#
#     [2]: <Moffat1D(amplitude=2967.45315666, x_0=77.81144388, gamma=7.31187926, alpha=3.89391229)>
#
#     [3]: <Moffat1D(amplitude=332.26832689, x_0=98.70140968, gamma=8.68753051, alpha=4.8027822)>
# Parameters:
#             c0_0           amplitude_1    ...     gamma_3           alpha_3
#     ------------------- ----------------- ... ---------------- ------------------
#     0.36212161322593994 84.46794911824439 ... 8.68753050979816 4.8027821986173445
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.71041685)>
#
#     [1]: <Gaussian1D(amplitude=70.05242472, mean=90.58588994, stddev=8.70500219)>
#
#     [2]: <Moffat1D(amplitude=2987.85764219, x_0=77.8407919, gamma=7.68734537, alpha=4.15031738)>
#
#     [3]: <Moffat1D(amplitude=265.51260677, x_0=98.42902719, gamma=7.68734537, alpha=4.15031738)>
# Parameters:
#            c0_0          amplitude_1    ...      gamma_3           alpha_3
#     ------------------ ---------------- ... ----------------- -----------------
#     -1.710416845196633 70.0524247177168 ... 7.687345368083919 4.150317379783296
#
# -------------------------------------------
# 0.158
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.23230708)>
#
#     [1]: <Gaussian1D(amplitude=190.75365868, mean=81.57410968, stddev=3.95845834)>
#
#     [2]: <Moffat1D(amplitude=3574.18888825, x_0=76.19828214, gamma=7.71733575, alpha=4.48196458)>
#
#     [3]: <Moffat1D(amplitude=370.42907855, x_0=95.92975845, gamma=15.92548688, alpha=16.18006755)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_3            alpha_3
#     ------------------- ------------------ ... ------------------ ------------------
#     0.23230707588909483 190.75365868168961 ... 15.925486884262618 16.180067552876977
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.59756892)>
#
#     [1]: <Gaussian1D(amplitude=105.74229967, mean=88.62649875, stddev=7.46292258)>
#
#     [2]: <Moffat1D(amplitude=3597.78196388, x_0=76.2847266, gamma=8.84243836, alpha=5.41362709)>
#
#     [3]: <Moffat1D(amplitude=287.56867933, x_0=96.22143546, gamma=8.84243836, alpha=5.41362709)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_3           alpha_3
#     ------------------- ------------------ ... ----------------- -----------------
#     -1.5975689196722804 105.74229966715362 ... 8.842438357931584 5.413627094867849
#
# -------------------------------------------
# 0.163
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.52647732)>
#
#     [1]: <Gaussian1D(amplitude=101.39961859, mean=75.90356275, stddev=6.4584924)>
#
#     [2]: <Moffat1D(amplitude=3263.61595063, x_0=72.80644846, gamma=6.92811487, alpha=3.98289378)>
#
#     [3]: <Moffat1D(amplitude=395.27155709, x_0=91.87782529, gamma=14.48224271, alpha=10.74230019)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_3            alpha_3
#     ------------------- ------------------ ... ------------------ ------------------
#     -1.5264773207466251 101.39961858854727 ... 14.482242714006928 10.742300186456529
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.70890663)>
#
#     [1]: <Gaussian1D(amplitude=104.77152516, mean=84.81513942, stddev=7.35349784)>
#
#     [2]: <Moffat1D(amplitude=3306.7747274, x_0=72.85194924, gamma=9.58849667, alpha=6.69801595)>
#
#     [3]: <Moffat1D(amplitude=261.31589134, x_0=92.17710261, gamma=9.58849667, alpha=6.69801595)>
# Parameters:
#            c0_0          amplitude_1    ...     gamma_3           alpha_3
#     ------------------ ---------------- ... ---------------- ------------------
#     -1.708906633617766 104.771525156106 ... 9.58849667088715 6.6980159529065855
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# 0.168
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.32954119)>
#
#     [1]: <Gaussian1D(amplitude=44.99479253, mean=75.98915625, stddev=5.26148861)>
#
#     [2]: <Moffat1D(amplitude=880.68392018, x_0=70.76412141, gamma=4.94107456, alpha=2.55556589)>
#
#     [3]: <Moffat1D(amplitude=90.8779331, x_0=89.47323818, gamma=6.08527372, alpha=3.1817565)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_3           alpha_3
#     -------------------- ----------------- ... ----------------- -----------------
#     -0.32954119062058174 44.99479253412716 ... 6.085273724939881 3.181756500964736
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.94231873)>
#
#     [1]: <Gaussian1D(amplitude=28.88452559, mean=82.42137361, stddev=6.8494468)>
#
#     [2]: <Moffat1D(amplitude=901.77208318, x_0=70.81423075, gamma=5.11991696, alpha=2.591426)>
#
#     [3]: <Moffat1D(amplitude=72.76954042, x_0=89.56423075, gamma=5.11991696, alpha=2.591426)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_3           alpha_3
#     ------------------- ----------------- ... ----------------- -----------------
#     -0.9423187335229076 28.88452558643323 ... 5.119916959795455 2.591425998559967
#
# -------------------------------------------

# %%
fig = plt.figure(figsize=(25, 20))
spec.plot_fitted_model(columns=3, fig=fig)

# %%
for sp in spec[5:]:
    sp.find_and_trace(sp.mod0, stepsize=25, fitorder={'stddev_1':3, 'mean_1':4, 'x_0_2':4, 'x_0_3':4},
                    fitrange=[0, 4100], polyorder=3)
    plt.show()
# Out:
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3

# %%
extrange_list = np.array([[900, -1], [600, -1], [200, -1], [0, -1], [0, 2000]])

for sp, ext in zip(spec[5:], extrange_list):
    sp.extract(method='modelfit', extrange=ext)
    plt.show()
# Out:
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 900 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  5810.63
#  Spectrum End:     6560.55
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#  Spectrum Start:  5810.63
#  Spectrum End:     6560.55
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#  Spectrum Start:  5810.63
#  Spectrum End:     6560.55
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#
# Plotting the spectrum
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 600 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  6380.37
#  Spectrum End:     7286.41
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#  Spectrum Start:  6380.37
#  Spectrum End:     7286.41
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#  Spectrum Start:  6380.37
#  Spectrum End:     7286.41
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#
# Plotting the spectrum
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 200 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  7066.66
#  Spectrum End:     8193.74
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29
#
#  Spectrum Start:  7066.66
#  Spectrum End:     8193.74
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29
#
#  Spectrum Start:  7066.66
#  Spectrum End:     8193.74
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29
#
#
# Plotting the spectrum
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 0 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  8012.11
#  Spectrum End:     9360.83
#  Dispersion (1st pixel):   0.30
#  Dispersion (average):      0.33
#
#  Spectrum Start:  8012.11
#  Spectrum End:     9360.83
#  Dispersion (1st pixel):   0.30
#  Dispersion (average):      0.33
#
#  Spectrum Start:  8012.11
#  Spectrum End:     9360.83
#  Dispersion (1st pixel):   0.30
#  Dispersion (average):      0.33
#
#
# Plotting the spectrum
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 0 - 2000
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  9337.74
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.35
#  Dispersion (average):      0.37
#
#  Spectrum Start:  9337.74
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.35
#  Dispersion (average):      0.37
#
#  Spectrum Start:  9337.74
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.35
#  Dispersion (average):      0.37
#
#
# Plotting the spectrum

# %%
outspec = []
orderinfo = np.array([6, 7, 8, 9, 10], dtype=[('order', int)])
for i in range(3):
    sp_l = []
    for sp in spec[5:]:
        sp_l.append(sp.spectra[i][1])
        #print(sp.spectra[i][0],'\n', sp.spectra[i][1])
    outspec.append(echelle1d.Ech1d(sp_l, ordinfo=orderinfo))
# Out:
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.66  8193.74   0.29
#   9  4096   8012.11  9360.83   0.33
#  10  2000   9337.74 10074.55   0.37
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.66  8193.74   0.29
#   9  4096   8012.11  9360.83   0.33
#  10  2000   9337.74 10074.55   0.37
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.66  8193.74   0.29
#   9  4096   8012.11  9360.83   0.33
#  10  2000   9337.74 10074.55   0.37

# %%
outspec[0].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))
outspec[1].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))
outspec[2].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))

# %%
outspec[0].save_multi('esi1d_J0147_frame32_gaussian')
outspec[1].save_multi('esi1d_J0147_frame32_moffat_primary')
outspec[2].save_multi('esi1d_J0147_frame32_moffat_secondary')
# Out:
# Spectrum saved in mode multitab to file esi1d_J0147_frame32_gaussian.fits
# Spectrum saved in mode multitab to file esi1d_J0147_frame32_moffat_primary.fits
# Spectrum saved in mode multitab to file esi1d_J0147_frame32_moffat_secondary.fits

# %%
outspec[0].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt', order=[6, 10])
# Out:
#  Spectrum Start:     3.76
#  Spectrum End:        4.00
#  Dispersion (1st pixel): 1.65e-05
#  Dispersion (average):    1.65e-05

# %%
outspec[1].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt', order=[6, 10])
# Out:
#  Spectrum Start:     3.76
#  Spectrum End:        4.00
#  Dispersion (1st pixel): 1.65e-05
#  Dispersion (average):    1.65e-05

# %%
outspec[2].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt', order=[6, 10])
# Out:
#  Spectrum Start:     3.76
#  Spectrum End:        4.00
#  Dispersion (1st pixel): 1.65e-05
#  Dispersion (average):    1.65e-05

# %%
outspec[0].spec1d.save('spec1d_J0147_frame32_deflector.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0147_frame32_deflector.fits in format fits

# %%
outspec[1].spec1d.save('spec1d_J0147_frame32_primary.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0147_frame32_primary.fits in format fits

# %%
outspec[2].spec1d.save('spec1d_J0147_frame32_secondary.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0147_frame32_secondary.fits in format fits

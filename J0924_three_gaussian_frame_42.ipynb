# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, spec1d

# %%
file_loc = '../galaxy_spectra/ESI_data/*'

# %%
spec2d_file_list = []
var2d_file_list = []
#out_file = []
for i,p in enumerate(glob.glob(file_loc)):
    if 'J0924' in p:
        if 'bgsub.fits' in p:
            spec2d_file_list.append(p)
        elif 'var.fits' in p:
            var2d_file_list.append(p)

# %%
spec = esi2d.Esi2d(spec2d_file_list[0], varfile=var2d_file_list[0])
print(spec2d_file_list[0])
print(var2d_file_list[0])
# Out:
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3461x165     x
#   2   4093x145     x
#   3   4096x146     x
#   4   4096x141     x
#   5   4096x130     x
#   6   4096x127     x
#   7   4096x124     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x111     x
# ../galaxy_spectra/ESI_data/J0924+0219_0042_bgsub.fits
# ../galaxy_spectra/ESI_data/J0924+0219_0042_var.fits

# %%
pixrange = [(1900, 2400)]
for sp, info in zip(spec, spec.ordinfo):
    title = 'Spatial profile for ' + str(info['name'])
    sp.spatial_profile(pixrange=pixrange[0], title=title)
    plt.show()
    sp.initial_model()
# Out:
# Profile max value (before normalization) 85.987645
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 80, 30, 2
#
# amplitude=80.000000, mu=30.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 15, 37, 2
#
# amplitude=15.000000, mu=37.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 15, 45, 2
#
# amplitude=15.000000, mu=45.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
# ...

# %%
def tie_pos1_gauss_1(model):
    return model.mean_1 + (0.87 / spec.ordinfo[0]['pixscale']) #(0.886 / pixscale) 0.87

def tie_pos2_gauss_1(model):
    return model.mean_1 + (1.81 / spec.ordinfo[0]['pixscale']) #(1.87 / pixscale) 1.81

def tie_pos1_gauss_2(model):
    return model.mean_1 + (0.87 / spec.ordinfo[1]['pixscale']) #(0.886 / pixscale) 0.87

def tie_pos2_gauss_2(model):
    return model.mean_1 + (1.81 / spec.ordinfo[1]['pixscale']) #(1.87 / pixscale) 1.81

def tie_pos1_gauss_3(model):
    return model.mean_1 + (0.87 / spec.ordinfo[2]['pixscale']) #(0.886 / pixscale) 0.87

def tie_pos2_gauss_3(model):
    return model.mean_1 + (1.81 / spec.ordinfo[2]['pixscale']) #(1.87 / pixscale) 1.81

def tie_pos1_gauss_4(model):
    return model.mean_1 + (0.87 / spec.ordinfo[3]['pixscale']) #(0.886 / pixscale) 0.87

def tie_pos2_gauss_4(model):
    return model.mean_1 + (1.81 / spec.ordinfo[3]['pixscale']) #(1.87 / pixscale) 1.81

def tie_pos1_gauss_5(model):
    return model.mean_1 + (0.87 / spec.ordinfo[4]['pixscale']) #(0.886 / pixscale) 0.87

def tie_pos2_gauss_5(model):
    return model.mean_1 + (1.81 / spec.ordinfo[4]['pixscale']) #(1.87 / pixscale) 1.81

def tie_pos1_gauss_6(model):
    return model.mean_1 + (0.87 / spec.ordinfo[5]['pixscale']) #(0.886 / pixscale) 0.87

def tie_pos2_gauss_6(model):
    return model.mean_1 + (1.81 / spec.ordinfo[5]['pixscale']) #(1.87 / pixscale) 1.81

def tie_pos1_gauss_7(model):
    return model.mean_1 + (0.87 / spec.ordinfo[6]['pixscale']) #(0.886 / pixscale) 0.87

def tie_pos2_gauss_7(model):
    return model.mean_1 + (1.81 / spec.ordinfo[6]['pixscale']) #(1.87 / pixscale) 1.81

def tie_pos1_gauss_8(model):
    return model.mean_1 + (0.87 / spec.ordinfo[7]['pixscale']) #(0.886 / pixscale) 0.87

def tie_pos2_gauss_8(model):
    return model.mean_1 + (1.81 / spec.ordinfo[7]['pixscale']) #(1.87 / pixscale) 1.81

def tie_pos1_gauss_9(model):
    return model.mean_1 + (0.87 / spec.ordinfo[8]['pixscale']) #(0.886 / pixscale) 0.87

def tie_pos2_gauss_9(model):
    return model.mean_1 + (1.81 / spec.ordinfo[8]['pixscale']) #(1.87 / pixscale) 1.81

def tie_pos1_gauss_10(model):
    return model.mean_1 + (0.87 / spec.ordinfo[9]['pixscale']) #(0.886 / pixscale) 0.87

def tie_pos2_gauss_10(model):
    return model.mean_1 + (1.81 / spec.ordinfo[9]['pixscale']) #(1.87 / pixscale) 1.81

def tie_stddev_gauss(model):
    return model.stddev_1

func_dict = {'1_1' : tie_pos1_gauss_1, '1_2' : tie_pos2_gauss_1,
             '2_1' : tie_pos1_gauss_2, '2_2' : tie_pos2_gauss_2,
             '3_1' : tie_pos1_gauss_3, '3_2' : tie_pos2_gauss_3,
             '4_1' : tie_pos1_gauss_4, '4_2' : tie_pos2_gauss_4,
             '5_1' : tie_pos1_gauss_5, '5_2' : tie_pos2_gauss_5,
             '6_1' : tie_pos1_gauss_6, '6_2' : tie_pos2_gauss_6,
             '7_1' : tie_pos1_gauss_7, '7_2' : tie_pos2_gauss_7,
             '8_1' : tie_pos1_gauss_8, '8_2' : tie_pos2_gauss_8,
             '9_1' : tie_pos1_gauss_9, '9_2' : tie_pos2_gauss_9,
             '10_1' : tie_pos1_gauss_10, '10_2' : tie_pos2_gauss_10
            }
    
for sp, info in zip(spec, spec.ordinfo):
    if sp.mod0 is not None:
        print(info['pixscale'])
        sp.mod0[2].mean.tied = func_dict['%d_%d' %(info['order'], 1)] #tie_pos1_gauss_
        sp.mod0[3].mean.tied = func_dict['%d_%d' %(info['order'], 2)] #tie_pos2_gauss
        sp.mod0[3].stddev.tied = tie_stddev_gauss
        sp.refined_model(sp.mod0)
# Out:
# 0.12
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.01738174)>
#
#     [1]: <Gaussian1D(amplitude=85.66808212, mean=29.52589685, stddev=3.03652232)>
#
#     [2]: <Gaussian1D(amplitude=4.4494564, mean=36.4062612, stddev=1.97309231)>
#
#     [3]: <Gaussian1D(amplitude=8.73811737, mean=43.72266827, stddev=3.84043054)>
# Parameters:
#              c0_0           amplitude_1    ...       mean_3           stddev_3
#     --------------------- ---------------- ... ----------------- ------------------
#     -0.017381739729238118 85.6680821216252 ... 43.72266826779475 3.8404305366631784
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.0042179)>
#
# ...

# %%
outspec = spec.extract_all(method='cdf', plot_profiles=False, plot_traces=True, plot_extracted=False,
                           stepsize=25, pixrange=[0, -1, 2200, -1], level=-20, fit_dict={10 : [0, 2000]}, 
                           extrange_dict={10 : [0, 2000]}, 
                           fitorder_dict={'common':{'mean_1': 4, 'mean_2':4, 'mean_3':4}})
# Out:
# Extracting spectra
# ------------------
# Order_01
#
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 138 segments
#   of the 2D spectrum with stepsize=25 pix ...
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: mean_2
# Fitting polynomial of degree 3 to parameter: stddev_2
# Fitting polynomial of degree 4 to parameter: mean_3
# Fitting polynomial of degree 3 to parameter: stddev_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1500 - 3000
# Fitting to the trace at 3461 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  4071.46
# ...

# %%
for sp in spec:
    if sp.mod0 is not None:
        a = 1.81/(sp.coarsepars['mean_3'] - sp.coarsepars['mean_1'])
        b = 0.87/(sp.coarsepars['mean_2'] - sp.coarsepars['mean_1'])
        #print('order: %d' %sp.ordinfo['order'])
        print(np.max(a), np.min(a))
        print(np.max(b), np.min(b))
# Out:
# 0.12000000000000001 0.11999999999999998
# 0.12000000000000006 0.11999999999999994
# 0.12700000000000003 0.12699999999999997
# 0.12700000000000003 0.1269999999999999
# 0.134 0.13399999999999998
# 0.13400000000000004 0.13399999999999995
# 0.13700000000000004 0.137
# 0.13700000000000004 0.13699999999999998
# 0.14400000000000002 0.14399999999999993
# 0.14400000000000004 0.14399999999999996
# 0.14900000000000005 0.14899999999999997
# 0.14899999999999997 0.14899999999999997
# 0.15300000000000005 0.15299999999999994
# 0.15300000000000005 0.15299999999999997
# 0.15800000000000003 0.15799999999999997
# 0.15800000000000003 0.15800000000000003
# 0.16300000000000003 0.16299999999999998
# 0.16300000000000003 0.16300000000000003
# 0.16800000000000004 0.16799999999999998
# 0.16800000000000004 0.16799999999999993

# %%
for sp, info in zip(spec, spec.ordinfo):
    if sp.mod0 is not None:
        a = 1.81/(sp.fitpars['mean_3'] - sp.fitpars['mean_1'])
        b = 0.87/(sp.fitpars['mean_2'] - sp.fitpars['mean_1'])
        print('order: %d' %info['order'])
        print(np.max(a), np.min(a))
        print(np.max(b), np.min(b))
# Out:
# order: 1
# 0.12000000000000004 0.1199999999999923
# 0.12000000000000059 0.11999999999998265
# order: 2
# 0.12700000000000825 0.1269999999999998
# 0.12700000000000056 0.12699999999999878
# order: 3
# 0.13400000000000006 0.13399999999999818
# 0.13400000000000017 0.13399999999999726
# order: 4
# 0.13700000000000262 0.13699999999999946
# 0.13700000000000948 0.13699999999999873
# order: 5
# 0.14399999999999955 0.14399999999999824
# 0.14400000000000074 0.14399999999999819
# order: 6
# 0.14900000000000035 0.14899999999999952
# 0.14900000000000044 0.14899999999999908
# order: 7
# 0.15300000000000008 0.1529999999999993
# 0.1530000000000009 0.1529999999999995
# order: 8
# 0.1580000000000003 0.15799999999999967
# 0.15800000000000003 0.1579999999999993
# order: 9
# 0.16300000000000028 0.16300000000000003
# 0.1630000000000006 0.16299999999999962
# order: 10
# 0.16800000000000015 0.16799999999996865
# 0.16800000000000004 0.16799999999985374

# %%
outspec[0].save_multi('esi1d_J0924_42_gauss_primary')
outspec[1].save_multi('esi1d_J0924_42_gauss_secondary')
outspec[2].save_multi('esi1d_J0924_42_gauss_tertiary')
# Out:
# Spectrum saved in mode multitab to file esi1d_J0924_42_gauss_primary.fits
# Spectrum saved in mode multitab to file esi1d_J0924_42_gauss_secondary.fits
# Spectrum saved in mode multitab to file esi1d_J0924_42_gauss_tertiary.fits

# %%
outspec[0].plot_all(fig=plt.figure(figsize=(10, 6)), ax=plt.subplot(111))

# %%
outspec[0].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt')
# Out:
#  Spectrum Start:  4071.46
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.25

# %%
outspec[0].spec1d.save('spec1d_J0924_42_gauss_primary.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0924_42_gauss_primary.fits in format fits

# %%
outspec[1].plot_all(fig=plt.figure(figsize=(10, 6)), ax=plt.subplot(111))

# %%
outspec[1].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt')
# Out:
#  Spectrum Start:  4071.46
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.25

# %%
outspec[1].spec1d.save('spec1d_J0924_42_gauss_secondary.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0924_42_gauss_secondary.fits in format fits

# %%
outspec[2].plot_all(fig=plt.figure(figsize=(10, 6)), ax=plt.subplot(111))

# %%
outspec[2].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt')
# Out:
#  Spectrum Start:  4071.46
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.25

# %%
outspec[2].spec1d.save('spec1d_J0924_42_gauss_tertiary.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0924_42_gauss_tertiary.fits in format fits

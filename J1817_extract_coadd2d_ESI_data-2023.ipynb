# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, echelle1d, spec1d, echelle2d

# %%
file_loc = 'J1817_ESI_spectra/spectra_2023/*'

# %%
spec2d_file_list = []
var2d_file_list = []
#out_file = []
for i, p in enumerate(glob.glob(file_loc)):
    file_name = p.split('/')[-1]
    if 'sp_order' in file_name:
        spec2d_file_list.append(p)
    elif 'var' in file_name:
        var2d_file_list.append(p)

# %%
spec2d_file_list = sorted(spec2d_file_list)
var2d_file_list = sorted(var2d_file_list)
spec2d_file_list, var2d_file_list
# Out:
# (['J1817_ESI_spectra/spectra_2023/J1817_coadd2d_sp_order_4.fits',
#   'J1817_ESI_spectra/spectra_2023/J1817_coadd2d_sp_order_5.fits',
#   'J1817_ESI_spectra/spectra_2023/J1817_coadd2d_sp_order_6.fits',
#   'J1817_ESI_spectra/spectra_2023/J1817_coadd2d_sp_order_7.fits',
#   'J1817_ESI_spectra/spectra_2023/J1817_coadd2d_sp_order_8.fits',
#   'J1817_ESI_spectra/spectra_2023/J1817_coadd2d_sp_order_9.fits'],
#  ['J1817_ESI_spectra/spectra_2023/J1817_coadd2d_var_order_4.fits',
#   'J1817_ESI_spectra/spectra_2023/J1817_coadd2d_var_order_5.fits',
#   'J1817_ESI_spectra/spectra_2023/J1817_coadd2d_var_order_6.fits',
#   'J1817_ESI_spectra/spectra_2023/J1817_coadd2d_var_order_7.fits',
#   'J1817_ESI_spectra/spectra_2023/J1817_coadd2d_var_order_8.fits',
#   'J1817_ESI_spectra/spectra_2023/J1817_coadd2d_var_order_9.fits'])

# %%
#spec_ord_3 = spec2d.Spec2d(inspec=spec2d_file_list[1], invar=var2d_file_list[1], logwav=True)
spec_ord_4 = spec2d.Spec2d(inspec=spec2d_file_list[0], invar=var2d_file_list[0], logwav=True, ytrim=[25, 110])
spec_ord_5 = spec2d.Spec2d(inspec=spec2d_file_list[1], invar=var2d_file_list[1], logwav=True, ytrim=[25, 110])
spec_ord_6 = spec2d.Spec2d(inspec=spec2d_file_list[2], invar=var2d_file_list[2], logwav=True, ytrim=[25, 110])
spec_ord_7 = spec2d.Spec2d(inspec=spec2d_file_list[3], invar=var2d_file_list[3], logwav=True, ytrim=[25, 110])
spec_ord_8 = spec2d.Spec2d(inspec=spec2d_file_list[4], invar=var2d_file_list[4], logwav=True, ytrim=[25, 110])
spec_ord_9 = spec2d.Spec2d(inspec=spec2d_file_list[5], invar=var2d_file_list[5], logwav=True, ytrim=[25, 110])
#spec_ord_10 = spec2d.Spec2d(inspec=spec2d_file_list[0], invar=var2d_file_list[0], logwav=True)
# Out:
# Loading file J1817_ESI_spectra/spectra_2023/J1817_coadd2d_sp_order_4.fits
# -----------------------------------------------
#
# Loading file J1817_ESI_spectra/spectra_2023/J1817_coadd2d_var_order_4.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from J1817_ESI_spectra/spectra_2023/J1817_coadd2d_sp_order_4.fits (HDU=0)
# The input dataset was trimmed
#  xrange: 0:4096.  yrange: 25:111
# Final data dimensions (x y): 4096 x 86
#
# Dispersion axis:              x
# N_pixels along dispersion axis: 4096
#
#
# Loading file J1817_ESI_spectra/spectra_2023/J1817_coadd2d_sp_order_5.fits
# -----------------------------------------------
#
# Loading file J1817_ESI_spectra/spectra_2023/J1817_coadd2d_var_order_5.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from J1817_ESI_spectra/spectra_2023/J1817_coadd2d_sp_order_5.fits (HDU=0)
# The input dataset was trimmed
#  xrange: 0:4096.  yrange: 25:111
# ...

# %%
spec_list= [spec_ord_4, spec_ord_5, spec_ord_6, spec_ord_7, spec_ord_8, 
            spec_ord_9] #spec_ord_3,  spec_ord_10

pixrange_list = [[2100, 2500], [2700, 3100], [2700, 3100], [1800, 2200],
            [1600, 2000], [1500, 1900]]# [2800, 3100], [800, 1200]

for i, sp in enumerate(spec_list):
    sp.spatial_profile(pixrange=pixrange_list[i])
    plt.show()
    sp.initial_model()
# Out:
# Profile max value (before normalization) 193.961680
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 5
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 150, 28, 3, 4
#
# amplitude=150.000000, x_0=28.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 175, 43, 3, 4
#
# amplitude=175.000000, x_0=43.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 3 : 30, 47, 2, 3
#
# amplitude=30.000000, x_0=47.000000, gamma=2.000000, alpha=3.000000
#
# Parameters of Moffat profile 4 : 30, 51, 2, 3
#
# amplitude=30.000000, x_0=51.000000, gamma=2.000000, alpha=3.000000
#
# ...

# %%
def tie_pos1_moffat_3(model):
    return model.x_0_1 + (2.10 / pixscale[0])  

def tie_pos2_moffat_3(model):
    return model.x_0_1 + (3.2 / pixscale[0])

def tie_pos3_moffat_3(model):
    return model.x_0_1 + (3.89 / pixscale[0]) 

def tie_pos4_moffat_3(model):
    return model.x_0_1 + (2.61 / pixscale[0]) 

def tie_pos1_moffat_4(model):
    return model.x_0_1 + (2.10 / pixscale[1])  

def tie_pos2_moffat_4(model):
    return model.x_0_1 + (3.2 / pixscale[1])

def tie_pos3_moffat_4(model):
    return model.x_0_1 + (3.89 / pixscale[1])

def tie_pos4_moffat_4(model):
    return model.x_0_1 + (2.61 / pixscale[1]) 

def tie_pos1_moffat_5(model):
    return model.x_0_1 + (2.10 / pixscale[2])  

def tie_pos2_moffat_5(model):
    return model.x_0_1 + (3.2 / pixscale[2]) 

def tie_pos3_moffat_5(model):
    return model.x_0_1 + (3.89 / pixscale[2])

def tie_pos4_moffat_5(model):
    return model.x_0_1 + (2.61 / pixscale[2]) 

def tie_pos1_moffat_6(model):
    return model.x_0_1 + (2.10 / pixscale[3])  

def tie_pos2_moffat_6(model):
    return model.x_0_1 + (3.2 / pixscale[3])

def tie_pos3_moffat_6(model):
    return model.x_0_1 + (3.89 / pixscale[3])

def tie_pos4_moffat_6(model):
    return model.x_0_1 + (2.61 / pixscale[3]) 

def tie_pos1_moffat_7(model):
    return model.x_0_1 + (2.10 / pixscale[4])  

def tie_pos2_moffat_7(model):
    return model.x_0_1 + (3.2 / pixscale[4])

def tie_pos3_moffat_7(model):
    return model.x_0_1 + (3.89 / pixscale[4])

def tie_pos4_moffat_7(model):
    return model.x_0_1 + (2.61 / pixscale[4]) 

def tie_pos1_moffat_8(model):
    return model.x_0_1 + (2.10 /  pixscale[5])  

def tie_pos2_moffat_8(model):
    return model.x_0_1 + (3.2 /  pixscale[5])

def tie_pos3_moffat_8(model):
    return model.x_0_1 + (3.89 / pixscale[5])

def tie_pos4_moffat_8(model):
    return model.x_0_1 + (2.61 / pixscale[5]) 

def tie_pos1_moffat_9(model):
    return model.x_0_1 + (2.10 /  pixscale[6])  

def tie_pos2_moffat_9(model):
    return model.x_0_1 + (3.2 /  pixscale[6])

def tie_pos3_moffat_9(model):
    return model.x_0_1 + (3.89 / pixscale[6])

def tie_pos4_moffat_9(model):
    return model.x_0_1 + (2.61 / pixscale[6]) 

def tie_pos1_moffat_10(model):
    return model.x_0_1 + (2.10 /  pixscale[7])  

def tie_pos2_moffat_10(model):
    return model.x_0_1 + (3.2 /  pixscale[7])

def tie_pos3_moffat_10(model):
    return model.x_0_1 + (3.89 / pixscale[7])

def tie_pos4_moffat_10(model):
    return model.x_0_1 + (2.61 / pixscale[7]) 

def tie_gamma_moffat(model):
    return model.gamma_1

def tie_alpha_moffat(model):
    return model.alpha_1 

def tie_gamma_moffat1(model):
    return model.gamma_1 * 0.5

def tie_alpha_moffat1(model):
    return model.alpha_1 * 0.5

func_dict = {
 '4_1' : tie_pos1_moffat_4, '4_2' : tie_pos2_moffat_4, '4_3' : tie_pos3_moffat_4, '4_4' : tie_pos4_moffat_4,
 '5_1' : tie_pos1_moffat_5, '5_2' : tie_pos2_moffat_5, '5_3' : tie_pos3_moffat_5, '5_4' : tie_pos4_moffat_5,
 '6_1' : tie_pos1_moffat_6, '6_2' : tie_pos2_moffat_6, '6_3' : tie_pos3_moffat_6, '6_4' : tie_pos4_moffat_6,
 '7_1' : tie_pos1_moffat_7, '7_2' : tie_pos2_moffat_7, '7_3' : tie_pos3_moffat_7, '7_4' : tie_pos4_moffat_7,
 '8_1' : tie_pos1_moffat_8, '8_2' : tie_pos2_moffat_8, '8_3' : tie_pos3_moffat_8, '8_4' : tie_pos4_moffat_8,
 '9_1' : tie_pos1_moffat_9, '9_2' : tie_pos2_moffat_9, '9_3' : tie_pos3_moffat_9, '9_4' : tie_pos4_moffat_9,
}
pixscale = [0.134, 0.137, 0.144, 0.149, 0.153, 0.158, 0.163]
ord_list = [4, 5, 6, 7, 8, 9]
for i, sp in enumerate(spec_list):
    if sp.mod0 is not None:
        print(pixscale[i])
        sp.mod0[2].x_0.tied = func_dict['%d_%d' %(ord_list[i], 1)] #tie_pos1_moffat
        #sp.mod0[1].mean.tied = func_dict['%d_%d' %(ord_list[i], 2)] #tie_pos1_moffat
        sp.mod0[3].x_0.tied = func_dict['%d_%d' %(ord_list[i], 4)] #tie_pos2_moffat
        sp.mod0[4].x_0.tied = func_dict['%d_%d' %(ord_list[i], 2)]
        sp.mod0[5].x_0.tied = func_dict['%d_%d' %(ord_list[i], 3)]
        sp.mod0[2].gamma.tied = tie_gamma_moffat
        sp.mod0[2].alpha.tied = tie_alpha_moffat
        sp.mod0[3].gamma.tied = tie_gamma_moffat
        sp.mod0[3].alpha.tied = tie_alpha_moffat
        sp.mod0[4].gamma.tied = tie_gamma_moffat
        sp.mod0[4].alpha.tied = tie_alpha_moffat
        sp.mod0[5].gamma.tied = tie_gamma_moffat
        sp.mod0[5].alpha.tied = tie_alpha_moffat
        sp.refined_model(sp.mod0)
# Out:
# 0.134
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3] + [4] + [5]
# Components:
#     [0]: <Polynomial1D(0, c0=0.4833679)>
#
#     [1]: <Moffat1D(amplitude=153.41296576, x_0=28.3301335, gamma=9.18557718, alpha=7.01744714)>
#
#     [2]: <Moffat1D(amplitude=139.97983537, x_0=42.91346684, gamma=9.18557718, alpha=7.01744714)>
#
#     [3]: <Moffat1D(amplitude=78.36848413, x_0=46.4551335, gamma=9.18557718, alpha=7.01744714)>
#
#     [4]: <Moffat1D(amplitude=-11.60337528, x_0=50.55235573, gamma=9.18557718, alpha=7.01744714)>
#
#     [5]: <Moffat1D(amplitude=61.88436293, x_0=55.34402239, gamma=9.18557718, alpha=7.01744714)>
# Parameters:
#             c0_0          amplitude_1    ...     gamma_5           alpha_5
#     ------------------- ---------------- ... ---------------- -----------------
#     0.48336789642689043 153.412965755695 ... 9.18557717639077 7.017447139948545
#
# ...

# %%
fitrange_list = np.array([[1100, 4100], [1000, 4100], [800, 4100], [500, 4100],
                          [100, 4100], [0, 4100]]) #[1200, 3700], , [0, 2600]
for i, sp in enumerate(spec_list):
    sp.find_and_trace(sp.mod0, stepsize=25, fitorder={'x_0_1':5, 'x_0_2':5, 'x_0_3':5, 'x_0_4':5, 'x_0_5':5},
                    fitrange=fitrange_list[i], polyorder=4)
    plt.show()
# Out:
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
#     Done
# Fitting polynomial of degree 4 to parameter: c0_0
# Fitting polynomial of degree 5 to parameter: x_0_1
# Fitting polynomial of degree 4 to parameter: gamma_1
# Fitting polynomial of degree 4 to parameter: alpha_1
# Fitting polynomial of degree 5 to parameter: x_0_2
# Fitting polynomial of degree 4 to parameter: gamma_2
# Fitting polynomial of degree 4 to parameter: alpha_2
# Fitting polynomial of degree 5 to parameter: x_0_3
# Fitting polynomial of degree 4 to parameter: gamma_3
# Fitting polynomial of degree 4 to parameter: alpha_3
# Fitting polynomial of degree 5 to parameter: x_0_4
# Fitting polynomial of degree 4 to parameter: gamma_4
# Fitting polynomial of degree 4 to parameter: alpha_4
# Fitting polynomial of degree 5 to parameter: x_0_5
# Fitting polynomial of degree 4 to parameter: gamma_5
# ...

# %%
extrange_list = np.array([[1200, -1], [1100, -1], [900, -1], [600, -1], 
                          [200, -1], [0, -1]]) # [1300, 3700],, [0, 2500]
for sp, ext in zip(spec_list, extrange_list):
    sp.extract(method='modelfit', extrange=ext)
    plt.show()
# Out:
# Fitting to 5 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1200 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#
# Plotting the spectrum
# Fitting to 5 components, plus a background
# Extracting the spectrum.  Please be patient
# ...

# %%
outspec = []
orderinfo = np.array([4, 5, 6, 7, 8, 9], dtype=[('order', int)])

# %%
for i, spp in enumerate(spec_ord_4.spectra):
    s = []
    for sp in spec_list:
        s.append(sp.spectra[i][1])
    outspec.append(echelle1d.Ech1d(s, ordinfo=orderinfo))
# Out:
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   4  2896   4902.88  5472.92   0.20
#   5  2996   5325.24  5967.01   0.21
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.93  8194.05   0.29
#   9  4096   8012.11  9360.83   0.33
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   4  2896   4902.88  5472.92   0.20
#   5  2996   5325.24  5967.01   0.21
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.93  8194.05   0.29
#   9  4096   8012.11  9360.83   0.33
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   4  2896   4902.88  5472.92   0.20
#   5  2996   5325.24  5967.01   0.21
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.93  8194.05   0.29
#   9  4096   8012.11  9360.83   0.33
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
# ...

# %%
outspec[0].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))
outspec[1].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))
outspec[2].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))
outspec[3].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))
outspec[4].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))

# %%
resp_file = 'response_curve_ESI_optimal_smooth_new.txt'

# %%
outspec[0].stitch_to_spec1d(respfile=resp_file, order=[4, 9])
outspec[1].stitch_to_spec1d(respfile=resp_file, order=[4, 9])
outspec[2].stitch_to_spec1d(respfile=resp_file, order=[4, 9])
outspec[3].stitch_to_spec1d(respfile=resp_file, order=[4, 9])
outspec[4].stitch_to_spec1d(respfile=resp_file, order=[4, 9])
# Out:
#  Spectrum Start:     3.69
#  Spectrum End:        3.97
#  Dispersion (1st pixel): 1.65e-05
#  Dispersion (average):    1.65e-05
#  Spectrum Start:     3.69
#  Spectrum End:        3.97
#  Dispersion (1st pixel): 1.65e-05
#  Dispersion (average):    1.65e-05
#  Spectrum Start:     3.69
#  Spectrum End:        3.97
#  Dispersion (1st pixel): 1.65e-05
#  Dispersion (average):    1.65e-05
#  Spectrum Start:     3.69
#  Spectrum End:        3.97
#  Dispersion (1st pixel): 1.65e-05
#  Dispersion (average):    1.65e-05
#  Spectrum Start:     3.69
#  Spectrum End:        3.97
#  Dispersion (1st pixel): 1.65e-05
#  Dispersion (average):    1.65e-05

# %%
sp_d = spec1d.Spec1d(flux= outspec[3].spec1d['flux'], wav=outspec[3].spec1d['wav'], 
                     var=outspec[3].spec1d['var'], logwav=True,
                     trimsec=[1500, -2300])
# Out:
#  Spectrum Start:  5190.41
#  Spectrum End:     8577.57
#  Dispersion (1st pixel):   0.20
#  Dispersion (average):      0.26

# %%
fg = plt.figure(figsize=(12, 8))
sp_d.smooth(19, fig=fg)
sp_d.mark_lines('abs', z=0.409, usesmooth=True)
# Out:
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-kappa       3750.00       5283.75
# [Fe VII]      3761.40       5299.81
# H-iota        3770.00       5311.93
# H-theta       3797.00       5349.97
# H-eta         3835.00       5403.52
# CN bandhd     3883.00       5471.15
# CaII K        3933.67       5542.54
# CaII H        3968.47       5591.57
# H-delta       4101.00       5778.31
# G-band        4305.00       6065.74
# H-gamma       4340.00       6115.06
# Fe4383        4383.00       6175.65
# Ca4455        4455.00       6277.10
# Fe4531        4531.00       6384.18
# H-beta        4861.00       6849.15
# Mg I (b)      5176.00       7292.98
# Na I (D)      5889.95       8298.94
# Na I (D)      5895.92       8307.35

# %%
outspec[3].spec1d.save('J1817_ESI_spectra/spectra_2023/spec1d_J1817_esi_coadd2d_2023_data_deflector.fits', outformat='fits')
outspec[1].spec1d.save('J1817_ESI_spectra/spectra_2023/spec1d_J1817_esi_coadd2d_2023_data_quasar_primary.fits', outformat='fits')
outspec[4].spec1d.save('J1817_ESI_spectra/spectra_2023/spec1d_J1817_esi_coadd2d_2023_data_quasar_secondary.fits', outformat='fits')
outspec[2].spec1d.save('J1817_ESI_spectra/spectra_2023/spec1d_J1817_esi_coadd2d_2023_data_quasar_tertiary.fits', outformat='fits')
# Out:
# Saved spectrum to file J1817_ESI_spectra/spectra_2023/spec1d_J1817_esi_coadd2d_2023_data_deflector.fits in format fits
# Saved spectrum to file J1817_ESI_spectra/spectra_2023/spec1d_J1817_esi_coadd2d_2023_data_quasar_primary.fits in format fits
# Saved spectrum to file J1817_ESI_spectra/spectra_2023/spec1d_J1817_esi_coadd2d_2023_data_quasar_secondary.fits in format fits
# Saved spectrum to file J1817_ESI_spectra/spectra_2023/spec1d_J1817_esi_coadd2d_2023_data_quasar_tertiary.fits in format fits

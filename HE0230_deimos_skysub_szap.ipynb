# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
from specim_test.specim.specfuncs import spec2d
from astropy.io import fits as pf
import os

# %%
file_loc = '../galaxy_spectra/DEIMOS_data/HE0230_data/*'

# %%
file_list = []
out_file_det3 = []
out_file_det7 = []

for i,p in enumerate(glob.glob(file_loc)):
    if 'spec2d' in p and 'HE0230' in p:
        file_list.append(p)
        f = p.split('_')
        frame = f[-4]+ '_' + f[-3][:4]
        out_file_det3.append('HE0230_DEIMOS_spectra/HE0230_deimos_det3_'+ frame + '_clean.fits')
        out_file_det7.append('HE0230_DEIMOS_spectra/HE0230_deimos_det7_'+ frame + '_clean.fits')

# %%
file_list = sorted(file_list)
file_list
# Out:
# ['../galaxy_spectra/DEIMOS_data/HE0230_data/spec2d_d0929_0079-HE0230m1_DEIMOS_20210929T121858.234-001.fits',
#  '../galaxy_spectra/DEIMOS_data/HE0230_data/spec2d_d0929_0080-HE0230m1_DEIMOS_20210929T125056.832-004.fits',
#  '../galaxy_spectra/DEIMOS_data/HE0230_data/spec2d_d0929_0081-HE0230m1_DEIMOS_20210929T132227.437-003.fits',
#  '../galaxy_spectra/DEIMOS_data/HE0230_data/spec2d_d0929_0084-HE0230m2_DEIMOS_20210929T140036.778-002.fits']

# %%
out_file_det3 = sorted(out_file_det3)
out_file_det7 = sorted(out_file_det7)
out_file_det3, out_file_det7
# Out:
# (['HE0230_DEIMOS_spectra/HE0230_deimos_det3_d0929_0079_clean.fits',
#   'HE0230_DEIMOS_spectra/HE0230_deimos_det3_d0929_0080_clean.fits',
#   'HE0230_DEIMOS_spectra/HE0230_deimos_det3_d0929_0081_clean.fits',
#   'HE0230_DEIMOS_spectra/HE0230_deimos_det3_d0929_0084_clean.fits'],
#  ['HE0230_DEIMOS_spectra/HE0230_deimos_det7_d0929_0079_clean.fits',
#   'HE0230_DEIMOS_spectra/HE0230_deimos_det7_d0929_0080_clean.fits',
#   'HE0230_DEIMOS_spectra/HE0230_deimos_det7_d0929_0081_clean.fits',
#   'HE0230_DEIMOS_spectra/HE0230_deimos_det7_d0929_0084_clean.fits'])

# %% [markdown]
# ### finding out spatial location of 2d lens spectra in science image¶

# %%
file_list_spec1d = []
frame_list = []
for i,p in enumerate(glob.glob(file_loc)):
    if 'spec1d' in p and 'HE0230' in p:
        file_list_spec1d.append(p)
        f = p.split('_')
        frame = f[-4]+ '_' + f[-3][:4]
        frame_list.append(frame)
        
for fl, frm in zip(file_list_spec1d, frame_list):
    sp = pf.open(fl)
    #m = sp.slitinfo['objid']=='lens'
    nspec = sp[0].header['NSPEC']
    print(frm, nspec)
    #if frm =='d0613_0105':
        #pass
    #elif frm =='d0613_0106':
        #pass
    #else:
    for i in range(nspec):
        if 'lens' in sp[i+1].header['HIERARCH MASKDEF_OBJNAME']:
            print(sp[i+1].header['NAME'])
# Out:
# d0929_0080 131
# SPAT0498-SLIT0478-DET03
# SPAT0499-SLIT0479-DET07
# d0929_0081 134
# SPAT0498-SLIT0478-DET03
# SPAT0499-SLIT0479-DET07
# d0929_0084 128
# SPAT0752-SLIT0648-DET03
# SPAT0753-SLIT0649-DET07
# d0929_0079 133
# SPAT0498-SLIT0478-DET03
# SPAT0499-SLIT0479-DET07

# %% [markdown]
# ## median image after sky subtraction

# %%
79 - [[335, 625], [[335, 625]]], 80, 81 -[[335, 625], [335, 625]] ; 84 - [[460, 845], [460, 845]]

# %%
xtrim_det = [[398, 591], [652, 845]]

spec_det_3 = []
spec_det_7 = []

for i, fl in enumerate(file_list):
    
    spec1 = spec2d.Spec2d(fl, hext=31, varext=32, do_invar=True)
    spec2 = spec2d.Spec2d(fl, hext=91, varext=92, do_invar=True)
    
    spec1.set_dispaxis('y')
    spec1.subtract_sky_2d(use_skymod=True)
    
    spec2.set_dispaxis('y')
    spec2.subtract_sky_2d(use_skymod=True)
    
    if i<3:
        spec_det_3.append(spec1.data[:, xtrim_det[0][0]:xtrim_det[0][1]])
        spec_det_7.append(spec2.data[:, xtrim_det[0][0]:xtrim_det[0][1]])
    else:
        spec_det_3.append(spec1.data[:, xtrim_det[1][0]:xtrim_det[1][1]])
        spec_det_7.append(spec2.data[:, xtrim_det[1][0]:xtrim_det[1][1]])
# Out:
# Loading file ../galaxy_spectra/DEIMOS_data/HE0230_data/spec2d_d0929_0079-HE0230m1_DEIMOS_20210929T121858.234-001.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from ../galaxy_spectra/DEIMOS_data/HE0230_data/spec2d_d0929_0079-HE0230m1_DEIMOS_20210929T121858.234-001.fits (HDU=31)
# Final data dimensions (x y): 2048 x 4096
#
# Dispersion axis:              x
# N_pixels along dispersion axis: 2048
#
#
# Loading file ../galaxy_spectra/DEIMOS_data/HE0230_data/spec2d_d0929_0079-HE0230m1_DEIMOS_20210929T121858.234-001.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from ../galaxy_spectra/DEIMOS_data/HE0230_data/spec2d_d0929_0079-HE0230m1_DEIMOS_20210929T121858.234-001.fits (HDU=91)
# Final data dimensions (x y): 2048 x 4096
#
# Dispersion axis:              x
# N_pixels along dispersion axis: 2048
#
#
# Old value of dispaxis: x
#
# Dispersion axis:              y
# N_pixels along dispersion axis: 4096
#
#
#
# ...

# %%
median_im_det3 = np.median(np.asarray(spec_det_3), axis=0)
median_im_det7 = np.median(np.asarray(spec_det_7), axis=0)

# %%
folder_path = 'HE0230_DEIMOS_spectra' 
# Create the folder
try:
    os.makedirs(folder_path)
except:
    print(f'folder already exist for {folder_path}')
    pass
pf.PrimaryHDU(median_im_det3).writeto('HE0230_DEIMOS_spectra/HE0230_median_image_det3.fits', overwrite=True)
pf.PrimaryHDU(median_im_det7).writeto('HE0230_DEIMOS_spectra/HE0230_median_image_det7.fits', overwrite=True)
# Out:
# folder already exist for HE0230_DEIMOS_spectra

# %% [markdown]
# ### subtract sky and cosmic rays

# %%
extension = [31, 91]
trim = [[398, 591], [652, 845]]

median_im = ['HE0230_DEIMOS_spectra/HE0230_median_image_det3.fits', 
             'HE0230_DEIMOS_spectra/HE0230_median_image_det7.fits']
i=0
for fl, ofl1, ofl2 in zip(file_list, out_file_det3, out_file_det7):
    if i<3:
         x1, x2 = xtrim_det[0][0], xtrim_det[0][1]
    else:
        x1, x2 = xtrim_det[1][0], xtrim_det[1][1]
        
    for ext, mdim in zip(extension, median_im):
        print(ext, mdim)
        spec = spec2d.Spec2d(fl, hext=ext, varext=ext+1)
        #spec2 = spec2d.Spec2d(fl, hext=66, xtrim=[970, 1080])
        spec.set_dispaxis('y')
        spec.subtract_sky_2d(use_skymod=True)
        spec.data = spec.data[:, x1:x2]
        spec.szap_new(infile=mdim)

        if ext==31:
            filled_data = spec.data
            mask = spec.szap_mask
            #print(filled_data.shape)
            ivar_im = pf.open(fl)[ext+1].data[spec.ymin:spec.ymax, spec.xmin:spec.xmax][:, x1:x2]
            sky_im = pf.open(fl)[ext+2].data[spec.ymin:spec.ymax, spec.xmin:spec.xmax][:, x1:x2]
            wav_im = pf.open(fl)[ext+7].data[spec.ymin:spec.ymax, spec.xmin:spec.xmax][:, x1:x2]

        elif ext==91:
            filled_data = spec.data
            mask = spec.szap_mask
            #print(filled_data.shape)
            ivar_im = pf.open(fl)[ext+1].data[spec.ymin:spec.ymax, spec.xmin:spec.xmax][:, x1:x2]
            sky_im = pf.open(fl)[ext+2].data[spec.ymin:spec.ymax, spec.xmin:spec.xmax][:, x1:x2]
            wav_im = pf.open(fl)[ext+7].data[spec.ymin:spec.ymax, spec.xmin:spec.xmax][:, x1:x2]

        ivar_im[mask] = 1.e-5
        #print(ivar_im.shape)

        prim_hdr = pf.open(fl)[0].header
        prim_hdr.append(('OBJECT', 'HE0230-2130'))
        prim_hdr.append(('', 'Trimmed and cleaned data by Pritom'))
        phdu = pf.PrimaryHDU(header=prim_hdr)

        sci_hdr = pf.Header()
        sci_hdr.append(('OBJECT', 'HE0230-2130'))
        sci_hdr.append(('IMTYPE', 'SCIENCE_IMAGE'))
        sci_im_hdu = pf.ImageHDU(data=filled_data, header=sci_hdr, name='SCI_IM')

        ivar_hdr = pf.Header()
        ivar_hdr.append(('IMTYPE', 'IVAR_IMAGE'))
        ivar_im_hdu = pf.ImageHDU(data=ivar_im, header=ivar_hdr, name='IVAR')

        sky_hdr = pf.Header()
        sky_hdr.append(('IMTYPE', 'SKY_MODEL'))
        sky_im_hdu = pf.ImageHDU(data=sky_im, header=sky_hdr, name='SKY_MOD')

        wav_hdr = pf.Header()
        wav_hdr.append(('IMTYPE', 'WAV_IMAGE'))
        wav_im_hdu = pf.ImageHDU(data=wav_im, header=wav_hdr, name='WAV_IM')

        mask_hdr = pf.Header()
        mask_hdr.append(('IMTYPE', 'MASK'))
        cmt = 'pixels masked as cosmic rays and filled with pixel values at same pixel'\
            'location from median image'
        mask_hdr.append(('', cmt))
        mask_hdu = pf.ImageHDU(data=mask, header=mask_hdr, name='MASK')

        hdul = pf.HDUList([phdu, sci_im_hdu, ivar_im_hdu, sky_im_hdu, wav_im_hdu, mask_hdu ])

        if ext==31:
            hdul.writeto(ofl1)
            print(ofl1)
        else:
            hdul.writeto(ofl2)
            print(ofl2)
    i +=1
# Out:
# 31 HE0230_DEIMOS_spectra/HE0230_median_image_det3.fits
#
# Loading file ../galaxy_spectra/DEIMOS_data/HE0230_data/spec2d_d0929_0079-HE0230m1_DEIMOS_20210929T121858.234-001.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from ../galaxy_spectra/DEIMOS_data/HE0230_data/spec2d_d0929_0079-HE0230m1_DEIMOS_20210929T121858.234-001.fits (HDU=31)
# Final data dimensions (x y): 2048 x 4096
#
# Dispersion axis:              x
# N_pixels along dispersion axis: 2048
#
#
# Old value of dispaxis: x
#
# Dispersion axis:              y
# N_pixels along dispersion axis: 4096
#
#
#
# pypeit generated sky model will be used for sky subtraction
#
#
# From this point sky subtracted data will be used
#  Spectrum Start:     0.00
#  Spectrum End:     4095.00
#  Dispersion (1st pixel):   1.00
#  Dispersion (average):      1.00
#
#
# From now cosmic ray rejected data will be used
# HE0230_DEIMOS_spectra/HE0230_deimos_det3_d0929_0079_clean.fits
# ...

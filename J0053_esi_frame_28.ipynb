# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, spec1d

# %%
file_loc = '../galaxy_spectra/ESI_data/*'

# %%
spec2d_file_list = []
var2d_file_list = []
#out_file = []
for i,p in enumerate(glob.glob(file_loc)):
    if 'J0053' in p:
        if 'bgsub.fits' in p:
            spec2d_file_list.append(p)
        elif 'var.fits' in p:
            var2d_file_list.append(p)

# %%
spec = esi2d.Esi2d(spec2d_file_list[0], varfile=var2d_file_list[1])
print(spec2d_file_list[0])
print(var2d_file_list[1])
# Out:
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3461x165     x
#   2   4093x145     x
#   3   4096x146     x
#   4   4096x141     x
#   5   4096x130     x
#   6   4096x127     x
#   7   4096x124     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x111     x
# ../galaxy_spectra/ESI_data/J0053-2012_0028_bgsub.fits
# ../galaxy_spectra/ESI_data/J0053-2012_0028_var.fits

# %%
spec.plot_profiles()
# Out:
# Plotting spatial profiles
# -------------------------
# Profile max value (before normalization) 4.057989
# Profile max value (before normalization) 13.168634
# Profile max value (before normalization) 25.148050
# Profile max value (before normalization) 40.883378
# Profile max value (before normalization) 50.786707
# Profile max value (before normalization) 90.022671
# Profile max value (before normalization) 90.472753
# Profile max value (before normalization) 100.600848
# Profile max value (before normalization) 98.052164
# Profile max value (before normalization) 14.176432

# %%
pixrange = [(1900, 2400)]
for sp, info in zip(spec, spec.ordinfo):
    title = 'Spatial profile for ' + str(info['name'])
    sp.spatial_profile(pixrange=pixrange[0], title=title)
    plt.show()
    sp.initial_model()
# Out:
# Profile max value (before normalization) 4.315099
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 4, 77, 1
#
# amplitude=4.000000, mu=77.000000, sigma=1.000000
#
# Parameters of Gaussian profile 2 : 1.5, 85, 1
#
# amplitude=1.500000, mu=85.000000, sigma=1.000000
#
# Parameters of Gaussian profile 3 : 0.8, 93, 1
#
# amplitude=0.800000, mu=93.000000, sigma=1.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.15236955)>
#
#     [1]: <Gaussian1D(amplitude=3.80220689, mean=75.99880261, stddev=4.43717824)>
#
#     [2]: <Gaussian1D(amplitude=1.13011448, mean=84.52852182, stddev=0.49982642)>
#
#     [3]: <Gaussian1D(amplitude=0.94830552, mean=91.48255478, stddev=3.13704065)>
# Parameters:
#             c0_0            amplitude_1    ...       mean_3           stddev_3
#     -------------------- ----------------- ... ----------------- ------------------
#     -0.15236954646497458 3.802206889019914 ... 91.48255477970038 3.1370406519654486
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 15.656941
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 13, 65, 2
#
# amplitude=13.000000, mu=65.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 6, 74, 2
#
# amplitude=6.000000, mu=74.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 2, 83, 2
#
# amplitude=2.000000, mu=83.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.256262)>
#
#     [1]: <Gaussian1D(amplitude=12.03516294, mean=67.22320236, stddev=3.39652339)>
#
#     [2]: <Gaussian1D(amplitude=3.58624308, mean=69.00599245, stddev=7.69939874)>
#
#     [3]: <Gaussian1D(amplitude=1.26017151, mean=84.72127602, stddev=3.38800779)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3           stddev_3
#     ------------------- ------------------ ... ----------------- -----------------
#     -0.2562620025954129 12.035162941448773 ... 84.72127601643398 3.388007788745006
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 23.609541
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 25, 65, 2
#
# amplitude=25.000000, mu=65.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 6, 72, 2
#
# amplitude=6.000000, mu=72.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 3, 80, 2
#
# amplitude=3.000000, mu=80.000000, sigma=2.000000
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.22056362)>
#
#     [1]: <Gaussian1D(amplitude=23.4707675, mean=64.79529182, stddev=3.58660199)>
#
#     [2]: <Gaussian1D(amplitude=1.53164316, mean=71.53923672, stddev=1.55965471)>
#
#     [3]: <Gaussian1D(amplitude=2.75894173, mean=78.66696043, stddev=4.91980779)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3           stddev_3
#     ------------------- ----------------- ... ----------------- -----------------
#     -0.2205636239535272 23.47076749876812 ... 78.66696043313132 4.919807789825413
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 59.021791
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 60, 62, 2
#
# amplitude=60.000000, mu=62.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 15, 69, 2
#
# amplitude=15.000000, mu=69.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 8, 76, 2
#
# amplitude=8.000000, mu=76.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.07532438)>
#
#     [1]: <Gaussian1D(amplitude=58.18257137, mean=61.96090894, stddev=3.46977674)>
#
#     [2]: <Gaussian1D(amplitude=2.86703632, mean=68.95748879, stddev=1.1944395)>
#
#     [3]: <Gaussian1D(amplitude=6.44556597, mean=75.37254587, stddev=4.6345898)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3           stddev_3
#     -------------------- ---------------- ... ----------------- -----------------
#     -0.07532438072213828 58.1825713744628 ... 75.37254587168968 4.634589802733807
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 39.080199
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 60, 62, 2
#
# amplitude=60.000000, mu=62.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 15, 69, 2
#
# amplitude=15.000000, mu=69.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 8, 76, 2
#
# amplitude=8.000000, mu=76.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.28682025)>
#
#     [1]: <Gaussian1D(amplitude=31.75549977, mean=58.1071388, stddev=2.98878241)>
#
#     [2]: <Gaussian1D(amplitude=6.81054212, mean=59.6547781, stddev=9.62990944)>
#
#     [3]: <Gaussian1D(amplitude=1.78454427, mean=73.48499601, stddev=2.08586271)>
# Parameters:
#             c0_0           amplitude_1    ...      mean_3           stddev_3
#     ------------------- ----------------- ... ---------------- ------------------
#     -0.2868202510888177 31.75549976908556 ... 73.4849960052126 2.0858627130360663
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 107.536512
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 110, 53, 2
#
# amplitude=110.000000, mu=53.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 20, 59, 2
#
# amplitude=20.000000, mu=59.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 10, 66, 2
#
# amplitude=10.000000, mu=66.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.01959867)>
#
#     [1]: <Gaussian1D(amplitude=105.44282086, mean=52.2172782, stddev=3.27302141)>
#
#     [2]: <Gaussian1D(amplitude=5.69678399, mean=58.39828022, stddev=1.46995184)>
#
#     [3]: <Gaussian1D(amplitude=12.68433327, mean=64.53055997, stddev=3.96392003)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3           stddev_3
#     ------------------- ------------------ ... ----------------- -----------------
#     0.01959867150817372 105.44282085986302 ... 64.53055996540695 3.963920025725015
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 124.037790
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 120, 52, 2
#
# amplitude=120.000000, mu=52.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 30, 58, 2
#
# amplitude=30.000000, mu=58.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 15, 65, 2
#
# amplitude=15.000000, mu=65.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.06143826)>
#
#     [1]: <Gaussian1D(amplitude=121.78892188, mean=50.9367338, stddev=3.19704154)>
#
#     [2]: <Gaussian1D(amplitude=9.14679587, mean=57.14472293, stddev=2.25095627)>
#
#     [3]: <Gaussian1D(amplitude=15.42717848, mean=63.47692891, stddev=3.69737454)>
# Parameters:
#             c0_0            amplitude_1     ...       mean_3           stddev_3
#     -------------------- ------------------ ... ----------------- ------------------
#     0.061438261376728955 121.78892188144665 ... 63.47692891277771 3.6973745427004023
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 110.709092
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 110, 50, 2
#
# amplitude=110.000000, mu=50.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 30, 56, 2
#
# amplitude=30.000000, mu=56.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 18, 62, 2
#
# amplitude=18.000000, mu=62.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.14012943)>
#
#     [1]: <Gaussian1D(amplitude=109.53547671, mean=49.56453598, stddev=3.0697362)>
#
#     [2]: <Gaussian1D(amplitude=10.34076574, mean=55.50834982, stddev=1.49656691)>
#
#     [3]: <Gaussian1D(amplitude=14.47531843, mean=61.26886756, stddev=4.1477334)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3            stddev_3
#     ------------------- ----------------- ... ------------------ -----------------
#     0.14012942697165262 109.5354767097521 ... 61.268867559113005 4.147733404096611
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 125.225825
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 120, 48, 2
#
# amplitude=120.000000, mu=48.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 30, 54, 2
#
# amplitude=30.000000, mu=54.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 20, 60, 2
#
# amplitude=20.000000, mu=60.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.13173837)>
#
#     [1]: <Gaussian1D(amplitude=123.47915786, mean=47.17884139, stddev=3.04759115)>
#
#     [2]: <Gaussian1D(amplitude=12.53335908, mean=52.77807822, stddev=1.36682857)>
#
#     [3]: <Gaussian1D(amplitude=21.35725434, mean=58.42300622, stddev=3.69927395)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3            stddev_3
#     ------------------- ------------------ ... ------------------ ------------------
#     0.13173836894448443 123.47915786276457 ... 58.423006219903115 3.6992739506839625
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 15.185593
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 15, 46, 2
#
# amplitude=15.000000, mu=46.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 7, 52, 2
#
# amplitude=7.000000, mu=52.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 2.5, 58, 2
#
# amplitude=2.500000, mu=58.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.46893104)>
#
#     [1]: <Gaussian1D(amplitude=12.09423703, mean=45.21402199, stddev=2.28634826)>
#
#     [2]: <Gaussian1D(amplitude=2.29511956, mean=50.33431811, stddev=1.27589108)>
#
#     [3]: <Gaussian1D(amplitude=3.84427839, mean=48.54921083, stddev=9.98195713)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3            stddev_3
#     -------------------- ---------------- ... ------------------ -----------------
#     -0.46893103504703115 12.0942370287633 ... 48.549210827825036 9.981957129557333
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no

# %%
def tie_stddev_gauss(model):
    return model.stddev_1

for sp, info in zip(spec, spec.ordinfo):
    if sp.mod0 is not None:
        print(info['pixscale'])
        #sp.mod0[2].mean.tied = func_dict['%d_%d' %(info['order'], 1)] #tie_pos1_gauss_
        #sp.mod0[3].mean.tied = func_dict['%d_%d' %(info['order'], 2)] #tie_pos2_gauss
        sp.mod0[3].stddev.tied = tie_stddev_gauss
        sp.refined_model(sp.mod0)
# Out:
# 0.12
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.15236955)>
#
#     [1]: <Gaussian1D(amplitude=3.80220689, mean=75.99880261, stddev=4.43717824)>
#
#     [2]: <Gaussian1D(amplitude=1.13011448, mean=84.52852182, stddev=0.49982642)>
#
#     [3]: <Gaussian1D(amplitude=0.94830552, mean=91.48255478, stddev=3.13704065)>
# Parameters:
#             c0_0            amplitude_1    ...       mean_3           stddev_3
#     -------------------- ----------------- ... ----------------- ------------------
#     -0.15236954646497458 3.802206889019914 ... 91.48255477970038 3.1370406519654486
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.15433965)>
#
#     [1]: <Gaussian1D(amplitude=3.84308869, mean=75.92760275, stddev=4.29551563)>
#
#     [2]: <Gaussian1D(amplitude=2.04144004, mean=84.51100387, stddev=0.32957913)>
#
#     [3]: <Gaussian1D(amplitude=0.81977202, mean=91.10494226, stddev=4.29551563)>
# Parameters:
#             c0_0            amplitude_1     ...      mean_3          stddev_3
#     -------------------- ------------------ ... ---------------- ----------------
#     -0.15433965180815915 3.8430886920039016 ... 91.1049422612742 4.29551562592819
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# 0.127
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.256262)>
#
#     [1]: <Gaussian1D(amplitude=12.03516294, mean=67.22320236, stddev=3.39652339)>
#
#     [2]: <Gaussian1D(amplitude=3.58624308, mean=69.00599245, stddev=7.69939874)>
#
#     [3]: <Gaussian1D(amplitude=1.26017151, mean=84.72127602, stddev=3.38800779)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3           stddev_3
#     ------------------- ------------------ ... ----------------- -----------------
#     -0.2562620025954129 12.035162941448773 ... 84.72127601643398 3.388007788745006
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.25680863)>
#
#     [1]: <Gaussian1D(amplitude=11.97121649, mean=67.2277919, stddev=3.39148544)>
#
#     [2]: <Gaussian1D(amplitude=3.64544943, mean=68.9750969, stddev=7.68116348)>
#
#     [3]: <Gaussian1D(amplitude=1.26929461, mean=84.67216496, stddev=3.39148544)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3           stddev_3
#     ------------------- ------------------ ... ----------------- ------------------
#     -0.2568086283650843 11.971216489994172 ... 84.67216495905883 3.3914854418078018
#
# -------------------------------------------
# 0.134
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.22056362)>
#
#     [1]: <Gaussian1D(amplitude=23.4707675, mean=64.79529182, stddev=3.58660199)>
#
#     [2]: <Gaussian1D(amplitude=1.53164316, mean=71.53923672, stddev=1.55965471)>
#
#     [3]: <Gaussian1D(amplitude=2.75894173, mean=78.66696043, stddev=4.91980779)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3           stddev_3
#     ------------------- ----------------- ... ----------------- -----------------
#     -0.2205636239535272 23.47076749876812 ... 78.66696043313132 4.919807789825413
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.2052533)>
#
#     [1]: <Gaussian1D(amplitude=23.47219977, mean=64.82931511, stddev=3.61810363)>
#
#     [2]: <Gaussian1D(amplitude=2.02091278, mean=72.02103331, stddev=1.80186806)>
#
#     [3]: <Gaussian1D(amplitude=2.95333345, mean=79.28358633, stddev=3.61810363)>
# Parameters:
#             c0_0            amplitude_1     ...       mean_3           stddev_3
#     -------------------- ------------------ ... ----------------- ------------------
#     -0.20525330304841938 23.472199766977262 ... 79.28358633458369 3.6181036292662534
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# 0.137
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.07532438)>
#
#     [1]: <Gaussian1D(amplitude=58.18257137, mean=61.96090894, stddev=3.46977674)>
#
#     [2]: <Gaussian1D(amplitude=2.86703632, mean=68.95748879, stddev=1.1944395)>
#
#     [3]: <Gaussian1D(amplitude=6.44556597, mean=75.37254587, stddev=4.6345898)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3           stddev_3
#     -------------------- ---------------- ... ----------------- -----------------
#     -0.07532438072213828 58.1825713744628 ... 75.37254587168968 4.634589802733807
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.04886734)>
#
#     [1]: <Gaussian1D(amplitude=58.20929232, mean=61.97745823, stddev=3.48379475)>
#
#     [2]: <Gaussian1D(amplitude=4.12574878, mean=69.50711686, stddev=1.83818705)>
#
#     [3]: <Gaussian1D(amplitude=6.69276863, mean=76.20429066, stddev=3.48379475)>
# Parameters:
#              c0_0            amplitude_1     ...      stddev_3
#     --------------------- ------------------ ... ------------------
#     -0.048867341072939115 58.209292322600376 ... 3.4837947505996336
#
# -------------------------------------------
# 0.144
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.28682025)>
#
#     [1]: <Gaussian1D(amplitude=31.75549977, mean=58.1071388, stddev=2.98878241)>
#
#     [2]: <Gaussian1D(amplitude=6.81054212, mean=59.6547781, stddev=9.62990944)>
#
#     [3]: <Gaussian1D(amplitude=1.78454427, mean=73.48499601, stddev=2.08586271)>
# Parameters:
#             c0_0           amplitude_1    ...      mean_3           stddev_3
#     ------------------- ----------------- ... ---------------- ------------------
#     -0.2868202510888177 31.75549976908556 ... 73.4849960052126 2.0858627130360663
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.32348151)>
#
#     [1]: <Gaussian1D(amplitude=32.81477562, mean=58.12620323, stddev=3.04723826)>
#
#     [2]: <Gaussian1D(amplitude=6.23561575, mean=60.78352053, stddev=9.69909356)>
#
#     [3]: <Gaussian1D(amplitude=1.27065654, mean=72.98971413, stddev=3.04723826)>
# Parameters:
#             c0_0            amplitude_1    ...       mean_3           stddev_3
#     -------------------- ----------------- ... ----------------- ------------------
#     -0.32348151327818386 32.81477562073984 ... 72.98971413421897 3.0472382554547965
#
# -------------------------------------------
# 0.149
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.01959867)>
#
#     [1]: <Gaussian1D(amplitude=105.44282086, mean=52.2172782, stddev=3.27302141)>
#
#     [2]: <Gaussian1D(amplitude=5.69678399, mean=58.39828022, stddev=1.46995184)>
#
#     [3]: <Gaussian1D(amplitude=12.68433327, mean=64.53055997, stddev=3.96392003)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3           stddev_3
#     ------------------- ------------------ ... ----------------- -----------------
#     0.01959867150817372 105.44282085986302 ... 64.53055996540695 3.963920025725015
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.05225783)>
#
#     [1]: <Gaussian1D(amplitude=105.3994724, mean=52.23014418, stddev=3.28641379)>
#
#     [2]: <Gaussian1D(amplitude=7.40172531, mean=58.79087652, stddev=1.73334116)>
#
#     [3]: <Gaussian1D(amplitude=13.04234474, mean=65.00495143, stddev=3.28641379)>
# Parameters:
#             c0_0            amplitude_1     ...       mean_3           stddev_3
#     -------------------- ------------------ ... ----------------- -----------------
#     0.052257829137101926 105.39947239832972 ... 65.00495143060631 3.286413785691195
#
# -------------------------------------------
# 0.153
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.06143826)>
#
#     [1]: <Gaussian1D(amplitude=121.78892188, mean=50.9367338, stddev=3.19704154)>
#
#     [2]: <Gaussian1D(amplitude=9.14679587, mean=57.14472293, stddev=2.25095627)>
#
#     [3]: <Gaussian1D(amplitude=15.42717848, mean=63.47692891, stddev=3.69737454)>
# Parameters:
#             c0_0            amplitude_1     ...       mean_3           stddev_3
#     -------------------- ------------------ ... ----------------- ------------------
#     0.061438261376728955 121.78892188144665 ... 63.47692891277771 3.6973745427004023
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.09227859)>
#
#     [1]: <Gaussian1D(amplitude=121.35720934, mean=50.96338233, stddev=3.22292351)>
#
#     [2]: <Gaussian1D(amplitude=10.56186392, mean=57.36288064, stddev=1.96632602)>
#
#     [3]: <Gaussian1D(amplitude=16.04905445, mean=63.66281885, stddev=3.22292351)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3           stddev_3
#     ------------------- ------------------ ... ----------------- ------------------
#     0.09227858660425856 121.35720933516848 ... 63.66281884758995 3.2229235131463763
#
# -------------------------------------------
# 0.158
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.14012943)>
#
#     [1]: <Gaussian1D(amplitude=109.53547671, mean=49.56453598, stddev=3.0697362)>
#
#     [2]: <Gaussian1D(amplitude=10.34076574, mean=55.50834982, stddev=1.49656691)>
#
#     [3]: <Gaussian1D(amplitude=14.47531843, mean=61.26886756, stddev=4.1477334)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3            stddev_3
#     ------------------- ----------------- ... ------------------ -----------------
#     0.14012942697165262 109.5354767097521 ... 61.268867559113005 4.147733404096611
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.19350313)>
#
#     [1]: <Gaussian1D(amplitude=109.52831113, mean=49.57496862, stddev=3.08086197)>
#
#     [2]: <Gaussian1D(amplitude=13.90070352, mean=55.96249043, stddev=1.92040887)>
#
#     [3]: <Gaussian1D(amplitude=14.62113071, mean=62.23530738, stddev=3.08086197)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3          stddev_3
#     ------------------- ------------------ ... ----------------- ----------------
#     0.19350312952651993 109.52831113154845 ... 62.23530737573459 3.08086196889993
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# 0.163
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.13173837)>
#
#     [1]: <Gaussian1D(amplitude=123.47915786, mean=47.17884139, stddev=3.04759115)>
#
#     [2]: <Gaussian1D(amplitude=12.53335908, mean=52.77807822, stddev=1.36682857)>
#
#     [3]: <Gaussian1D(amplitude=21.35725434, mean=58.42300622, stddev=3.69927395)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3            stddev_3
#     ------------------- ------------------ ... ------------------ ------------------
#     0.13173836894448443 123.47915786276457 ... 58.423006219903115 3.6992739506839625
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.18064528)>
#
#     [1]: <Gaussian1D(amplitude=123.40547066, mean=47.19239846, stddev=3.06350023)>
#
#     [2]: <Gaussian1D(amplitude=15.44153561, mean=53.0822535, stddev=1.63625046)>
#
#     [3]: <Gaussian1D(amplitude=21.82127936, mean=58.92753877, stddev=3.06350023)>
# Parameters:
#            c0_0           amplitude_1     ...       mean_3           stddev_3
#     ------------------ ------------------ ... ----------------- -----------------
#     0.1806452774438561 123.40547065779977 ... 58.92753876848461 3.063500229345418
#
# -------------------------------------------
# 0.168
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.46893104)>
#
#     [1]: <Gaussian1D(amplitude=12.09423703, mean=45.21402199, stddev=2.28634826)>
#
#     [2]: <Gaussian1D(amplitude=2.29511956, mean=50.33431811, stddev=1.27589108)>
#
#     [3]: <Gaussian1D(amplitude=3.84427839, mean=48.54921083, stddev=9.98195713)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3            stddev_3
#     -------------------- ---------------- ... ------------------ -----------------
#     -0.46893103504703115 12.0942370287633 ... 48.549210827825036 9.981957129557333
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.47655633)>
#
#     [1]: <Gaussian1D(amplitude=11.74069458, mean=44.94038918, stddev=2.10088287)>
#
#     [2]: <Gaussian1D(amplitude=3.77109788, mean=48.39342802, stddev=10.18214545)>
#
#     [3]: <Gaussian1D(amplitude=2.96479589, mean=49.27569795, stddev=2.10088287)>
# Parameters:
#             c0_0            amplitude_1     ...       mean_3           stddev_3
#     -------------------- ------------------ ... ----------------- ------------------
#     -0.47655632993271685 11.740694582381481 ... 49.27569795328617 2.1008828683128593
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]

# %%
fig = plt.figure(figsize=(18, 25))
spec.plot_fitted_model(columns=3, fig=fig)

# %%
from specim.specfuncs import spec1d

# %%
spec = spec1d.Spec1d('../galaxy_spectra/LRIS_blue_data_201213/keck_lris_blue_A/Science/', informat='pypeit')
# Out:
# Reading spectrum from ../galaxy_spectra/LRIS_blue_data_201213/keck_lris_blue_A/Science/spec1d_b201213_0045-MG0751+2716_LRISb_2020Dec13T124523.328.fits
# Expected file format: pypeit
#  Spectrum Start:  3137.72
#  Spectrum End:     5643.29
#  Dispersion (1st pixel):   0.55
#  Dispersion (average):      0.61

# %%
spec.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# %matplotlib notebook
spec.smooth(11)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

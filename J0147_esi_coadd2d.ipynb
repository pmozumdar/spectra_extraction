# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from astropy.table import Table
from astropy.modeling import models
from astropy.io import fits
from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, echelle1d, spec1d
from scipy.ndimage import shift, map_coordinates

# %%
file_loc = '../galaxy_spectra/ESI_data/2018/*'

# %%
spec2d_file_list = []
var2d_file_list = []

for i,p in enumerate(glob.glob(file_loc)):
    if 'J0147' in p:
        if 'bgsub.fits' in p:
            spec2d_file_list.append(p)
        elif 'var.fits' in p:
            var2d_file_list.append(p)

# %%
print(spec2d_file_list)
print(var2d_file_list)
# Out:
# ['../galaxy_spectra/ESI_data/2018/J0147+4630_0031_bgsub.fits', '../galaxy_spectra/ESI_data/2018/J0147+4630_0033_bgsub.fits', '../galaxy_spectra/ESI_data/2018/J0147+4630_0032_bgsub.fits']
# ['../galaxy_spectra/ESI_data/2018/J0147+4630_0032_var.fits', '../galaxy_spectra/ESI_data/2018/J0147+4630_0031_var.fits', '../galaxy_spectra/ESI_data/2018/J0147+4630_0033_var.fits']

# %%
spec1 = esi2d.Esi2d(spec2d_file_list[0], varfile=var2d_file_list[1])
spec2 = esi2d.Esi2d(spec2d_file_list[2], varfile=var2d_file_list[0])
spec3 = esi2d.Esi2d(spec2d_file_list[1], varfile=var2d_file_list[2])
# Out:
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3461x165     x
#   2   4093x145     x
#   3   4096x146     x
#   4   4096x141     x
#   5   4096x130     x
#   6   4096x127     x
#   7   4096x124     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x111     x
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3461x165     x
#   2   4093x145     x
#   3   4096x146     x
#   4   4096x141     x
#   5   4096x130     x
#   6   4096x127     x
#   7   4096x124     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x111     x
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3461x165     x
#   2   4093x145     x
#   3   4096x146     x
#   4   4096x141     x
#   5   4096x130     x
#   6   4096x127     x
#   7   4096x124     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x111     x

# %%
pixrange = [2700, 3000]
spec_list = [spec1, spec2, spec3]
order_list = spec1.ordinfo

for order in order_list[3:6]:
    print(order['name'], 'pixscale:', order['pixscale'])
    for sp in spec_list:
        profile = sp[order['order']-1].spatial_profile(pixrange=pixrange)
        plt.show()
        sp[order['order']-1].initial_model()
# Out:
# Order_04 pixscale: 0.137
# Profile max value (before normalization) 3102.588439
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3000, 62, 3, 4.765
#
# amplitude=3000.000000, x_0=62.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 350, 85, 3, 4.765
#
# amplitude=350.000000, x_0=85.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-4.37467547)>
#
#     [1]: <Moffat1D(amplitude=3107.62548277, x_0=62.22350231, gamma=5.65994821, alpha=2.50567532)>
#
#     [2]: <Moffat1D(amplitude=339.37852117, x_0=85.02643352, gamma=2.87791774, alpha=0.98221336)>
# Parameters:
#            c0_0          amplitude_1    ...      gamma_2           alpha_2
#     ----------------- ----------------- ... ----------------- ------------------
#     -4.37467546801646 3107.625482766771 ... 2.877917744947922 0.9822133632138236
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 2783.712249
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 2700, 88, 3, 4.765
#
# amplitude=2700.000000, x_0=88.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 300, 111, 3, 4.765
#
# amplitude=300.000000, x_0=111.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-2.61416509)>
#
#     [1]: <Moffat1D(amplitude=2829.34992399, x_0=89.67735076, gamma=6.08502976, alpha=2.59823558)>
#
#     [2]: <Moffat1D(amplitude=295.27925932, x_0=112.23647317, gamma=3.44189163, alpha=1.14736754)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------ ------------------ ... ------------------ ------------------
#     -2.614165092257262 2829.3499239851294 ... 3.4418916323793884 1.1473675436095385
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 2581.121137
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 2500, 32, 3, 4.765
#
# amplitude=2500.000000, x_0=32.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 270, 55, 3, 4.765
#
# amplitude=270.000000, x_0=55.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-3.06099717)>
#
#     [1]: <Moffat1D(amplitude=2591.74971777, x_0=33.38024518, gamma=6.52545696, alpha=2.70173123)>
#
#     [2]: <Moffat1D(amplitude=256.21969266, x_0=56.24791232, gamma=3.3178345, alpha=1.05598119)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------ ------------------ ... ------------------ ------------------
#     -3.060997171207902 2591.7497177652394 ... 3.3178345034819605 1.0559811884098524
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_05 pixscale: 0.144
# Profile max value (before normalization) 2529.601719
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 2500, 59, 3, 4.765
#
# amplitude=2500.000000, x_0=59.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 250, 81, 3, 4.765
#
# amplitude=250.000000, x_0=81.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-2.84581918)>
#
#     [1]: <Moffat1D(amplitude=2542.41801945, x_0=59.33877134, gamma=5.54753004, alpha=2.52456566)>
#
#     [2]: <Moffat1D(amplitude=306.80239395, x_0=81.31253948, gamma=3.03178385, alpha=1.08304496)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------ ------------------ ... ------------------ -----------------
#     -2.845819178826343 2542.4180194482133 ... 3.0317838532864805 1.083044959477877
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 2303.057438
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 2300, 86, 3, 4.765
#
# amplitude=2300.000000, x_0=86.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 250, 108, 3, 4.765
#
# amplitude=250.000000, x_0=108.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.67822379)>
#
#     [1]: <Moffat1D(amplitude=2317.09416456, x_0=85.99028115, gamma=6.00879096, alpha=2.65400959)>
#
#     [2]: <Moffat1D(amplitude=271.69848796, x_0=107.51672647, gamma=3.85388046, alpha=1.42679566)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ -----------------
#     -1.6782237876428945 2317.0941645601865 ... 3.8538804580587067 1.426795655793759
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 2107.450598
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 2100, 30, 3, 4.765
#
# amplitude=2100.000000, x_0=30.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 250, 52, 3, 4.765
#
# amplitude=250.000000, x_0=52.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.79005411)>
#
#     [1]: <Moffat1D(amplitude=2146.40288466, x_0=31.69525333, gamma=6.41504208, alpha=2.82398507)>
#
#     [2]: <Moffat1D(amplitude=242.85131467, x_0=53.52205018, gamma=3.66923734, alpha=1.26917837)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2            alpha_2
#     ------------------- ----------------- ... ------------------ ------------------
#     -1.7900541071727323 2146.402884658116 ... 3.6692373357030674 1.2691783737618418
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_06 pixscale: 0.149
# Profile max value (before normalization) 3390.179474
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3400, 53, 3, 4.765
#
# amplitude=3400.000000, x_0=53.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 250, 74.5, 3, 4.765
#
# amplitude=250.000000, x_0=74.500000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-5.81627689)>
#
#     [1]: <Moffat1D(amplitude=3442.88672021, x_0=53.69931205, gamma=5.39711801, alpha=2.565279)>
#
#     [2]: <Moffat1D(amplitude=377.8646736, x_0=74.54868164, gamma=2.56243898, alpha=0.89569124)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2           alpha_2
#     ------------------- ----------------- ... ----------------- ------------------
#     -5.8162768864405585 3442.886720212969 ... 2.562438975185803 0.8956912383859561
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 3133.147007
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3100, 79, 3, 4.675
#
# amplitude=3100.000000, x_0=79.000000, gamma=3.000000, alpha=4.675000
#
# Parameters of Moffat profile 2 : 260, 100, 3, 4.765
#
# amplitude=260.000000, x_0=100.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-2.90641391)>
#
#     [1]: <Moffat1D(amplitude=3153.72373866, x_0=79.06465786, gamma=6.29852803, alpha=2.96824091)>
#
#     [2]: <Moffat1D(amplitude=338.40035633, x_0=100.05259229, gamma=3.46859426, alpha=1.16194363)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------ ------------------ ... ------------------ ------------------
#     -2.906413905113764 3153.7237386633146 ... 3.4685942583847154 1.1619436331841626
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 2952.689256
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 2900, 27, 3, 4.765
#
# amplitude=2900.000000, x_0=27.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 230, 48, 3, 4.765
#
# amplitude=230.000000, x_0=48.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.97705899)>
#
#     [1]: <Moffat1D(amplitude=2963.2670475, x_0=27.32660173, gamma=6.750492, alpha=3.15277104)>
#
#     [2]: <Moffat1D(amplitude=302.346634, x_0=48.25555144, gamma=3.54798814, alpha=1.25126741)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ ------------------
#     -1.9770589868023687 2963.2670475047357 ... 3.5479881446702173 1.2512674067562668
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no

# %%
order_list = [4, 5, 6]
spec_list = [spec1, spec2, spec3]
shifted_sp = []
shifted_var = []
shift_pixel = np.array([[0.0, -27.21, 28.78], [0.0, -26.204, 27.791], 
                       [0.0, -25.50, 26.293]])
for shft, order in zip(shift_pixel, order_list):
    new_sp = []
    new_var = []
    for i, sp in enumerate(spec_list):
        #print(sp[order-1].mod0, shift[i])
        nanmask = (sp[order-1].vardata <= 0) | (np.isnan(sp[order-1].vardata)) 
        nnan = nanmask.sum()
        if nnan > 0:
            print('Found %d NaNs in the two-dimensional variance '\
                  'spectrum' % nnan)

            """ Replace the NaNs with a big value """
            sp[order-1].vardata[nanmask] = 1.e5
        new_sp.append(shift(sp[order-1].data, [shft[i], 0], order=1))
        new_var.append(shift(sp[order-1].vardata, [shft[i], 0], order=1))
    shifted_sp.append(new_sp)
    shifted_var.append(new_var)
# Out:
# Found 1593 NaNs in the two-dimensional variance spectrum
# Found 2128 NaNs in the two-dimensional variance spectrum
# Found 1688 NaNs in the two-dimensional variance spectrum
# Found 1899 NaNs in the two-dimensional variance spectrum
# Found 2101 NaNs in the two-dimensional variance spectrum
# Found 1568 NaNs in the two-dimensional variance spectrum
# Found 1199 NaNs in the two-dimensional variance spectrum
# Found 1912 NaNs in the two-dimensional variance spectrum
# Found 1540 NaNs in the two-dimensional variance spectrum

# %%
for od, sp_list in zip(order_list, shifted_sp):
    plt.figure(figsize=(8, 6))
    pixrange = [2700, 3000]
    color = ['b', 'r', 'k']
    label = ['frame_31', 'frame_32', 'frame_33']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pixrange[0]:pixrange[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    plt.legend()
    plt.title('order %d' %od)

# %%
outsp = []
outvar = []

for sp_list, var_list in zip(shifted_sp, shifted_var):
    wtsp = np.zeros(sp_list[0].shape)
    wtsum = np.zeros(sp_list[0].shape)
    for s, v in zip(sp_list, var_list):
        wt = np.zeros(wtsp.shape)
        mask = np.isnan(v) | (v<=0)
        wt[~mask] = 1.0 / v[~mask]
        #print(sum(sum(np.isnan(wt) | (wt<=0))))
        wtsp += wt * s
        #print(sum(sum(wtsp==0)))
        wtsum += wt
        #print(sum(sum(wtsum==0)))

    wtsp[wtsum == 0] = 0
    wtsum[wtsum == 0] = 1
    outsp.append(wtsp / wtsum)
    outvar.append(1.0 / wtsum)

# %%
for od, sp_list, cd_sp in zip(order_list, shifted_sp, outsp):
    plt.figure(figsize=(8, 6))
    pixrange = [2700, 3000]
    color = ['b', 'r', 'k']
    label = ['frame_31', 'frame_32', 'frame_33']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pixrange[0]:pixrange[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    
    tmpdata = cd_sp[:, pixrange[0]:pixrange[1]]
    pflux = np.median(tmpdata, axis=1)
    x = np.arange(cd_sp.shape[0])
    plt.plot(x, pflux, color='g', drawstyle='steps', label='coadded')
    plt.legend()
    plt.title('order %d' %od)

# %%
for od, cd_sp in zip(order_list, outsp):
    plt.figure(figsize=(10, 6))
    tmpdata = cd_sp[:, pixrange[0]:pixrange[1]]
    pflux = np.median(tmpdata, axis=1)
    x = np.arange(cd_sp.shape[0])
    plt.plot(x, pflux, color='g', drawstyle='steps', label='coadded')
    plt.legend()
    plt.title('order %d' %od)

# %%
s = fits.open('../galaxy_spectra/ESI_data/2018/J0147+4630_0031_bgsub.fits')
for od, cd_sp, cd_var in zip(order_list, outsp, outvar):
    file_name1 = 'J0147_ESI_spectra/J0147_coadd2d_sp_order_' + str(od) + '.fits'
    file_name2 = 'J0147_ESI_spectra/J0147_coadd2d_var_order_' + str(od) + '.fits'
    fits.writeto(file_name1, cd_sp, header=s[od].header)
    fits.writeto(file_name2, cd_var, header=s[od].header)

# %%
pixrange = [1800, 2200]
spec_list = [spec1, spec2, spec3]
order_list = spec1.ordinfo

for order in order_list[6:]:
    print(order['name'], 'pixscale:', order['pixscale'])
    for sp in spec_list:
        profile = sp[order['order']-1].spatial_profile(pixrange=pixrange)
        plt.show()
        sp[order['order']-1].initial_model()
#profile2 = spec2[4].spatial_profile(pixrange=pixrange)
#profile3 = spec3[4].spatial_profile(pixrange=pixrange)
# Out:
# Order_07 pixscale: 0.153
# Profile max value (before normalization) 2757.582512
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 2600, 51, 3, 4.765
#
# amplitude=2600.000000, x_0=51.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 300, 72, 3, 4.765
#
# amplitude=300.000000, x_0=72.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-4.89820081)>
#
#     [1]: <Moffat1D(amplitude=2818.68519434, x_0=52.66087001, gamma=4.80832523, alpha=2.10344336)>
#
#     [2]: <Moffat1D(amplitude=320.80587109, x_0=73.25577588, gamma=3.45764599, alpha=1.20465773)>
# Parameters:
#            c0_0          amplitude_1     ...      gamma_2           alpha_2
#     ----------------- ------------------ ... ----------------- ------------------
#     -4.89820081121658 2818.6851943441798 ... 3.457645988912369 1.2046577285773397
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 2553.079254
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 2500, 78, 3, 4.765
#
# amplitude=2500.000000, x_0=78.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 300, 99, 3, 4.765
#
# amplitude=300.000000, x_0=99.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-3.48165266)>
#
#     [1]: <Moffat1D(amplitude=2578.64070325, x_0=77.70081264, gamma=6.57620953, alpha=3.12576162)>
#
#     [2]: <Moffat1D(amplitude=304.89705822, x_0=98.1546758, gamma=3.27962044, alpha=1.05163594)>
# Parameters:
#             c0_0         amplitude_1   ...      gamma_2            alpha_2
#     ------------------- -------------- ... ------------------ ------------------
#     -3.4816526620449766 2578.640703249 ... 3.2796204377486027 1.0516359358621654
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 2428.605056
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 2450, 26, 3, 4.765
#
# amplitude=2450.000000, x_0=26.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 300, 46.5, 3, 4.765
#
# amplitude=300.000000, x_0=46.500000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-2.6003011)>
#
#     [1]: <Moffat1D(amplitude=2458.3387727, x_0=26.87716147, gamma=6.81463504, alpha=3.27149332)>
#
#     [2]: <Moffat1D(amplitude=277.76059415, x_0=47.26966369, gamma=3.35546292, alpha=1.10956898)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------ ------------------ ... ------------------ ------------------
#     -2.600301101177977 2458.3387727032305 ... 3.3554629189378433 1.1095689766348351
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_08 pixscale: 0.158
# Profile max value (before normalization) 3140.569783
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3100, 49, 3, 4.765
#
# amplitude=3100.000000, x_0=49.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 300, 69, 3, 4.765
#
# amplitude=300.000000, x_0=69.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-11.96872439)>
#
#     [1]: <Moffat1D(amplitude=3150.55657462, x_0=51.60753517, gamma=6.10595558, alpha=2.99280712)>
#
#     [2]: <Moffat1D(amplitude=352.13759962, x_0=71.5635986, gamma=-2.35013572, alpha=0.71284886)>
# Parameters:
#             c0_0           amplitude_1     ...      alpha_2
#     ------------------- ------------------ ... ------------------
#     -11.968724393440205 3150.5565746223333 ... 0.7128488615265431
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 2923.399727
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 2900, 76, 3, 4.765
#
# amplitude=2900.000000, x_0=76.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 300, 96, 3, 4.765
#
# amplitude=300.000000, x_0=96.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-4.1401234)>
#
#     [1]: <Moffat1D(amplitude=2932.83498314, x_0=76.16560119, gamma=7.2676052, alpha=3.74980933)>
#
#     [2]: <Moffat1D(amplitude=332.64721663, x_0=95.63173906, gamma=3.12891992, alpha=0.9896001)>
# Parameters:
#            c0_0           amplitude_1    ...      gamma_2            alpha_2
#     ------------------ ----------------- ... ------------------ ------------------
#     -4.140123402580734 2932.834983137528 ... 3.1289199200314113 0.9896000967622012
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 2817.189884
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 2700, 24, 3, 4.765
#
# amplitude=2700.000000, x_0=24.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 260, 44, 3, 4.765
#
# amplitude=260.000000, x_0=44.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-4.97664549)>
#
#     [1]: <Moffat1D(amplitude=2812.09162997, x_0=26.24494839, gamma=7.51650687, alpha=3.8887614)>
#
#     [2]: <Moffat1D(amplitude=310.0398528, x_0=46.25339591, gamma=3.14128206, alpha=0.97080495)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_2           alpha_2
#     ------------------ ------------------ ... ----------------- ------------------
#     -4.976645492132571 2812.0916299742294 ... 3.141282055425347 0.9708049504273754
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_09 pixscale: 0.163
# Profile max value (before normalization) 3561.645217
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3500, 48, 3, 4.765
#
# amplitude=3500.000000, x_0=48.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 300, 67.3, 3, 4.765
#
# amplitude=300.000000, x_0=67.300000, gamma=3.000000, alpha=4.765000
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-11.4952999)>
#
#     [1]: <Moffat1D(amplitude=3566.75590984, x_0=49.38526124, gamma=5.79643407, alpha=2.88923123)>
#
#     [2]: <Moffat1D(amplitude=383.50771261, x_0=68.51302015, gamma=2.42269592, alpha=0.74511512)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2           alpha_2
#     ------------------- ----------------- ... ----------------- -----------------
#     -11.495299897244502 3566.755909844281 ... 2.422695921748284 0.745115121725651
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 3270.689288
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3200, 72, 3, 4.765
#
# amplitude=3200.000000, x_0=72.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 300, 91.3, 3, 4.765
#
# amplitude=300.000000, x_0=91.300000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-4.76818507)>
#
#     [1]: <Moffat1D(amplitude=3338.08300302, x_0=72.88134528, gamma=7.56297857, alpha=4.29547812)>
#
#     [2]: <Moffat1D(amplitude=356.97795684, x_0=91.66944127, gamma=3.17723904, alpha=0.9972904)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------ ------------------ ... ------------------ ------------------
#     -4.768185065203741 3338.0830030168163 ... 3.1772390420184626 0.9972904037514007
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 3237.829770
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3200, 23, 3, 4.765
#
# amplitude=3200.000000, x_0=23.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 300, 43, 3, 4.765
#
# amplitude=300.000000, x_0=43.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-4.05442882)>
#
#     [1]: <Moffat1D(amplitude=3262.17642732, x_0=25.02412498, gamma=7.69693632, alpha=4.25213582)>
#
#     [2]: <Moffat1D(amplitude=335.72349227, x_0=44.35643577, gamma=3.25880325, alpha=1.03964891)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------ ------------------ ... ------------------ ------------------
#     -4.054428824512745 3262.1764273249755 ... 3.2588032537993596 1.0396489111241902
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_10 pixscale: 0.168
# Profile max value (before normalization) 584.313098
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 570, 47.5, 3, 4.765
#
# amplitude=570.000000, x_0=47.500000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 70, 66.25, 3, 4.765
#
# amplitude=70.000000, x_0=66.250000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-3.87477052)>
#
#     [1]: <Moffat1D(amplitude=596.23132112, x_0=47.8494177, gamma=4.74346267, alpha=2.2553874)>
#
#     [2]: <Moffat1D(amplitude=65.47648754, x_0=66.49398933, gamma=2.3885826, alpha=0.59270713)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2            alpha_2
#     ------------------- ----------------- ... ------------------ ------------------
#     -3.8747705165974144 596.2313211158356 ... 2.3885826049123935 0.5927071320238985
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 537.700258
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 600, 70, 3, 4.765
#
# amplitude=600.000000, x_0=70.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 70, 89, 3, 4.765
#
# amplitude=70.000000, x_0=89.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.94811033)>
#
#     [1]: <Moffat1D(amplitude=549.55388914, x_0=70.97633333, gamma=5.13847535, alpha=2.42694881)>
#
#     [2]: <Moffat1D(amplitude=59.4650974, x_0=89.05871026, gamma=3.82878921, alpha=1.18014418)>
# Parameters:
#            c0_0           amplitude_1    ...      gamma_2            alpha_2
#     ------------------ ----------------- ... ------------------ ------------------
#     -0.948110334764957 549.5538891406246 ... 3.8287892131778154 1.1801441752471453
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 499.710967
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 500, 23, 3, 4.765
#
# amplitude=500.000000, x_0=23.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 70, 42, 3, 4.765
#
# amplitude=70.000000, x_0=42.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.65162669)>
#
#     [1]: <Moffat1D(amplitude=507.07401916, x_0=24.0250276, gamma=5.17985233, alpha=2.44819013)>
#
#     [2]: <Moffat1D(amplitude=56.31784187, x_0=42.8170758, gamma=3.45298666, alpha=0.92288058)>
# Parameters:
#            c0_0           amplitude_1    ...      gamma_2           alpha_2
#     ------------------ ----------------- ... ----------------- ------------------
#     -1.651626688359872 507.0740191615238 ... 3.452986661604151 0.9228805800747429
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no

# %%
order_list = [7, 8, 9, 10]
spec_list = [spec1, spec2, spec3]
shifted_sp = []
shifted_var = []
shift_pixel = np.array([[0.0, -24.90, 25.98], [0.0, -24.068, 25.311], 
                       [0.0, -23.156, 24.157], [0.0, -23.127, 23.824]])
for shft, order in zip(shift_pixel, order_list):
    new_sp = []
    new_var = []
    for i, sp in enumerate(spec_list):
        #print(sp[order-1].mod0, shift[i])
        nanmask = (sp[order-1].vardata <= 0) | (np.isnan(sp[order-1].vardata)) 
        nnan = nanmask.sum()
        if nnan > 0:
            print('Found %d NaNs in the two-dimensional variance '\
                  'spectrum' % nnan)

            """ Replace the NaNs with a big value """
            sp[order-1].vardata[nanmask] = 1.e5
        new_sp.append(shift(sp[order-1].data, [shft[i], 0], order=1))
        new_var.append(shift(sp[order-1].vardata, [shft[i], 0], order=1))
    shifted_sp.append(new_sp)
    shifted_var.append(new_var)
# Out:
# Found 1213 NaNs in the two-dimensional variance spectrum
# Found 1400 NaNs in the two-dimensional variance spectrum
# Found 1418 NaNs in the two-dimensional variance spectrum
# Found 1621 NaNs in the two-dimensional variance spectrum
# Found 1569 NaNs in the two-dimensional variance spectrum
# Found 1953 NaNs in the two-dimensional variance spectrum
# Found 1954 NaNs in the two-dimensional variance spectrum
# Found 1694 NaNs in the two-dimensional variance spectrum
# Found 2333 NaNs in the two-dimensional variance spectrum
# Found 1055 NaNs in the two-dimensional variance spectrum
# Found 1140 NaNs in the two-dimensional variance spectrum
# Found 1060 NaNs in the two-dimensional variance spectrum

# %%
for od, sp_list in zip(order_list, shifted_sp):
    plt.figure(figsize=(8, 6))
    pixrange = [1900, 2200]
    color = ['b', 'r', 'k']
    label = ['frame_31', 'frame_32', 'frame_33']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pixrange[0]:pixrange[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    plt.legend()
    plt.title('order %d' %od)

# %%
outsp = []
outvar = []

for sp_list, var_list in zip(shifted_sp, shifted_var):
    wtsp = np.zeros(sp_list[0].shape)
    wtsum = np.zeros(sp_list[0].shape)
    for s, v in zip(sp_list, var_list):
        wt = np.zeros(wtsp.shape)
        mask = np.isnan(v) | (v<=0)
        wt[~mask] = 1.0 / v[~mask]
        #print(sum(sum(np.isnan(wt) | (wt<=0))))
        wtsp += wt * s
        #print(sum(sum(wtsp==0)))
        wtsum += wt
        #print(sum(sum(wtsum==0)))

    wtsp[wtsum == 0] = 0
    wtsum[wtsum == 0] = 1
    outsp.append(wtsp / wtsum)
    outvar.append(1.0 / wtsum)

# %%
for od, sp_list, cd_sp in zip(order_list, shifted_sp, outsp):
    plt.figure(figsize=(8, 6))
    pixrange = [1900, 2200]
    color = ['b', 'r', 'k']
    label = ['frame_31', 'frame_32', 'frame_33']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pixrange[0]:pixrange[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    
    tmpdata = cd_sp[:, pixrange[0]:pixrange[1]]
    pflux = np.median(tmpdata, axis=1)
    x = np.arange(cd_sp.shape[0])
    plt.plot(x, pflux, color='g', drawstyle='steps', label='coadded')
    plt.legend()
    plt.title('order %d' %od)

# %%
for od, cd_sp in zip(order_list, outsp):
    plt.figure(figsize=(10, 6))
    tmpdata = cd_sp[:, pixrange[0]:pixrange[1]]
    pflux = np.median(tmpdata, axis=1)
    x = np.arange(cd_sp.shape[0])
    plt.plot(x, pflux, color='g', drawstyle='steps', label='coadded')
    plt.legend()
    plt.title('order %d' %od)

# %%
s = fits.open('../galaxy_spectra/ESI_data/2018/J0147+4630_0031_bgsub.fits')
for od, cd_sp, cd_var in zip(order_list, outsp, outvar):
    file_name1 = 'J0147_ESI_spectra/J0147_coadd2d_sp_order_' + str(od) + '.fits'
    file_name2 = 'J0147_ESI_spectra/J0147_coadd2d_var_order_' + str(od) + '.fits'
    fits.writeto(file_name1, cd_sp, header=s[od].header)
    fits.writeto(file_name2, cd_var, header=s[od].header)

# %% [markdown]
# ## coadding order 1-3

# %%
pixrange = [1800, 2200]
spec_list = [spec1, spec2, spec3]
order_list = spec1.ordinfo

for order in order_list[:3]:
    print(order['name'], 'pixscale:', order['pixscale'])
    for sp in spec_list:
        profile = sp[order['order']-1].spatial_profile(pixrange=pixrange)
        plt.show()
        sp[order['order']-1].initial_model()
# Out:
# Order_01 pixscale: 0.12
# Profile max value (before normalization) 746.996591
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 2
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 740, 73, 3, 4
#
# amplitude=740.000000, x_0=73.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 40, 101, 2, 3
#
# amplitude=40.000000, x_0=101.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.69900341)>
#
#     [1]: <Moffat1D(amplitude=749.20934429, x_0=74.62586887, gamma=8.34458572, alpha=3.1327684)>
#
#     [2]: <Moffat1D(amplitude=55.40849035, x_0=101.02654959, gamma=-3.02464367, alpha=0.7022066)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2            alpha_2
#     ------------------- ----------------- ... ------------------ ------------------
#     -1.6990034137917638 749.2093442878737 ... -3.024643671530712 0.7022065963163842
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 630.405943
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 2
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 630, 105, 3, 4
#
# amplitude=630.000000, x_0=105.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 40, 131, 2, 3
#
# amplitude=40.000000, x_0=131.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.6590187)>
#
#     [1]: <Moffat1D(amplitude=634.57105048, x_0=106.41101234, gamma=9.79455007, alpha=3.62681182)>
#
#     [2]: <Moffat1D(amplitude=41.0921258, x_0=132.25395606, gamma=-4.47511269, alpha=0.92620671)>
# Parameters:
#             c0_0           amplitude_1    ...       gamma_2            alpha_2
#     ------------------- ----------------- ... ------------------- ------------------
#     -0.6590187005868107 634.5710504802774 ... -4.4751126912303425 0.9262067130755611
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 543.682249
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 540, 39, 3, 4
#
# amplitude=540.000000, x_0=39.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 40, 65, 2, 3
#
# amplitude=40.000000, x_0=65.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.7408873)>
#
#     [1]: <Moffat1D(amplitude=550.8470533, x_0=40.68749455, gamma=9.65375297, alpha=3.3113507)>
#
#     [2]: <Moffat1D(amplitude=33.82301375, x_0=66.7972267, gamma=3.62171398, alpha=0.67686764)>
# Parameters:
#             c0_0          amplitude_1    ...      gamma_2           alpha_2
#     ------------------- ---------------- ... ----------------- -----------------
#     -1.7408873030912353 550.847053303413 ... 3.621713983206254 0.676867635036551
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_02 pixscale: 0.127
# Profile max value (before normalization) 711.454741
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -2
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 700, 63, 3, 4
#
# amplitude=700.000000, x_0=63.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 40, 90, 2, 3
#
# amplitude=40.000000, x_0=90.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.62513418)>
#
#     [1]: <Moffat1D(amplitude=711.567576, x_0=66.51754312, gamma=6.99941754, alpha=2.6439586)>
#
#     [2]: <Moffat1D(amplitude=80.87661606, x_0=92.02772766, gamma=3.38762367, alpha=0.94896248)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2           alpha_2
#     ------------------- ----------------- ... ----------------- ------------------
#     -1.6251341793182532 711.5675760011754 ... 3.387623668206333 0.9489624797989568
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 607.723574
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 2
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 600, 95, 3, 4
#
# amplitude=600.000000, x_0=95.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 40, 121, 2, 3
#
# amplitude=40.000000, x_0=121.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.04434355)>
#
#     [1]: <Moffat1D(amplitude=611.52055733, x_0=97.04063982, gamma=8.13522645, alpha=3.06574531)>
#
#     [2]: <Moffat1D(amplitude=65.28943882, x_0=121.52717496, gamma=4.19416104, alpha=1.24576506)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2           alpha_2
#     ------------------- ----------------- ... ----------------- ------------------
#     -1.0443435488431885 611.5205573280338 ... 4.194161040594443 1.2457650586914293
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 545.914170
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -2
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 540, 33, 3, 4
#
# amplitude=540.000000, x_0=33.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 40, 59, 2, 3
#
# amplitude=40.000000, x_0=59.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.68156563)>
#
#     [1]: <Moffat1D(amplitude=552.73848039, x_0=34.2848701, gamma=8.64782677, alpha=3.13833527)>
#
#     [2]: <Moffat1D(amplitude=53.90716267, x_0=59.38757684, gamma=3.64221533, alpha=0.89581934)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2            alpha_2
#     ------------------- ----------------- ... ------------------ ------------------
#     -1.6815656279684879 552.7384803872361 ... 3.6422153317298265 0.8958193369208418
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_03 pixscale: 0.134
# Profile max value (before normalization) 1168.959586
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 2
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 1160, 62, 3, 4
#
# amplitude=1160.000000, x_0=62.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 100, 88, 2, 3
#
# amplitude=100.000000, x_0=88.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.80696858)>
#
#     [1]: <Moffat1D(amplitude=1195.03366984, x_0=64.65328168, gamma=6.2187963, alpha=2.62330828)>
#
#     [2]: <Moffat1D(amplitude=122.87068426, x_0=88.3978664, gamma=2.94366671, alpha=0.9060937)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2           alpha_2
#     ------------------- ------------------ ... ----------------- ------------------
#     -1.8069685761943555 1195.0336698395142 ... 2.943666711955077 0.9060937008486606
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 1071.451489
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -2
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 1070, 92, 3, 4
#
# amplitude=1070.000000, x_0=92.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 100, 116, 2, 3
#
# amplitude=100.000000, x_0=116.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-5.19440084)>
#
#     [1]: <Moffat1D(amplitude=1066.57092248, x_0=93.18318398, gamma=6.82957826, alpha=2.80122408)>
#
#     [2]: <Moffat1D(amplitude=111.37176243, x_0=116.8921882, gamma=1.95488747, alpha=0.51637238)>
# Parameters:
#            c0_0           amplitude_1    ...      gamma_2           alpha_2
#     ------------------ ----------------- ... ----------------- ------------------
#     -5.194400836687262 1066.570922477455 ... 1.954887473970294 0.5163723750297069
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 968.262946
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -2
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 960, 34, 3, 4
#
# amplitude=960.000000, x_0=34.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 80, 58, 2, 3
#
# amplitude=80.000000, x_0=58.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.62511896)>
#
#     [1]: <Moffat1D(amplitude=973.5559767, x_0=34.44301649, gamma=7.32324729, alpha=2.81196055)>
#
#     [2]: <Moffat1D(amplitude=88.68671364, x_0=58.24785835, gamma=3.12303108, alpha=0.90570277)>
# Parameters:
#             c0_0          amplitude_1    ...      gamma_2           alpha_2
#     ------------------- ---------------- ... ----------------- -----------------
#     -1.6251189575178915 973.555976696479 ... 3.123031082180758 0.905702772742073
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no

# %%
for order in order_list[0:3]:
    print(order['name'])
    i = 0
    for sp in spec_list:
        if i==0:
            print(sp[order['order']-1].mod0.x_0_1.value)
            #print(sp[order['order']-1].mod0.x_0_2.value)
            cen1 = sp[order['order']-1].mod0.x_0_1.value
            #cen2 = sp[order['order']-1].mod0.x_0_2.value

        else:
            print(cen1 - sp[order['order']-1].mod0.x_0_1.value)
            #print(cen2 - sp[order['order']-1].mod0.x_0_2.value)
        i += 1
# Out:
# Order_01
# 74.62586886652497
# -31.78514347673149
# 33.93837431983861
# Order_02
# 66.51754311574459
# -30.523096699411624
# 32.23267301497416
# Order_03
# 64.6532816821287
# -28.52990229842416
# 30.210265194858124

# %%
order_list = [1, 2, 3]
spec_list = [spec1, spec2, spec3]
shifted_sp = []
shifted_var = []
shift_pixel = np.array([[0.0, -31.79, 33.94], [0.0, -30.52, 32.23], [0.0, -28.53, 30.21]])
for shft, order in zip(shift_pixel, order_list):
    new_sp = []
    new_var = []
    for i, sp in enumerate(spec_list):
        #print(sp[order-1].mod0, shift[i])
        nanmask = (sp[order-1].vardata <= 0) | (np.isnan(sp[order-1].vardata)) 
        nnan = nanmask.sum()
        if nnan > 0:
            print('Found %d NaNs in the two-dimensional variance '\
                  'spectrum' % nnan)

            """ Replace the NaNs with a big value """
            sp[order-1].vardata[nanmask] = 1.e5
        new_sp.append(shift(sp[order-1].data, [shft[i], 0], order=1))
        new_var.append(shift(sp[order-1].vardata, [shft[i], 0], order=1))
    shifted_sp.append(new_sp)
    shifted_var.append(new_var)
# Out:
# Found 25949 NaNs in the two-dimensional variance spectrum
# Found 25923 NaNs in the two-dimensional variance spectrum
# Found 26069 NaNs in the two-dimensional variance spectrum
# Found 13770 NaNs in the two-dimensional variance spectrum
# Found 13917 NaNs in the two-dimensional variance spectrum
# Found 14227 NaNs in the two-dimensional variance spectrum
# Found 6246 NaNs in the two-dimensional variance spectrum
# Found 6358 NaNs in the two-dimensional variance spectrum
# Found 6671 NaNs in the two-dimensional variance spectrum

# %%
for od, sp_list in zip(order_list, shifted_sp):
    plt.figure(figsize=(8, 6))
    color = ['b', 'r', 'k']
    label = ['frame_31', 'frame_32', 'frame_33']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pixrange[0]:pixrange[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    plt.legend()
    plt.title('order %d' %od)

# %%
outsp = []
outvar = []

for sp_list, var_list in zip(shifted_sp, shifted_var):
    wtsp = np.zeros(sp_list[0].shape)
    wtsum = np.zeros(sp_list[0].shape)
    for s, v in zip(sp_list, var_list):
        wt = np.zeros(wtsp.shape)
        mask = np.isnan(v) | (v<=0)
        wt[~mask] = 1.0 / v[~mask]
        #print(sum(sum(np.isnan(wt) | (wt<=0))))
        wtsp += wt * s
        #print(sum(sum(wtsp==0)))
        wtsum += wt
        #print(sum(sum(wtsum==0)))

    wtsp[wtsum == 0] = 0
    wtsum[wtsum == 0] = 1
    outsp.append(wtsp / wtsum)
    outvar.append(1.0 / wtsum)

# %%
for od, sp_list, cd_sp in zip(order_list, shifted_sp, outsp):
    plt.figure(figsize=(8, 6))
    #pixrange = [1900, 2200]
    color = ['b', 'r', 'k']
    label = ['frame_31', 'frame_32', 'frame_33']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pixrange[0]:pixrange[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    
    tmpdata = cd_sp[:, pixrange[0]:pixrange[1]]
    pflux = np.median(tmpdata, axis=1)
    x = np.arange(cd_sp.shape[0])
    plt.plot(x, pflux, color='g', drawstyle='steps', label='coadded')
    plt.legend()
    plt.title('order %d' %od)

# %%
s = fits.open('../galaxy_spectra/ESI_data/2018/J0147+4630_0031_bgsub.fits')
for od, cd_sp, cd_var in zip(order_list, outsp, outvar):
    file_name1 = 'J0147_ESI_spectra/J0147_coadd2d_sp_order_' + str(od) + '.fits'
    file_name2 = 'J0147_ESI_spectra/J0147_coadd2d_var_order_' + str(od) + '.fits'
    fits.writeto(file_name1, cd_sp, header=s[od].header)
    fits.writeto(file_name2, cd_var, header=s[od].header)

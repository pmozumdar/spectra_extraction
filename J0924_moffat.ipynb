# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from astropy.table import Table
from astropy.modeling import models
from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, spec1d

# %%
file_loc = '../galaxy_spectra/ESI_data/*'

# %%
spec2d_file_list = []
var2d_file_list = []
#out_file = []
for i,p in enumerate(glob.glob(file_loc)):
    if 'J0924' in p:
        if 'bgsub.fits' in p:
            spec2d_file_list.append(p)
        elif 'var.fits' in p:
            var2d_file_list.append(p)
            #frame = p.split('_')[-3][:4]
            #out_file.append('0053m1_r'+ frame + '_cleaned.fits')
        #print(p)

# %%
spec = esi2d.Esi2d(spec2d_file_list[1], varfile=var2d_file_list[1])
print(spec2d_file_list[1])
print(var2d_file_list[1])
# Out:
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3461x165     x
#   2   4093x145     x
#   3   4096x146     x
#   4   4096x141     x
#   5   4096x130     x
#   6   4096x127     x
#   7   4096x124     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x111     x
# ../galaxy_spectra/ESI_data/J0924+0219_0041_bgsub.fits
# ../galaxy_spectra/ESI_data/J0924+0219_0041_var.fits

# %%
pixrange = [(1900, 2400)] #(1900, 2400)
sp_list = [spec[1], spec[2], spec[5],spec[6], spec[8], spec[9]]
sp_info = [spec.ordinfo[1], spec.ordinfo[2], spec.ordinfo[5], spec.ordinfo[6], spec.ordinfo[8],
          spec.ordinfo[9]]
for sp, info in zip(spec, spec.ordinfo):
    title = 'Spatial profile for ' + str(info['name'])
    sp.spatial_profile(pixrange=pixrange[0], title=title)
    plt.show()
    sp.initial_model()
# Out:
# Profile max value (before normalization) 73.196768
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 15, 116, 2
#
# amplitude=15.000000, mu=116.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 70, 110, 3, 3
#
# amplitude=70.000000, x_0=110.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 15, 125, 3, 3
#
# amplitude=15.000000, x_0=125.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.18221148)>
#
#     [1]: <Gaussian1D(amplitude=25.29535526, mean=112.51798885, stddev=3.1530056)>
#
#     [2]: <Moffat1D(amplitude=53.11066481, x_0=110.32668597, gamma=5.38907363, alpha=2.08087744)>
#
#     [3]: <Moffat1D(amplitude=9.78489657, x_0=124.75337461, gamma=7.77181602, alpha=2.50009233)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_3           alpha_3
#     ------------------- ------------------ ... ----------------- ------------------
#     -0.1822114795160219 25.295355256543292 ... 7.771816016114372 2.5000923342538344
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 102.552883
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 20, 108, 2
#
# amplitude=20.000000, mu=108.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 100, 102, 3, 3
#
# amplitude=100.000000, x_0=102.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 15, 116, 3, 3
#
# amplitude=15.000000, x_0=116.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.1631177)>
#
#     [1]: <Gaussian1D(amplitude=20.4660177, mean=104.16050657, stddev=3.2368264)>
#
#     [2]: <Moffat1D(amplitude=86.76175945, x_0=101.66290204, gamma=5.46953495, alpha=2.48684289)>
#
#     [3]: <Moffat1D(amplitude=12.83318693, x_0=115.11221879, gamma=8.8166649, alpha=3.71382697)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_3           alpha_3
#     -------------------- ------------------ ... ----------------- ------------------
#     -0.16311769966290024 20.466017696028075 ... 8.816664896034084 3.7138269732937217
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 154.397818
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 30, 106, 2
#
# amplitude=30.000000, mu=106.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 150, 100, 3, 3
#
# amplitude=150.000000, x_0=100.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 20, 114, 3, 3
#
# amplitude=20.000000, x_0=114.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.10603097)>
#
#     [1]: <Gaussian1D(amplitude=15.6165257, mean=102.50409492, stddev=3.0036427)>
#
#     [2]: <Moffat1D(amplitude=148.75436238, x_0=98.63934378, gamma=5.41567796, alpha=2.7200831)>
#
#     [3]: <Moffat1D(amplitude=19.73066553, x_0=111.64953751, gamma=6.13458542, alpha=2.25755886)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_3           alpha_3
#     ------------------- ------------------ ... ----------------- ------------------
#     -0.1060309696503334 15.616525696436092 ... 6.134585418716665 2.2575588555308794
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 189.689997
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 35, 101, 2
#
# amplitude=35.000000, mu=101.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 175, 96, 3, 3
#
# amplitude=175.000000, x_0=96.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 25, 108, 3, 3
#
# amplitude=25.000000, x_0=108.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.1021745)>
#
#     [1]: <Gaussian1D(amplitude=21.26190853, mean=99.29064684, stddev=3.35981771)>
#
#     [2]: <Moffat1D(amplitude=178.10355272, x_0=95.78992219, gamma=5.0304964, alpha=2.65181409)>
#
#     [3]: <Moffat1D(amplitude=23.54455111, x_0=108.0853195, gamma=5.15458191, alpha=1.9414965)>
# Parameters:
#             c0_0            amplitude_1     ...     gamma_3           alpha_3
#     -------------------- ------------------ ... ---------------- ------------------
#     -0.10217449509701948 21.261908532457493 ... 5.15458190774051 1.9414964966976336
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 220.397446
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 50, 98, 2
#
# amplitude=50.000000, mu=98.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 230, 93, 3, 3
#
# amplitude=230.000000, x_0=93.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 35, 106, 3, 3
#
# amplitude=35.000000, x_0=106.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.04969347)>
#
#     [1]: <Gaussian1D(amplitude=20.50159946, mean=96.58150181, stddev=3.46901254)>
#
#     [2]: <Moffat1D(amplitude=214.69593297, x_0=92.35828009, gamma=4.93619575, alpha=2.61419222)>
#
#     [3]: <Moffat1D(amplitude=27.11519447, x_0=104.17147956, gamma=5.61043299, alpha=2.43798862)>
# Parameters:
#              c0_0            amplitude_1     ...      alpha_3
#     --------------------- ------------------ ... ------------------
#     -0.049693465838354975 20.501599460364297 ... 2.4379886218685045
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 277.905045
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 55, 90, 2
#
# amplitude=55.000000, mu=90.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 260, 85, 3, 3
#
# amplitude=260.000000, x_0=85.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 40, 97, 3, 3
#
# amplitude=40.000000, x_0=97.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.12431574)>
#
#     [1]: <Gaussian1D(amplitude=49.81911974, mean=89.09168743, stddev=3.18186106)>
#
#     [2]: <Moffat1D(amplitude=252.38714897, x_0=85.59620501, gamma=4.62633536, alpha=2.61676661)>
#
#     [3]: <Moffat1D(amplitude=39.06017317, x_0=97.04165788, gamma=5.92445854, alpha=2.34745224)>
# Parameters:
#             c0_0            amplitude_1     ...      alpha_3
#     -------------------- ------------------ ... ------------------
#     -0.12431573958967715 49.819119736557525 ... 2.3474522372660664
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 290.782916
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 60, 89, 2
#
# amplitude=60.000000, mu=89.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 280, 84, 3, 3
#
# amplitude=280.000000, x_0=84.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 40, 95, 3, 3
#
# amplitude=40.000000, x_0=95.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.11953619)>
#
#     [1]: <Gaussian1D(amplitude=86.10301397, mean=87.48920395, stddev=3.30495157)>
#
#     [2]: <Moffat1D(amplitude=229.82026812, x_0=84.60903442, gamma=4.32567224, alpha=2.50733929)>
#
#     [3]: <Moffat1D(amplitude=44.11431507, x_0=95.46171812, gamma=6.71119388, alpha=2.47023393)>
# Parameters:
#             c0_0          amplitude_1    ...      gamma_3           alpha_3
#     ------------------- ---------------- ... ----------------- ------------------
#     -0.1195361869041312 86.1030139747685 ... 6.711193878848271 2.4702339301012706
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 288.759002
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 70, 88, 2
#
# amplitude=70.000000, mu=88.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 280, 83, 3, 3
#
# amplitude=280.000000, x_0=83.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 50, 95, 3, 3
#
# amplitude=50.000000, x_0=95.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.03766231)>
#
#     [1]: <Gaussian1D(amplitude=92.69134285, mean=86.5782563, stddev=2.79238304)>
#
#     [2]: <Moffat1D(amplitude=242.89511437, x_0=83.24098806, gamma=4.48379467, alpha=2.79875937)>
#
#     [3]: <Moffat1D(amplitude=45.9836769, x_0=93.30346281, gamma=9.39075298, alpha=4.66812671)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_3           alpha_3
#     -------------------- ----------------- ... ----------------- -----------------
#     -0.03766231341005248 92.69134284818821 ... 9.390752982493828 4.668126706217724
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 288.236581
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 70, 85, 2
#
# amplitude=70.000000, mu=85.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 280, 80, 3, 3
#
# amplitude=280.000000, x_0=80.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 50, 91, 3, 3
#
# amplitude=50.000000, x_0=91.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.12003637)>
#
#     [1]: <Gaussian1D(amplitude=99.18698343, mean=83.6389133, stddev=2.68502172)>
#
#     [2]: <Moffat1D(amplitude=249.02745827, x_0=80.08051598, gamma=4.47400914, alpha=2.88210007)>
#
#     [3]: <Moffat1D(amplitude=51.19248755, x_0=89.79548346, gamma=12.75460943, alpha=8.01371013)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_3            alpha_3
#     -------------------- ----------------- ... ------------------ -----------------
#     -0.12003636592326947 99.18698343258492 ... 12.754609428760944 8.013710134944505
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 26.795155
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 10, 84, 2
#
# amplitude=10.000000, mu=84.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 25, 79, 3, 3
#
# amplitude=25.000000, x_0=79.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 5, 90, 3, 3
#
# amplitude=5.000000, x_0=90.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.13361434)>
#
#     [1]: <Gaussian1D(amplitude=11.40597564, mean=83.83244331, stddev=3.48264352)>
#
#     [2]: <Moffat1D(amplitude=22.58528282, x_0=78.65734059, gamma=5.74579261, alpha=4.13978244)>
#
#     [3]: <Moffat1D(amplitude=3.78218565, x_0=90.16480604, gamma=1.09840454, alpha=0.74666777)>
# Parameters:
#             c0_0            amplitude_1     ...      alpha_3
#     -------------------- ------------------ ... ------------------
#     -0.13361434335205397 11.405975639928366 ... 0.7466677681346479
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no

# %%
def tie_pos2_moffat(model):
    #print(pixscale)
    return model.x_0_2 + (1.81 / pixscale)  #(1.87 / pixscale)  

def tie_pos1_moffat(model):
    #print(pixscale)
    return model.x_0_2 + (0.87 / pixscale) #(0.886 / pixscale)

def tie_gamma_moffat(model):
    return model.gamma_2

def tie_alpha_moffat(model):
    return model.alpha_2
    
for sp, info in zip(spec, spec.ordinfo):
    if sp.mod0 is not None:
        pixscale = info['pixscale']
        sp.mod0[1].mean.tied = tie_pos1_moffat
        #sp.mod0[3].mean.tied = tie_pos2_gauss
        #sp.mod0[1].stddev.tied = tie_stddev_gauss
        sp.mod0[3].x_0.tied = tie_pos2_moffat
        #sp.mod0[2].x_0.tied = tie_pos1_moffat
        sp.mod0[3].gamma.tied = tie_gamma_moffat
        sp.mod0[3].alpha.tied = tie_alpha_moffat
        sp.refined_model(sp.mod0)
# Out:
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.18221148)>
#
#     [1]: <Gaussian1D(amplitude=25.29535526, mean=112.51798885, stddev=3.1530056)>
#
#     [2]: <Moffat1D(amplitude=53.11066481, x_0=110.32668597, gamma=5.38907363, alpha=2.08087744)>
#
#     [3]: <Moffat1D(amplitude=9.78489657, x_0=124.75337461, gamma=7.77181602, alpha=2.50009233)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_3           alpha_3
#     ------------------- ------------------ ... ----------------- ------------------
#     -0.1822114795160219 25.295355256543292 ... 7.771816016114372 2.5000923342538344
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.12002696)>
#
#     [1]: <Gaussian1D(amplitude=4.71010912, mean=118.17834879, stddev=5.72907593)>
#
#     [2]: <Moffat1D(amplitude=72.06225991, x_0=110.92834879, gamma=8.03533367, alpha=3.72232014)>
#
#     [3]: <Moffat1D(amplitude=7.7142007, x_0=126.01168212, gamma=8.03533367, alpha=3.72232014)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_3           alpha_3
#     -------------------- ----------------- ... ----------------- ------------------
#     -0.12002696375146503 4.710109122944164 ... 8.035333666931345 3.7223201395495886
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.1631177)>
#
#     [1]: <Gaussian1D(amplitude=20.4660177, mean=104.16050657, stddev=3.2368264)>
#
#     [2]: <Moffat1D(amplitude=86.76175945, x_0=101.66290204, gamma=5.46953495, alpha=2.48684289)>
#
#     [3]: <Moffat1D(amplitude=12.83318693, x_0=115.11221879, gamma=8.8166649, alpha=3.71382697)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_3           alpha_3
#     -------------------- ------------------ ... ----------------- ------------------
#     -0.16311769966290024 20.466017696028075 ... 8.816664896034084 3.7138269732937217
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.13058559)>
#
#     [1]: <Gaussian1D(amplitude=7.47068892, mean=108.79375075, stddev=4.66436963)>
#
#     [2]: <Moffat1D(amplitude=99.63409864, x_0=101.94335705, gamma=6.83377721, alpha=3.34991857)>
#
#     [3]: <Moffat1D(amplitude=10.40889514, x_0=116.19532556, gamma=6.83377721, alpha=3.34991857)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_3           alpha_3
#     -------------------- ----------------- ... ----------------- ------------------
#     -0.13058558952114238 7.470688921697327 ... 6.833777205864411 3.3499185685116672
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.10603097)>
#
#     [1]: <Gaussian1D(amplitude=15.6165257, mean=102.50409492, stddev=3.0036427)>
#
#     [2]: <Moffat1D(amplitude=148.75436238, x_0=98.63934378, gamma=5.41567796, alpha=2.7200831)>
#
#     [3]: <Moffat1D(amplitude=19.73066553, x_0=111.64953751, gamma=6.13458542, alpha=2.25755886)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_3           alpha_3
#     ------------------- ------------------ ... ----------------- ------------------
#     -0.1060309696503334 15.616525696436092 ... 6.134585418716665 2.2575588555308794
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.0359434)>
#
#     [1]: <Gaussian1D(amplitude=11.00849748, mean=105.26537761, stddev=3.44537621)>
#
#     [2]: <Moffat1D(amplitude=153.9704374, x_0=98.77284029, gamma=5.93315335, alpha=3.02913359)>
#
#     [3]: <Moffat1D(amplitude=18.61172541, x_0=112.28030298, gamma=5.93315335, alpha=3.02913359)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_3           alpha_3
#     -------------------- ------------------ ... ----------------- -----------------
#     -0.03594339525160218 11.008497476589858 ... 5.933153351645329 3.029133591746242
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.01397965)>
#
#     [1]: <Gaussian1D(amplitude=17.76916629, mean=102.23014002, stddev=4.70625947)>
#
#     [2]: <Moffat1D(amplitude=183.17405326, x_0=95.87977506, gamma=5.73096578, alpha=3.20652322)>
#
#     [3]: <Moffat1D(amplitude=16.44872835, x_0=109.09145389, gamma=5.73096578, alpha=3.20652322)>
# Parameters:
#              c0_0            amplitude_1    ...      gamma_3           alpha_3
#     --------------------- ----------------- ... ----------------- -----------------
#     -0.013979648667698711 17.76916629106761 ... 5.730965777297893 3.206523223039457
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.0139785)>
#
#     [1]: <Gaussian1D(amplitude=17.76921102, mean=102.23014022, stddev=4.70630247)>
#
#     [2]: <Moffat1D(amplitude=183.17390373, x_0=95.87977525, gamma=5.73097952, alpha=3.20653768)>
#
#     [3]: <Moffat1D(amplitude=16.44857834, x_0=109.09145409, gamma=5.73097952, alpha=3.20653768)>
# Parameters:
#              c0_0            amplitude_1    ...     gamma_3           alpha_3
#     --------------------- ----------------- ... ---------------- -----------------
#     -0.013978497591009276 17.76921101861987 ... 5.73097951617264 3.206537682271234
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.00535106)>
#
#     [1]: <Gaussian1D(amplitude=21.48366135, mean=98.43521674, stddev=4.80237663)>
#
#     [2]: <Moffat1D(amplitude=214.90682747, x_0=92.39355008, gamma=5.13234845, alpha=2.77067998)>
#
#     [3]: <Moffat1D(amplitude=18.79629042, x_0=104.96299452, gamma=5.13234845, alpha=2.77067998)>
# Parameters:
#              c0_0            amplitude_1     ...      alpha_3
#     --------------------- ------------------ ... ------------------
#     -0.005351056428761908 21.483661353148182 ... 2.7706799815723664
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.00535333)>
#
#     [1]: <Gaussian1D(amplitude=21.48375798, mean=98.4352171, stddev=4.80245984)>
#
#     [2]: <Moffat1D(amplitude=214.90653009, x_0=92.39355043, gamma=5.13234985, alpha=2.77068446)>
#
#     [3]: <Moffat1D(amplitude=18.7959401, x_0=104.96299488, gamma=5.13234985, alpha=2.77068446)>
# Parameters:
#              c0_0            amplitude_1     ...      gamma_3           alpha_3
#     --------------------- ------------------ ... ----------------- -----------------
#     -0.005353326035991443 21.483757975536857 ... 5.132349846166239 2.770684455013919
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.04960192)>
#
#     [1]: <Gaussian1D(amplitude=39.76025951, mean=91.59106113, stddev=3.13821156)>
#
#     [2]: <Moffat1D(amplitude=272.75572252, x_0=85.75213496, gamma=5.41529416, alpha=3.16983841)>
#
#     [3]: <Moffat1D(amplitude=34.66187763, x_0=97.89978597, gamma=5.41529416, alpha=3.16983841)>
# Parameters:
#             c0_0           amplitude_1    ...     gamma_3           alpha_3
#     ------------------- ----------------- ... ---------------- -----------------
#     0.04960191796225214 39.76025950940084 ... 5.41529415779805 3.169838407844971
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.04960192)>
#
#     [1]: <Gaussian1D(amplitude=39.76025951, mean=91.59106113, stddev=3.13821156)>
#
#     [2]: <Moffat1D(amplitude=272.75572252, x_0=85.75213496, gamma=5.41529416, alpha=3.16983841)>
#
#     [3]: <Moffat1D(amplitude=34.66187763, x_0=97.89978597, gamma=5.41529416, alpha=3.16983841)>
# Parameters:
#             c0_0           amplitude_1    ...     gamma_3           alpha_3
#     ------------------- ----------------- ... ---------------- -----------------
#     0.04960191796225214 39.76025950940084 ... 5.41529415779805 3.169838407844971
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.11953619)>
#
#     [1]: <Gaussian1D(amplitude=86.10301397, mean=87.48920395, stddev=3.30495157)>
#
#     [2]: <Moffat1D(amplitude=229.82026812, x_0=84.60903442, gamma=4.32567224, alpha=2.50733929)>
#
#     [3]: <Moffat1D(amplitude=44.11431507, x_0=95.46171812, gamma=6.71119388, alpha=2.47023393)>
# Parameters:
#             c0_0          amplitude_1    ...      gamma_3           alpha_3
#     ------------------- ---------------- ... ----------------- ------------------
#     -0.1195361869041312 86.1030139747685 ... 6.711193878848271 2.4702339301012706
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.13977546)>
#
#     [1]: <Gaussian1D(amplitude=60.77605018, mean=90.5662354, stddev=2.9118034)>
#
#     [2]: <Moffat1D(amplitude=281.21153231, x_0=84.87996089, gamma=5.98411439, alpha=3.74136185)>
#
#     [3]: <Moffat1D(amplitude=38.00565112, x_0=96.71002625, gamma=5.98411439, alpha=3.74136185)>
# Parameters:
#             c0_0           amplitude_1     ...     gamma_3          alpha_3
#     ------------------- ------------------ ... ---------------- ----------------
#     0.13977546346745293 60.776050183241985 ... 5.98411438837843 3.74136185116236
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.03766231)>
#
#     [1]: <Gaussian1D(amplitude=92.69134285, mean=86.5782563, stddev=2.79238304)>
#
#     [2]: <Moffat1D(amplitude=242.89511437, x_0=83.24098806, gamma=4.48379467, alpha=2.79875937)>
#
#     [3]: <Moffat1D(amplitude=45.9836769, x_0=93.30346281, gamma=9.39075298, alpha=4.66812671)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_3           alpha_3
#     -------------------- ----------------- ... ----------------- -----------------
#     -0.03766231341005248 92.69134284818821 ... 9.390752982493828 4.668126706217724
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.10363399)>
#
#     [1]: <Gaussian1D(amplitude=72.50592786, mean=89.07263087, stddev=2.81082377)>
#
#     [2]: <Moffat1D(amplitude=279.93268482, x_0=83.56630175, gamma=6.62248456, alpha=4.71092601)>
#
#     [3]: <Moffat1D(amplitude=34.07198309, x_0=95.02199796, gamma=6.62248456, alpha=4.71092601)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_3           alpha_3
#     ------------------- ----------------- ... ----------------- -----------------
#     0.10363399138088955 72.50592786449897 ... 6.622484559353463 4.710926011561287
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.12003637)>
#
#     [1]: <Gaussian1D(amplitude=99.18698343, mean=83.6389133, stddev=2.68502172)>
#
#     [2]: <Moffat1D(amplitude=249.02745827, x_0=80.08051598, gamma=4.47400914, alpha=2.88210007)>
#
#     [3]: <Moffat1D(amplitude=51.19248755, x_0=89.79548346, gamma=12.75460943, alpha=8.01371013)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_3            alpha_3
#     -------------------- ----------------- ... ------------------ -----------------
#     -0.12003636592326947 99.18698343258492 ... 12.754609428760944 8.013710134944505
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.0258147)>
#
#     [1]: <Gaussian1D(amplitude=87.36416927, mean=85.72898179, stddev=2.64629967)>
#
#     [2]: <Moffat1D(amplitude=281.40592724, x_0=80.39155847, gamma=6.51402755, alpha=4.76362179)>
#
#     [3]: <Moffat1D(amplitude=39.53224553, x_0=91.49585295, gamma=6.51402755, alpha=4.76362179)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_3           alpha_3
#     ------------------- ----------------- ... ----------------- -----------------
#     0.02581469990963188 87.36416927484396 ... 6.514027553250365 4.763621794698047
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.13361434)>
#
#     [1]: <Gaussian1D(amplitude=11.40597564, mean=83.83244331, stddev=3.48264352)>
#
#     [2]: <Moffat1D(amplitude=22.58528282, x_0=78.65734059, gamma=5.74579261, alpha=4.13978244)>
#
#     [3]: <Moffat1D(amplitude=3.78218565, x_0=90.16480604, gamma=1.09840454, alpha=0.74666777)>
# Parameters:
#             c0_0            amplitude_1     ...      alpha_3
#     -------------------- ------------------ ... ------------------
#     -0.13361434335205397 11.405975639928366 ... 0.7466677681346479
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.10387404)>
#
#     [1]: <Gaussian1D(amplitude=11.17827721, mean=83.92275557, stddev=2.63300749)>
#
#     [2]: <Moffat1D(amplitude=25.00180375, x_0=78.74418414, gamma=6.14686414, alpha=4.54383425)>
#
#     [3]: <Moffat1D(amplitude=4.76449155, x_0=89.51799366, gamma=6.14686414, alpha=4.54383425)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_3           alpha_3
#     -------------------- ------------------ ... ----------------- -----------------
#     -0.10387403956848866 11.178277214397625 ... 6.146864144942847 4.543834249796671
#
# -------------------------------------------

# %%
outspec = spec.extract_all(method='cdf', plot_profiles=False, plot_traces=True, plot_extracted=False,
                          stepsize=25)
# Out:
# Extracting spectra
# ------------------
# Order_01
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 2 to parameter: c0_0
# Fitting polynomial of degree 2 to parameter: mean_1
# Fitting polynomial of degree 2 to parameter: stddev_1
# Fitting polynomial of degree 2 to parameter: x_0_2
# Fitting polynomial of degree 2 to parameter: gamma_2
# Fitting polynomial of degree 2 to parameter: alpha_2
# Fitting polynomial of degree 2 to parameter: x_0_3
# Fitting polynomial of degree 2 to parameter: gamma_3
# Fitting polynomial of degree 2 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1500 - 3000
# Fitting to the trace at 3461 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  4071.46
#  Spectrum End:     4310.06
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.16
#
#  Spectrum Start:  4071.46
#  Spectrum End:     4310.06
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.16
#
#  Spectrum Start:  4071.46
#  Spectrum End:     4310.06
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.16
#
#
# Plotting the spectrum
# Order_02
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 2 to parameter: c0_0
# Fitting polynomial of degree 2 to parameter: mean_1
# Fitting polynomial of degree 2 to parameter: stddev_1
# Fitting polynomial of degree 2 to parameter: x_0_2
# Fitting polynomial of degree 2 to parameter: gamma_2
# Fitting polynomial of degree 2 to parameter: alpha_2
# Fitting polynomial of degree 2 to parameter: x_0_3
# Fitting polynomial of degree 2 to parameter: gamma_3
# Fitting polynomial of degree 2 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1400 - 3400
# Fitting to the trace at 4093 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  4240.70
#  Spectrum End:     4575.32
#  Dispersion (1st pixel):   0.16
#  Dispersion (average):      0.17
#
#  Spectrum Start:  4240.70
#  Spectrum End:     4575.32
#  Dispersion (1st pixel):   0.16
#  Dispersion (average):      0.17
#
#  Spectrum Start:  4240.70
#  Spectrum End:     4575.32
#  Dispersion (1st pixel):   0.16
#  Dispersion (average):      0.17
#
#
# Plotting the spectrum
# Order_03
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 2 to parameter: c0_0
# Fitting polynomial of degree 2 to parameter: mean_1
# Fitting polynomial of degree 2 to parameter: stddev_1
# Fitting polynomial of degree 2 to parameter: x_0_2
# Fitting polynomial of degree 2 to parameter: gamma_2
# Fitting polynomial of degree 2 to parameter: alpha_2
# Fitting polynomial of degree 2 to parameter: x_0_3
# Fitting polynomial of degree 2 to parameter: gamma_3
# Fitting polynomial of degree 2 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1300 - 3700
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  4546.04
#  Spectrum End:     4979.85
#  Dispersion (1st pixel):   0.17
#  Dispersion (average):      0.18
#
#  Spectrum Start:  4546.04
#  Spectrum End:     4979.85
#  Dispersion (1st pixel):   0.17
#  Dispersion (average):      0.18
#
#  Spectrum Start:  4546.04
#  Spectrum End:     4979.85
#  Dispersion (1st pixel):   0.17
#  Dispersion (average):      0.18
#
#
# Plotting the spectrum
# Order_04
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 2 to parameter: c0_0
# Fitting polynomial of degree 2 to parameter: mean_1
# Fitting polynomial of degree 2 to parameter: stddev_1
# Fitting polynomial of degree 2 to parameter: x_0_2
# Fitting polynomial of degree 2 to parameter: gamma_2
# Fitting polynomial of degree 2 to parameter: alpha_2
# Fitting polynomial of degree 2 to parameter: x_0_3
# Fitting polynomial of degree 2 to parameter: gamma_3
# Fitting polynomial of degree 2 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1200 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#
# Plotting the spectrum
# Order_05
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 2 to parameter: c0_0
# Fitting polynomial of degree 2 to parameter: mean_1
# Fitting polynomial of degree 2 to parameter: stddev_1
# Fitting polynomial of degree 2 to parameter: x_0_2
# Fitting polynomial of degree 2 to parameter: gamma_2
# Fitting polynomial of degree 2 to parameter: alpha_2
# Fitting polynomial of degree 2 to parameter: x_0_3
# Fitting polynomial of degree 2 to parameter: gamma_3
# Fitting polynomial of degree 2 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1100 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  5325.24
#  Spectrum End:     5967.01
#  Dispersion (1st pixel):   0.20
#  Dispersion (average):      0.21
#
#  Spectrum Start:  5325.24
#  Spectrum End:     5967.01
#  Dispersion (1st pixel):   0.20
#  Dispersion (average):      0.21
#
#  Spectrum Start:  5325.24
#  Spectrum End:     5967.01
#  Dispersion (1st pixel):   0.20
#  Dispersion (average):      0.21
#
#
# Plotting the spectrum
# Order_06
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 2 to parameter: c0_0
# Fitting polynomial of degree 2 to parameter: mean_1
# Fitting polynomial of degree 2 to parameter: stddev_1
# Fitting polynomial of degree 2 to parameter: x_0_2
# Fitting polynomial of degree 2 to parameter: gamma_2
# Fitting polynomial of degree 2 to parameter: alpha_2
# Fitting polynomial of degree 2 to parameter: x_0_3
# Fitting polynomial of degree 2 to parameter: gamma_3
# Fitting polynomial of degree 2 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 900 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  5810.63
#  Spectrum End:     6560.55
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#  Spectrum Start:  5810.63
#  Spectrum End:     6560.55
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#  Spectrum Start:  5810.63
#  Spectrum End:     6560.55
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#
# Plotting the spectrum
# Order_07
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 2 to parameter: c0_0
# Fitting polynomial of degree 2 to parameter: mean_1
# Fitting polynomial of degree 2 to parameter: stddev_1
# Fitting polynomial of degree 2 to parameter: x_0_2
# Fitting polynomial of degree 2 to parameter: gamma_2
# Fitting polynomial of degree 2 to parameter: alpha_2
# Fitting polynomial of degree 2 to parameter: x_0_3
# Fitting polynomial of degree 2 to parameter: gamma_3
# Fitting polynomial of degree 2 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 600 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  6380.37
#  Spectrum End:     7286.41
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#  Spectrum Start:  6380.37
#  Spectrum End:     7286.41
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#  Spectrum Start:  6380.37
#  Spectrum End:     7286.41
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#
# Plotting the spectrum
# Order_08
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 2 to parameter: c0_0
# Fitting polynomial of degree 2 to parameter: mean_1
# Fitting polynomial of degree 2 to parameter: stddev_1
# Fitting polynomial of degree 2 to parameter: x_0_2
# Fitting polynomial of degree 2 to parameter: gamma_2
# Fitting polynomial of degree 2 to parameter: alpha_2
# Fitting polynomial of degree 2 to parameter: x_0_3
# Fitting polynomial of degree 2 to parameter: gamma_3
# Fitting polynomial of degree 2 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 200 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  7066.66
#  Spectrum End:     8193.74
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29
#
#  Spectrum Start:  7066.66
#  Spectrum End:     8193.74
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29
#
#  Spectrum Start:  7066.66
#  Spectrum End:     8193.74
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29
#
#
# Plotting the spectrum
# Order_09
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 2 to parameter: c0_0
# Fitting polynomial of degree 2 to parameter: mean_1
# Fitting polynomial of degree 2 to parameter: stddev_1
# Fitting polynomial of degree 2 to parameter: x_0_2
# Fitting polynomial of degree 2 to parameter: gamma_2
# Fitting polynomial of degree 2 to parameter: alpha_2
# Fitting polynomial of degree 2 to parameter: x_0_3
# Fitting polynomial of degree 2 to parameter: gamma_3
# Fitting polynomial of degree 2 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 0 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  8012.11
#  Spectrum End:     9360.83
#  Dispersion (1st pixel):   0.30
#  Dispersion (average):      0.33
#
#  Spectrum Start:  8012.11
#  Spectrum End:     9360.83
#  Dispersion (1st pixel):   0.30
#  Dispersion (average):      0.33
#
#  Spectrum Start:  8012.11
#  Spectrum End:     9360.83
#  Dispersion (1st pixel):   0.30
#  Dispersion (average):      0.33
#
#
# Plotting the spectrum
# Order_10
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 2 to parameter: c0_0
# Fitting polynomial of degree 2 to parameter: mean_1
# Fitting polynomial of degree 2 to parameter: stddev_1
# Fitting polynomial of degree 2 to parameter: x_0_2
# Fitting polynomial of degree 2 to parameter: gamma_2
# Fitting polynomial of degree 2 to parameter: alpha_2
# Fitting polynomial of degree 2 to parameter: x_0_3
# Fitting polynomial of degree 2 to parameter: gamma_3
# Fitting polynomial of degree 2 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 0 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  9337.74
#  Spectrum End:    10909.62
#  Dispersion (1st pixel):   0.35
#  Dispersion (average):      0.38
#
#  Spectrum Start:  9337.74
#  Spectrum End:    10909.62
#  Dispersion (1st pixel):   0.35
#  Dispersion (average):      0.38
#
#  Spectrum Start:  9337.74
#  Spectrum End:    10909.62
#  Dispersion (1st pixel):   0.35
#  Dispersion (average):      0.38
#
#
# Plotting the spectrum
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   1  1500   4071.46  4310.06   0.16
#   2  2000   4240.70  4575.32   0.17
#   3  2400   4546.04  4979.85   0.18
#   4  2896   4902.88  5472.92   0.20
#   5  2996   5325.24  5967.01   0.21
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.66  8193.74   0.29
#   9  4096   8012.11  9360.83   0.33
#  10  4096   9337.74 10909.62   0.38
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   1  1500   4071.46  4310.06   0.16
#   2  2000   4240.70  4575.32   0.17
#   3  2400   4546.04  4979.85   0.18
#   4  2896   4902.88  5472.92   0.20
#   5  2996   5325.24  5967.01   0.21
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.66  8193.74   0.29
#   9  4096   8012.11  9360.83   0.33
#  10  4096   9337.74 10909.62   0.38
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   1  1500   4071.46  4310.06   0.16
#   2  2000   4240.70  4575.32   0.17
#   3  2400   4546.04  4979.85   0.18
#   4  2896   4902.88  5472.92   0.20
#   5  2996   5325.24  5967.01   0.21
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.66  8193.74   0.29
#   9  4096   8012.11  9360.83   0.33
#  10  4096   9337.74 10909.62   0.38

# %%
resp_corr = np.loadtxt('response_curve_ESI_optimal_smooth.txt')
r = []
order = [4, 5, 6] #, 9, 10]
for i, p in enumerate(order):
    r.append(resp_corr[p-1])
#r.append(resp_corr[5:7])
#r.append(resp_corr[8:])
np.savetxt('resp_file_for_testing.txt', r)

# %%
outspec[0].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth.txt', resp_corr=True)
# Out:
#  Spectrum Start:  4071.46
#  Spectrum End:    10909.62
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.26

# %%
outspec[1].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth.txt', resp_corr=True)
# Out:
#  Spectrum Start:  4071.46
#  Spectrum End:    10909.62
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.26

# %%
outspec[2].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth.txt', resp_corr=True)
# Out:
#  Spectrum Start:  4071.46
#  Spectrum End:    10909.62
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.26

# %%
outspec[0].spec1d.save('spec1d_J0924_41_moffat_secondary.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0924_41_moffat_secondary.fits in format fits

# %%
outspec[1].spec1d.save('spec1d_J0924_41_moffat_primary.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0924_41_moffat_primary.fits in format fits

# %%
outspec[2].spec1d.save('spec1d_J0924_41_moffat_tertiary.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0924_41_moffat_tertiary.fits in format fits

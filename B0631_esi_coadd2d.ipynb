# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from astropy.io import fits
from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, spec1d, echelle1d
from scipy.ndimage import shift

# %%
file_loc = '../galaxy_spectra/ESI_data/2019_01/*'

# %%
spec2d_file_list = []
var2d_file_list = []
#out_file = []
for i,p in enumerate(glob.glob(file_loc)):
    if 'B0631' in p:
        if 'bgsub.fits' in p:
            spec2d_file_list.append(p)
        elif 'var.fits' in p:
            var2d_file_list.append(p)

# %%
spec2d_file_list, var2d_file_list
# Out:
# (['../galaxy_spectra/ESI_data/2019_01/B0631+519_0049_bgsub.fits',
#   '../galaxy_spectra/ESI_data/2019_01/B0631+519_0046_bgsub.fits',
#   '../galaxy_spectra/ESI_data/2019_01/B0631+519_0047_bgsub.fits',
#   '../galaxy_spectra/ESI_data/2019_01/B0631+519_0048_bgsub.fits'],
#  ['../galaxy_spectra/ESI_data/2019_01/B0631+519_0049_var.fits',
#   '../galaxy_spectra/ESI_data/2019_01/B0631+519_0046_var.fits',
#   '../galaxy_spectra/ESI_data/2019_01/B0631+519_0047_var.fits',
#   '../galaxy_spectra/ESI_data/2019_01/B0631+519_0048_var.fits'])

# %%
# create a list of spec2d object for particular order
spec1 = esi2d.Esi2d(spec2d_file_list[1], varfile=var2d_file_list[1])
spec2 = esi2d.Esi2d(spec2d_file_list[2], varfile=var2d_file_list[2])
spec3 = esi2d.Esi2d(spec2d_file_list[3], varfile=var2d_file_list[3])
spec4 = esi2d.Esi2d(spec2d_file_list[0], varfile=var2d_file_list[0])
# Out:
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3460x164     x
#   2   4093x155     x
#   3   4096x145     x
#   4   4096x140     x
#   5   4096x134     x
#   6   4096x129     x
#   7   4096x125     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x116     x
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3460x164     x
#   2   4093x155     x
#   3   4096x145     x
#   4   4096x140     x
#   5   4096x134     x
#   6   4096x129     x
#   7   4096x125     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x116     x
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3460x164     x
#   2   4093x155     x
#   3   4096x145     x
#   4   4096x140     x
#   5   4096x134     x
#   6   4096x129     x
#   7   4096x125     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x116     x
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3460x164     x
#   2   4093x155     x
#   3   4096x145     x
#   4   4096x140     x
#   5   4096x134     x
#   6   4096x129     x
#   7   4096x125     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x116     x

# %%
pixrange = [[3000, 3400], [1700, 2100], [1600, 2000], [650, 950]] 
           # pixrange for order 5 and 6 [2000, 2300], [1700, 2100], 
spec_list = [spec1, spec2, spec3, spec4]
order_list = spec1.ordinfo

for order, pix in zip(order_list[6:], pixrange):
    print(order['name'], 'pixscale:', order['pixscale'])
    for sp in spec_list:
        profile = sp[order['order']-1].spatial_profile(pixrange=pix)
        plt.show()
        sp[order['order']-1].initial_model()
# Out:
# Order_07 pixscale: 0.153
# Profile max value (before normalization) 8.208469
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 7, 56, 3, 4
#
# amplitude=7.000000, x_0=56.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.1104244)>
#
#     [1]: <Moffat1D(amplitude=7.59746863, x_0=56.27822135, gamma=15.06955415, alpha=4.83509018)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_1            alpha_1
#     -------------------- ----------------- ... ------------------ -----------------
#     -0.11042439985355389 7.597468628357097 ... 15.069554154825218 4.835090180182398
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 7.849912
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 7, 75, 3, 4
#
# amplitude=7.000000, x_0=75.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.09285913)>
#
#     [1]: <Moffat1D(amplitude=6.91818624, x_0=75.32407497, gamma=11.50485041, alpha=2.82919551)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_1            alpha_1
#     -------------------- ----------------- ... ------------------ ------------------
#     -0.09285913100190317 6.918186244376722 ... 11.504850414371123 2.8291955106933213
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 7.741653
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 7, 36, 3, 4
#
# amplitude=7.000000, x_0=36.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.21464291)>
#
#     [1]: <Moffat1D(amplitude=7.47896846, x_0=36.03967138, gamma=10.9195617, alpha=2.63305116)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_1            alpha_1
#     -------------------- ----------------- ... ------------------ -----------------
#     -0.21464290920157325 7.478968462027793 ... 10.919561697345806 2.633051157379693
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 5.949377
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 6, 55, 3, 4
#
# amplitude=6.000000, x_0=55.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.142664)>
#
#     [1]: <Moffat1D(amplitude=5.86685958, x_0=55.32249072, gamma=14.69177628, alpha=4.11516183)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_1            alpha_1
#     -------------------- ----------------- ... ------------------ ------------------
#     -0.14266400286021136 5.866859580372692 ... 14.691776282940335 4.1151618303433555
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Order_08 pixscale: 0.158
# Profile max value (before normalization) 12.515941
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 12, 54, 3, 4
#
# amplitude=12.000000, x_0=54.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.29904331)>
#
#     [1]: <Moffat1D(amplitude=12.43299142, x_0=53.16063211, gamma=9.02119378, alpha=1.98477626)>
# Parameters:
#             c0_0            amplitude_1     ...     gamma_1           alpha_1
#     -------------------- ------------------ ... ---------------- ------------------
#     -0.29904331068564427 12.432991419451024 ... 9.02119377836823 1.9847762553670465
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 11.867870
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 11, 71, 3, 4
#
# amplitude=11.000000, x_0=71.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.17453558)>
#
#     [1]: <Moffat1D(amplitude=11.32973376, x_0=71.3030028, gamma=10.46705338, alpha=2.49933215)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_1            alpha_1
#     -------------------- ------------------ ... ------------------ -----------------
#     -0.17453558146369247 11.329733756839545 ... 10.467053380809894 2.499332152968092
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 11.878668
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 11, 32, 3, 4
#
# amplitude=11.000000, x_0=32.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.10375242)>
#
#     [1]: <Moffat1D(amplitude=11.62795393, x_0=33.43604261, gamma=13.50549002, alpha=4.2544649)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_1            alpha_1
#     -------------------- ------------------ ... ------------------ -----------------
#     -0.10375241926900239 11.627953926273118 ... 13.505490020317547 4.254464904180168
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 10.309161
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 10, 50, 3, 4
#
# amplitude=10.000000, x_0=50.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.16007267)>
#
#     [1]: <Moffat1D(amplitude=10.04822915, x_0=51.71626875, gamma=12.57949645, alpha=3.62619715)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_1            alpha_1
#     ------------------- ------------------ ... ------------------ -----------------
#     -0.1600726714040991 10.048229153310961 ... 12.579496454910496 3.626197150275007
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Order_09 pixscale: 0.163
# Profile max value (before normalization) 15.048648
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 15, 50, 3, 4
#
# amplitude=15.000000, x_0=50.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.08192126)>
#
#     [1]: <Moffat1D(amplitude=15.13268031, x_0=50.52262397, gamma=11.80488176, alpha=3.82566726)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_1            alpha_1
#     -------------------- ------------------ ... ------------------ -----------------
#     -0.08192126270245716 15.132680314813758 ... 11.804881762600873 3.825667264932388
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 13.676874
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 13, 66, 3, 4
#
# amplitude=13.000000, x_0=66.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.12941754)>
#
#     [1]: <Moffat1D(amplitude=13.67633218, x_0=68.19737946, gamma=15.4285148, alpha=5.33849041)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_1            alpha_1
#     ------------------- ----------------- ... ------------------ -----------------
#     -0.1294175427144603 13.67633217692754 ... 15.428514803833954 5.338490407801467
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 14.947404
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 13, 30, 3, 4
#
# amplitude=13.000000, x_0=30.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.11356224)>
#
#     [1]: <Moffat1D(amplitude=14.0783405, x_0=31.66511213, gamma=15.1099528, alpha=5.64244709)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_1           alpha_1
#     -------------------- ------------------ ... ------------------ ----------------
#     -0.11356224311065453 14.078340500975703 ... 15.109952796070461 5.64244709034956
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 12.242440
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 12, 48, 3, 4
#
# amplitude=12.000000, x_0=48.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.14826598)>
#
#     [1]: <Moffat1D(amplitude=12.25175633, x_0=49.37515467, gamma=15.15919502, alpha=5.33682331)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_1            alpha_1
#     ------------------- ------------------ ... ------------------ -----------------
#     -0.1482659769827194 12.251756333848396 ... 15.159195018214106 5.336823313853914
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Order_10 pixscale: 0.168
# Profile max value (before normalization) 6.106618
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 5.5, 48, 3, 4
#
# amplitude=5.500000, x_0=48.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.16935088)>
#
#     [1]: <Moffat1D(amplitude=6.20258672, x_0=50.95202176, gamma=22.38127611, alpha=12.13519061)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_1            alpha_1
#     -------------------- ----------------- ... ------------------ ------------------
#     -0.16935087778877161 6.202586722727197 ... 22.381276106538497 12.135190611975407
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 5.849281
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 5.5, 67, 3, 4
#
# amplitude=5.500000, x_0=67.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.1130912)>
#
#     [1]: <Moffat1D(amplitude=5.60798831, x_0=68.11853256, gamma=17.39674018, alpha=7.90676666)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_1           alpha_1
#     -------------------- ----------------- ... ----------------- -----------------
#     -0.11309119594459333 5.607988314177939 ... 17.39674018365222 7.906766662283731
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 5.914792
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 6, 31, 3, 4
#
# amplitude=6.000000, x_0=31.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.64230104)>
#
#     [1]: <Moffat1D(amplitude=6.49554989, x_0=32.58472096, gamma=41.03581347, alpha=53.58258512)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_1            alpha_1
#     ------------------- ----------------- ... ------------------ ------------------
#     -0.6423010395689898 6.495549891832246 ... 41.035813470580116 53.582585115445916
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 5.312380
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 5.5, 49, 3, 4
#
# amplitude=5.500000, x_0=49.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.19761247)>
#
#     [1]: <Moffat1D(amplitude=5.47636325, x_0=50.12999011, gamma=8.62363229, alpha=1.94888328)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_1          alpha_1
#     -------------------- ----------------- ... ----------------- ----------------
#     -0.19761246993071388 5.476363245454523 ... 8.623632290308505 1.94888328158368
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no

# %%
for od in order_list[6:]:
    for i, sp in enumerate(spec_list):
        if i==0:
            print(od['name']+':')
            print(sp[od['order']-1].mod0.x_0_1.value)
            center = sp[od['order']-1].mod0.x_0_1.value
        else:
            print(center - sp[od['order']-1].mod0.x_0_1.value)
# Out:
# Order_07:
# 56.27822134929845
# -19.045853624318113
# 20.238549966783104
# 0.9557306299428063
# Order_08:
# 53.16063211260464
# -18.14237068247862
# 19.72458949910103
# 1.4443633660562298
# Order_09:
# 50.52262397036956
# -17.674755491094494
# 18.857511841185033
# 1.1474693043359068
# Order_10:
# 50.95202176431398
# -17.166510792980304
# 18.36730080793295
# 0.8220316520361592

# %%
order_list = [7, 8, 9, 10]
spec_list = [spec1, spec2, spec3, spec4]
shifted_sp = []
shifted_var = []
shift_pixel = np.array([[0.0, -20.05, 19.24, 0.96], [0.0, -18.14, 19.72, 1.44], [0.0, -17.67, 18.86, 1.15],
                        [0.0, -17.17, 18.37, 0.82]])
for shft, order in zip(shift_pixel, order_list):
    new_sp = []
    new_var = []
    for i, sp in enumerate(spec_list):
        #print(sp[order-1].mod0, shift[i])
        nanmask = (sp[order-1].vardata <= 0) | (np.isnan(sp[order-1].vardata)) 
        nnan = nanmask.sum()
        if nnan > 0:
            print('Found %d NaNs in the two-dimensional variance '\
                  'spectrum' % nnan)

            """ Replace the NaNs with a big value """
            sp[order-1].vardata[nanmask] = 1.e9
        new_sp.append(shift(sp[order-1].data, [shft[i], 0], order=1))
        new_var.append(shift(sp[order-1].vardata, [shft[i], 0], order=1))
    shifted_sp.append(new_sp)
    shifted_var.append(new_var)
# Out:
# Found 927 NaNs in the two-dimensional variance spectrum
# Found 986 NaNs in the two-dimensional variance spectrum
# Found 1008 NaNs in the two-dimensional variance spectrum
# Found 1269 NaNs in the two-dimensional variance spectrum
# Found 1164 NaNs in the two-dimensional variance spectrum
# Found 943 NaNs in the two-dimensional variance spectrum
# Found 1268 NaNs in the two-dimensional variance spectrum
# Found 1298 NaNs in the two-dimensional variance spectrum
# Found 1206 NaNs in the two-dimensional variance spectrum
# Found 1117 NaNs in the two-dimensional variance spectrum
# Found 1351 NaNs in the two-dimensional variance spectrum
# Found 1257 NaNs in the two-dimensional variance spectrum
# Found 1024 NaNs in the two-dimensional variance spectrum
# Found 1055 NaNs in the two-dimensional variance spectrum
# Found 896 NaNs in the two-dimensional variance spectrum
# Found 1162 NaNs in the two-dimensional variance spectrum

# %%
# %matplotlib notebook
for od, sp_list, pix in zip(order_list, shifted_sp, pixrange):
    plt.figure(figsize=(8, 6))
    #pixrange = [[2200, 2600], [2200, 2600], [1800, 2200], [1500, 1900], [1500, 1900], [1500, 1900]]
    color = ['b', 'r', 'k', 'g']
    label = ['frame_46', 'frame_47', 'frame_48', 'frame_49']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pix[0]:pix[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    plt.legend()
    plt.title('order %d' %od)
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
# <img src="data:image/png;base64,..." width="799.9999826604674">
# <img src="data:image/png;base64,..." width="799.9999826604674">
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
for od, sp_list, pix in zip(order_list, shifted_sp, pixrange):
    plt.figure(figsize=(8, 6))
    #pixrange = [[2200, 2600], [2200, 2600], [1800, 2200], [1500, 1900], [1500, 1900], [1500, 1900]]
    color = ['b', 'r', 'k', 'g']
    label = ['frame_46', 'frame_47', 'frame_48', 'frame_49']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pix[0]:pix[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    plt.legend()
    plt.title('order %d' %od)
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
outsp = []
outvar = []

for sp_list, var_list in zip(shifted_sp, shifted_var):
    wtsp = np.zeros(sp_list[0].shape)
    wtsum = np.zeros(sp_list[0].shape)
    for s, v in zip(sp_list, var_list):
        wt = np.zeros(wtsp.shape)
        mask = np.isnan(v) | (v<=0)
        wt[~mask] = 1.0 / v[~mask]
        #print(sum(sum(np.isnan(wt) | (wt<=0))))
        wtsp += wt * s
        #print(sum(sum(wtsp==0)))
        wtsum += wt
        #print(sum(sum(wtsum==0)))

    wtsp[wtsum == 0] = 0
    wtsum[wtsum == 0] = 1
    outsp.append(wtsp / wtsum)
    outvar.append(1.0 / wtsum)

# %%
#pixrange = [[2200, 2600], [2700, 3000], [2600, 3000], [1800, 2200], [1500, 1900], [1500, 1900], [1500, 1900]]
for od, sp_list, cd_sp, pix in zip(order_list, shifted_sp, outsp, pixrange):
    plt.figure(figsize=(8, 6))
    #pixrange = [2700, 3000]
    color = ['b', 'r', 'k', 'g']
    label = ['frame_46', 'frame_47', 'frame_48', 'frame_49']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pix[0]:pix[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    
    tmpdata = cd_sp[:, pix[0]:pix[1]]
    pflux = np.median(tmpdata, axis=1)
    x = np.arange(cd_sp.shape[0])
    plt.plot(x, pflux, color='y', drawstyle='steps', label='coadded')
    plt.legend()
    plt.title('order %d' %od)
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
# <img src="data:image/png;base64,..." width="799.9999826604674">
# <img src="data:image/png;base64,..." width="799.9999826604674">
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
s = fits.open('../galaxy_spectra/ESI_data/2019_01/B0631+519_0046_bgsub.fits')
for od, cd_sp, cd_var in zip(order_list, outsp, outvar):
    file_name1 = 'B0631_ESI_spectra/B0631_coadd2d_sp_order_' + str(od) + '.fits'
    file_name2 = 'B0631_ESI_spectra/B0631_coadd2d_var_order_' + str(od) + '.fits'
    fits.writeto(file_name1, cd_sp, header=s[od].header)
    fits.writeto(file_name2, cd_var, header=s[od].header)

# %%
# coadded order 6 later
pixrange = [[2000, 2400]] 
           # pixrange for order 5 and 6 [2000, 2300], [1700, 2100], 
spec_list = [spec1, spec2, spec3, spec4]
order_list = spec1.ordinfo

for order, pix in zip(order_list[5:6], pixrange):
    print(order['name'], 'pixscale:', order['pixscale'])
    for sp in spec_list:
        profile = sp[order['order']-1].spatial_profile(pixrange=pix)
        plt.show()
        sp[order['order']-1].initial_model()
# Out:
# Order_06 pixscale: 0.149
# Profile max value (before normalization) 3.573758
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3.5, 56, 2, 3
#
# amplitude=3.500000, x_0=56.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.07617735)>
#
#     [1]: <Moffat1D(amplitude=3.04257663, x_0=56.65549067, gamma=35.07790013, alpha=30.83844255)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_1           alpha_1
#     -------------------- ------------------ ... ----------------- ------------------
#     -0.07617735305327633 3.0425766345567724 ... 35.07790013076999 30.838442547042227
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 3.207816
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.2
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3, 75, 2, 3
#
# amplitude=3.000000, x_0=75.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.03359791)>
#
#     [1]: <Moffat1D(amplitude=3.03473241, x_0=76.01893445, gamma=53.01972737, alpha=54.07714416)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_1           alpha_1
#     -------------------- ----------------- ... ------------------ ----------------
#     -0.03359790729647477 3.034732406684398 ... 53.019727371703944 54.0771441562325
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 3.113542
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -0.2
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3, 35, 2, 3
#
# amplitude=3.000000, x_0=35.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.06824239)>
#
#     [1]: <Moffat1D(amplitude=3.03383506, x_0=35.65284008, gamma=49.22617359, alpha=49.83714269)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_1           alpha_1
#     -------------------- ---------------- ... ----------------- -----------------
#     -0.06824239329656308 3.03383506204183 ... 49.22617359247524 49.83714268906673
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 2.705524
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3, 54, 2, 3
#
# amplitude=3.000000, x_0=54.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.05603039)>
#
#     [1]: <Moffat1D(amplitude=2.5040244, x_0=55.04948374, gamma=17.32880812, alpha=11.14476241)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_1           alpha_1
#     -------------------- ------------------ ... ----------------- ------------------
#     -0.05603038691820731 2.5040244036202433 ... 17.32880812379942 11.144762405985864
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no

# %%
for od in order_list[5:6]:
    for i, sp in enumerate(spec_list):
        if i==0:
            print(od['name']+':')
            print(sp[od['order']-1].mod0.x_0_1.value)
            center = sp[od['order']-1].mod0.x_0_1.value
        else:
            print(center - sp[od['order']-1].mod0.x_0_1.value)
# Out:
# Order_06:
# 56.65549067377623
# -19.363443780345634
# 21.002650591988974
# 1.6060069353461586

# %%
order_list = [6]
spec_list = [spec1, spec2, spec3, spec4]
shifted_sp = []
shifted_var = []
shift_pixel = np.array([[0.0, -19.36, 21.0, 1.61]])
for shft, order in zip(shift_pixel, order_list):
    new_sp = []
    new_var = []
    for i, sp in enumerate(spec_list):
        #print(sp[order-1].mod0, shift[i])
        nanmask = (sp[order-1].vardata <= 0) | (np.isnan(sp[order-1].vardata)) 
        nnan = nanmask.sum()
        if nnan > 0:
            print('Found %d NaNs in the two-dimensional variance '\
                  'spectrum' % nnan)

            """ Replace the NaNs with a big value """
            sp[order-1].vardata[nanmask] = 1.e9
        new_sp.append(shift(sp[order-1].data, [shft[i], 0], order=1))
        new_var.append(shift(sp[order-1].vardata, [shft[i], 0], order=1))
    shifted_sp.append(new_sp)
    shifted_var.append(new_var)
# Out:
# Found 1466 NaNs in the two-dimensional variance spectrum
# Found 1125 NaNs in the two-dimensional variance spectrum
# Found 1141 NaNs in the two-dimensional variance spectrum
# Found 1169 NaNs in the two-dimensional variance spectrum

# %%
# %matplotlib notebook
for od, sp_list, pix in zip(order_list, shifted_sp, pixrange):
    plt.figure(figsize=(8, 6))
    #pixrange = [[2200, 2600], [2200, 2600], [1800, 2200], [1500, 1900], [1500, 1900], [1500, 1900]]
    color = ['b', 'r', 'k', 'g']
    label = ['frame_46', 'frame_47', 'frame_48', 'frame_49']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pix[0]:pix[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    plt.legend()
    plt.title('order %d' %od)
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
outsp = []
outvar = []

for sp_list, var_list in zip(shifted_sp, shifted_var):
    wtsp = np.zeros(sp_list[0].shape)
    wtsum = np.zeros(sp_list[0].shape)
    for s, v in zip(sp_list, var_list):
        wt = np.zeros(wtsp.shape)
        mask = np.isnan(v) | (v<=0)
        wt[~mask] = 1.0 / v[~mask]
        #print(sum(sum(np.isnan(wt) | (wt<=0))))
        wtsp += wt * s
        #print(sum(sum(wtsp==0)))
        wtsum += wt
        #print(sum(sum(wtsum==0)))

    wtsp[wtsum == 0] = 0
    wtsum[wtsum == 0] = 1
    outsp.append(wtsp / wtsum)
    outvar.append(1.0 / wtsum)

# %%
for od, sp_list, cd_sp, pix in zip(order_list, shifted_sp, outsp, pixrange):
    plt.figure(figsize=(8, 6))
    #pixrange = [2700, 3000]
    color = ['b', 'r', 'k', 'g']
    label = ['frame_46', 'frame_47', 'frame_48', 'frame_49']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pix[0]:pix[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    
    tmpdata = cd_sp[:, pix[0]:pix[1]]
    pflux = np.median(tmpdata, axis=1)
    x = np.arange(cd_sp.shape[0])
    plt.plot(x, pflux, color='y', drawstyle='steps', label='coadded')
    plt.legend()
    plt.title('order %d' %od)
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
s = fits.open('../galaxy_spectra/ESI_data/2019_01/B0631+519_0046_bgsub.fits')
for od, cd_sp, cd_var in zip(order_list, outsp, outvar):
    file_name1 = 'B0631_ESI_spectra/B0631_coadd2d_sp_order_' + str(od) + '.fits'
    file_name2 = 'B0631_ESI_spectra/B0631_coadd2d_var_order_' + str(od) + '.fits'
    fits.writeto(file_name1, cd_sp, header=s[od].header)
    fits.writeto(file_name2, cd_var, header=s[od].header)

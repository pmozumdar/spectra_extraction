# %%
from specim.specfuncs import spec1d
from astropy.io import fits
import numpy as np

# %%
sp = fits.open('../RXJ1131_arc.fits')

# %%
wave = np.arange(5215) * 0.5 + 3329.0

# %%
sp_arc = spec1d.Spec1d(wav=wave[800:-800], flux=sp[0].data[800:-800])
# Out:
#  Spectrum Start:  3729.00
#  Spectrum End:     5536.00
#  Dispersion (1st pixel):   0.50
#  Dispersion (average):      0.50

# %%
# %matplotlib notebook
sp_arc.smooth(1) # The integer input is the number of box to be used in smoothing
sp_arc.mark_lines('abs', z=0.655, usesmooth=True)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# Fe II         2375.00       3930.62
# Fe II         2383.00       3943.87
# Fe II         2587.00       4281.48
# Fe II         2600.00       4303.00
# Fe II         2750.30       4551.75
# Mg II         2795.53       4626.60
# Mg II         2802.71       4638.49
# Mg I          2852.00       4720.06

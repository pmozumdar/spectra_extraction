# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from astropy.table import Table
from astropy.modeling import models
from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, spec1d

# %%
file_loc = '../galaxy_spectra/ESI_data/*'

# %%
spec2d_file_list = []
var2d_file_list = []
#out_file = []
for i,p in enumerate(glob.glob(file_loc)):
    if 'J0924' in p:
        if 'bgsub.fits' in p:
            spec2d_file_list.append(p)
        elif 'var.fits' in p:
            var2d_file_list.append(p)

# %%
spec = esi2d.Esi2d(spec2d_file_list[1], varfile=var2d_file_list[1])
print(spec2d_file_list[1])
print(var2d_file_list[1])
# Out:
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3461x165     x
#   2   4093x145     x
#   3   4096x146     x
#   4   4096x141     x
#   5   4096x130     x
#   6   4096x127     x
#   7   4096x124     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x111     x
# ../galaxy_spectra/ESI_data/J0924+0219_0041_bgsub.fits
# ../galaxy_spectra/ESI_data/J0924+0219_0041_var.fits

# %%
spec.plot_2d()

# %%
pixrange = [(1900, 2400)]
for sp, info in zip(spec, spec.ordinfo):
    title = 'Spatial profile for ' + str(info['name'])
    sp.spatial_profile(pixrange=pixrange[0], title=title)
    plt.show()
    sp.initial_model()
# Out:
# Profile max value (before normalization) 73.196768
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 70, 110, 2
#
# amplitude=70.000000, mu=110.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 10, 116, 2
#
# amplitude=10.000000, mu=116.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 10, 125, 2
#
# amplitude=10.000000, mu=125.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.16011443)>
#
#     [1]: <Gaussian1D(amplitude=64.42404388, mean=110.92947028, stddev=2.96567262)>
#
#     [2]: <Gaussian1D(amplitude=10.19293592, mean=114.83481883, stddev=8.48014118)>
#
#     [3]: <Gaussian1D(amplitude=5.51649432, mean=125.96749614, stddev=2.64850688)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3            stddev_3
#     ------------------- ----------------- ... ------------------ -----------------
#     -0.1601144337346538 64.42404387970254 ... 125.96749614474145 2.648506881093665
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 102.552883
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 100, 102, 2
#
# amplitude=100.000000, mu=102.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 16, 108, 2
#
# amplitude=16.000000, mu=108.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 15, 116, 2
#
# amplitude=15.000000, mu=116.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.02362914)>
#
#     [1]: <Gaussian1D(amplitude=99.99719981, mean=101.98043794, stddev=2.91808228)>
#
#     [2]: <Gaussian1D(amplitude=8.43468681, mean=108.35628125, stddev=1.98198695)>
#
#     [3]: <Gaussian1D(amplitude=13.24893785, mean=114.96016969, stddev=3.5054278)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3            stddev_3
#     -------------------- ---------------- ... ------------------ -----------------
#     0.023629139841357952 99.9971998084847 ... 114.96016969242866 3.505427796748391
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 154.397818
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 150, 100, 2
#
# amplitude=150.000000, mu=100.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 30, 106, 2
#
# amplitude=30.000000, mu=106.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 20, 114, 2
#
# amplitude=20.000000, mu=114.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.17059785)>
#
#     [1]: <Gaussian1D(amplitude=152.31875397, mean=98.79755136, stddev=2.68936791)>
#
#     [2]: <Gaussian1D(amplitude=13.6665342, mean=104.82586979, stddev=1.65294052)>
#
#     [3]: <Gaussian1D(amplitude=20.016764, mean=111.23342593, stddev=3.59027188)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3            stddev_3
#     ------------------- ------------------ ... ------------------ ------------------
#     0.17059784655401758 152.31875396831643 ... 111.23342592941847 3.5902718817598087
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 189.689997
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 175, 96, 2
#
# amplitude=175.000000, mu=96.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 35, 101, 2
#
# amplitude=35.000000, mu=101.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 25, 108, 2
#
# amplitude=25.000000, mu=108.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.2306379)>
#
#     [1]: <Gaussian1D(amplitude=186.27180169, mean=95.93917818, stddev=2.53850415)>
#
#     [2]: <Gaussian1D(amplitude=18.42543005, mean=101.78516419, stddev=1.6151622)>
#
#     [3]: <Gaussian1D(amplitude=24.43550172, mean=107.56323474, stddev=3.35927364)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3            stddev_3
#     ------------------- ------------------ ... ------------------ ------------------
#     0.23063790337187134 186.27180169078434 ... 107.56323473504342 3.3592736435662913
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 220.397446
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 :  220, 93, 2
#
# amplitude=220.000000, mu=93.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 50, 98, 2
#
# amplitude=50.000000, mu=98.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 35, 106, 2
#
# amplitude=35.000000, mu=106.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.38246561)>
#
#     [1]: <Gaussian1D(amplitude=218.69127721, mean=92.45816357, stddev=2.50487285)>
#
#     [2]: <Gaussian1D(amplitude=20.8539552, mean=98.23995924, stddev=1.56559888)>
#
#     [3]: <Gaussian1D(amplitude=30.31678425, mean=103.4788837, stddev=3.20325774)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3            stddev_3
#     ------------------- ------------------ ... ------------------ -----------------
#     0.38246561446933275 218.69127720926465 ... 103.47888369736108 3.203257740405181
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 277.905045
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 260, 85, 2
#
# amplitude=260.000000, mu=85.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 55, 90, 2
#
# amplitude=55.000000, mu=90.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 40, 97, 2
#
# amplitude=40.000000, mu=97.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.38216819)>
#
#     [1]: <Gaussian1D(amplitude=273.74258938, mean=85.81108907, stddev=2.39856588)>
#
#     [2]: <Gaussian1D(amplitude=34.38995984, mean=91.0481233, stddev=1.52235097)>
#
#     [3]: <Gaussian1D(amplitude=43.14615564, mean=96.13909657, stddev=3.56427267)>
# Parameters:
#            c0_0           amplitude_1    ...       mean_3           stddev_3
#     ------------------ ----------------- ... ----------------- ------------------
#     0.3821681923322296 273.7425893823049 ... 96.13909657164258 3.5642726664468025
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 290.782916
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 280, 84, 2
#
# amplitude=280.000000, mu=84.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 80, 89, 2
#
# amplitude=80.000000, mu=89.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 50, 95, 2
#
# amplitude=50.000000, mu=95.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.37645039)>
#
#     [1]: <Gaussian1D(amplitude=282.0339564, mean=84.92015913, stddev=2.38206824)>
#
#     [2]: <Gaussian1D(amplitude=39.95947594, mean=89.89522296, stddev=1.61903623)>
#
#     [3]: <Gaussian1D(amplitude=52.28588301, mean=94.14931238, stddev=3.98526638)>
# Parameters:
#            c0_0           amplitude_1     ...       mean_3           stddev_3
#     ------------------ ------------------ ... ----------------- -----------------
#     0.3764503882662114 282.03395639692894 ... 94.14931237521064 3.985266375619554
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 288.759002
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 280, 83, 2
#
# amplitude=280.000000, mu=83.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 110, 88, 2
#
# amplitude=110.000000, mu=88.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 50, 95, 2
#
# amplitude=50.000000, mu=95.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.31917372)>
#
#     [1]: <Gaussian1D(amplitude=278.65272922, mean=83.56361205, stddev=2.26701279)>
#
#     [2]: <Gaussian1D(amplitude=42.26296845, mean=88.1235126, stddev=1.46026895)>
#
#     [3]: <Gaussian1D(amplitude=58.2610839, mean=91.49597671, stddev=4.08836843)>
# Parameters:
#            c0_0           amplitude_1    ...       mean_3           stddev_3
#     ------------------ ----------------- ... ----------------- ------------------
#     0.3191737220615865 278.6527292172731 ... 91.49597671241969 4.0883684250828525
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 288.236581
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 280, 80, 2
#
# amplitude=280.000000, mu=80.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 140, 85, 2
#
# amplitude=140.000000, mu=85.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 50, 91, 2
#
# amplitude=50.000000, mu=91.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.25515628)>
#
#     [1]: <Gaussian1D(amplitude=231.40636591, mean=80.26836116, stddev=1.92367075)>
#
#     [2]: <Gaussian1D(amplitude=37.05199183, mean=84.25678951, stddev=1.4147001)>
#
#     [3]: <Gaussian1D(amplitude=87.66966627, mean=84.97646741, stddev=5.51968055)>
# Parameters:
#             c0_0           amplitude_1    ...      mean_3           stddev_3
#     -------------------- ---------------- ... ---------------- -----------------
#     -0.25515628033380494 231.406365908643 ... 84.9764674135609 5.519680545859907
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# yes
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 290, 81, 2
#
# amplitude=290.000000, mu=81.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 130, 85.5, 2
#
# amplitude=130.000000, mu=85.500000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 50, 91, 2
#
# amplitude=50.000000, mu=91.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.02715579)>
#
#     [1]: <Gaussian1D(amplitude=242.64158497, mean=80.29865467, stddev=2.0967023)>
#
#     [2]: <Gaussian1D(amplitude=29.28328009, mean=84.71051463, stddev=1.22349268)>
#
#     [3]: <Gaussian1D(amplitude=81.53558451, mean=85.60104025, stddev=5.30061327)>
# Parameters:
#             c0_0            amplitude_1     ...       mean_3           stddev_3
#     -------------------- ------------------ ... ----------------- -----------------
#     0.027155785903657054 242.64158496923278 ... 85.60104025086815 5.300613269240257
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 26.795155
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 27, 80, 2
#
# amplitude=27.000000, mu=80.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 15, 84, 2
#
# amplitude=15.000000, mu=84.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 6, 90, 2
#
# amplitude=6.000000, mu=90.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.10717935)>
#
#     [1]: <Gaussian1D(amplitude=17.19194388, mean=78.67323306, stddev=1.90552357)>
#
#     [2]: <Gaussian1D(amplitude=-2.56755949, mean=78.66340837, stddev=5.33125308)>
#
#     [3]: <Gaussian1D(amplitude=15.09616698, mean=82.30021776, stddev=5.08673635)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3          stddev_3
#     ------------------- ----------------- ... ----------------- ----------------
#     -0.1071793498341334 17.19194387626277 ... 82.30021776444033 5.08673635166306
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# yes
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 27, 80, 2
#
# amplitude=27.000000, mu=80.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 15, 84, 2
#
# amplitude=15.000000, mu=84.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 5, 90, 2
#
# amplitude=5.000000, mu=90.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.11970551)>
#
#     [1]: <Gaussian1D(amplitude=17.53850653, mean=78.6313164, stddev=1.93739445)>
#
#     [2]: <Gaussian1D(amplitude=-2.55923682, mean=76.57075423, stddev=3.88751277)>
#
#     [3]: <Gaussian1D(amplitude=13.91358204, mean=82.23157046, stddev=5.20782534)>
# Parameters:
#             c0_0            amplitude_1     ...       mean_3           stddev_3
#     -------------------- ------------------ ... ----------------- -----------------
#     -0.11970550968013845 17.538506529776985 ... 82.23157045584983 5.207825335739639
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# yes
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 25, 79, 2
#
# amplitude=25.000000, mu=79.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 12, 84, 2
#
# amplitude=12.000000, mu=84.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 5, 90, 2
#
# amplitude=5.000000, mu=90.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.0792387)>
#
#     [1]: <Gaussian1D(amplitude=26.32780024, mean=79.02241484, stddev=2.34193166)>
#
#     [2]: <Gaussian1D(amplitude=10.04211576, mean=84.18074536, stddev=1.74652766)>
#
#     [3]: <Gaussian1D(amplitude=6.46281129, mean=88.58740779, stddev=2.39792408)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3           stddev_3
#     -------------------- ---------------- ... ----------------- ------------------
#     -0.07923870281415094 26.3278002425235 ... 88.58740779318356 2.3979240757166576
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no

# %%
def tie_pos1_gauss(model):
    #print(pixscale)
    return model.mean_1 + (0.87 / pixscale) #(0.886 / pixscale)

def tie_pos2_gauss(model):
    #print(pixscale)
    return model.mean_1 + (1.81 / pixscale) #(1.87 / pixscale)

def tie_stddev_gauss(model):
    return model.stddev_1

    
for sp, info in zip(spec, spec.ordinfo):
    if sp.mod0 is not None:
        pixscale = info['pixscale']
        sp.mod0[2].mean.tied = tie_pos1_gauss
        sp.mod0[3].mean.tied = tie_pos2_gauss
        sp.mod0[3].stddev.tied = tie_stddev_gauss
        sp.refined_model(sp.mod0)
# Out:
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.16011443)>
#
#     [1]: <Gaussian1D(amplitude=64.42404388, mean=110.92947028, stddev=2.96567262)>
#
#     [2]: <Gaussian1D(amplitude=10.19293592, mean=114.83481883, stddev=8.48014118)>
#
#     [3]: <Gaussian1D(amplitude=5.51649432, mean=125.96749614, stddev=2.64850688)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3            stddev_3
#     ------------------- ----------------- ... ------------------ -----------------
#     -0.1601144337346538 64.42404387970254 ... 125.96749614474145 2.648506881093665
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.14069178)>
#
#     [1]: <Gaussian1D(amplitude=67.36958715, mean=110.89972808, stddev=3.0875131)>
#
#     [2]: <Gaussian1D(amplitude=8.18988269, mean=118.14972808, stddev=8.71538441)>
#
#     [3]: <Gaussian1D(amplitude=3.69893196, mean=125.98306141, stddev=3.0875131)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3            stddev_3
#     ------------------- ----------------- ... ------------------ -----------------
#     -0.1406917759020632 67.36958714687167 ... 125.98306141499012 3.087513103509778
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.02362914)>
#
#     [1]: <Gaussian1D(amplitude=99.99719981, mean=101.98043794, stddev=2.91808228)>
#
#     [2]: <Gaussian1D(amplitude=8.43468681, mean=108.35628125, stddev=1.98198695)>
#
#     [3]: <Gaussian1D(amplitude=13.24893785, mean=114.96016969, stddev=3.5054278)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3            stddev_3
#     -------------------- ---------------- ... ------------------ -----------------
#     0.023629139841357952 99.9971998084847 ... 114.96016969242866 3.505427796748391
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.03503238)>
#
#     [1]: <Gaussian1D(amplitude=98.17687878, mean=101.8926994, stddev=2.87732572)>
#
#     [2]: <Gaussian1D(amplitude=11.12897358, mean=108.7430931, stddev=3.51572455)>
#
#     [3]: <Gaussian1D(amplitude=11.36046542, mean=116.14466791, stddev=2.87732572)>
# Parameters:
#             c0_0            amplitude_1    ...       mean_3            stddev_3
#     -------------------- ----------------- ... ------------------ ------------------
#     0.035032378507937105 98.17687878088857 ... 116.14466790501729 2.8773257200324136
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.17059785)>
#
#     [1]: <Gaussian1D(amplitude=152.31875397, mean=98.79755136, stddev=2.68936791)>
#
#     [2]: <Gaussian1D(amplitude=13.6665342, mean=104.82586979, stddev=1.65294052)>
#
#     [3]: <Gaussian1D(amplitude=20.016764, mean=111.23342593, stddev=3.59027188)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3            stddev_3
#     ------------------- ------------------ ... ------------------ ------------------
#     0.17059784655401758 152.31875396831643 ... 111.23342592941847 3.5902718817598087
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.22557346)>
#
#     [1]: <Gaussian1D(amplitude=151.07510775, mean=98.73695653, stddev=2.65426694)>
#
#     [2]: <Gaussian1D(amplitude=17.85238845, mean=105.22949384, stddev=2.68754474)>
#
#     [3]: <Gaussian1D(amplitude=19.56167945, mean=112.24441921, stddev=2.65426694)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3            stddev_3
#     ------------------- ------------------ ... ------------------ -----------------
#     0.22557346474911938 151.07510774731045 ... 112.24441921370827 2.654266940018169
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.2306379)>
#
#     [1]: <Gaussian1D(amplitude=186.27180169, mean=95.93917818, stddev=2.53850415)>
#
#     [2]: <Gaussian1D(amplitude=18.42543005, mean=101.78516419, stddev=1.6151622)>
#
#     [3]: <Gaussian1D(amplitude=24.43550172, mean=107.56323474, stddev=3.35927364)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3            stddev_3
#     ------------------- ------------------ ... ------------------ ------------------
#     0.23063790337187134 186.27180169078434 ... 107.56323473504342 3.3592736435662913
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.27020798)>
#
#     [1]: <Gaussian1D(amplitude=182.20184852, mean=95.83855083, stddev=2.48659712)>
#
#     [2]: <Gaussian1D(amplitude=24.46943104, mean=102.18891579, stddev=3.25696502)>
#
#     [3]: <Gaussian1D(amplitude=19.99173975, mean=109.05022966, stddev=2.48659712)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3            stddev_3
#     ------------------- ------------------ ... ------------------ -----------------
#     0.27020797869823043 182.20184851524988 ... 109.05022966342011 2.486597119550633
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.38246561)>
#
#     [1]: <Gaussian1D(amplitude=218.69127721, mean=92.45816357, stddev=2.50487285)>
#
#     [2]: <Gaussian1D(amplitude=20.8539552, mean=98.23995924, stddev=1.56559888)>
#
#     [3]: <Gaussian1D(amplitude=30.31678425, mean=103.4788837, stddev=3.20325774)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3            stddev_3
#     ------------------- ------------------ ... ------------------ -----------------
#     0.38246561446933275 218.69127720926465 ... 103.47888369736108 3.203257740405181
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.44143196)>
#
#     [1]: <Gaussian1D(amplitude=212.48525085, mean=92.33360323, stddev=2.43528756)>
#
#     [2]: <Gaussian1D(amplitude=30.0828059, mean=98.37526989, stddev=3.3235342)>
#
#     [3]: <Gaussian1D(amplitude=23.39959129, mean=104.90304767, stddev=2.43528756)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3            stddev_3
#     ------------------- ------------------ ... ------------------ -----------------
#     0.44143195530262325 212.48525084593584 ... 104.90304767147579 2.435287563850504
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.38216819)>
#
#     [1]: <Gaussian1D(amplitude=273.74258938, mean=85.81108907, stddev=2.39856588)>
#
#     [2]: <Gaussian1D(amplitude=34.38995984, mean=91.0481233, stddev=1.52235097)>
#
#     [3]: <Gaussian1D(amplitude=43.14615564, mean=96.13909657, stddev=3.56427267)>
# Parameters:
#            c0_0           amplitude_1    ...       mean_3           stddev_3
#     ------------------ ----------------- ... ----------------- ------------------
#     0.3821681923322296 273.7425893823049 ... 96.13909657164258 3.5642726664468025
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.49880003)>
#
#     [1]: <Gaussian1D(amplitude=268.40359893, mean=85.72260198, stddev=2.3574163)>
#
#     [2]: <Gaussian1D(amplitude=51.14586698, mean=91.56152816, stddev=2.68879627)>
#
#     [3]: <Gaussian1D(amplitude=36.70092565, mean=97.87025299, stddev=2.3574163)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3           stddev_3
#     ------------------- ----------------- ... ----------------- ------------------
#     0.49880002696133063 268.4035989300597 ... 97.87025298986859 2.3574163020063166
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.37645039)>
#
#     [1]: <Gaussian1D(amplitude=282.0339564, mean=84.92015913, stddev=2.38206824)>
#
#     [2]: <Gaussian1D(amplitude=39.95947594, mean=89.89522296, stddev=1.61903623)>
#
#     [3]: <Gaussian1D(amplitude=52.28588301, mean=94.14931238, stddev=3.98526638)>
# Parameters:
#            c0_0           amplitude_1     ...       mean_3           stddev_3
#     ------------------ ------------------ ... ----------------- -----------------
#     0.3764503882662114 282.03395639692894 ... 94.14931237521064 3.985266375619554
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.52815848)>
#
#     [1]: <Gaussian1D(amplitude=277.04983291, mean=84.85587161, stddev=2.36448987)>
#
#     [2]: <Gaussian1D(amplitude=70.76791662, mean=90.54214612, stddev=2.66851526)>
#
#     [3]: <Gaussian1D(amplitude=39.52700652, mean=96.68593697, stddev=2.36448987)>
# Parameters:
#            c0_0           amplitude_1    ...       mean_3           stddev_3
#     ------------------ ----------------- ... ----------------- -----------------
#     0.5281584819434574 277.0498329091456 ... 96.68593696547441 2.364489873480846
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.31917372)>
#
#     [1]: <Gaussian1D(amplitude=278.65272922, mean=83.56361205, stddev=2.26701279)>
#
#     [2]: <Gaussian1D(amplitude=42.26296845, mean=88.1235126, stddev=1.46026895)>
#
#     [3]: <Gaussian1D(amplitude=58.2610839, mean=91.49597671, stddev=4.08836843)>
# Parameters:
#            c0_0           amplitude_1    ...       mean_3           stddev_3
#     ------------------ ----------------- ... ----------------- ------------------
#     0.3191737220615865 278.6527292172731 ... 91.49597671241969 4.0883684250828525
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.38384613)>
#
#     [1]: <Gaussian1D(amplitude=277.05281164, mean=83.55241613, stddev=2.29614509)>
#
#     [2]: <Gaussian1D(amplitude=80.27716631, mean=89.05874524, stddev=2.62215145)>
#
#     [3]: <Gaussian1D(amplitude=35.59128106, mean=95.00811233, stddev=2.29614509)>
# Parameters:
#             c0_0           amplitude_1    ...      mean_3           stddev_3
#     ------------------- ----------------- ... ---------------- ------------------
#     0.38384613405459167 277.0528116375737 ... 95.0081123290341 2.2961450855950787
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.02715579)>
#
#     [1]: <Gaussian1D(amplitude=242.64158497, mean=80.29865467, stddev=2.0967023)>
#
#     [2]: <Gaussian1D(amplitude=29.28328009, mean=84.71051463, stddev=1.22349268)>
#
#     [3]: <Gaussian1D(amplitude=81.53558451, mean=85.60104025, stddev=5.30061327)>
# Parameters:
#             c0_0            amplitude_1     ...       mean_3           stddev_3
#     -------------------- ------------------ ... ----------------- -----------------
#     0.027155785903657054 242.64158496923278 ... 85.60104025086815 5.300613269240257
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.3165888)>
#
#     [1]: <Gaussian1D(amplitude=278.45260863, mean=80.37868381, stddev=2.24305125)>
#
#     [2]: <Gaussian1D(amplitude=95.32635571, mean=85.71610713, stddev=2.50193086)>
#
#     [3]: <Gaussian1D(amplitude=40.88660799, mean=91.48297829, stddev=2.24305125)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3           stddev_3
#     ------------------- ------------------ ... ----------------- ------------------
#     0.31658879631352693 278.45260862751104 ... 91.48297829327261 2.2430512507251135
#
# -------------------------------------------
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.0792387)>
#
#     [1]: <Gaussian1D(amplitude=26.32780024, mean=79.02241484, stddev=2.34193166)>
#
#     [2]: <Gaussian1D(amplitude=10.04211576, mean=84.18074536, stddev=1.74652766)>
#
#     [3]: <Gaussian1D(amplitude=6.46281129, mean=88.58740779, stddev=2.39792408)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3           stddev_3
#     -------------------- ---------------- ... ----------------- ------------------
#     -0.07923870281415094 26.3278002425235 ... 88.58740779318356 2.3979240757166576
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.07427776)>
#
#     [1]: <Gaussian1D(amplitude=24.67804332, mean=78.70998732, stddev=2.16489254)>
#
#     [2]: <Gaussian1D(amplitude=12.02184138, mean=83.88855875, stddev=2.53458133)>
#
#     [3]: <Gaussian1D(amplitude=4.88649746, mean=89.48379684, stddev=2.16489254)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3           stddev_3
#     ------------------- ----------------- ... ----------------- -----------------
#     -0.0742777612687433 24.67804332214842 ... 89.48379684286711 2.164892544789472
#
# -------------------------------------------

# %%
outspec = spec.extract_all(method='cdf', plot_profiles=False, plot_traces=True, plot_extracted=False,
                           stepsize=25, pixrange=[0, -1, 2200, -1], level=-20, fit_dict={10 : [0, 2000]}, 
                           extrange_dict={10 : [0, 2000]}, 
                           fitorder_dict={'common':{'mean_1': 4, 'mean_2':4, 'mean_3':4}})
# Out:
# Extracting spectra
# ------------------
# Order_01
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: mean_2
# Fitting polynomial of degree 3 to parameter: stddev_2
# Fitting polynomial of degree 4 to parameter: mean_3
# Fitting polynomial of degree 3 to parameter: stddev_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1500 - 3000
# Fitting to the trace at 3461 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  4071.46
#  Spectrum End:     4310.06
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.16
#
#  Spectrum Start:  4071.46
#  Spectrum End:     4310.06
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.16
#
#  Spectrum Start:  4071.46
#  Spectrum End:     4310.06
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.16
#
#
# Plotting the spectrum
# Order_02
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: mean_2
# Fitting polynomial of degree 3 to parameter: stddev_2
# Fitting polynomial of degree 4 to parameter: mean_3
# Fitting polynomial of degree 3 to parameter: stddev_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1400 - 3400
# Fitting to the trace at 4093 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  4240.70
#  Spectrum End:     4575.32
#  Dispersion (1st pixel):   0.16
#  Dispersion (average):      0.17
#
#  Spectrum Start:  4240.70
#  Spectrum End:     4575.32
#  Dispersion (1st pixel):   0.16
#  Dispersion (average):      0.17
#
#  Spectrum Start:  4240.70
#  Spectrum End:     4575.32
#  Dispersion (1st pixel):   0.16
#  Dispersion (average):      0.17
#
#
# Plotting the spectrum
# Order_03
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: mean_2
# Fitting polynomial of degree 3 to parameter: stddev_2
# Fitting polynomial of degree 4 to parameter: mean_3
# Fitting polynomial of degree 3 to parameter: stddev_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1300 - 3700
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  4546.04
#  Spectrum End:     4979.85
#  Dispersion (1st pixel):   0.17
#  Dispersion (average):      0.18
#
#  Spectrum Start:  4546.04
#  Spectrum End:     4979.85
#  Dispersion (1st pixel):   0.17
#  Dispersion (average):      0.18
#
#  Spectrum Start:  4546.04
#  Spectrum End:     4979.85
#  Dispersion (1st pixel):   0.17
#  Dispersion (average):      0.18
#
#
# Plotting the spectrum
# Order_04
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: mean_2
# Fitting polynomial of degree 3 to parameter: stddev_2
# Fitting polynomial of degree 4 to parameter: mean_3
# Fitting polynomial of degree 3 to parameter: stddev_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1200 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#
# Plotting the spectrum
# Order_05
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: mean_2
# Fitting polynomial of degree 3 to parameter: stddev_2
# Fitting polynomial of degree 4 to parameter: mean_3
# Fitting polynomial of degree 3 to parameter: stddev_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1100 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  5325.24
#  Spectrum End:     5967.01
#  Dispersion (1st pixel):   0.20
#  Dispersion (average):      0.21
#
#  Spectrum Start:  5325.24
#  Spectrum End:     5967.01
#  Dispersion (1st pixel):   0.20
#  Dispersion (average):      0.21
#
#  Spectrum Start:  5325.24
#  Spectrum End:     5967.01
#  Dispersion (1st pixel):   0.20
#  Dispersion (average):      0.21
#
#
# Plotting the spectrum
# Order_06
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: mean_2
# Fitting polynomial of degree 3 to parameter: stddev_2
# Fitting polynomial of degree 4 to parameter: mean_3
# Fitting polynomial of degree 3 to parameter: stddev_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 900 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  5810.63
#  Spectrum End:     6560.55
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#  Spectrum Start:  5810.63
#  Spectrum End:     6560.55
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#  Spectrum Start:  5810.63
#  Spectrum End:     6560.55
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#
# Plotting the spectrum
# Order_07
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: mean_2
# Fitting polynomial of degree 3 to parameter: stddev_2
# Fitting polynomial of degree 4 to parameter: mean_3
# Fitting polynomial of degree 3 to parameter: stddev_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 600 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  6380.37
#  Spectrum End:     7286.41
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#  Spectrum Start:  6380.37
#  Spectrum End:     7286.41
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#  Spectrum Start:  6380.37
#  Spectrum End:     7286.41
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#
# Plotting the spectrum
# Order_08
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: mean_2
# Fitting polynomial of degree 3 to parameter: stddev_2
# Fitting polynomial of degree 4 to parameter: mean_3
# Fitting polynomial of degree 3 to parameter: stddev_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 200 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  7066.66
#  Spectrum End:     8193.74
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29
#
#  Spectrum Start:  7066.66
#  Spectrum End:     8193.74
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29
#
#  Spectrum Start:  7066.66
#  Spectrum End:     8193.74
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29
#
#
# Plotting the spectrum
# Order_09
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: mean_2
# Fitting polynomial of degree 3 to parameter: stddev_2
# Fitting polynomial of degree 4 to parameter: mean_3
# Fitting polynomial of degree 3 to parameter: stddev_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 0 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  8012.11
#  Spectrum End:     9360.83
#  Dispersion (1st pixel):   0.30
#  Dispersion (average):      0.33
#
#  Spectrum Start:  8012.11
#  Spectrum End:     9360.83
#  Dispersion (1st pixel):   0.30
#  Dispersion (average):      0.33
#
#  Spectrum Start:  8012.11
#  Spectrum End:     9360.83
#  Dispersion (1st pixel):   0.30
#  Dispersion (average):      0.33
#
#
# Plotting the spectrum
# Order_10
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: mean_2
# Fitting polynomial of degree 3 to parameter: stddev_2
# Fitting polynomial of degree 4 to parameter: mean_3
# Fitting polynomial of degree 3 to parameter: stddev_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 0 - 2000
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  9337.74
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.35
#  Dispersion (average):      0.37
#
#  Spectrum Start:  9337.74
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.35
#  Dispersion (average):      0.37
#
#  Spectrum Start:  9337.74
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.35
#  Dispersion (average):      0.37
#
#
# Plotting the spectrum
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   1  1500   4071.46  4310.06   0.16
#   2  2000   4240.70  4575.32   0.17
#   3  2400   4546.04  4979.85   0.18
#   4  2896   4902.88  5472.92   0.20
#   5  2996   5325.24  5967.01   0.21
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.66  8193.74   0.29
#   9  4096   8012.11  9360.83   0.33
#  10  2000   9337.74 10074.55   0.37
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   1  1500   4071.46  4310.06   0.16
#   2  2000   4240.70  4575.32   0.17
#   3  2400   4546.04  4979.85   0.18
#   4  2896   4902.88  5472.92   0.20
#   5  2996   5325.24  5967.01   0.21
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.66  8193.74   0.29
#   9  4096   8012.11  9360.83   0.33
#  10  2000   9337.74 10074.55   0.37
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   1  1500   4071.46  4310.06   0.16
#   2  2000   4240.70  4575.32   0.17
#   3  2400   4546.04  4979.85   0.18
#   4  2896   4902.88  5472.92   0.20
#   5  2996   5325.24  5967.01   0.21
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.66  8193.74   0.29
#   9  4096   8012.11  9360.83   0.33
#  10  2000   9337.74 10074.55   0.37

# %%
outspec[0].save_multi('esi1d_J0924_41_gauss_primary_new')
outspec[1].save_multi('esi1d_J0924_41_gauss_secondary_new')
outspec[2].save_multi('esi1d_J0924_41_gauss_tertiary_new')
# Out:
# Spectrum saved in mode multitab to file esi1d_J0924_41_gauss_primary_new.fits
# Spectrum saved in mode multitab to file esi1d_J0924_41_gauss_secondary_new.fits
# Spectrum saved in mode multitab to file esi1d_J0924_41_gauss_tertiary_new.fits

# %%
outspec[0].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt')
# Out:
#  Spectrum Start:  4071.46
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.25

# %%
outspec[1].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt')
# Out:
#  Spectrum Start:  4071.46
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.25

# %%
outspec[2].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt')
# Out:
#  Spectrum Start:  4071.46
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.25

# %%
outspec[0].spec1d.save('spec1d_J0924_41_gauss_primary.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0924_41_gauss_primary.fits in format fits

# %%
outspec[1].spec1d.save('spec1d_J0924_41_gauss_secondary.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0924_41_gauss_secondary.fits in format fits

# %%
outspec[2].spec1d.save('spec1d_J0924_41_gauss_tertiary.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0924_41_gauss_tertiary.fits in format fits

# %%
outspec[1].spec1d.smooth(11)

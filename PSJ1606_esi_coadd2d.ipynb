# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from astropy.io import fits
from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, spec1d, echelle1d
from scipy.ndimage import shift

# %%
file_loc = '../galaxy_spectra/ESI_data/2019_04/*'

# %%
spec2d_file_list = []
var2d_file_list = []
#out_file = []
for i,p in enumerate(glob.glob(file_loc)):
    if 'PSJ1606' in p:
        if 'bgsub.fits' in p:
            spec2d_file_list.append(p)
        elif 'var.fits' in p:
            var2d_file_list.append(p)

# %%
spec2d_file_list, var2d_file_list
# Out:
# (['../galaxy_spectra/ESI_data/2019_04/PSJ1606-2333_0047_bgsub.fits',
#   '../galaxy_spectra/ESI_data/2019_04/PSJ1606-2333_0048_bgsub.fits',
#   '../galaxy_spectra/ESI_data/2019_04/PSJ1606-2333_0046_bgsub.fits'],
#  ['../galaxy_spectra/ESI_data/2019_04/PSJ1606-2333_0046_var.fits',
#   '../galaxy_spectra/ESI_data/2019_04/PSJ1606-2333_0048_var.fits',
#   '../galaxy_spectra/ESI_data/2019_04/PSJ1606-2333_0047_var.fits'])

# %%
# create a list of spec2d object for particular order
spec1 = esi2d.Esi2d(spec2d_file_list[2], varfile=var2d_file_list[0])
spec2 = esi2d.Esi2d(spec2d_file_list[0], varfile=var2d_file_list[2])
spec3 = esi2d.Esi2d(spec2d_file_list[1], varfile=var2d_file_list[1])
# Out:
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3466x163     x
#   2   4093x154     x
#   3   4096x147     x
#   4   4096x140     x
#   5   4096x136     x
#   6   4096x128     x
#   7   4096x126     x
#   8   4096x121     x
#   9   4096x116     x
#  10   4096x115     x
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3466x163     x
#   2   4093x154     x
#   3   4096x147     x
#   4   4096x140     x
#   5   4096x136     x
#   6   4096x128     x
#   7   4096x126     x
#   8   4096x121     x
#   9   4096x116     x
#  10   4096x115     x
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3466x163     x
#   2   4093x154     x
#   3   4096x147     x
#   4   4096x140     x
#   5   4096x136     x
#   6   4096x128     x
#   7   4096x126     x
#   8   4096x121     x
#   9   4096x116     x
#  10   4096x115     x

# %%
pixrange = [[2200, 2600],[2200, 2600], [2700, 3100], [2100, 2500], [1800, 2200],
            [1600, 2000], [1500, 1900], [800, 1200]]
spec_list = [spec1, spec2, spec3]
order_list = spec1.ordinfo

for order, pix in zip(order_list[2:], pixrange):
    print(order['name'], 'pixscale:', order['pixscale'])
    for sp in spec_list:
        profile = sp[order['order']-1].spatial_profile(pixrange=pix)
        plt.show()
        sp[order['order']-1].initial_model()
# Out:
# Order_03 pixscale: 0.134
# Profile max value (before normalization) 62.838100
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 62, 71, 3, 4
#
# amplitude=62.000000, x_0=71.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 55, 61, 3, 4
#
# amplitude=55.000000, x_0=61.000000, gamma=3.000000, alpha=4.000000
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.01574674)>
#
#     [1]: <Moffat1D(amplitude=61.05860408, x_0=72.69535392, gamma=22.88375477, alpha=10.26548242)>
#
#     [2]: <Moffat1D(amplitude=48.68137671, x_0=62.12203963, gamma=12.9966091, alpha=5.92068084)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_2            alpha_2
#     -------------------- ------------------ ... ------------------ -----------------
#     -0.01574673992300219 61.058604075212436 ... 12.996609096862185 5.920680841035911
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 68.023031
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 68, 106, 3, 4
#
# amplitude=68.000000, x_0=106.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 62, 97, 3, 4
#
# amplitude=62.000000, x_0=97.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=0.36685141)>
#
#     [1]: <Moffat1D(amplitude=65.20960574, x_0=109.02924502, gamma=16.49205298, alpha=7.01298896)>
#
#     [2]: <Moffat1D(amplitude=58.48346878, x_0=98.7489045, gamma=12.26232247, alpha=5.74975762)>
# Parameters:
#            c0_0           amplitude_1    ...      gamma_2            alpha_2
#     ------------------ ----------------- ... ------------------ -----------------
#     0.3668514129036654 65.20960574425168 ... 12.262322467895736 5.749757624944754
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 64.808147
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 65, 33, 3, 4
#
# amplitude=65.000000, x_0=33.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 60, 22, 3, 4
#
# amplitude=60.000000, x_0=22.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=0.06915501)>
#
#     [1]: <Moffat1D(amplitude=62.26356535, x_0=33.86607711, gamma=22.03632916, alpha=10.71626126)>
#
#     [2]: <Moffat1D(amplitude=52.24011558, x_0=23.37479541, gamma=17.86713651, alpha=10.25419455)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2           alpha_2
#     ------------------- ----------------- ... ----------------- ------------------
#     0.06915500952827244 62.26356534662993 ... 17.86713650936855 10.254194546193958
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_04 pixscale: 0.137
# Profile max value (before normalization) 140.771087
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 140, 68, 3, 4
#
# amplitude=140.000000, x_0=68.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 120, 58, 3, 4
#
# amplitude=120.000000, x_0=58.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.66775058)>
#
#     [1]: <Moffat1D(amplitude=136.58170632, x_0=69.63085833, gamma=19.81537707, alpha=8.69357998)>
#
#     [2]: <Moffat1D(amplitude=105.8299956, x_0=59.56156534, gamma=11.59285303, alpha=5.32798498)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ -----------------
#     -0.6677505751304373 136.58170632236983 ... 11.592853032070433 5.327984977002269
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 145.985789
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 145, 105, 3, 4
#
# amplitude=145.000000, x_0=105.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 125, 95, 3, 4
#
# amplitude=125.000000, x_0=95.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.66116103)>
#
#     [1]: <Moffat1D(amplitude=144.64423632, x_0=104.44993187, gamma=14.41265722, alpha=5.89442443)>
#
#     [2]: <Moffat1D(amplitude=119.71094022, x_0=94.53471642, gamma=10.07901475, alpha=4.44430754)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------ ------------------ ... ------------------ -----------------
#     -0.661161030307923 144.64423632226362 ... 10.079014745994273 4.444307539976773
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 135.847277
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 135, 32, 3, 4
#
# amplitude=135.000000, x_0=32.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 120, 21, 3, 4
#
# amplitude=120.000000, x_0=21.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.45487508)>
#
#     [1]: <Moffat1D(amplitude=133.97661827, x_0=33.07127922, gamma=30.04230659, alpha=20.8140528)>
#
#     [2]: <Moffat1D(amplitude=107.60204243, x_0=23.01682725, gamma=14.80741259, alpha=8.01206821)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2            alpha_2
#     ------------------- ----------------- ... ------------------ -----------------
#     -0.4548750828285223 133.9766182667798 ... 14.807412593799054 8.012068207567067
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_05 pixscale: 0.144
# Profile max value (before normalization) 119.027620
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 120, 67, 3, 4
#
# amplitude=120.000000, x_0=67.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 105, 58, 3, 4
#
# amplitude=105.000000, x_0=58.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.56553937)>
#
#     [1]: <Moffat1D(amplitude=114.45317872, x_0=68.6084319, gamma=17.09836398, alpha=7.9731685)>
#
#     [2]: <Moffat1D(amplitude=95.31539017, x_0=58.92655249, gamma=14.56586133, alpha=7.66748836)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ -----------------
#     -0.5655393661357481 114.45317871604769 ... 14.565861332717864 7.667488358248988
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 123.763023
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 120, 103, 3, 4
#
# amplitude=120.000000, x_0=103.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 105, 91, 3, 4
#
# amplitude=105.000000, x_0=91.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.41727015)>
#
#     [1]: <Moffat1D(amplitude=120.39810504, x_0=102.03796078, gamma=35.77124432, alpha=35.55243409)>
#
#     [2]: <Moffat1D(amplitude=104.08814694, x_0=92.26834309, gamma=11.43118974, alpha=5.50191169)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2           alpha_2
#     ------------------- ------------------ ... ----------------- ------------------
#     -0.4172701531096766 120.39810503814422 ... 11.43118973704981 5.5019116912204336
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 113.189505
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 110, 33, 3, 4
#
# amplitude=110.000000, x_0=33.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 100, 21, 3, 4
#
# amplitude=100.000000, x_0=21.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.52114702)>
#
#     [1]: <Moffat1D(amplitude=110.59976599, x_0=33.94618035, gamma=29.6740071, alpha=22.68715136)>
#
#     [2]: <Moffat1D(amplitude=94.73626872, x_0=24.08288624, gamma=15.77186176, alpha=8.66683827)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ -----------------
#     -0.5211470155646651 110.59976598531946 ... 15.771861764078196 8.666838270792384
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_06 pixscale: 0.149
# Profile max value (before normalization) 136.716398
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 135, 62, 3, 4
#
# amplitude=135.000000, x_0=62.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 115, 50, 3, 4
#
# amplitude=115.000000, x_0=50.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.5770316)>
#
#     [1]: <Moffat1D(amplitude=133.23270009, x_0=62.50728596, gamma=25.9912045, alpha=16.70362129)>
#
#     [2]: <Moffat1D(amplitude=97.89579208, x_0=53.18637312, gamma=15.99053089, alpha=10.40798598)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ ------------------
#     -0.5770315970278201 133.23270008567812 ... 15.990530886735224 10.407985980133589
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 143.356984
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 140, 95, 3, 4
#
# amplitude=140.000000, x_0=95.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 120, 84, 3, 4
#
# amplitude=120.000000, x_0=84.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.44634205)>
#
#     [1]: <Moffat1D(amplitude=138.65251971, x_0=94.94303248, gamma=26.18812329, alpha=20.36023128)>
#
#     [2]: <Moffat1D(amplitude=110.97988559, x_0=85.75241306, gamma=11.95009909, alpha=6.36508964)>
# Parameters:
#            c0_0           amplitude_1    ...      gamma_2            alpha_2
#     ------------------ ----------------- ... ------------------ -----------------
#     -0.446342051928428 138.6525197106817 ... 11.950099089447493 6.365089635316263
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 130.006677
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 130, 28, 3, 4
#
# amplitude=130.000000, x_0=28.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 115, 18, 3, 4
#
# amplitude=115.000000, x_0=18.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.41666376)>
#
#     [1]: <Moffat1D(amplitude=124.40015765, x_0=29.68072905, gamma=17.40299134, alpha=9.41022289)>
#
#     [2]: <Moffat1D(amplitude=103.91083156, x_0=20.31274157, gamma=20.24523956, alpha=12.99654862)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_2           alpha_2
#     -------------------- ------------------ ... ----------------- ------------------
#     -0.41666375643425124 124.40015765291578 ... 20.24523955547536 12.996548618484027
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_07 pixscale: 0.153
# Profile max value (before normalization) 159.785504
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 159, 61, 3, 4
#
# amplitude=159.000000, x_0=61.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 130, 50, 3, 4
#
# amplitude=130.000000, x_0=50.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.65935812)>
#
#     [1]: <Moffat1D(amplitude=156.63397566, x_0=61.54989908, gamma=23.80601935, alpha=14.1196016)>
#
#     [2]: <Moffat1D(amplitude=102.72092907, x_0=52.62100325, gamma=18.93204471, alpha=14.81649639)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ ------------------
#     -0.6593581203812491 156.63397566058134 ... 18.932044714972818 14.816496391156411
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 165.752785
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 165, 94, 3, 4
#
# amplitude=165.000000, x_0=94.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 125, 83, 3, 4
#
# amplitude=125.000000, x_0=83.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.53885311)>
#
#     [1]: <Moffat1D(amplitude=161.47924664, x_0=93.27517819, gamma=19.65838823, alpha=11.03982397)>
#
#     [2]: <Moffat1D(amplitude=112.88305055, x_0=84.45869021, gamma=14.72282155, alpha=9.27834597)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ -----------------
#     -0.5388531100734497 161.47924663504583 ... 14.722821554858331 9.278345966593665
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 153.836732
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 150, 28, 3, 4
#
# amplitude=150.000000, x_0=28.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 130, 17, 3, 4
#
# amplitude=130.000000, x_0=17.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.55058081)>
#
#     [1]: <Moffat1D(amplitude=147.22252242, x_0=30.02907984, gamma=14.16377041, alpha=6.34805298)>
#
#     [2]: <Moffat1D(amplitude=113.62233636, x_0=21.09798941, gamma=20.85498069, alpha=14.03911376)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------ ------------------ ... ------------------ ------------------
#     -0.550580813487541 147.22252242093418 ... 20.854980693191354 14.039113755270323
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_08 pixscale: 0.158
# Profile max value (before normalization) 265.685559
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 265, 59, 3, 4
#
# amplitude=265.000000, x_0=59.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 170, 48, 3, 4
#
# amplitude=170.000000, x_0=48.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=0.02189928)>
#
#     [1]: <Moffat1D(amplitude=263.02477926, x_0=58.06376997, gamma=44.95304276, alpha=38.82757532)>
#
#     [2]: <Moffat1D(amplitude=116.91910948, x_0=49.53458995, gamma=7.35564433, alpha=3.42803099)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_2           alpha_2
#     -------------------- ------------------ ... ----------------- -----------------
#     0.021899275500407257 263.02477925550994 ... 7.355644330371625 3.428030988685739
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 269.818189
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 270, 91, 3, 4
#
# amplitude=270.000000, x_0=91.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 200, 80, 3, 4
#
# amplitude=200.000000, x_0=80.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.90602328)>
#
#     [1]: <Moffat1D(amplitude=263.0126466, x_0=89.37425963, gamma=20.60082216, alpha=11.44021395)>
#
#     [2]: <Moffat1D(amplitude=150.01906518, x_0=81.14671227, gamma=15.47299457, alpha=10.67149469)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2            alpha_2
#     ------------------- ----------------- ... ------------------ ------------------
#     -0.9060232844385689 263.0126465982946 ... 15.472994573081447 10.671494690473809
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 255.821462
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 250, 28, 3, 4
#
# amplitude=250.000000, x_0=28.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 200, 18, 3, 4
#
# amplitude=200.000000, x_0=18.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.82064492)>
#
#     [1]: <Moffat1D(amplitude=241.13256991, x_0=28.31222006, gamma=18.14289012, alpha=9.79599994)>
#
#     [2]: <Moffat1D(amplitude=167.95749438, x_0=19.87688797, gamma=23.02251861, alpha=17.81392403)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ ------------------
#     -0.8206449195653107 241.13256991134176 ... 23.022518608439718 17.813924026187077
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_09 pixscale: 0.163
# Profile max value (before normalization) 165.547650
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 165, 58, 3, 4
#
# amplitude=165.000000, x_0=58.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 130, 47, 3, 4
#
# amplitude=130.000000, x_0=47.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.12856988)>
#
#     [1]: <Moffat1D(amplitude=165.86495066, x_0=55.72948044, gamma=20.80859278, alpha=10.20904034)>
#
#     [2]: <Moffat1D(amplitude=74.47778128, x_0=47.6857307, gamma=14.52575477, alpha=10.61375769)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_2            alpha_2
#     -------------------- ------------------ ... ------------------ -----------------
#     -0.12856987623635824 165.86495066322286 ... 14.525754773098729 10.61375768795844
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 172.235586
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 170, 86, 3, 4
#
# amplitude=170.000000, x_0=86.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 130, 75, 3, 4
#
# amplitude=130.000000, x_0=75.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.05632478)>
#
#     [1]: <Moffat1D(amplitude=164.13016014, x_0=86.35628173, gamma=19.19765463, alpha=10.56848421)>
#
#     [2]: <Moffat1D(amplitude=97.4691897, x_0=78.51313029, gamma=23.74446499, alpha=22.08528897)>
# Parameters:
#              c0_0            amplitude_1     ...      alpha_2
#     --------------------- ------------------ ... ------------------
#     -0.056324776972855845 164.13016013573218 ... 22.085288973536443
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 163.510911
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 160, 27, 3, 4
#
# amplitude=160.000000, x_0=27.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 125, 17, 3, 4
#
# amplitude=125.000000, x_0=17.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.59231793)>
#
#     [1]: <Moffat1D(amplitude=150.86972467, x_0=27.03148779, gamma=17.67053715, alpha=9.96918566)>
#
#     [2]: <Moffat1D(amplitude=111.19885899, x_0=18.99720138, gamma=22.12657474, alpha=16.54453283)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2           alpha_2
#     ------------------- ------------------ ... ------------------ ----------------
#     -0.5923179255842564 150.86972467266756 ... 22.126574744240774 16.5445328267132
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_10 pixscale: 0.168
# Profile max value (before normalization) 44.120266
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 40, 56, 3, 4
#
# amplitude=40.000000, x_0=56.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 30, 46, 3, 4
#
# amplitude=30.000000, x_0=46.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=0.02701191)>
#
#     [1]: <Moffat1D(amplitude=44.38509842, x_0=54.87374574, gamma=28.04558815, alpha=16.78468404)>
#
#     [2]: <Moffat1D(amplitude=14.95835444, x_0=47.16192306, gamma=6.85288706, alpha=3.41367782)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2           alpha_2
#     -------------------- ---------------- ... ----------------- -----------------
#     0.027011909186549755 44.3850984189664 ... 6.852887059960134 3.413677824349171
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 46.412002
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 46, 84, 3, 4
#
# amplitude=46.000000, x_0=84.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 30, 77, 3, 4
#
# amplitude=30.000000, x_0=77.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=0.15828551)>
#
#     [1]: <Moffat1D(amplitude=40.58849451, x_0=85.75086559, gamma=14.65462546, alpha=7.96983218)>
#
#     [2]: <Moffat1D(amplitude=30.3565797, x_0=78.58315074, gamma=18.42610331, alpha=12.8130111)>
# Parameters:
#             c0_0          amplitude_1    ...      gamma_2            alpha_2
#     ------------------- ---------------- ... ------------------ -----------------
#     0.15828551281943812 40.5884945106257 ... 18.426103310247214 12.81301110097591
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 45.307809
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 45, 27, 3, 4
#
# amplitude=45.000000, x_0=27.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 30, 19, 3, 4
#
# amplitude=30.000000, x_0=19.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=0.09226689)>
#
#     [1]: <Moffat1D(amplitude=38.90869053, x_0=27.46067438, gamma=14.5774317, alpha=7.53657536)>
#
#     [2]: <Moffat1D(amplitude=31.28440234, x_0=19.87543431, gamma=15.01587005, alpha=7.50187514)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2            alpha_2
#     ------------------- ----------------- ... ------------------ -----------------
#     0.09226689117046391 38.90869052838963 ... 15.015870049817991 7.501875140698226
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no

# %%
[0.70, -36.33, 38.83], [0.63, -34.82, 36.56], [0.61, -33.43, 34.66],
                        [0.51, -32.43, 32.83], [0.55, -31.73, 31.52],
                        [0.06, -31.31, 29.75], [0.73, -30.63, 28.70], [0.87, -30.88, 27.41]

# %%
order_list = [3, 4, 5, 6, 7, 8, 9, 10]
spec_list = [spec1, spec2, spec3]
shifted_sp = []
shifted_var = []
shift_pixel = np.array([[0.0, -36.33, 38.83], [0.0, -34.82, 36.56], [0.0, -33.43, 34.66],
                        [0.0, -32.43, 32.83], [0.0, -31.73, 31.52],
                        [0.0, -31.31, 29.75], [0.0, -30.63, 28.70], [0.0, -30.88, 27.41]])
for shft, order in zip(shift_pixel, order_list):
    new_sp = []
    new_var = []
    for i, sp in enumerate(spec_list):
        #print(sp[order-1].mod0, shift[i])
        nanmask = (sp[order-1].vardata <= 0) | (np.isnan(sp[order-1].vardata)) 
        nnan = nanmask.sum()
        if nnan > 0:
            print('Found %d NaNs in the two-dimensional variance '\
                  'spectrum' % nnan)

            """ Replace the NaNs with a big value """
            sp[order-1].vardata[nanmask] = 1.e9
        new_sp.append(shift(sp[order-1].data, [shft[i], 0], order=1))
        new_var.append(shift(sp[order-1].vardata, [shft[i], 0], order=1))
    shifted_sp.append(new_sp)
    shifted_var.append(new_var)
# Out:
# Found 7240 NaNs in the two-dimensional variance spectrum
# Found 7681 NaNs in the two-dimensional variance spectrum
# Found 7733 NaNs in the two-dimensional variance spectrum
# Found 2416 NaNs in the two-dimensional variance spectrum
# Found 2017 NaNs in the two-dimensional variance spectrum
# Found 2754 NaNs in the two-dimensional variance spectrum
# Found 1955 NaNs in the two-dimensional variance spectrum
# Found 1877 NaNs in the two-dimensional variance spectrum
# Found 2836 NaNs in the two-dimensional variance spectrum
# Found 1383 NaNs in the two-dimensional variance spectrum
# Found 2063 NaNs in the two-dimensional variance spectrum
# Found 2591 NaNs in the two-dimensional variance spectrum
# Found 1580 NaNs in the two-dimensional variance spectrum
# Found 1601 NaNs in the two-dimensional variance spectrum
# Found 2007 NaNs in the two-dimensional variance spectrum
# Found 1431 NaNs in the two-dimensional variance spectrum
# Found 1713 NaNs in the two-dimensional variance spectrum
# Found 1613 NaNs in the two-dimensional variance spectrum
# Found 1201 NaNs in the two-dimensional variance spectrum
# Found 1873 NaNs in the two-dimensional variance spectrum
# Found 2095 NaNs in the two-dimensional variance spectrum
# Found 1082 NaNs in the two-dimensional variance spectrum
# Found 1543 NaNs in the two-dimensional variance spectrum
# Found 1864 NaNs in the two-dimensional variance spectrum

# %%
pixrange = [[2200, 2600],[2200, 2600], [2700, 3100], [2100, 2500], [1800, 2200],
            [1600, 2000], [1500, 1900], [800, 1200]]
for od, sp_list, pix in zip(order_list, shifted_sp, pixrange):
    plt.figure(figsize=(8, 6))
    #pixrange = [[2200, 2600], [2200, 2600], [1800, 2200], [1500, 1900], [1500, 1900], [1500, 1900]]
    color = ['b', 'r', 'k']
    label = ['frame_46', 'frame_47', 'frame_48']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pix[0]:pix[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    plt.legend()
    plt.title('order %d' %od)

# %%
outsp = []
outvar = []

for sp_list, var_list in zip(shifted_sp, shifted_var):
    wtsp = np.zeros(sp_list[0].shape)
    wtsum = np.zeros(sp_list[0].shape)
    for s, v in zip(sp_list, var_list):
        wt = np.zeros(wtsp.shape)
        mask = np.isnan(v) | (v<=0)
        wt[~mask] = 1.0 / v[~mask]
        #print(sum(sum(np.isnan(wt) | (wt<=0))))
        wtsp += wt * s
        #print(sum(sum(wtsp==0)))
        wtsum += wt
        #print(sum(sum(wtsum==0)))

    wtsp[wtsum == 0] = 0
    wtsum[wtsum == 0] = 1
    outsp.append(wtsp / wtsum)
    outvar.append(1.0 / wtsum)

# %%
for od, sp_list, cd_sp, pix in zip(order_list, shifted_sp, outsp, pixrange):
    plt.figure(figsize=(8, 6))
    #pixrange = [2700, 3000]
    color = ['b', 'r', 'k']
    label = ['frame_46', 'frame_47', 'frame_48']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pix[0]:pix[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    
    tmpdata = cd_sp[:, pix[0]:pix[1]]
    pflux = np.median(tmpdata, axis=1)
    x = np.arange(cd_sp.shape[0])
    plt.plot(x, pflux, color='g', drawstyle='steps', label='coadded')
    plt.legend()
    plt.title('order %d' %od)

# %%
for od, cd_sp, pix in zip(order_list, outsp, pixrange):
    plt.figure(figsize=(10, 6))
    tmpdata = cd_sp[:, pix[0]:pix[1]]
    pflux = np.median(tmpdata, axis=1)
    x = np.arange(cd_sp.shape[0])
    plt.plot(x, pflux, color='g', drawstyle='steps', label='coadded')
    plt.legend()
    plt.title('order %d' %od)

# %%
s = fits.open('../galaxy_spectra/ESI_data/2019_04/PSJ1606-2333_0046_bgsub.fits')
for od, cd_sp, cd_var in zip(order_list, outsp, outvar):
    file_name1 = 'PSJ1606_ESI_spectra/PSJ1606_coadd2d_sp_order_' + str(od) + '.fits'
    file_name2 = 'PSJ1606_ESI_spectra/PSJ1606_coadd2d_var_order_' + str(od) + '.fits'
    fits.writeto(file_name1, cd_sp, header=s[od].header)
    fits.writeto(file_name2, cd_var, header=s[od].header)

# %%
pixscale = np.array([0.134, 0.137, 0.144, 0.149, 0.153, 0.158, 0.163, 0.168])
dist = [1.712, 0.62, 0.81]
for p in pixscale:
    print(dist/p)
# Out:
# [12.7761194   4.62686567  6.04477612]
# [12.49635036  4.52554745  5.91240876]
# [11.88888889  4.30555556  5.625     ]
# [11.48993289  4.16107383  5.43624161]
# [11.18954248  4.05228758  5.29411765]
# [10.83544304  3.92405063  5.12658228]
# [10.50306748  3.80368098  4.96932515]
# [10.19047619  3.69047619  4.82142857]

# %%
from specim_test.specim.specfuncs import spec1d
import matplotlib.pyplot as plt
import numpy as np

# %%
spq = spec1d.Spec1d('../../project_contaminted_veldis/KCWI_data/quasar_A.fits', informat='fitsflux')
# Out:
# Reading spectrum from ../../project_contaminted_veldis/KCWI_data/quasar_A.fits
# Expected file format: fitsflux
#  Spectrum Start:  3329.00
#  Spectrum End:     5936.00
#  Dispersion (1st pixel):   0.50
#  Dispersion (average):      0.50

# %%
fg = plt.figure(figsize=(12, 5))
spq.smooth(1, fig=fg)
spq.mark_lines('strongem', z=0.658, usesmooth=True, markatm=False)
# Out:
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# Mg II         2799.80       4642.07

# %%
spd = spec1d.Spec1d('../../project_contaminted_veldis/KCWI_data/lens.fits', informat='fitsflux',
                   trimsec=[2500, -800])
# Out:
# Reading spectrum from ../../project_contaminted_veldis/KCWI_data/lens.fits
# Expected file format: fitsflux
#  Spectrum Start:  4579.00
#  Spectrum End:     5536.00
#  Dispersion (1st pixel):   0.50
#  Dispersion (average):      0.50

# %%
# %matplotlib notebook
fg = plt.figure(figsize=(12, 5))
spd.smooth(1, fig=fg)
spd.mark_lines('abs', z=0.295, usesmooth=True, markatm=False)
# Out:
# <img src="data:image/png;base64,..." width="1199.999973990701">
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-kappa       3750.00       4856.25
# [Fe VII]      3761.40       4871.01
# H-iota        3770.00       4882.15
# H-theta       3797.00       4917.11
# H-eta         3835.00       4966.32
# CN bandhd     3883.00       5028.48
# CaII K        3933.67       5094.10
# CaII H        3968.47       5139.17
# H-delta       4101.00       5310.80

# %%
np.array([3985, 4085]) *1.295
# Out:
# array([5160.575, 5290.075])

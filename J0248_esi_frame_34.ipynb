# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, spec1d

# %%
file_loc = '../galaxy_spectra/ESI_data/*'

# %%
spec2d_file_list = []
var2d_file_list = []
#out_file = []
for i,p in enumerate(glob.glob(file_loc)):
    if 'J0248' in p:
        if 'bgsub.fits' in p:
            spec2d_file_list.append(p)
        elif 'var.fits' in p:
            var2d_file_list.append(p)

# %%
spec = esi2d.Esi2d(spec2d_file_list[1], varfile=var2d_file_list[2])
print(spec2d_file_list[1])
print(var2d_file_list[2])
# Out:
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3461x165     x
#   2   4093x145     x
#   3   4096x146     x
#   4   4096x141     x
#   5   4096x130     x
#   6   4096x127     x
#   7   4096x124     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x111     x
# ../galaxy_spectra/ESI_data/J0248+1913_0034_bgsub.fits
# ../galaxy_spectra/ESI_data/J0248+1913_0034_var.fits

# %%
pixrange = [(1900, 2400)]
for sp, info in zip(spec, spec.ordinfo):
    title = 'Spatial profile for ' + str(info['name'])
    sp.spatial_profile(pixrange=pixrange[0], title=title)
    plt.show()
    sp.initial_model()
# Out:
# Profile max value (before normalization) 29.680112
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 6, 63, 2
#
# amplitude=6.000000, mu=63.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 15, 70, 2
#
# amplitude=15.000000, mu=70.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 25, 77, 2
#
# amplitude=25.000000, mu=77.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.02950146)>
#
#     [1]: <Gaussian1D(amplitude=5.22420367, mean=65.06792261, stddev=3.09659472)>
#
#     [2]: <Gaussian1D(amplitude=5.22070818, mean=68.53563769, stddev=1.44198431)>
#
#     [3]: <Gaussian1D(amplitude=28.25534635, mean=75.78871401, stddev=4.0805698)>
# Parameters:
#              c0_0            amplitude_1    ...       mean_3           stddev_3
#     --------------------- ----------------- ... ----------------- -----------------
#     -0.029501458896088302 5.224203671187194 ... 75.78871401108694 4.080569797523398
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 20.751202
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 6, 59, 2
#
# amplitude=6.000000, mu=59.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 10, 64, 2
#
# amplitude=10.000000, mu=64.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 20, 70, 2
#
# amplitude=20.000000, mu=70.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.07681952)>
#
#     [1]: <Gaussian1D(amplitude=5.12883218, mean=61.44661344, stddev=3.12179943)>
#
#     [2]: <Gaussian1D(amplitude=2.32897944, mean=67.01906696, stddev=8.35880571)>
#
#     [3]: <Gaussian1D(amplitude=17.88530782, mean=68.85520924, stddev=3.1255081)>
# Parameters:
#             c0_0            amplitude_1    ...       mean_3           stddev_3
#     -------------------- ----------------- ... ----------------- ------------------
#     -0.07681951990637557 5.128832175012566 ... 68.85520923937581 3.1255080977708993
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# yes
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 5, 58, 2
#
# amplitude=5.000000, mu=58.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 7, 64, 2
#
# amplitude=7.000000, mu=64.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 20, 70, 2
#
# amplitude=20.000000, mu=70.000000, sigma=2.000000
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.071472)>
#
#     [1]: <Gaussian1D(amplitude=4.69955178, mean=61.47473622, stddev=3.05535069)>
#
#     [2]: <Gaussian1D(amplitude=3.07775324, mean=66.65370131, stddev=7.53365372)>
#
#     [3]: <Gaussian1D(amplitude=17.25622442, mean=68.86243657, stddev=3.08329018)>
# Parameters:
#             c0_0            amplitude_1    ...      mean_3           stddev_3
#     -------------------- ----------------- ... ---------------- ------------------
#     -0.07147200078972729 4.699551784560778 ... 68.8624365725447 3.0832901812867513
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 24.097534
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 5, 58, 2
#
# amplitude=5.000000, mu=58.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 8, 63, 2
#
# amplitude=8.000000, mu=63.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 20,69, 2
#
# amplitude=20.000000, mu=69.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.08578268)>
#
#     [1]: <Gaussian1D(amplitude=4.0904623, mean=60.57280628, stddev=2.28810675)>
#
#     [2]: <Gaussian1D(amplitude=6.86889662, mean=65.3336159, stddev=5.97820592)>
#
#     [3]: <Gaussian1D(amplitude=17.85908408, mean=67.70581027, stddev=2.63300717)>
# Parameters:
#             c0_0            amplitude_1    ...       mean_3           stddev_3
#     -------------------- ----------------- ... ----------------- -----------------
#     -0.08578267908595164 4.090462304263985 ... 67.70581027342178 2.633007166979053
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 48.892439
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 10, 56, 2
#
# amplitude=10.000000, mu=56.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 15, 61, 2
#
# amplitude=15.000000, mu=61.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 45, 66, 2
#
# amplitude=45.000000, mu=66.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.02800142)>
#
#     [1]: <Gaussian1D(amplitude=14.33279818, mean=58.35702852, stddev=2.48432368)>
#
#     [2]: <Gaussian1D(amplitude=7.7304757, mean=59.70382466, stddev=0.)>
#
#     [3]: <Gaussian1D(amplitude=47.66767189, mean=65.79455995, stddev=3.06161967)>
# Parameters:
#             c0_0            amplitude_1     ...       mean_3           stddev_3
#     -------------------- ------------------ ... ----------------- -----------------
#     0.028001421924925697 14.332798178863538 ... 65.79455994938995 3.061619672278461
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# yes
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 10, 56, 2
#
# amplitude=10.000000, mu=56.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 10, 61, 2
#
# amplitude=10.000000, mu=61.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 45, 66, 2
#
# amplitude=45.000000, mu=66.000000, sigma=2.000000
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.02800142)>
#
#     [1]: <Gaussian1D(amplitude=14.33279818, mean=58.35702852, stddev=2.48432368)>
#
#     [2]: <Gaussian1D(amplitude=7.7304757, mean=59.05573699, stddev=0.)>
#
#     [3]: <Gaussian1D(amplitude=47.66767189, mean=65.79455995, stddev=3.06161967)>
# Parameters:
#             c0_0            amplitude_1     ...       mean_3           stddev_3
#     -------------------- ------------------ ... ----------------- -----------------
#     0.028001421939656573 14.332798178858285 ... 65.79455994938978 3.061619672277092
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# yes
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 10, 55, 2
#
# amplitude=10.000000, mu=55.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 10, 60, 2
#
# amplitude=10.000000, mu=60.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 45, 66, 2
#
# amplitude=45.000000, mu=66.000000, sigma=2.000000
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.00481956)>
#
#     [1]: <Gaussian1D(amplitude=7.99596335, mean=57.01297472, stddev=2.51345069)>
#
#     [2]: <Gaussian1D(amplitude=8.35158814, mean=59.19703122, stddev=1.60339259)>
#
#     [3]: <Gaussian1D(amplitude=47.95529597, mean=65.71579303, stddev=3.11657626)>
# Parameters:
#             c0_0            amplitude_1    ...       mean_3           stddev_3
#     -------------------- ----------------- ... ----------------- ------------------
#     0.004819562720400065 7.995963352210426 ... 65.71579302754844 3.1165762573901916
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 62.644270
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 15, 53, 2
#
# amplitude=15.000000, mu=53.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 15, 58, 2
#
# amplitude=15.000000, mu=58.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 60, 64, 2
#
# amplitude=60.000000, mu=64.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.05174265)>
#
#     [1]: <Gaussian1D(amplitude=8.31270364, mean=53.94061693, stddev=2.94371996)>
#
#     [2]: <Gaussian1D(amplitude=14.97817388, mean=56.46648054, stddev=1.72897158)>
#
#     [3]: <Gaussian1D(amplitude=61.88711455, mean=62.92262627, stddev=2.91451153)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3          stddev_3
#     ------------------- ----------------- ... ----------------- ----------------
#     0.05174265235253339 8.312703640532394 ... 62.92262627275849 2.91451153008029
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 78.782192
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 20, 47, 2
#
# amplitude=20.000000, mu=47.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 20, 52, 2
#
# amplitude=20.000000, mu=52.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 70, 58, 2
#
# amplitude=70.000000, mu=58.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.05480167)>
#
#     [1]: <Gaussian1D(amplitude=11.95947713, mean=49.41999418, stddev=2.30963772)>
#
#     [2]: <Gaussian1D(amplitude=18.05836204, mean=51.66053528, stddev=1.54395717)>
#
#     [3]: <Gaussian1D(amplitude=77.9428318, mean=57.59140232, stddev=2.80160696)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3            stddev_3
#     ------------------- ------------------ ... ------------------ ------------------
#     0.05480167308430968 11.959477129107588 ... 57.591402324333245 2.8016069588646726
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 91.187684
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 20, 46, 2
#
# amplitude=20.000000, mu=46.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 20, 51, 2
#
# amplitude=20.000000, mu=51.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 90, 57, 2
#
# amplitude=90.000000, mu=57.000000, sigma=2.000000
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.06330763)>
#
#     [1]: <Gaussian1D(amplitude=24.9767201, mean=49.95358637, stddev=2.20158116)>
#
#     [2]: <Gaussian1D(amplitude=6.21599787, mean=51.4556061, stddev=0.72783419)>
#
#     [3]: <Gaussian1D(amplitude=87.89084286, mean=56.99350881, stddev=2.92501961)>
# Parameters:
#             c0_0           amplitude_1     ...      mean_3           stddev_3
#     ------------------- ------------------ ... ---------------- -----------------
#     0.06330763432278357 24.976720100615626 ... 56.9935088066067 2.925019613822401
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 88.228575
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 2
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 40, 49, 2
#
# amplitude=40.000000, mu=49.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 80, 58, 2
#
# amplitude=80.000000, mu=58.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=0.15078408)>
#
#     [1]: <Gaussian1D(amplitude=26.45457777, mean=49.45922308, stddev=2.09206639)>
#
#     [2]: <Gaussian1D(amplitude=85.77761538, mean=56.19114489, stddev=3.02967603)>
# Parameters:
#            c0_0           amplitude_1     ...       mean_2            stddev_2
#     ------------------ ------------------ ... ------------------ -----------------
#     0.1507840837695845 26.454577766964622 ... 56.191144888136414 3.029676027580743
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# yes
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 20, 46, 2
#
# amplitude=20.000000, mu=46.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 20, 51, 2
#
# amplitude=20.000000, mu=51.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 80, 57, 2
#
# amplitude=80.000000, mu=57.000000, sigma=2.000000
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.07389763)>
#
#     [1]: <Gaussian1D(amplitude=11.0578503, mean=47.62960164, stddev=2.28437447)>
#
#     [2]: <Gaussian1D(amplitude=20.15717553, mean=50.04126897, stddev=1.3611223)>
#
#     [3]: <Gaussian1D(amplitude=86.2663279, mean=56.11137585, stddev=3.08684019)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3           stddev_3
#     ------------------- ------------------ ... ----------------- -----------------
#     0.07389762851095553 11.057850298773833 ... 56.11137585287781 3.086840191576222
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 117.319011
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 20, 44, 2
#
# amplitude=20.000000, mu=44.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 20, 49, 2
#
# amplitude=20.000000, mu=49.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 110, 55, 2
#
# amplitude=110.000000, mu=55.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.07058559)>
#
#     [1]: <Gaussian1D(amplitude=13.36703831, mean=46.12162744, stddev=2.42277844)>
#
#     [2]: <Gaussian1D(amplitude=31.30424707, mean=48.22585908, stddev=1.4642335)>
#
#     [3]: <Gaussian1D(amplitude=115.08662475, mean=54.06919021, stddev=2.95422996)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3            stddev_3
#     ------------------- ----------------- ... ------------------ -----------------
#     0.07058559240293376 13.36703830601108 ... 54.069190205681394 2.954229962386249
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 15.532945
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 2.5, 43, 2
#
# amplitude=2.500000, mu=43.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 2.5, 48, 2
#
# amplitude=2.500000, mu=48.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 15, 55, 2
#
# amplitude=15.000000, mu=55.000000, sigma=2.000000
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.19874039)>
#
#     [1]: <Gaussian1D(amplitude=-6.92282344, mean=43.63933212, stddev=3.75744377)>
#
#     [2]: <Gaussian1D(amplitude=12.48385455, mean=47.85906958, stddev=5.66926495)>
#
#     [3]: <Gaussian1D(amplitude=8.54681698, mean=53.62458108, stddev=1.8647353)>
# Parameters:
#             c0_0            amplitude_1     ...       mean_3            stddev_3
#     -------------------- ------------------ ... ------------------ -----------------
#     -0.19874038936486313 -6.922823444150396 ... 53.624581076541915 1.864735299873262
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# yes
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 2.5, 43, 2
#
# amplitude=2.500000, mu=43.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 2.5, 48, 2
#
# amplitude=2.500000, mu=48.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 15, 54, 2
#
# amplitude=15.000000, mu=54.000000, sigma=2.000000
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.15882113)>
#
#     [1]: <Gaussian1D(amplitude=-0.60927678, mean=27.63169081, stddev=0.)>
#
#     [2]: <Gaussian1D(amplitude=11.54161845, mean=50.91676767, stddev=4.22425515)>
#
#     [3]: <Gaussian1D(amplitude=6.58077731, mean=53.82166853, stddev=1.58158005)>
# Parameters:
#             c0_0             amplitude_1     ...      stddev_3
#     -------------------- ------------------- ... ------------------
#     -0.15882112931033618 -0.6092767798216135 ... 1.5815800499341939
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# yes
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 2.5, 43, 2
#
# amplitude=2.500000, mu=43.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 3, 48, 2
#
# amplitude=3.000000, mu=48.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 15, 53, 2
#
# amplitude=15.000000, mu=53.000000, sigma=2.000000
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.11928136)>
#
#     [1]: <Gaussian1D(amplitude=0.23713023, mean=38.5502491, stddev=0.)>
#
#     [2]: <Gaussian1D(amplitude=7.1850829, mean=47.62409119, stddev=2.67136414)>
#
#     [3]: <Gaussian1D(amplitude=14.9200183, mean=53.28960447, stddev=2.56151405)>
# Parameters:
#             c0_0             amplitude_1     ...      stddev_3
#     -------------------- ------------------- ... ------------------
#     -0.11928136453157248 0.23713023102357433 ... 2.5615140506353193
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# yes
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 2.5, 42, 2
#
# amplitude=2.500000, mu=42.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 3, 47, 2
#
# amplitude=3.000000, mu=47.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 15, 52, 2
#
# amplitude=15.000000, mu=52.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.11927938)>
#
#     [1]: <Gaussian1D(amplitude=7.18348643, mean=47.62279408, stddev=2.670511)>
#
#     [2]: <Gaussian1D(amplitude=2.21729434, mean=44.11575699, stddev=0.)>
#
#     [3]: <Gaussian1D(amplitude=14.9219137, mean=53.28901319, stddev=2.56187997)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3           stddev_3
#     ------------------- ----------------- ... ----------------- ------------------
#     -0.1192793752914863 7.183486434097237 ... 53.28901319469517 2.5618799709784046
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# yes
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 2.5, 43, 2
#
# amplitude=2.500000, mu=43.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 2.5, 47, 2
#
# amplitude=2.500000, mu=47.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 14, 52, 2
#
# amplitude=14.000000, mu=52.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.17265515)>
#
#     [1]: <Gaussian1D(amplitude=1.02123283, mean=49.07753155, stddev=8.50222179)>
#
#     [2]: <Gaussian1D(amplitude=6.04003605, mean=47.31211653, stddev=2.15322538)>
#
#     [3]: <Gaussian1D(amplitude=14.60703669, mean=53.04810591, stddev=2.59572356)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3           stddev_3
#     ------------------- ------------------ ... ----------------- -----------------
#     -0.1726551545007127 1.0212328267675304 ... 53.04810590617975 2.595723563849828
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no

# %%
def tie_stddev_gauss(model):
    return model.stddev_3

for sp, info in zip(spec, spec.ordinfo):
    if sp.mod0 is not None:
        print(info['pixscale'])
        #sp.mod0[2].mean.tied = func_dict['%d_%d' %(info['order'], 1)] #tie_pos1_gauss_
        #sp.mod0[3].mean.tied = func_dict['%d_%d' %(info['order'], 2)] #tie_pos2_gauss
        sp.mod0[1].stddev.tied = tie_stddev_gauss
        sp.refined_model(sp.mod0)
# Out:
# 0.12
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.02950146)>
#
#     [1]: <Gaussian1D(amplitude=5.22420367, mean=65.06792261, stddev=3.09659472)>
#
#     [2]: <Gaussian1D(amplitude=5.22070818, mean=68.53563769, stddev=1.44198431)>
#
#     [3]: <Gaussian1D(amplitude=28.25534635, mean=75.78871401, stddev=4.0805698)>
# Parameters:
#              c0_0            amplitude_1    ...       mean_3           stddev_3
#     --------------------- ----------------- ... ----------------- -----------------
#     -0.029501458896088302 5.224203671187194 ... 75.78871401108694 4.080569797523398
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.03460565)>
#
#     [1]: <Gaussian1D(amplitude=5.63614426, mean=66.10823229, stddev=3.97062141)>
#
#     [2]: <Gaussian1D(amplitude=4.20865539, mean=68.52412949, stddev=1.36753273)>
#
#     [3]: <Gaussian1D(amplitude=27.96935342, mean=75.94761922, stddev=3.97062141)>
# Parameters:
#              c0_0            amplitude_1    ...       mean_3           stddev_3
#     --------------------- ----------------- ... ----------------- -----------------
#     -0.034605646917267016 5.636144259282784 ... 75.94761921518462 3.970621406115965
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# 0.127
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.071472)>
#
#     [1]: <Gaussian1D(amplitude=4.69955178, mean=61.47473622, stddev=3.05535069)>
#
#     [2]: <Gaussian1D(amplitude=3.07775324, mean=66.65370131, stddev=7.53365372)>
#
#     [3]: <Gaussian1D(amplitude=17.25622442, mean=68.86243657, stddev=3.08329018)>
# Parameters:
#             c0_0            amplitude_1    ...      mean_3           stddev_3
#     -------------------- ----------------- ... ---------------- ------------------
#     -0.07147200078972729 4.699551784560778 ... 68.8624365725447 3.0832901812867513
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.07793786)>
#
#     [1]: <Gaussian1D(amplitude=5.18848784, mean=61.44734493, stddev=3.13099628)>
#
#     [2]: <Gaussian1D(amplitude=2.24451651, mean=67.05795821, stddev=8.4341488)>
#
#     [3]: <Gaussian1D(amplitude=17.94934646, mean=68.85728615, stddev=3.13099628)>
# Parameters:
#             c0_0            amplitude_1    ...       mean_3           stddev_3
#     -------------------- ----------------- ... ----------------- -----------------
#     -0.07793786003326339 5.188487843601441 ... 68.85728614825958 3.130996276321534
#
# -------------------------------------------
# 0.134
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.08578268)>
#
#     [1]: <Gaussian1D(amplitude=4.0904623, mean=60.57280628, stddev=2.28810675)>
#
#     [2]: <Gaussian1D(amplitude=6.86889662, mean=65.3336159, stddev=5.97820592)>
#
#     [3]: <Gaussian1D(amplitude=17.85908408, mean=67.70581027, stddev=2.63300717)>
# Parameters:
#             c0_0            amplitude_1    ...       mean_3           stddev_3
#     -------------------- ----------------- ... ----------------- -----------------
#     -0.08578267908595164 4.090462304263985 ... 67.70581027342178 2.633007166979053
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.08526715)>
#
#     [1]: <Gaussian1D(amplitude=3.2273583, mean=60.48632951, stddev=2.49453624)>
#
#     [2]: <Gaussian1D(amplitude=8.78958896, mean=65.59282729, stddev=5.67343934)>
#
#     [3]: <Gaussian1D(amplitude=16.18718036, mean=67.80589336, stddev=2.49453624)>
# Parameters:
#             c0_0            amplitude_1     ...       mean_3           stddev_3
#     -------------------- ------------------ ... ----------------- ------------------
#     -0.08526715335115057 3.2273583007306725 ... 67.80589336494809 2.4945362437320298
#
# -------------------------------------------
# 0.137
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.00481956)>
#
#     [1]: <Gaussian1D(amplitude=7.99596335, mean=57.01297472, stddev=2.51345069)>
#
#     [2]: <Gaussian1D(amplitude=8.35158814, mean=59.19703122, stddev=1.60339259)>
#
#     [3]: <Gaussian1D(amplitude=47.95529597, mean=65.71579303, stddev=3.11657626)>
# Parameters:
#             c0_0            amplitude_1    ...       mean_3           stddev_3
#     -------------------- ----------------- ... ----------------- ------------------
#     0.004819562720400065 7.995963352210426 ... 65.71579302754844 3.1165762573901916
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.02684893)>
#
#     [1]: <Gaussian1D(amplitude=2.92790082, mean=54.52062172, stddev=3.120389)>
#
#     [2]: <Gaussian1D(amplitude=13.23054012, mean=58.59600443, stddev=1.96125984)>
#
#     [3]: <Gaussian1D(amplitude=47.92610707, mean=65.71968263, stddev=3.120389)>
# Parameters:
#             c0_0            amplitude_1    ...      mean_3           stddev_3
#     -------------------- ----------------- ... ---------------- ------------------
#     -0.02684893216196965 2.927900822903545 ... 65.7196826345346 3.1203889957294244
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# 0.144
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.05174265)>
#
#     [1]: <Gaussian1D(amplitude=8.31270364, mean=53.94061693, stddev=2.94371996)>
#
#     [2]: <Gaussian1D(amplitude=14.97817388, mean=56.46648054, stddev=1.72897158)>
#
#     [3]: <Gaussian1D(amplitude=61.88711455, mean=62.92262627, stddev=2.91451153)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3          stddev_3
#     ------------------- ----------------- ... ----------------- ----------------
#     0.05174265235253339 8.312703640532394 ... 62.92262627275849 2.91451153008029
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.05244352)>
#
#     [1]: <Gaussian1D(amplitude=8.30821236, mean=53.86250291, stddev=2.91015032)>
#
#     [2]: <Gaussian1D(amplitude=15.12693699, mean=56.47965525, stddev=1.73555439)>
#
#     [3]: <Gaussian1D(amplitude=61.89672947, mean=62.926561, stddev=2.91015032)>
# Parameters:
#             c0_0          amplitude_1    ...       mean_3           stddev_3
#     ------------------- ---------------- ... ----------------- -----------------
#     0.05244351980178714 8.30821235933187 ... 62.92656100316901 2.910150315387915
#
# -------------------------------------------
# 0.149
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.05480167)>
#
#     [1]: <Gaussian1D(amplitude=11.95947713, mean=49.41999418, stddev=2.30963772)>
#
#     [2]: <Gaussian1D(amplitude=18.05836204, mean=51.66053528, stddev=1.54395717)>
#
#     [3]: <Gaussian1D(amplitude=77.9428318, mean=57.59140232, stddev=2.80160696)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3            stddev_3
#     ------------------- ------------------ ... ------------------ ------------------
#     0.05480167308430968 11.959477129107588 ... 57.591402324333245 2.8016069588646726
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.04081199)>
#
#     [1]: <Gaussian1D(amplitude=8.89741495, mean=49.36103833, stddev=2.78406597)>
#
#     [2]: <Gaussian1D(amplitude=19.5450718, mean=51.43337993, stddev=1.69652029)>
#
#     [3]: <Gaussian1D(amplitude=77.81096375, mean=57.61684267, stddev=2.78406597)>
# Parameters:
#             c0_0          amplitude_1  ...       mean_3           stddev_3
#     -------------------- ------------- ... ----------------- -----------------
#     0.040811986186165494 8.89741495088 ... 57.61684267418995 2.784065971358185
#
# -------------------------------------------
# 0.153
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.00732925)>
#
#     [1]: <Gaussian1D(amplitude=8.75162365, mean=48.31953736, stddev=2.92560028)>
#
#     [2]: <Gaussian1D(amplitude=22.54761176, mean=50.68455275, stddev=1.63643098)>
#
#     [3]: <Gaussian1D(amplitude=88.11267076, mean=56.98850295, stddev=2.92560028)>
# Parameters:
#              c0_0            amplitude_1    ...       mean_3           stddev_3
#     --------------------- ----------------- ... ----------------- -----------------
#     -0.007329245545490844 8.751623649565284 ... 56.98850295075628 2.925600278800414
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.00706908)>
#
#     [1]: <Gaussian1D(amplitude=8.93179561, mean=48.37229606, stddev=2.92709332)>
#
#     [2]: <Gaussian1D(amplitude=22.31875748, mean=50.68315465, stddev=1.62393582)>
#
#     [3]: <Gaussian1D(amplitude=88.09748468, mean=56.98728831, stddev=2.92709332)>
# Parameters:
#              c0_0            amplitude_1    ...       mean_3           stddev_3
#     --------------------- ----------------- ... ----------------- ------------------
#     -0.007069080449229281 8.931795607914912 ... 56.98728831369721 2.9270933183924734
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# 0.158
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.04850582)>
#
#     [1]: <Gaussian1D(amplitude=8.44573406, mean=47.69568973, stddev=3.05876583)>
#
#     [2]: <Gaussian1D(amplitude=20.68536146, mean=49.84515696, stddev=1.50189845)>
#
#     [3]: <Gaussian1D(amplitude=86.0672174, mean=56.15125662, stddev=3.05876583)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3           stddev_3
#     ------------------- ----------------- ... ----------------- ------------------
#     0.04850582328175529 8.445734057829661 ... 56.15125661838098 3.0587658298196465
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.04849035)>
#
#     [1]: <Gaussian1D(amplitude=8.44078706, mean=47.69391049, stddev=3.05871679)>
#
#     [2]: <Gaussian1D(amplitude=20.69139481, mean=49.84528161, stddev=1.50236603)>
#
#     [3]: <Gaussian1D(amplitude=86.06779968, mean=56.15129655, stddev=3.05871679)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3           stddev_3
#     ------------------- ----------------- ... ----------------- -----------------
#     0.04849034824801883 8.440787060769054 ... 56.15129654942756 3.058716785530446
#
# -------------------------------------------
# 0.163
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.04340731)>
#
#     [1]: <Gaussian1D(amplitude=9.03348605, mean=45.70007473, stddev=2.93947597)>
#
#     [2]: <Gaussian1D(amplitude=34.5133336, mean=48.08255011, stddev=1.59524452)>
#
#     [3]: <Gaussian1D(amplitude=114.9225489, mean=54.09187505, stddev=2.93947597)>
# Parameters:
#             c0_0           amplitude_1    ...       mean_3           stddev_3
#     ------------------- ----------------- ... ----------------- -----------------
#     0.04340731288499179 9.033486053765955 ... 54.09187505003061 2.939475973233695
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.04345515)>
#
#     [1]: <Gaussian1D(amplitude=9.05429352, mean=45.70665915, stddev=2.93960997)>
#
#     [2]: <Gaussian1D(amplitude=34.48522961, mean=48.08249465, stddev=1.59436118)>
#
#     [3]: <Gaussian1D(amplitude=114.92089239, mean=54.09175803, stddev=2.93960997)>
# Parameters:
#             c0_0          amplitude_1    ...       mean_3           stddev_3
#     ------------------- ---------------- ... ----------------- -----------------
#     0.04345514865323497 9.05429351694567 ... 54.09175802701377 2.939609967020279
#
# -------------------------------------------
# 0.168
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.17265515)>
#
#     [1]: <Gaussian1D(amplitude=1.02123283, mean=49.07753155, stddev=8.50222179)>
#
#     [2]: <Gaussian1D(amplitude=6.04003605, mean=47.31211653, stddev=2.15322538)>
#
#     [3]: <Gaussian1D(amplitude=14.60703669, mean=53.04810591, stddev=2.59572356)>
# Parameters:
#             c0_0           amplitude_1     ...       mean_3           stddev_3
#     ------------------- ------------------ ... ----------------- -----------------
#     -0.1726551545007127 1.0212328267675304 ... 53.04810590617975 2.595723563849828
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.11962082)>
#
#     [1]: <Gaussian1D(amplitude=1.28988418, mean=48.03872754, stddev=2.54835637)>
#
#     [2]: <Gaussian1D(amplitude=5.97412682, mean=47.58950792, stddev=2.72459364)>
#
#     [3]: <Gaussian1D(amplitude=14.85736823, mean=53.31172866, stddev=2.54835637)>
# Parameters:
#             c0_0            amplitude_1     ...       mean_3           stddev_3
#     -------------------- ------------------ ... ----------------- ------------------
#     -0.11962081634861518 1.2898841759399904 ... 53.31172865555977 2.5483563673923277
#
# -------------------------------------------

# %%
fig = plt.figure(figsize=(15, 25))
spec.plot_fitted_model(fig=fig)

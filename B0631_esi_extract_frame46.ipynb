# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, echelle1d, spec1d, echelle2d

# %%
file_loc = '../galaxy_spectra/ESI_data/2019_01/*'

# %%
spec2d_file_list = []
var2d_file_list = []
#out_file = []
for i,p in enumerate(glob.glob(file_loc)):
    if 'B0631' in p:
        if 'bgsub.fits' in p:
            spec2d_file_list.append(p)
        elif 'var.fits' in p:
            var2d_file_list.append(p)

# %%
print(spec2d_file_list, var2d_file_list)
# Out:
# ['../galaxy_spectra/ESI_data/2019_01/B0631+519_0049_bgsub.fits', '../galaxy_spectra/ESI_data/2019_01/B0631+519_0046_bgsub.fits', '../galaxy_spectra/ESI_data/2019_01/B0631+519_0047_bgsub.fits', '../galaxy_spectra/ESI_data/2019_01/B0631+519_0048_bgsub.fits'] ['../galaxy_spectra/ESI_data/2019_01/B0631+519_0049_var.fits', '../galaxy_spectra/ESI_data/2019_01/B0631+519_0046_var.fits', '../galaxy_spectra/ESI_data/2019_01/B0631+519_0047_var.fits', '../galaxy_spectra/ESI_data/2019_01/B0631+519_0048_var.fits']

# %%
spec = esi2d.Esi2d(spec2d_file_list[1], varfile=var2d_file_list[1])
print(spec2d_file_list[1])
print(var2d_file_list[1])
# Out:
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3460x164     x
#   2   4093x155     x
#   3   4096x145     x
#   4   4096x140     x
#   5   4096x134     x
#   6   4096x129     x
#   7   4096x125     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x116     x
# ../galaxy_spectra/ESI_data/2019_01/B0631+519_0046_bgsub.fits
# ../galaxy_spectra/ESI_data/2019_01/B0631+519_0046_var.fits

# %%
pixscale = np.array([0.153, 0.158, 0.163, 0.168])
distance = np.array([0.67, 0.453, 0.518])

for p in pixscale:
    print(distance/p)
# Out:
# [4.37908497 2.96078431 3.38562092]
# [4.24050633 2.86708861 3.27848101]
# [4.11042945 2.7791411  3.17791411]
# [3.98809524 2.69642857 3.08333333]

# %%
pixrange = [[2000, 2400], [3000, 3400], [1700, 2100], [1600, 2000], [650, 950]] 
i=0
for sp, info in zip(spec[5:], spec.ordinfo[5:]):
    print(info['pixscale'])
    title = 'Spatial profile for ' + str(info['name'])
    sp.spatial_profile(pixrange=pixrange[i], title=title)
    plt.show()
    sp.initial_model()
    i += 1
# Out:
# 0.149
# Profile max value (before normalization) 3.573758
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -0.2
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-eaa43d00175e> in <module>
#       6     sp.spatial_profile(pixrange=pixrange[i], title=title)
#       7     plt.show()
# ----> 8     sp.initial_model()
#       9     i += 1
#
# ~/Project/new_project/spectra_extraction/specim_test/specim/specfuncs/spec2d.py in initial_model(self, profile, verbose)
#    1246
# ...

# %%
pixrange = [[2000, 2400], [3000, 3400], [1700, 2100], [1600, 2000], [650, 950]] 
i=0
for sp, info in zip(spec[5:], spec.ordinfo[5:]):
    print(info['pixscale'])
    title = 'Spatial profile for ' + str(info['name'])
    sp.spatial_profile(pixrange=pixrange[i], title=title)
    plt.show()
    sp.initial_model()
    i += 1
# Out:
# 0.153
# Profile max value (before normalization) 8.208469
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 3
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 8, 56, 3, 4
#
# amplitude=8.000000, x_0=56.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 4, 52, 3, 4
#
# amplitude=4.000000, x_0=52.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 3 : 4, 59.4, 3, 4
#
# amplitude=4.000000, x_0=59.400000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# ...

# %%
#spec_list= [spec_ord_7, spec_ord_8, spec_ord_9, spec_ord_10]
pixrange = [[3000, 3400], [1700, 2100], [1600, 2000], [650, 950]] 
i=0
for sp, info in zip(spec[6:], spec.ordinfo[6:]):
    print(info['pixscale'])
    title = 'Spatial profile for ' + str(info['name'])
    sp.spatial_profile(pixrange=pixrange[i], title=title)
    plt.show()
    sp.initial_model()
    i += 1
# Out:
# 0.153
# Profile max value (before normalization) 8.208469
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 3
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 8, 56, 3, 4
#
# amplitude=8.000000, x_0=56.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 4, 52.6, 3, 4
#
# amplitude=4.000000, x_0=52.600000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 3 : 4, 60.4, 3, 4
#
# amplitude=4.000000, x_0=60.400000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# ...

# %%
spec_list= [spec_ord_7, spec_ord_8, spec_ord_9, spec_ord_10]
pixrange_list = [[3000, 3400], [1700, 2100], [1600, 2000], [650, 950]] 

for i, sp in enumerate(spec_list):
    sp.spatial_profile(pixrange=pixrange_list[i])
    plt.show()
    sp.initial_model()
# Out:
# Profile max value (before normalization) 6.382854
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 3
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 6, 55, 3, 4
#
# amplitude=6.000000, x_0=55.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 2, 51.3, 3, 4
#
# amplitude=2.000000, x_0=51.300000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 3 : 3.5, 59.5, 3, 4
#
# amplitude=3.500000, x_0=59.500000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# ...

# %%
#def tie_pos1_moffat_6(model):
#    return model.x_0_1 - (0.67 / pixscale[3]) #(0.67086 / pixscale)

#def tie_pos2_moffat_6(model):
#    return model.x_0_1 + (0.52 / pixscale[3])

def tie_pos1_moffat_7(model):
    return model.x_0_1 - (0.67 / pixscale[0]) #(0.67086 / pixscale)

def tie_pos2_moffat_7(model):
    return model.x_0_1 + (0.52 / pixscale[0])  #(1.87 / pixscale) 

def tie_pos1_moffat_8(model):
    return model.x_0_1 - (0.67 /  pixscale[1]) #(0.67086 / pixscale)

def tie_pos2_moffat_8(model):
    return model.x_0_1 + (0.52 /  pixscale[1])  #(1.87 / pixscale) 

def tie_pos1_moffat_9(model):
    return model.x_0_1 - (0.67 /  pixscale[2]) #(0.67086 / pixscale)

def tie_pos2_moffat_9(model):
    return model.x_0_1 + (0.52 /  pixscale[2])  #(1.87 / pixscale) 

def tie_pos1_moffat_10(model):
    return model.x_0_1 - (0.67 /  pixscale[3]) #(0.67086 / pixscale)

def tie_pos2_moffat_10(model):
    return model.x_0_1 + (0.52 /  pixscale[3])  #(1.87 / pixscale) 

def tie_gamma_moffat(model):
    return model.gamma_3

def tie_alpha_moffat(model):
    return model.alpha_3 

def tie_stddev_gauss(model):
    return model.stddev_2

def tie_gamma_moffat1(model):
    return model.gamma_3 

def tie_alpha_moffat1(model):
    return model.alpha_3 

func_dict = {
             #'6_1' : tie_pos1_moffat_6, '6_2' : tie_pos2_moffat_6,
             '7_1' : tie_pos1_moffat_7, '7_2' : tie_pos2_moffat_7,
             '8_1' : tie_pos1_moffat_8, '8_2' : tie_pos2_moffat_8,
             '9_1' : tie_pos1_moffat_9, '9_2' : tie_pos2_moffat_9,
             '10_1' : tie_pos1_moffat_10, '10_2' : tie_pos2_moffat_10
            }
pixscale = [0.153, 0.158, 0.163, 0.168]
ord_list = [7, 8, 9, 10]

i=0
for sp, info in zip(spec[6:], spec.ordinfo[6:]):
    if sp.mod0 is not None:
        print(info['pixscale'])
        sp.mod0[2].x_0.tied = func_dict['%d_%d' %(ord_list[i], 1)] #tie_pos1_moffat
        sp.mod0[3].x_0.tied = func_dict['%d_%d' %(ord_list[i], 2)] #tie_pos2_moffat
        #sp.mod0[1].stddev.tied = tie_stddev_gauss
        #sp.mod0[2].gamma.tied = tie_gamma_moffat
        #sp.mod0[2].alpha.tied = tie_alpha_moffat
        #sp.mod0[1].gamma.tied = tie_gamma_moffat
        #sp.mod0[1].alpha.tied = tie_alpha_moffat
        sp.refined_model(sp.mod0)
        i += 1
# Out:
# 0.153
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.15083848)>
#
#     [1]: <Moffat1D(amplitude=5.24875604, x_0=56.83020129, gamma=4.5784504, alpha=2.25995857)>
#
#     [2]: <Moffat1D(amplitude=4.3154427, x_0=52.19249674, gamma=5.1913552, alpha=2.05382042)>
#
#     [3]: <Moffat1D(amplitude=3.25535016, x_0=61.53382267, gamma=4.29499979, alpha=0.97152178)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_3           alpha_3
#     ------------------- ----------------- ... ----------------- ------------------
#     -0.1508384772913956 5.248756036451131 ... 4.294999786625408 0.9715217780762662
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
# ...

# %%
fitrange_list = np.array([[0, 4100], [0, 4100], [0, 4100], [0, 4100]])

for i, sp in enumerate(spec[6:]):
    sp.find_and_trace(sp.mod0, stepsize=25, fitorder={'x_0_1':4, 'x_0_2':4, 'x_0_3':4},
                    fitrange=fitrange_list[i], polyorder=3)
    plt.show()
# Out:
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: x_0_1
# Fitting polynomial of degree 3 to parameter: gamma_1
# Fitting polynomial of degree 3 to parameter: alpha_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# ...

# %%
extrange_list = np.array([[600, -1], [200, -1], [0, -1], [0, 2000]])

for sp, ext in zip(spec[6:], extrange_list):
    sp.extract(method='modelfit', extrange=ext)
    plt.show()
# Out:
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 600 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  6380.13
#  Spectrum End:     7286.13
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#  Spectrum Start:  6380.13
#  Spectrum End:     7286.13
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#  Spectrum Start:  6380.13
#  Spectrum End:     7286.13
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#
# Plotting the spectrum
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 200 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  7066.40
#  Spectrum End:     8193.43
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29
#
# ...

# %%
outspec = []
orderinfo = np.array([7, 8, 9, 10], dtype=[('order', int)])

# %%
for i, spp in enumerate(spec[6].spectra):
    s = []
    for sp in spec[6:]:
        s.append(sp.spectra[i][1])
    outspec.append(echelle1d.Ech1d(s, ordinfo=orderinfo))
# Out:
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   7  3496   6380.13  7286.13   0.26
#   8  3896   7066.40  8193.43   0.29
#   9  4096   8011.81  9360.48   0.33
#  10  2000   9337.74 10074.55   0.37
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   7  3496   6380.13  7286.13   0.26
#   8  3896   7066.40  8193.43   0.29
#   9  4096   8011.81  9360.48   0.33
#  10  2000   9337.74 10074.55   0.37
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   7  3496   6380.13  7286.13   0.26
#   8  3896   7066.40  8193.43   0.29
#   9  4096   8011.81  9360.48   0.33
#  10  2000   9337.74 10074.55   0.37

# %%
#%matplotlib notebook
outspec[0].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))
outspec[1].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))
outspec[2].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))

# %%
outspec[0].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt', order=[7, 10])
outspec[1].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt', order=[7, 10])
outspec[2].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt', order=[7, 10])
# Out:
#  Spectrum Start:     3.80
#  Spectrum End:        4.00
#  Dispersion (1st pixel): 1.65e-05
#  Dispersion (average):    1.65e-05
#  Spectrum Start:     3.80
#  Spectrum End:        4.00
#  Dispersion (1st pixel): 1.65e-05
#  Dispersion (average):    1.65e-05
#  Spectrum Start:     3.80
#  Spectrum End:        4.00
#  Dispersion (1st pixel): 1.65e-05
#  Dispersion (average):    1.65e-05

# %%
sp_d = spec1d.Spec1d(wav=outspec[0].spec1d['wav'], flux=outspec[0].spec1d['flux'],
                     var=outspec[0].spec1d['var'], logwav=True, trimsec=[0, -1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2f459587535c> in <module>
# ----> 1 sp_d = spec1d.Spec1d(wav=outspec[0].spec1d['wav'], flux=outspec[0].spec1d['flux'],
#       2                      var=outspec[0].spec1d['var'], logwav=True, trimsec=[0, -1])
#
# NameError: name 'spec1d' is not defined

# %%
sp_d.smooth(61)

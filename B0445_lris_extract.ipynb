# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
from specim_test.specim.specfuncs import spec2d, spec1d
from astropy.io import fits as pf
from scipy import interpolate

# %%
file_loc = 'B0445_LRIS_spectra/*'

# %%
file_list = []
out_file = []
for i,p in enumerate(glob.glob(file_loc)):
    if 'cleaned' in p and 'B0445' in p:
        file_list.append(p)
        frame = p.split('_')[-2][3:]
        out_file.append('B0445_LRIS_spectra/spec1d_B0445_lris_frame'+ frame)

# %%
file_list
# Out:
# ['B0445_LRIS_spectra/B0445_r0032_cleaned.fits',
#  'B0445_LRIS_spectra/B0445_r0033_cleaned.fits',
#  'B0445_LRIS_spectra/B0445_r0031_cleaned.fits',
#  'B0445_LRIS_spectra/B0445_r0029_cleaned.fits',
#  'B0445_LRIS_spectra/B0445_r0030_cleaned.fits']

# %% [markdown]
# ### I have used this notebook to extract 1d spectra from each frame and coadd them. I have tried adding Gaussian or moffat profile for image but the extracted spectra for those profiles doesn't look good. So ultimately used onle one moffat profile to extract the deflector spectra. The following two profile trial is just for demonstration.

# %%
spec1 = spec2d.Spec2d(file_list[3], hext=0, varext=1, xtrim=[60, 140])
spec2 = spec2d.Spec2d(file_list[4], hext=0, varext=1, xtrim=[60, 140])
spec3 = spec2d.Spec2d(file_list[2], hext=0, varext=1, xtrim=[60, 140])
spec4 = spec2d.Spec2d(file_list[0], hext=0, varext=1, xtrim=[60, 140])
spec5 = spec2d.Spec2d(file_list[1], hext=0, varext=1, xtrim=[60, 140])

spec_list = [spec1, spec2, spec3, spec4, spec5]
#spec = spec2d.Spec2d(infile, xtrim=[265, 385])       #, hext=12, xtrim=[30, 500])
# Out:
# Loading file B0445_LRIS_spectra/B0445_r0029_cleaned.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from B0445_LRIS_spectra/B0445_r0029_cleaned.fits (HDU=0)
# The input dataset was trimmed
#  xrange: 60:141.  yrange: 0:4096
# Final data dimensions (x y): 81 x 4096
#
# Dispersion axis:              x
# N_pixels along dispersion axis: 81
#
#
# Loading file B0445_LRIS_spectra/B0445_r0030_cleaned.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from B0445_LRIS_spectra/B0445_r0030_cleaned.fits (HDU=0)
# The input dataset was trimmed
#  xrange: 60:141.  yrange: 0:4096
# Final data dimensions (x y): 81 x 4096
#
# Dispersion axis:              x
# N_pixels along dispersion axis: 81
#
#
# Loading file B0445_LRIS_spectra/B0445_r0031_cleaned.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from B0445_LRIS_spectra/B0445_r0031_cleaned.fits (HDU=0)
# The input dataset was trimmed
# ...

# %%
for sp in spec_list:
    sp.set_dispaxis('y')
    plt.show()
    sp.do_waverect(doplot=True, resamp_ord=1, wavext=3)
# Out:
# Old value of dispaxis: x
#
# Dispersion axis:              y
# N_pixels along dispersion axis: 4096
#
#
# Dispersion : 0.800000
# Found 133 NaNs in the two-dimensional spectrum
#
# sky subtracted and cosmic ray rejected data has been resampled along with vardata in place of the coordinateds whcih rectify the tilted wave image
#
# Old value of dispaxis: x
#
# Dispersion axis:              y
# N_pixels along dispersion axis: 4096
# Dispersion : 0.800000
# Found 130 NaNs in the two-dimensional spectrum
#
# sky subtracted and cosmic ray rejected data has been resampled along with vardata in place of the coordinateds whcih rectify the tilted wave image
#
# Old value of dispaxis: x
#
# Dispersion axis:              y
# N_pixels along dispersion axis: 4096
# Dispersion : 0.800000
# Found 128 NaNs in the two-dimensional spectrum
#
# sky subtracted and cosmic ray rejected data has been resampled along with vardata in place of the coordinateds whcih rectify the tilted wave image
#
# ...

# %%
for sp in spec_list:
    sp.spatial_profile(pixrange=[2100, 2400])
    plt.show()
    sp.initial_model()
# Out:
# Profile max value (before normalization) 25.397997
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 25, 43, 3, 4
#
# amplitude=25.000000, x_0=43.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=0.44277751)>
#
#     [1]: <Moffat1D(amplitude=23.14605986, x_0=43.24914525, gamma=23.87668943, alpha=5.4302087)>
# Parameters:
# ...

# %%
for sp in spec_list:
    sp.spatial_profile(pixrange=[2100, 2400])
    plt.show()
    sp.initial_model()
# Out:
# Profile max value (before normalization) 25.397997
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 25, 42, 3, 4
#
# amplitude=25.000000, x_0=42.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 12, 34, 3, 4
#
# amplitude=12.000000, x_0=34.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.21729662)>
#
# ...

# %%
for sp in spec_list[2:]:
    sp.spatial_profile(pixrange=[2100, 2400])
    plt.show()
    sp.initial_model()
# Out:
# Profile max value (before normalization) 29.544909
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 5, 53, 2
#
# amplitude=5.000000, mu=53.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 :  28, 42, 2, 3
#
# amplitude=28.000000, x_0=42.000000, gamma=2.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 12, 34, 2, 3
#
# amplitude=12.000000, x_0=34.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# ...

# %%
#spec.subtract_sky_2d(outfile='sky_subtracted_using_pypeit_B0445_29.fits', use_skymod=True)
#spec.szap(use_skymod=True, outfile='B0445_29_szapeed.fits')

# %%
#%matplotlib notebook
#spec.display_spec(use_skymod=True, doszap=True)

# %%
def tie_pos1_moffat(model):
     return model.x_0_1 - 8.0
            
def tie_pos2_moffat(model):
    return model.x_0_1 + 11.0

def tie_gamma_moffat(model):
    return model.gamma_1

def tie_alpha_moffat(model):
    return model.alpha_1 

for sp in spec_list:
    sp.mod0[2].x_0.tied = tie_pos1_moffat
    #sp.mod0[3].x_0.tied = tie_pos2_moffat
    sp.mod0[2].gamma.tied = tie_gamma_moffat
    sp.mod0[2].alpha.tied = tie_alpha_moffat
    sp.refined_model(sp.mod0)
# Out:
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.21729662)>
#
#     [1]: <Moffat1D(amplitude=24.70093435, x_0=43.6006346, gamma=10.92239773, alpha=1.61445851)>
#
#     [2]: <Moffat1D(amplitude=6.53936469, x_0=33.77956711, gamma=1.04676089, alpha=1.54218114)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_2           alpha_2
#     -------------------- ------------------ ... ----------------- -----------------
#     -0.21729662005560593 24.700934347831936 ... 1.046760887199845 1.542181135435357
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=0.36950205)>
#
# ...

# %%
def tie_pos1_gauss(model):
    return model.mean_1 - 8.5     #28.43

def tie_pos2_gauss(model):
     return model.x_0_2 + 10.5        # 32.289
    
def tie_stddev_gauss(model):
    return model.stddev_1

def tie_pos1_moffat(model):
     return model.x_0_1 - 8.0
            
def tie_pos2_moffat(model):
    return model.x_0_1 + 11.0

def tie_gamma_moffat(model):
    return model.gamma_1

def tie_alpha_moffat(model):
    return model.alpha_1 

for sp in spec_list[2:]:
    sp.mod0[3].x_0.tied = tie_pos1_moffat
    #sp.mod0[3].x_0.tied = tie_pos2_moffat
    sp.mod0[1].mean.tied = tie_pos2_gauss
    #sp.mod0[3].stddev.tied = tie_stddev_gauss
    #sp.mod0[2].gamma.tied = tie_gamma_moffat
    #sp.mod0[2].alpha.tied = tie_alpha_moffat
    sp.mod0[3].gamma.tied = tie_gamma_moffat
    sp.mod0[3].alpha.tied = tie_alpha_moffat
    sp.refined_model(sp.mod0)
    
#spec.mod0[3].x_0.tied = tie_pos1_moffat 
#spec.mod0[2].x_0.tied = tie_pos2_moffat 



#spec.mod0[2].gamma.tied = tie_gamma_moffat
#spec.mod0[2].alpha.tied = tie_alpha_moffat
#spec.mod0[3].gamma.tied = tie_gamma_moffat
#spec.mod0[3].alpha.tied = tie_alpha_moffat

#mod1[4].stddev = 3.0
#mod1[4].stddev.fixed = True

# for two Gaussian profile
#mod[1].mean.tied = tie_pos1_gauss 
#mod[3].mean.tied = tie_pos2_gauss 
#mod1[4].mean.tied = tie_pos4_gauss 
#mod1[4].mean.tied = tie_pos4_gauss
# Out:
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.26617982)>
#
#     [1]: <Gaussian1D(amplitude=16.62466438, mean=44.13363849, stddev=6.20325134)>
#
#     [2]: <Moffat1D(amplitude=10.04292462, x_0=43.34000829, gamma=5.58538314, alpha=0.82585688)>
#
#     [3]: <Moffat1D(amplitude=5.57463664, x_0=35.20991344, gamma=8.33534815, alpha=2.38050859)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_3           alpha_3
#     ------------------- ------------------ ... ----------------- -----------------
#     0.26617982216420544 16.624664376055428 ... 8.335348154575248 2.380508590133346
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
# ...

# %%
#mod[1].stddev.bounds = (0, 8.5)

# %%
#mod_new = spec.refined_model(mod)

# %%
for sp in spec_list:
    sp.find_and_trace(sp.mod0, stepsize=25, fitorder={'x_0_1':3, 'x_0_2':3},
                    fitrange=[0,4100], polyorder=4)
    plt.show()
# Out:
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
#     Done
# Fitting polynomial of degree 4 to parameter: c0_0
# Fitting polynomial of degree 3 to parameter: x_0_1
# Fitting polynomial of degree 4 to parameter: gamma_1
# Fitting polynomial of degree 4 to parameter: alpha_1
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
#     Done
# Fitting polynomial of degree 4 to parameter: c0_0
# Fitting polynomial of degree 3 to parameter: x_0_1
# Fitting polynomial of degree 4 to parameter: gamma_1
# Fitting polynomial of degree 4 to parameter: alpha_1
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
#     Done
# ...

# %%
for sp in spec_list[2:]:
    sp.find_and_trace(sp.mod0, stepsize=50, fitorder={'stddev_1':3, 'stddev_2':3, 'gamma_2':3, 'alpha_2':3},
                    fitrange=[0,4100], polyorder=3)
    plt.show()
# Out:
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 81 segments
#   of the 2D spectrum with stepsize=50 pix ...
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 3 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 3 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 3 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 81 segments
#   of the 2D spectrum with stepsize=50 pix ...
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 3 to parameter: mean_1
# ...

# %%
for sp in spec_list:
    sp.extract(method='modelfit')
    plt.show()
# Out:
# Fitting to 1 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 0 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  5650.60
#  Spectrum End:     8926.60
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#
#
# Plotting the spectrum
# Fitting to 1 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 0 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  5651.22
#  Spectrum End:     8927.22
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#
#
# Plotting the spectrum
# Fitting to 1 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 0 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  5651.72
# ...

# %%
for sp in spec_list:
    for spec in sp.spectra:
        sp_d = spec1d.Spec1d(wav=spec[1]['wav'], flux=spec[1]['flux'],
                     var=spec[1]['var'], trimsec=[5, -10])
        sp_d.smooth(11)
        plt.show()
# Out:
#  Spectrum Start:  5654.60
#  Spectrum End:     8918.60
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#  Spectrum Start:  5655.21
#  Spectrum End:     8919.22
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#  Spectrum Start:  5655.72
#  Spectrum End:     8919.72
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#  Spectrum Start:  5655.42
#  Spectrum End:     8919.43
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#  Spectrum Start:  5655.28
#  Spectrum End:     8919.28
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80

# %%
resp_sp = spec1d.Spec1d('../other_spectra/response_curve_from_feige110_r12132020.txt')
# Out:
# Reading spectrum from ../other_spectra/response_curve_from_feige110_r12132020.txt
# Expected file format: text
#  Spectrum Start:  5649.45
#  Spectrum End:     8924.96
#  Dispersion (1st pixel):   0.77
#  Dispersion (average):      0.80

# %%
for sp in spec_list:
    for spec in sp.spectra:
        print(spec[0])
        resp_sp.resample(owave=spec[1]['wav'])
        spec[1].resp_corr(resp_sp.rsflux*10**-2, action='divide')
        spec[1].smooth(11)
        plt.show()
# Out:
# Extracted Spectrum from moffat_1
# resample: replacing input spectrum with resampled version
# resample: for now not resampling the variance
# Extracted Spectrum from moffat_1
# resample: replacing input spectrum with resampled version
# resample: for now not resampling the variance
# Extracted Spectrum from moffat_1
# resample: replacing input spectrum with resampled version
# resample: for now not resampling the variance
# Extracted Spectrum from moffat_1
# resample: replacing input spectrum with resampled version
# resample: for now not resampling the variance
# Extracted Spectrum from moffat_1
# resample: replacing input spectrum with resampled version
# resample: for now not resampling the variance

# %%
coadd_de = spec1.spectra[0][1]
#coadd_other = spec5.spectra[1][1]
#coadd_im = spec1.spectra[1][1]

# %%
for sp in spec_list[1:]:
    for i, spec in enumerate(sp.spectra):
        spec[1].resample(owave=coadd_de['wav'])
        varmod = interpolate.splrep(spec[1]['wav'], np.sqrt(spec[1]['var']))
        varout = interpolate.splev(coadd_de['wav'], varmod)**2

        resampled_sp = spec1d.Spec1d(wav=spec[1].rswav, flux=spec[1].rsflux, var=varout)
        if i==0:
            coadd_de = coadd_de.__add__(resampled_sp)
            coadd_de.smooth(7)
            plt.show()
        #elif i==1:
            #coadd_other = coadd_other.__add__(resampled_sp)
        else:
            coadd_im = coadd_im.__add__(resampled_sp)
# Out:
# resample: replacing input spectrum with resampled version
# resample: for now not resampling the variance
#  Spectrum Start:  5650.60
#  Spectrum End:     8926.60
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#
#  Spectrum Start:  5650.60
#  Spectrum End:     8926.60
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
# resample: replacing input spectrum with resampled version
# resample: for now not resampling the variance
#  Spectrum Start:  5650.60
#  Spectrum End:     8926.60
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#
#  Spectrum Start:  5650.60
#  Spectrum End:     8926.60
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
# resample: replacing input spectrum with resampled version
# resample: for now not resampling the variance
#  Spectrum Start:  5650.60
#  Spectrum End:     8926.60
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#
#  Spectrum Start:  5650.60
# ...

# %%
# %matplotlib notebook
sppp = spec1d.Spec1d(wav=coadd_de['wav'], flux=coadd_de['flux'],
                     var=coadd_de['var'], trimsec=[15, -470])
sppp.smooth(1)
sppp.mark_lines('abs', z=0.558, usesmooth=True)
# Out:
#  Spectrum Start:  5662.59
#  Spectrum End:     8550.60
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-kappa       3750.00       5842.50
# [Fe VII]      3761.40       5860.26
# H-iota        3770.00       5873.66
# H-theta       3797.00       5915.73
# H-eta         3835.00       5974.93
# CN bandhd     3883.00       6049.71
# CaII K        3933.67       6128.66
# CaII H        3968.47       6182.88
# H-delta       4101.00       6389.36
# G-band        4305.00       6707.19
# H-gamma       4340.00       6761.72
# Fe4383        4383.00       6828.71
# Ca4455        4455.00       6940.89
# Fe4531        4531.00       7059.30
# H-beta        4861.00       7573.44
# Mg I (b)      5176.00       8064.21

# %%
sppp = spec1d.Spec1d('B0445_LRIS_spectra/spec1d_B0445_lris_coadd1d_deflector.fits', informat='fits',
                     trimsec=[15, -470])
# Out:
# Reading spectrum from B0445_LRIS_spectra/spec1d_B0445_lris_coadd1d_deflector.fits
# Expected file format: fits
#  Spectrum Start:  5662.59
#  Spectrum End:     8550.60
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80

# %%
# %matplotlib notebook
#sppp = spec1d.Spec1d(wav=coadd_de['wav'], flux=coadd_de['flux'],
#                     var=coadd_de['var'], trimsec=[15, -470])
sppp.smooth(1)
sppp.mark_lines('abs', z=0.558, usesmooth=True)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-kappa       3750.00       5842.50
# [Fe VII]      3761.40       5860.26
# H-iota        3770.00       5873.66
# H-theta       3797.00       5915.73
# H-eta         3835.00       5974.93
# CN bandhd     3883.00       6049.71
# CaII K        3933.67       6128.66
# CaII H        3968.47       6182.88
# H-delta       4101.00       6389.36
# G-band        4305.00       6707.19
# H-gamma       4340.00       6761.72
# Fe4383        4383.00       6828.71
# Ca4455        4455.00       6940.89
# Fe4531        4531.00       7059.30
# H-beta        4861.00       7573.44
# Mg I (b)      5176.00       8064.21

# %%
coadd_de.save('B0445_LRIS_spectra/spec1d_B0445_lris_coadd1d_deflector_Jan2022.fits', outformat='fits')
# Out:
# Saved spectrum to file B0445_LRIS_spectra/spec1d_B0445_lris_coadd1d_deflector_Jan2022.fits in format fits

# %%
#%matplotlib notebook
spp = spec1d.Spec1d(wav=coadd_im['wav'], flux=coadd_im['flux'],
                     var=coadd_im['var'], trimsec=[15, -160])
spp.smooth(31)
#sppp.mark_lines('em', z=2.385, usesmooth=True)
# Out:
#  Spectrum Start:  5662.59
#  Spectrum End:     8798.61
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
resp_sp.plot()

# %%
resp_sp.resample(owave=spec.spectra[2][1]['wav'])
# Out:
# resample: replacing input spectrum with resampled version
# resample: for now not resampling the variance

# %%
spec.spectra[2][1].resp_corr(resp_sp.rsflux*10**-2, action='divide')

# %%
sp = spec1d.Spec1d(wav=spec.spectra[2][1]['wav'], flux=spec.spectra[2][1]['flux'],
                     var=spec.spectra[2][1]['var'], trimsec=[0, -160])
# Out:
#  Spectrum Start:  5651.43
#  Spectrum End:     8799.43
#  Dispersion (1st pixel):   0.79
#  Dispersion (average):      0.80

# %%
sp.smooth(31)
sp.mark_lines('strongem', z=2.85, usesmooth=True)
# Out:
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# N IV]         1486.50       5723.03
# C IV          1549.10       5964.03
# Al III        1858.70       7155.99
# Si III]       1892.00       7284.20
# C III]        1908.70       7348.49

# %%
# %matplotlib notebook
spec1.smooth(5)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
spec.spectra[0][1].save('spec1d_B0445_r0029_bright.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_B0445_r0029_bright.fits in format fits

# %%
sp = spec1d.Spec1d('spec1d_B0445_r0029_bright.fits', informat='fits', trimsec=[0, 4050])
# Out:
# Reading spectrum from spec1d_B0445_r0029_bright.fits
# Expected file format: fits
#  Spectrum Start:  5650.03
#  Spectrum End:     8889.26
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80

# %%
flag = 1
for i,p in enumerate(glob.glob('*')):
    if 'spec1d' in p and 'bright' not in p:
        print(p)
        if flag :
            spec_coadd = spec1d.Spec1d(p, informat='fits', trimsec=[0, 3930])
            flag = 0 
            k = 0
        else:
            sp = spec1d.Spec1d(p, informat='fits', trimsec=[0, 3930])
            k = k+1
        if k:    
            spec_coadd = spec_coadd.__add__(sp)
# Out:
# spec1d_B0445_r0030.fits
#
# Reading spectrum from spec1d_B0445_r0030.fits
# Expected file format: fits
#  Spectrum Start:  5651.17
#  Spectrum End:     8794.39
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#
# spec1d_B0445_r0031.fits
#
# Reading spectrum from spec1d_B0445_r0031.fits
# Expected file format: fits
#  Spectrum Start:  5651.67
#  Spectrum End:     8794.89
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#
#  Spectrum Start:  5651.17
#  Spectrum End:     8794.39
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#
# spec1d_B0445_r0033.fits
#
# Reading spectrum from spec1d_B0445_r0033.fits
# Expected file format: fits
#  Spectrum Start:  5651.23
#  Spectrum End:     8794.46
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#
#  Spectrum Start:  5651.17
#  Spectrum End:     8794.39
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#
# spec1d_B0445_r0032.fits
#
# ...

# %%
spec_coadd.plot()
#spec_coadd.mark_lines('abs', z=0.558, usesmooth=True)
# Out:
# <img src="data:image/png;base64,..." width="754.5454381911226">
# <img src="data:image/png;base64,..." width="754.5454381911226">

# %%
flag = 1
for i,p in enumerate(glob.glob('*')):
    if 'spec1d' in p and 'bright' in p:
        print(p)
        if flag :
            spec_coadd = spec1d.Spec1d(p, informat='fits', trimsec=[0, 4050])
            flag = 0 
            k = 0
        else:
            sp = spec1d.Spec1d(p, informat='fits', trimsec=[0, 4050])
            k = k+1
        if k:    
            spec_coadd = spec_coadd.__add__(sp)
# Out:
# spec1d_B0445_r0029_bright.fits
#
# Reading spectrum from spec1d_B0445_r0029_bright.fits
# Expected file format: fits
#  Spectrum Start:  5650.03
#  Spectrum End:     8889.26
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#
# spec1d_B0445_r0033_bright.fits
#
# Reading spectrum from spec1d_B0445_r0033_bright.fits
# Expected file format: fits
#  Spectrum Start:  5650.71
#  Spectrum End:     8889.94
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#
#  Spectrum Start:  5650.03
#  Spectrum End:     8889.26
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#
# spec1d_B0445_r0031_bright.fits
#
# Reading spectrum from spec1d_B0445_r0031_bright.fits
# Expected file format: fits
#  Spectrum Start:  5651.15
#  Spectrum End:     8890.38
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#
#  Spectrum Start:  5650.03
#  Spectrum End:     8889.26
#  Dispersion (1st pixel):   0.80
#  Dispersion (average):      0.80
#
# ...

# %%
spec_coadd.plot()
# Out:
# <img src="data:image/png;base64,..." width="838.1818000147169">
# <img src="data:image/png;base64,..." width="838.1818000147169">

# %%
spec_coadd.smooth(7)
spec_coadd.mark_lines('abs', z=0.00005, usesmooth=True)
# Out:
# <img src="data:image/png;base64,..." width="1004.5454327725187">
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# Na I (D)      5889.95       5890.24
# Na I (D)      5895.92       5896.21
# H-alpha       6562.80       6563.13
# Ca triplet    8498.03       8498.45
# Ca triplet    8542.09       8542.52
# Ca triplet    8662.14       8662.57

# %%
spec.spectra[0][1]['sky']

# %%
for i in range(9, -1, -1):
    print(i)

# %%
a = np.array([np.nan, np.nan, np.nan, np.nan])

# %%
np.nanmedian(a)
# Out:
# nan

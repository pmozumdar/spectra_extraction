# %%
## Most of the contribution for this code snippet is from Chris 

from astropy.io import fits as pf

# %%
f26a = pf.open('../galaxy_spectra/LRIS_red_data_201213/Raw_data/r201213_0026a.fits', mode='update')
f26b = pf.open('../galaxy_spectra/LRIS_red_data_201213/Raw_data/r201213_0026b.fits')
hdra = f26a[0].header
hdrb = f26b[0].header

# %%
hdrb
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# BZERO   =                32768 / offset data range to that of unsigned short
# BSCALE  =                    1 / default scaling factor
# DATE    = '2020-12-13T05:36:27' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# COMMENT BEGIN observation-specific keywords written by write_image
# COMMENT BEGIN keywords that came from KTL via watch_ccd
# TEMPDET =        -109.84648132
# TEMPSET =        -109.94863892
# UTBTEMP =           2.00000000
# UTBP30V =          34.78017426
# UTBP15V =          16.37276840
# UTBM15V =         -16.22767830
# ...

# %%
hd_key = ['SLITGRAB', 'SLITMASK', 'SLITNAME', 
          'BLUFILT', 'BLUFNUM', 'BLUFNUM', 'BLUFTRAN', 'BTRAN', 'BLUFOCUS', 'DICHNAME', 'DICHROIC',
          'DICHTRAN', 'DTRAN', 'GRANAME', 'GRANGLE', 'GRATING', 'GRISM', 'GRISNAME', 'GRISTRAN', 'GTRAN', 
          'INSTRUME', 'REDFILT', 'REDFNUM', 'REDFOCUS', 'TRAPDOOR', 'MERCURY', 'NEON', 'ARGON', 'CADMIUM',
          'ZINC', 'HALOGEN', 'KRYPTON', 'XENON', 'FEARGON', 'DEUTERI', 'FLAMP1', 'FLAMP2', 'MJD-OBS',
          'AIRMASS', 'OBJECT', 'DEC', 'RA','TARGNAME', 'TTIME', 'ELAPTIME', 'EXPTIME', 'POSTPIX', 'NUMAMPS']

# %%
for k in hd_key:
    if k in hdrb.keys():
        #print(k)
        if k in hdra.keys():
            pass
        else:
            hdra[k] = hdrb[k]
            print(k)
        
f26a.flush()
f26b.close()
# Out:
# NUMAMPS

# %%
hdra
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# BZERO   =                32768 / offset data range to that of unsigned short
# BSCALE  =                    1 / default scaling factor
# DATE    = '2020-12-13T06:20:16' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# COMMENT BEGIN observation-specific keywords written by write_image
# COMMENT BEGIN keywords that came from CCD crate imparm structure
# IMTYPE  = 'MOSAIC  '
# PRECOL  =                    7
# PREROW  =                    0
# PRELINE =                    0
# POSTLINE=                   20
# ERASLINE=                    0
# KEEPPREP=                    1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from astropy.io import fits
from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, spec1d, echelle1d
from scipy.ndimage import shift

# %%
file_loc = '../galaxy_spectra/ESI_data/2019_04/*'

# %%
spec2d_file_list = []
var2d_file_list = []
#out_file = []
for i,p in enumerate(glob.glob(file_loc)):
    if 'J1433' in p:
        if 'bgsub.fits' in p:
            spec2d_file_list.append(p)
        elif 'var.fits' in p:
            var2d_file_list.append(p)

# %%
spec2d_file_list, var2d_file_list
# Out:
# (['../galaxy_spectra/ESI_data/2019_04/J1433+6007_0043_bgsub.fits',
#   '../galaxy_spectra/ESI_data/2019_04/J1433+6007_0045_bgsub.fits',
#   '../galaxy_spectra/ESI_data/2019_04/J1433+6007_0044_bgsub.fits'],
#  ['../galaxy_spectra/ESI_data/2019_04/J1433+6007_0044_var.fits',
#   '../galaxy_spectra/ESI_data/2019_04/J1433+6007_0045_var.fits',
#   '../galaxy_spectra/ESI_data/2019_04/J1433+6007_0043_var.fits'])

# %%
# create a list of spec2d object for particular order
spec1 = esi2d.Esi2d(spec2d_file_list[0], varfile=var2d_file_list[2])
spec2 = esi2d.Esi2d(spec2d_file_list[2], varfile=var2d_file_list[0])
spec3 = esi2d.Esi2d(spec2d_file_list[1], varfile=var2d_file_list[1])
# Out:
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3466x163     x
#   2   4093x154     x
#   3   4096x147     x
#   4   4096x140     x
#   5   4096x136     x
#   6   4096x128     x
#   7   4096x126     x
#   8   4096x121     x
#   9   4096x116     x
#  10   4096x115     x
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3466x163     x
#   2   4093x154     x
#   3   4096x147     x
#   4   4096x140     x
#   5   4096x136     x
#   6   4096x128     x
#   7   4096x126     x
#   8   4096x121     x
#   9   4096x116     x
#  10   4096x115     x
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3466x163     x
#   2   4093x154     x
#   3   4096x147     x
#   4   4096x140     x
#   5   4096x136     x
#   6   4096x128     x
#   7   4096x126     x
#   8   4096x121     x
#   9   4096x116     x
#  10   4096x115     x

# %%
pixrange = [[2200, 2600],[2200, 2600], [2700, 3100], [2100, 2500], [1800, 2200],
            [1600, 2000], [1500, 1900], [800, 1200]]
spec_list = [spec1, spec2, spec3]
order_list = spec1.ordinfo

for order, pix in zip(order_list[2:], pixrange):
    print(order['name'], 'pixscale:', order['pixscale'])
    for sp in spec_list:
        profile = sp[order['order']-1].spatial_profile(pixrange=pix)
        plt.show()
        sp[order['order']-1].initial_model()
# Out:
# Order_03 pixscale: 0.134
# Profile max value (before normalization) 20.598807
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 18, 67, 3, 4
#
# amplitude=18.000000, x_0=67.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 5, 46, 3, 4
#
# amplitude=5.000000, x_0=46.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.27555001)>
#
#     [1]: <Moffat1D(amplitude=18.35585727, x_0=68.67430362, gamma=10.1555013, alpha=3.3506562)>
#
#     [2]: <Moffat1D(amplitude=3.52419117, x_0=50.9340518, gamma=28.45218499, alpha=13.15042445)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_2            alpha_2
#     -------------------- ----------------- ... ------------------ ------------------
#     -0.27555000660629275 18.35585726849576 ... 28.452184994862485 13.150424452104001
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 22.798444
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 25, 104, 3, 4
#
# amplitude=25.000000, x_0=104.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 5, 83, 3, 4
#
# amplitude=5.000000, x_0=83.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.23167939)>
#
#     [1]: <Moffat1D(amplitude=22.3346954, x_0=105.3127078, gamma=9.28847733, alpha=4.15256818)>
#
#     [2]: <Moffat1D(amplitude=4.13644223, x_0=87.90920768, gamma=32.43306244, alpha=13.97606885)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_2           alpha_2
#     -------------------- ------------------ ... ----------------- ------------------
#     -0.23167938998471196 22.334695397982603 ... 32.43306244314345 13.976068848265506
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 27.107085
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 23, 28, 3, 4
#
# amplitude=23.000000, x_0=28.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 4, 7, 3, 4
#
# amplitude=4.000000, x_0=7.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.04955193)>
#
#     [1]: <Moffat1D(amplitude=22.61595527, x_0=30.02143456, gamma=9.85682835, alpha=4.9424731)>
#
#     [2]: <Moffat1D(amplitude=2.70246194, x_0=13.58989039, gamma=30.23991559, alpha=22.09968666)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2            alpha_2
#     -------------------- ---------------- ... ------------------ ------------------
#     -0.04955193268473076 22.6159552691326 ... 30.239915589372306 22.099686661630976
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_04 pixscale: 0.137
# Profile max value (before normalization) 22.481895
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 25, 63, 3, 4
#
# amplitude=25.000000, x_0=63.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 7, 43, 3, 4
#
# amplitude=7.000000, x_0=43.000000, gamma=3.000000, alpha=4.000000
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.69410938)>
#
#     [1]: <Moffat1D(amplitude=22.48383119, x_0=65.27091018, gamma=7.03351739, alpha=2.10328946)>
#
#     [2]: <Moffat1D(amplitude=6.09611619, x_0=49.641578, gamma=32.58717388, alpha=13.32283919)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2           alpha_2
#     ------------------- ----------------- ... ----------------- -----------------
#     -0.6941093832919434 22.48383118696416 ... 32.58717387624668 13.32283918964028
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 26.369652
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 26, 100, 3, 4
#
# amplitude=26.000000, x_0=100.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 7, 80, 3, 4
#
# amplitude=7.000000, x_0=80.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.76508351)>
#
#     [1]: <Moffat1D(amplitude=26.38834048, x_0=100.32851498, gamma=7.95141355, alpha=3.14311953)>
#
#     [2]: <Moffat1D(amplitude=7.14771643, x_0=84.78882699, gamma=24.94037492, alpha=8.3346834)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ -----------------
#     -0.7650835142527982 26.388340475623792 ... 24.940374924160132 8.334683403001703
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 26.359414
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 26, 28, 3, 4
#
# amplitude=26.000000, x_0=28.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 5, 8, 3, 4
#
# amplitude=5.000000, x_0=8.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.46686588)>
#
#     [1]: <Moffat1D(amplitude=26.9771554, x_0=29.07595411, gamma=9.51587204, alpha=5.13546799)>
#
#     [2]: <Moffat1D(amplitude=5.36977552, x_0=14.94835381, gamma=26.34604507, alpha=13.42556335)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_2           alpha_2
#     -------------------- ------------------ ... ----------------- ------------------
#     -0.46686587656539796 26.977155404978483 ... 26.34604506530279 13.425563349725625
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_05 pixscale: 0.144
# Profile max value (before normalization) 42.645960
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 45, 62, 3, 4
#
# amplitude=45.000000, x_0=62.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 16, 46, 3, 4
#
# amplitude=16.000000, x_0=46.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.8675975)>
#
#     [1]: <Moffat1D(amplitude=42.70405579, x_0=63.1048204, gamma=6.69668376, alpha=2.11351033)>
#
#     [2]: <Moffat1D(amplitude=14.96579035, x_0=48.1798653, gamma=44.52796296, alpha=23.76906521)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2            alpha_2
#     ------------------- ----------------- ... ------------------ -----------------
#     -0.8675974989506715 42.70405579174328 ... 44.527962958999126 23.76906520919777
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 51.781379
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 50, 97, 3, 4
#
# amplitude=50.000000, x_0=97.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 20, 82, 3, 4
#
# amplitude=20.000000, x_0=82.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.80888823)>
#
#     [1]: <Moffat1D(amplitude=50.53333243, x_0=96.82586672, gamma=5.84002043, alpha=2.12767866)>
#
#     [2]: <Moffat1D(amplitude=17.09371161, x_0=81.65493328, gamma=24.88947307, alpha=7.5960227)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2           alpha_2
#     ------------------- ------------------ ... ----------------- -----------------
#     -0.8088882274171229 50.533332427961646 ... 24.88947307162288 7.596022700468318
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 50.020622
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 50, 27, 3, 4
#
# amplitude=50.000000, x_0=27.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 10, 15, 3, 4
#
# amplitude=10.000000, x_0=15.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.98696785)>
#
#     [1]: <Moffat1D(amplitude=50.56311588, x_0=28.95801485, gamma=12.00015246, alpha=8.50684672)>
#
#     [2]: <Moffat1D(amplitude=12.3658135, x_0=14.42039786, gamma=43.12121622, alpha=35.65612931)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2           alpha_2
#     ------------------- ----------------- ... ------------------ ----------------
#     -0.9869678512795383 50.56311588263482 ... 43.121216221457544 35.6561293086952
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_06 pixscale: 0.149
# Profile max value (before normalization) 36.753470
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 38, 57, 3, 4
#
# amplitude=38.000000, x_0=57.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 20, 44, 3, 4
#
# amplitude=20.000000, x_0=44.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.58376946)>
#
#     [1]: <Moffat1D(amplitude=35.63667487, x_0=57.13873813, gamma=6.7821665, alpha=2.20387004)>
#
#     [2]: <Moffat1D(amplitude=16.56683256, x_0=44.11774452, gamma=37.7511347, alpha=18.05459703)>
# Parameters:
#             c0_0          amplitude_1    ...      gamma_2            alpha_2
#     ------------------- ---------------- ... ------------------ ------------------
#     -0.5837694554225388 35.6366748662625 ... 37.751134698226295 18.054597025762178
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 45.300570
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 50, 90, 3, 4
#
# amplitude=50.000000, x_0=90.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 20, 77, 3, 4
#
# amplitude=20.000000, x_0=77.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.67916548)>
#
#     [1]: <Moffat1D(amplitude=43.82785888, x_0=89.7541223, gamma=5.18911251, alpha=1.93243767)>
#
#     [2]: <Moffat1D(amplitude=19.30536058, x_0=76.85426547, gamma=21.56840257, alpha=6.4036807)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2           alpha_2
#     ------------------- ------------------ ... ----------------- -----------------
#     -0.6791654819796734 43.827858881261015 ... 21.56840256812993 6.403680698413845
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 47.031712
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 50, 23, 3, 4
#
# amplitude=50.000000, x_0=23.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 20, 12, 3, 4
#
# amplitude=20.000000, x_0=12.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.3296317)>
#
#     [1]: <Moffat1D(amplitude=45.33348017, x_0=24.30656042, gamma=7.61524191, alpha=3.93038799)>
#
#     [2]: <Moffat1D(amplitude=18.96164255, x_0=11.34619233, gamma=38.16807919, alpha=18.99091767)>
# Parameters:
#             c0_0          amplitude_1    ...      gamma_2           alpha_2
#     ------------------- ---------------- ... ----------------- -----------------
#     -0.3296317031175109 45.3334801679978 ... 38.16807919435044 18.99091767128491
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_07 pixscale: 0.153
# Profile max value (before normalization) 32.509935
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 35, 56, 3, 4
#
# amplitude=35.000000, x_0=56.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 28, 43, 3, 4
#
# amplitude=28.000000, x_0=43.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.61832482)>
#
#     [1]: <Moffat1D(amplitude=28.51568828, x_0=56.33800777, gamma=7.25286555, alpha=2.63276404)>
#
#     [2]: <Moffat1D(amplitude=26.02815058, x_0=44.57599065, gamma=12.36461097, alpha=2.8482801)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ ------------------
#     -0.6183248227608277 28.515688280374064 ... 12.364610972264913 2.8482800992573556
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 38.727463
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 38, 87, 3, 4
#
# amplitude=38.000000, x_0=87.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 30, 77, 3, 4
#
# amplitude=30.000000, x_0=77.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.58575177)>
#
#     [1]: <Moffat1D(amplitude=34.59705979, x_0=88.02649898, gamma=4.8804251, alpha=1.81738815)>
#
#     [2]: <Moffat1D(amplitude=28.86320836, x_0=76.39613228, gamma=10.0031919, alpha=2.16510458)>
# Parameters:
#             c0_0          amplitude_1    ...      gamma_2           alpha_2
#     ------------------- ---------------- ... ----------------- -----------------
#     -0.5857517720556721 34.5970597880436 ... 10.00319189809943 2.165104581069293
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 40.050602
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 40, 22, 3, 4
#
# amplitude=40.000000, x_0=22.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 32, 11, 3, 4
#
# amplitude=32.000000, x_0=11.000000, gamma=3.000000, alpha=4.000000
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.28575834)>
#
#     [1]: <Moffat1D(amplitude=36.07382949, x_0=24.62692519, gamma=7.54586131, alpha=3.9480816)>
#
#     [2]: <Moffat1D(amplitude=29.63869627, x_0=12.94981961, gamma=10.87115014, alpha=2.73349527)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_2           alpha_2
#     -------------------- ----------------- ... ------------------ ----------------
#     -0.28575834364282665 36.07382948774749 ... 10.871150137208433 2.73349526748889
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Order_08 pixscale: 0.158
# Profile max value (before normalization) 36.096674
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 32, 54, 3, 4
#
# amplitude=32.000000, x_0=54.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 36, 42, 3, 4
#
# amplitude=36.000000, x_0=42.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.75813848)>
#
#     [1]: <Moffat1D(amplitude=29.72057931, x_0=53.57817408, gamma=5.85226296, alpha=1.82828325)>
#
#     [2]: <Moffat1D(amplitude=34.51552266, x_0=42.16071448, gamma=10.79930578, alpha=2.57956485)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ ------------------
#     -0.7581384840939087 29.720579307154676 ... 10.799305779804559 2.5795648490529723
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 40.910843
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 37, 44, 3, 4
#
# amplitude=37.000000, x_0=44.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 40, 71, 3, 4
#
# amplitude=40.000000, x_0=71.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.78464939)>
#
#     [1]: <Moffat1D(amplitude=1.19460709, x_0=44.22511821, gamma=3.25580143, alpha=4.53126116)>
#
#     [2]: <Moffat1D(amplitude=37.95732615, x_0=77.39430655, gamma=29.04292087, alpha=5.51236355)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ -----------------
#     -0.7846493922933769 1.1946070902823378 ... 29.042920867197182 5.512363546771596
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# yes
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 37, 84, 3, 4
#
# amplitude=37.000000, x_0=84.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 40, 71, 3, 4
#
# amplitude=40.000000, x_0=71.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.00595293)>
#
#     [1]: <Moffat1D(amplitude=33.56543651, x_0=84.2922519, gamma=5.28310257, alpha=2.06456962)>
#
#     [2]: <Moffat1D(amplitude=38.70855344, x_0=73.30122693, gamma=7.33716457, alpha=1.5033761)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2          alpha_2
#     ------------------- ----------------- ... ----------------- ----------------
#     -1.0059529284811424 33.56543651057749 ... 7.337164565353369 1.50337609950203
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 40.848986
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 40, 21, 3, 4
#
# amplitude=40.000000, x_0=21.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 40, 10, 3, 4
#
# amplitude=40.000000, x_0=10.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.31663217)>
#
#     [1]: <Moffat1D(amplitude=35.34141292, x_0=22.8026232, gamma=7.68044516, alpha=3.8115922)>
#
#     [2]: <Moffat1D(amplitude=39.42114712, x_0=11.4656241, gamma=8.0942229, alpha=1.96433976)>
# Parameters:
#             c0_0            amplitude_1    ...     gamma_2           alpha_2
#     -------------------- ----------------- ... ---------------- ------------------
#     -0.31663217206981153 35.34141292211285 ... 8.09422289598909 1.9643397562832312
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_09 pixscale: 0.163
# Profile max value (before normalization) 40.899610
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 35, 50, 3, 4
#
# amplitude=35.000000, x_0=50.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 40, 40, 3, 4
#
# amplitude=40.000000, x_0=40.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.72048571)>
#
#     [1]: <Moffat1D(amplitude=27.65933503, x_0=50.6627486, gamma=7.14977426, alpha=2.56036249)>
#
#     [2]: <Moffat1D(amplitude=39.33876882, x_0=39.81476421, gamma=9.32612691, alpha=2.18998313)>
# Parameters:
#             c0_0           amplitude_1     ...     gamma_2           alpha_2
#     ------------------- ------------------ ... ---------------- -----------------
#     -0.7204857068349374 27.659335031827496 ... 9.32612690879999 2.189983128303807
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 44.407342
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 37, 39, 3, 4
#
# amplitude=37.000000, x_0=39.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 43, 70, 3, 4
#
# amplitude=43.000000, x_0=70.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.93577921)>
#
#     [1]: <Moffat1D(amplitude=0.32074356, x_0=39.00769478, gamma=0.70435129, alpha=6.77948603)>
#
#     [2]: <Moffat1D(amplitude=39.91790342, x_0=73.48081606, gamma=29.61839112, alpha=6.15162236)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_2           alpha_2
#     ------------------ ------------------ ... ------------------ ----------------
#     -0.935779210015771 0.3207435560027582 ... 29.618391117853804 6.15162236204445
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# yes
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 37, 79, 3, 4
#
# amplitude=37.000000, x_0=79.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 43, 70, 3, 4
#
# amplitude=43.000000, x_0=70.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.89523285)>
#
#     [1]: <Moffat1D(amplitude=30.57868471, x_0=80.85872106, gamma=5.61257463, alpha=2.14809389)>
#
#     [2]: <Moffat1D(amplitude=42.29314267, x_0=70.08528519, gamma=7.89430236, alpha=1.78585541)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ -----------------
#     -0.8952328489657111 30.578684707579765 ... 7.8943023554612575 1.785855410019677
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 45.979250
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 38, 20, 3, 4
#
# amplitude=38.000000, x_0=20.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 50, 9, 3, 4
#
# amplitude=50.000000, x_0=9.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.34724548)>
#
#     [1]: <Moffat1D(amplitude=32.57194473, x_0=21.2077047, gamma=6.78266029, alpha=3.08216257)>
#
#     [2]: <Moffat1D(amplitude=44.46278399, x_0=10.31476459, gamma=7.78225217, alpha=1.81907608)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_2           alpha_2
#     -------------------- ------------------ ... ----------------- ------------------
#     -0.34724548405907735 32.571944732799125 ... 7.782252167305304 1.8190760784114341
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_10 pixscale: 0.168
# Profile max value (before normalization) 13.107985
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 10, 49, 3, 4
#
# amplitude=10.000000, x_0=49.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 14, 39, 3, 4
#
# amplitude=14.000000, x_0=39.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.1632236)>
#
#     [1]: <Moffat1D(amplitude=8.37779344, x_0=50.3986097, gamma=12.46186426, alpha=9.33942718)>
#
#     [2]: <Moffat1D(amplitude=12.49685084, x_0=39.46817312, gamma=11.17294398, alpha=2.81966557)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_2            alpha_2
#     -------------------- ----------------- ... ------------------ -----------------
#     -0.16322360295004315 8.377793443108981 ... 11.172943975776134 2.819665572224395
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 14.739843
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 13,78, 3, 4
#
# amplitude=13.000000, x_0=78.000000, gamma=3.000000, alpha=4.000000

# %%
pixrange = [[2200, 2600],[2200, 2600], [2700, 3100], [2100, 2500], [1800, 2200],
            [1600, 2000], [1500, 1900], [800, 1200]]
spec_list = [spec1, spec2, spec3]
order_list = spec1.ordinfo

for order, pix in zip(order_list[2:], pixrange):
    if order['order']==10:
        print(order['name'], 'pixscale:', order['pixscale'])
        for sp in spec_list:
            profile = sp[order['order']-1].spatial_profile(pixrange=pix)
            plt.show()
            sp[order['order']-1].initial_model()
# Out:
# Order_10 pixscale: 0.168
# Profile max value (before normalization) 13.107985
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 10, 49, 3, 4
#
# amplitude=10.000000, x_0=49.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 14, 39, 3, 4
#
# amplitude=14.000000, x_0=39.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.1632236)>
#
#     [1]: <Moffat1D(amplitude=8.37779344, x_0=50.3986097, gamma=12.46186426, alpha=9.33942718)>
#
#     [2]: <Moffat1D(amplitude=12.49685084, x_0=39.46817312, gamma=11.17294398, alpha=2.81966557)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_2            alpha_2
#     -------------------- ----------------- ... ------------------ -----------------
#     -0.16322360295004315 8.377793443108981 ... 11.172943975776134 2.819665572224395
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 14.739843
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 13,78, 3, 4
#
# amplitude=13.000000, x_0=78.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 15, 67, 3, 4
#
# amplitude=15.000000, x_0=67.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.27787981)>
#
#     [1]: <Moffat1D(amplitude=10.64068267, x_0=79.76664756, gamma=3.8722955, alpha=1.45502531)>
#
#     [2]: <Moffat1D(amplitude=13.7921496, x_0=69.25447293, gamma=9.99315932, alpha=2.80228727)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2           alpha_2
#     ------------------- ------------------ ... ----------------- ------------------
#     -0.2778798109699493 10.640682673296011 ... 9.993159319554497 2.8022872731909425
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 16.511495
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 13, 21, 3, 4
#
# amplitude=13.000000, x_0=21.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 15, 10, 3, 4
#
# amplitude=15.000000, x_0=10.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.06674598)>
#
#     [1]: <Moffat1D(amplitude=10.49007873, x_0=21.61510829, gamma=6.69931595, alpha=3.83889348)>
#
#     [2]: <Moffat1D(amplitude=14.78175824, x_0=10.91538019, gamma=8.9668138, alpha=2.09536385)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2           alpha_2
#     ------------------- ------------------ ... ----------------- ------------------
#     -0.0667459794460709 10.490078733502532 ... 8.966813804520001 2.0953638514614403
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no

# %%
order_list = [3, 4, 5, 6, 7, 8, 9, 10]
spec_list = [spec1, spec2, spec3]
shifted_sp = []
shifted_var = []
shift_pixel = np.array([[0.67, -36.64, 38.65], [0.27, -35.06, 36.19], [0.10, -33.73, 34.14],
                        [0.14, -32.61, 32.83], [0.34, -31.69, 31.71], [0.58, -30.71, 30.78],
                        [0.81, -30.28, 29.50], [0.47, -29.78, 28.55]])
for shft, order in zip(shift_pixel, order_list):
    new_sp = []
    new_var = []
    for i, sp in enumerate(spec_list):
        #print(sp[order-1].mod0, shift[i])
        nanmask = (sp[order-1].vardata <= 0) | (np.isnan(sp[order-1].vardata)) 
        nnan = nanmask.sum()
        if nnan > 0:
            print('Found %d NaNs in the two-dimensional variance '\
                  'spectrum' % nnan)

            """ Replace the NaNs with a big value """
            sp[order-1].vardata[nanmask] = 1.e9
        new_sp.append(shift(sp[order-1].data, [shft[i], 0], order=1))
        new_var.append(shift(sp[order-1].vardata, [shft[i], 0], order=1))
    shifted_sp.append(new_sp)
    shifted_var.append(new_var)
# Out:
# Found 6499 NaNs in the two-dimensional variance spectrum
# Found 6590 NaNs in the two-dimensional variance spectrum
# Found 6682 NaNs in the two-dimensional variance spectrum
# Found 1753 NaNs in the two-dimensional variance spectrum
# Found 1752 NaNs in the two-dimensional variance spectrum
# Found 1648 NaNs in the two-dimensional variance spectrum
# Found 1723 NaNs in the two-dimensional variance spectrum
# Found 1203 NaNs in the two-dimensional variance spectrum
# Found 1521 NaNs in the two-dimensional variance spectrum
# Found 1410 NaNs in the two-dimensional variance spectrum
# Found 1250 NaNs in the two-dimensional variance spectrum
# Found 1357 NaNs in the two-dimensional variance spectrum
# Found 1119 NaNs in the two-dimensional variance spectrum
# Found 1212 NaNs in the two-dimensional variance spectrum
# Found 1242 NaNs in the two-dimensional variance spectrum
# Found 1314 NaNs in the two-dimensional variance spectrum
# Found 1238 NaNs in the two-dimensional variance spectrum
# Found 1429 NaNs in the two-dimensional variance spectrum
# Found 1308 NaNs in the two-dimensional variance spectrum
# Found 1362 NaNs in the two-dimensional variance spectrum
# Found 1344 NaNs in the two-dimensional variance spectrum
# Found 1001 NaNs in the two-dimensional variance spectrum
# Found 969 NaNs in the two-dimensional variance spectrum
# Found 1372 NaNs in the two-dimensional variance spectrum

# %%
pixrange = [[2200, 2600],[2200, 2600], [2700, 3100], [2100, 2500], [1800, 2200],
            [1600, 2000], [1500, 1900], [800, 1200]]
for od, sp_list, pix in zip(order_list, shifted_sp, pixrange):
    plt.figure(figsize=(8, 6))
    #pixrange = [[2200, 2600], [2200, 2600], [1800, 2200], [1500, 1900], [1500, 1900], [1500, 1900]]
    color = ['b', 'r', 'k']
    label = ['frame_43', 'frame_44', 'frame_45']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pix[0]:pix[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    plt.legend()
    plt.title('order %d' %od)

# %%
outsp = []
outvar = []

for sp_list, var_list in zip(shifted_sp, shifted_var):
    wtsp = np.zeros(sp_list[0].shape)
    wtsum = np.zeros(sp_list[0].shape)
    for s, v in zip(sp_list, var_list):
        wt = np.zeros(wtsp.shape)
        mask = np.isnan(v) | (v<=0)
        wt[~mask] = 1.0 / v[~mask]
        #print(sum(sum(np.isnan(wt) | (wt<=0))))
        wtsp += wt * s
        #print(sum(sum(wtsp==0)))
        wtsum += wt
        #print(sum(sum(wtsum==0)))

    wtsp[wtsum == 0] = 0
    wtsum[wtsum == 0] = 1
    outsp.append(wtsp / wtsum)
    outvar.append(1.0 / wtsum)

# %%
for od, sp_list, cd_sp, pix in zip(order_list, shifted_sp, outsp, pixrange):
    plt.figure(figsize=(8, 6))
    #pixrange = [2700, 3000]
    color = ['b', 'r', 'k']
    label = ['frame_43', 'frame_44', 'frame_45']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pix[0]:pix[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    
    tmpdata = cd_sp[:, pix[0]:pix[1]]
    pflux = np.median(tmpdata, axis=1)
    x = np.arange(cd_sp.shape[0])
    plt.plot(x, pflux, color='g', drawstyle='steps', label='coadded')
    plt.legend()
    plt.title('order %d' %od)

# %%
for od, cd_sp, pix in zip(order_list, outsp, pixrange):
    plt.figure(figsize=(10, 6))
    tmpdata = cd_sp[:, pix[0]:pix[1]]
    pflux = np.median(tmpdata, axis=1)
    x = np.arange(cd_sp.shape[0])
    plt.plot(x, pflux, color='g', drawstyle='steps', label='coadded')
    plt.legend()
    plt.title('order %d' %od)

# %%
s = fits.open('../galaxy_spectra/ESI_data/2019_04/J1433+6007_0043_bgsub.fits')
for od, cd_sp, cd_var in zip(order_list, outsp, outvar):
    file_name1 = 'J1433_ESI_spectra/J1433_coadd2d_sp_order_' + str(od) + '.fits'
    file_name2 = 'J1433_ESI_spectra/J1433_coadd2d_var_order_' + str(od) + '.fits'
    fits.writeto(file_name1, cd_sp, header=s[od].header)
    fits.writeto(file_name2, cd_var, header=s[od].header)

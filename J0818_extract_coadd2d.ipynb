# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, echelle1d, spec1d, echelle2d

# %%
file_loc = 'J0818_ESI_spectra/*'

# %%
spec2d_file_list = []
var2d_file_list = []
#out_file = []
for i, p in enumerate(glob.glob(file_loc)):
    file_name = p.split('/')[-1]
    if 'sp_order' in file_name:
        spec2d_file_list.append(p)
    elif 'var' in file_name:
        var2d_file_list.append(p)

# %%
print(spec2d_file_list, var2d_file_list)
# Out:
# ['J0818_ESI_spectra/J0818_coadd2d_sp_order_6.fits', 'J0818_ESI_spectra/J0818_coadd2d_sp_order_8.fits', 'J0818_ESI_spectra/J0818_coadd2d_sp_order_9.fits', 'J0818_ESI_spectra/J0818_coadd2d_sp_order_10.fits', 'J0818_ESI_spectra/J0818_coadd2d_sp_order_7.fits'] ['J0818_ESI_spectra/J0818_coadd2d_var_order_6.fits', 'J0818_ESI_spectra/J0818_coadd2d_var_order_10.fits', 'J0818_ESI_spectra/J0818_coadd2d_var_order_8.fits', 'J0818_ESI_spectra/J0818_coadd2d_var_order_7.fits', 'J0818_ESI_spectra/J0818_coadd2d_var_order_9.fits']

# %%
spec_ord_6 = spec2d.Spec2d(inspec=spec2d_file_list[0], invar=var2d_file_list[0], logwav=True)
spec_ord_7 = spec2d.Spec2d(inspec=spec2d_file_list[4], invar=var2d_file_list[3], logwav=True)
spec_ord_8 = spec2d.Spec2d(inspec=spec2d_file_list[1], invar=var2d_file_list[2], logwav=True)
spec_ord_9 = spec2d.Spec2d(inspec=spec2d_file_list[2], invar=var2d_file_list[4], logwav=True)
spec_ord_10 = spec2d.Spec2d(inspec=spec2d_file_list[3], invar=var2d_file_list[1], logwav=True)
# Out:
# Loading file J0818_ESI_spectra/J0818_coadd2d_sp_order_6.fits
# -----------------------------------------------
#
# Loading file J0818_ESI_spectra/J0818_coadd2d_var_order_6.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from J0818_ESI_spectra/J0818_coadd2d_sp_order_6.fits (HDU=0)
# Final data dimensions (x y): 4096 x 128
#
# Dispersion axis:              x
# N_pixels along dispersion axis: 4096
#
#
# Loading file J0818_ESI_spectra/J0818_coadd2d_sp_order_7.fits
# -----------------------------------------------
#
# Loading file J0818_ESI_spectra/J0818_coadd2d_var_order_7.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from J0818_ESI_spectra/J0818_coadd2d_sp_order_7.fits (HDU=0)
# Final data dimensions (x y): 4096 x 126
#
# Dispersion axis:              x
# N_pixels along dispersion axis: 4096
#
#
# Loading file J0818_ESI_spectra/J0818_coadd2d_sp_order_8.fits
# ...

# %%
pixscale = np.array([0.149, 0.153, 0.158, 0.163, 0.168])
dist = [2.8]
for p in pixscale:
    print(dist/p)
# Out:
# [18.79194631]
# [18.30065359]
# [17.72151899]
# [17.17791411]
# [16.66666667]

# %%
spec_list= [spec_ord_6, spec_ord_7, spec_ord_8, 
            spec_ord_9, spec_ord_10]

pixrange_list = [[2400, 2900], [2400, 2900], [2300, 2700], [1600, 2300], [1100, 1500]]

for i, sp in enumerate(spec_list):
    sp.spatial_profile(pixrange=pixrange_list[i])
    plt.show()
    sp.initial_model()
# Out:
# Profile max value (before normalization) 456.221570
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 440, 55, 3, 4
#
# amplitude=440.000000, x_0=55.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 15, 74, 2, 3
#
# amplitude=15.000000, x_0=74.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.77116281)>
#
# ...

# %%
pixscale = np.array([0.149, 0.153, 0.158, 0.163, 0.168])
pos1 = []
pos2 = []
pos3 = []
pos4 = []
for sp in spec_list:
    pos1.append(sp.mod0[1].x_0.value)
    pos2.append(sp.mod0[2].x_0.value)
    #pos3.append(sp.mod0[3].x_0.value)
    #pos4.append(sp.mod0[4].x_0.value)
print((np.array(pos2)-np.array(pos1))*pixscale)
#print((np.array(pos2)-np.array(pos3))*pixscale)
#print((np.array(pos2)-np.array(pos4))*pixscale)
# Out:
# [2.54889395 2.77088273 1.99762685 2.57332406 2.65286135]

# %%
#def tie_pos1_moffat_3(model):
#    return model.x_0_1 + (2.7  / pixscale[0])   

#def tie_pos1_moffat_4(model):
#    return model.x_0_1 + (2.7  / pixscale[1])  

 
#def tie_pos1_moffat_5(model):
#    return model.x_0_1 + (2.7  / pixscale[2])  

def tie_pos1_moffat_6(model):
    return model.x_0_1 + (2.7  / pixscale[0])  

def tie_pos1_moffat_7(model):
    return model.x_0_1 + (2.7  / pixscale[1])  
 
def tie_pos1_moffat_8(model):
    return model.x_0_1 + (2.7  /  pixscale[2])  

def tie_pos1_moffat_9(model):
    return model.x_0_1 + (2.7  /  pixscale[3])  

def tie_pos1_moffat_10(model):
    return model.x_0_1 + (2.7  /  pixscale[4])  

def tie_gamma_moffat(model):
    return model.gamma_1

def tie_alpha_moffat(model):
    return model.alpha_1 

def tie_gamma_moffat1(model):
    return model.gamma_1 * 0.5

def tie_alpha_moffat1(model):
    return model.alpha_1 * 0.5

func_dict = {
 #'3_1' : tie_pos1_moffat_3, '3_2' : tie_pos2_moffat_3, '3_3' : tie_pos3_moffat_3, '3_4' : tie_pos4_moffat_3,
 #'4_1' : tie_pos1_moffat_4, '4_2' : tie_pos2_moffat_4, '4_3' : tie_pos3_moffat_4, '4_4' : tie_pos4_moffat_4,
 #'5_1' : tie_pos1_moffat_5, '5_2' : tie_pos2_moffat_5, '5_3' : tie_pos3_moffat_5, '5_4' : tie_pos4_moffat_5,
 '6_1' : tie_pos1_moffat_6, 
 '7_1' : tie_pos1_moffat_7, 
 '8_1' : tie_pos1_moffat_8, 
 '9_1' : tie_pos1_moffat_9, 
 '10_1' : tie_pos1_moffat_10
}
pixscale = [0.149, 0.153, 0.158, 0.163, 0.168]
ord_list = [6, 7, 8, 9, 10]
for i, sp in enumerate(spec_list):
    if sp.mod0 is not None:
        print(pixscale[i])
        sp.mod0[2].x_0.tied = func_dict['%d_%d' %(ord_list[i], 1)] #tie_pos1_moffat
        #sp.mod0[1].mean.tied = func_dict['%d_%d' %(ord_list[i], 2)] #tie_pos1_moffat
        #sp.mod0[3].x_0.tied = func_dict['%d_%d' %(ord_list[i], 3)] #tie_pos2_moffat
        #sp.mod0[4].x_0.tied = func_dict['%d_%d' %(ord_list[i], 4)]
        #sp.mod0[5].x_0.tied = func_dict['%d_%d' %(ord_list[i], 3)]
        sp.mod0[2].gamma.tied = tie_gamma_moffat
        sp.mod0[2].alpha.tied = tie_alpha_moffat
        #sp.mod0[3].gamma.tied = tie_gamma_moffat
        #sp.mod0[3].alpha.tied = tie_alpha_moffat
        #sp.mod0[4].gamma.tied = tie_gamma_moffat
        #sp.mod0[4].alpha.tied = tie_alpha_moffat
        #sp.mod0[5].gamma.tied = tie_gamma_moffat
        #sp.mod0[5].alpha.tied = tie_alpha_moffat
        sp.refined_model(sp.mod0)
# Out:
# 0.149
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.77116281)>
#
#     [1]: <Moffat1D(amplitude=465.71387291, x_0=56.58543963, gamma=6.27659496, alpha=3.04159207)>
#
#     [2]: <Moffat1D(amplitude=2.97350807, x_0=73.69211043, gamma=-3.90809019, alpha=0.65586508)>
# Parameters:
#             c0_0           amplitude_1    ...       gamma_2            alpha_2
#     ------------------- ----------------- ... ------------------- ------------------
#     -0.7711628097681598 465.7138729118288 ... -3.9080901894671256 0.6558650751359933
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.5669371)>
#
# ...

# %%
fitrange_list = np.array([[1000, 4100], [0, 4100],
                          [0, 4100], [0, 4100], [0, 4100]])
for i, sp in enumerate(spec_list):
    sp.find_and_trace(sp.mod0, stepsize=25, fitorder={'x_0_1':4, 'x_0_2':4, 'x_0_3':4, 'mean_1':4, 'x_0_4':4},
                    fitrange=fitrange_list[i], polyorder=3)
    plt.show()
# Out:
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: x_0_1
# Fitting polynomial of degree 3 to parameter: gamma_1
# Fitting polynomial of degree 3 to parameter: alpha_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: x_0_1
# Fitting polynomial of degree 3 to parameter: gamma_1
# Fitting polynomial of degree 3 to parameter: alpha_1
# ...

# %%
extrange_list = np.array([[900, -1], [600, -1], 
                          [200, -1], [0, -1], [0, 2000]])
for sp, ext in zip(spec_list, extrange_list):
    sp.extract(method='modelfit', extrange=ext)
    plt.show()
# Out:
# Fitting to 2 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 900 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  5811.95
#  Spectrum End:     6562.05
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#  Spectrum Start:  5811.95
#  Spectrum End:     6562.05
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#
# Plotting the spectrum
# Fitting to 2 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 600 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  6381.83
#  Spectrum End:     7288.07
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#  Spectrum Start:  6381.83
#  Spectrum End:     7288.07
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#
# ...

# %%
outspec = []
orderinfo = np.array([6, 7, 8, 9, 10], dtype=[('order', int)])

# %%
for i, spp in enumerate(spec_ord_7.spectra):
    s = []
    for sp in spec_list:
        s.append(sp.spectra[i][1])
    outspec.append(echelle1d.Ech1d(s, ordinfo=orderinfo))
# Out:
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   6  3196   5811.95  6562.05   0.23
#   7  3496   6381.83  7288.07   0.26
#   8  3896   7068.28  8195.60   0.29
#   9  4096   8013.63  9362.61   0.33
#  10  2000   9338.81 10075.69   0.37
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   6  3196   5811.95  6562.05   0.23
#   7  3496   6381.83  7288.07   0.26
#   8  3896   7068.28  8195.60   0.29
#   9  4096   8013.63  9362.61   0.33
#  10  2000   9338.81 10075.69   0.37

# %%
outspec[0].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))
outspec[1].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))

# %%
outspec[0].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt', order=[6, 10])
outspec[1].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt', order=[6, 10])
# Out:
#  Spectrum Start:     3.76
#  Spectrum End:        4.00
#  Dispersion (1st pixel): 1.65e-05
#  Dispersion (average):    1.65e-05
#  Spectrum Start:     3.76
#  Spectrum End:        4.00
#  Dispersion (1st pixel): 1.65e-05
#  Dispersion (average):    1.65e-05

# %%
sp_d = spec1d.Spec1d(wav=outspec[1].spec1d['wav'], flux=outspec[1].spec1d['flux'],
                     var=outspec[1].spec1d['var'], logwav=True, trimsec=[3000, -500])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d5cff6a79b76> in <module>
# ----> 1 sp_d = spec1d.Spec1d(wav=outspec[1].spec1d['wav'], flux=outspec[1].spec1d['flux'],
#       2                      var=outspec[1].spec1d['var'], logwav=True, trimsec=[3000, -500])
#
# NameError: name 'spec1d' is not defined

# %%
sp_d = spec1d.Spec1d('J0818_ESI_spectra/spec1d_J0818_coadd2d_deflector.fits', informat='fits',
                     trimsec=[3000, -700], logwav=True)
# Out:
# Reading spectrum from J0818_ESI_spectra/spec1d_J0818_coadd2d_deflector.fits
# Expected file format: fits
#  Spectrum Start:  6513.61
#  Spectrum End:     9811.26
#  Dispersion (1st pixel):   0.25
#  Dispersion (average):      0.31

# %%
# %matplotlib notebook
sp_d.smooth(11)
sp_d.mark_lines('abs', z=0.867, usesmooth=True)
# Out:
# <img src="data:image/png;base64,..." width="1041.8181592373815">
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-kappa       3750.00       7001.25
# [Fe VII]      3761.40       7022.53
# H-iota        3770.00       7038.59
# H-theta       3797.00       7089.00
# H-eta         3835.00       7159.94
# CN bandhd     3883.00       7249.56
# CaII K        3933.67       7344.16
# CaII H        3968.47       7409.13
# H-delta       4101.00       7656.57
# G-band        4305.00       8037.44
# H-gamma       4340.00       8102.78
# Fe4383        4383.00       8183.06
# Ca4455        4455.00       8317.49
# Fe4531        4531.00       8459.38
# H-beta        4861.00       9075.49
# Mg I (b)      5176.00       9663.59

# %%
sp_im = spec1d.Spec1d(wav=outspec[0].spec1d['wav'], flux=outspec[0].spec1d['flux'],
                     var=outspec[0].spec1d['var'], logwav=True, trimsec=[0, -1])
# Out:
#  Spectrum Start:  5811.95
#  Spectrum End:    10075.31
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.29

# %%
sp_im = spec1d.Spec1d('J0818_ESI_spectra/spec1d_J0818_coadd2d_primary.fits', informat='fits', 
                     trimsec=[0, -1], logwav=True)
# Out:
# Reading spectrum from J0818_ESI_spectra/spec1d_J0818_coadd2d_primary.fits
# Expected file format: fits
#  Spectrum Start:  5811.95
#  Spectrum End:    10075.31
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.29

# %%
sp_im.smooth(15)
sp_im.mark_lines('strongem', z=2.15, usesmooth=True)
# Out:
# <img src="data:," width="0">
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# Al III        1858.70       5854.90
# Si III]       1892.00       5959.80
# C III]        1908.70       6012.40
# Mg II         2799.80       8819.37

# %%
outspec[0].spec1d.save('J0818_ESI_spectra/spec1d_J0818_coadd2d_deflector.fits', outformat='fits')
outspec[1].spec1d.save('J0818_ESI_spectra/spec1d_J0818_coadd2d_primary.fits', outformat='fits')
# Out:
# Saved spectrum to file J0818_ESI_spectra/spec1d_J0818_coadd2d_deflector.fits in format fits
# Saved spectrum to file J0818_ESI_spectra/spec1d_J0818_coadd2d_primary.fits in format fits

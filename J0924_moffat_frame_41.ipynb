# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, spec1d

# %%
file_loc = '../galaxy_spectra/ESI_data/*'

# %%
spec2d_file_list = []
var2d_file_list = []

for i,p in enumerate(glob.glob(file_loc)):
    if 'J0924' in p:
        if 'bgsub.fits' in p:
            spec2d_file_list.append(p)
        elif 'var.fits' in p:
            var2d_file_list.append(p)

# %%
spec = esi2d.Esi2d(spec2d_file_list[1], varfile=var2d_file_list[1])
print(spec2d_file_list[1])
print(var2d_file_list[1])
# Out:
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3461x165     x
#   2   4093x145     x
#   3   4096x146     x
#   4   4096x141     x
#   5   4096x130     x
#   6   4096x127     x
#   7   4096x124     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x111     x
# ../galaxy_spectra/ESI_data/J0924+0219_0041_bgsub.fits
# ../galaxy_spectra/ESI_data/J0924+0219_0041_var.fits

# %%
pixrange = [(1900, 2400)] #(1900, 2400)
for sp, info in zip(spec, spec.ordinfo):
    title = 'Spatial profile for ' + str(info['name'])
    sp.spatial_profile(pixrange=pixrange[0], title=title)
    plt.show()
    sp.initial_model()
# Out:
# Profile max value (before normalization) 73.196768
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 10, 116, 2
#
# amplitude=10.000000, mu=116.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 70, 110, 3, 3
#
# amplitude=70.000000, x_0=110.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 10, 124, 3, 3
#
# amplitude=10.000000, x_0=124.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.18092902)>
#
#     [1]: <Gaussian1D(amplitude=23.68695468, mean=112.84046547, stddev=2.99344284)>
#
#     [2]: <Moffat1D(amplitude=56.43220875, x_0=110.28349462, gamma=5.38900754, alpha=2.11492097)>
#
#     [3]: <Moffat1D(amplitude=9.72729947, x_0=124.7014312, gamma=8.98248787, alpha=3.0857642)>
# Parameters:
#             c0_0          amplitude_1   ...      gamma_3           alpha_3
#     -------------------- -------------- ... ----------------- ------------------
#     -0.18092901609149886 23.68695467922 ... 8.982487869410834 3.0857641954582897
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 102.552883
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 16, 108, 2
#
# amplitude=16.000000, mu=108.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 100, 102, 3, 3
#
# amplitude=100.000000, x_0=102.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 15, 116, 3, 3
#
# amplitude=15.000000, x_0=116.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.16360698)>
#
#     [1]: <Gaussian1D(amplitude=20.9743497, mean=104.12154401, stddev=3.22553094)>
#
#     [2]: <Moffat1D(amplitude=86.26944011, x_0=101.65544904, gamma=5.44019922, alpha=2.46802561)>
#
#     [3]: <Moffat1D(amplitude=12.8192054, x_0=115.09833319, gamma=9.10131547, alpha=3.90882872)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_3          alpha_3
#     -------------------- ----------------- ... ----------------- ----------------
#     -0.16360697675153618 20.97434969998739 ... 9.101315472970542 3.90882871785597
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 154.397818
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 30, 105, 2
#
# amplitude=30.000000, mu=105.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 150, 99, 3, 3
#
# amplitude=150.000000, x_0=99.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 20, 113, 3, 3
#
# amplitude=20.000000, x_0=113.000000, gamma=3.000000, alpha=3.000000
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.10801664)>
#
#     [1]: <Gaussian1D(amplitude=18.71805845, mean=101.71022476, stddev=3.36302815)>
#
#     [2]: <Moffat1D(amplitude=143.52268351, x_0=98.63012621, gamma=5.2805252, alpha=2.63313699)>
#
#     [3]: <Moffat1D(amplitude=19.61765581, x_0=111.6796318, gamma=6.08670557, alpha=2.24520793)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_3           alpha_3
#     -------------------- ------------------ ... ----------------- ------------------
#     -0.10801663586589944 18.718058450691903 ... 6.086705571511379 2.2452079289335694
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 189.689997
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 35, 101, 2
#
# amplitude=35.000000, mu=101.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 175, 96, 3, 3
#
# amplitude=175.000000, x_0=96.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 25, 108, 3, 3
#
# amplitude=25.000000, x_0=108.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.1021745)>
#
#     [1]: <Gaussian1D(amplitude=21.26190853, mean=99.29064684, stddev=3.35981771)>
#
#     [2]: <Moffat1D(amplitude=178.10355272, x_0=95.78992219, gamma=5.0304964, alpha=2.65181409)>
#
#     [3]: <Moffat1D(amplitude=23.54455111, x_0=108.0853195, gamma=5.15458191, alpha=1.9414965)>
# Parameters:
#             c0_0            amplitude_1     ...     gamma_3           alpha_3
#     -------------------- ------------------ ... ---------------- ------------------
#     -0.10217449509701948 21.261908532457493 ... 5.15458190774051 1.9414964966976336
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 220.397446
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 50, 98, 2
#
# amplitude=50.000000, mu=98.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 220, 93, 3, 3
#
# amplitude=220.000000, x_0=93.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 35, 106, 3, 3
#
# amplitude=35.000000, x_0=106.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.05263196)>
#
#     [1]: <Gaussian1D(amplitude=20.67435033, mean=96.51608453, stddev=3.48850266)>
#
#     [2]: <Moffat1D(amplitude=214.29936143, x_0=92.35602281, gamma=4.91386476, alpha=2.59581749)>
#
#     [3]: <Moffat1D(amplitude=27.12793368, x_0=104.16961144, gamma=5.59561345, alpha=2.42602004)>
# Parameters:
#             c0_0            amplitude_1     ...     gamma_3           alpha_3
#     -------------------- ------------------ ... ---------------- ------------------
#     -0.05263196422487639 20.674350334666435 ... 5.59561345369832 2.4260200351886008
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 277.905045
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 55, 90, 2
#
# amplitude=55.000000, mu=90.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 260, 85, 3, 3
#
# amplitude=260.000000, x_0=85.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 40, 97, 3, 3
#
# amplitude=40.000000, x_0=97.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.12431574)>
#
#     [1]: <Gaussian1D(amplitude=49.81911974, mean=89.09168743, stddev=3.18186106)>
#
#     [2]: <Moffat1D(amplitude=252.38714897, x_0=85.59620501, gamma=4.62633536, alpha=2.61676661)>
#
#     [3]: <Moffat1D(amplitude=39.06017317, x_0=97.04165788, gamma=5.92445854, alpha=2.34745224)>
# Parameters:
#             c0_0            amplitude_1     ...      alpha_3
#     -------------------- ------------------ ... ------------------
#     -0.12431573958967715 49.819119736557525 ... 2.3474522372660664
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 290.782916
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 80, 89, 2
#
# amplitude=80.000000, mu=89.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 280, 84, 3, 3
#
# amplitude=280.000000, x_0=84.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 50, 95, 3, 3
#
# amplitude=50.000000, x_0=95.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.10249643)>
#
#     [1]: <Gaussian1D(amplitude=77.74834244, mean=87.96775725, stddev=3.1570265)>
#
#     [2]: <Moffat1D(amplitude=244.12716619, x_0=84.62894977, gamma=4.57631229, alpha=2.6727283)>
#
#     [3]: <Moffat1D(amplitude=44.08709476, x_0=95.51172969, gamma=6.80491694, alpha=2.5803178)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_3           alpha_3
#     -------------------- ----------------- ... ----------------- ------------------
#     -0.10249643028960977 77.74834243851173 ... 6.804916942047589 2.5803177957055725
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 288.759002
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 110, 88, 2
#
# amplitude=110.000000, mu=88.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 280, 83, 3, 3
#
# amplitude=280.000000, x_0=83.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 50, 95, 3, 3
#
# amplitude=50.000000, x_0=95.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.03505375)>
#
#     [1]: <Gaussian1D(amplitude=93.34262173, mean=86.55776437, stddev=2.82384536)>
#
#     [2]: <Moffat1D(amplitude=241.50034532, x_0=83.23962516, gamma=4.48227995, alpha=2.79871175)>
#
#     [3]: <Moffat1D(amplitude=45.68836584, x_0=93.33619235, gamma=9.39031002, alpha=4.69959577)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_3          alpha_3
#     -------------------- ----------------- ... ----------------- ----------------
#     -0.03505374651019603 93.34262173138364 ... 9.390310015210247 4.69959576978031
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 288.236581
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 130, 85, 2
#
# amplitude=130.000000, mu=85.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 300, 81, 3, 3
#
# amplitude=300.000000, x_0=81.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 50, 90, 3, 3
#
# amplitude=50.000000, x_0=90.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.14871235)>
#
#     [1]: <Gaussian1D(amplitude=99.63391664, mean=83.82652922, stddev=2.7141478)>
#
#     [2]: <Moffat1D(amplitude=251.7974517, x_0=80.09199648, gamma=4.5304893, alpha=2.92129415)>
#
#     [3]: <Moffat1D(amplitude=49.92250997, x_0=90.05344404, gamma=8.27915846, alpha=4.00379186)>
# Parameters:
#             c0_0           amplitude_1   ...      gamma_3           alpha_3
#     -------------------- --------------- ... ----------------- -----------------
#     -0.14871235022153567 99.633916637489 ... 8.279158464709024 4.003791863167999
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 26.795155
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 1
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 15, 84, 2
#
# amplitude=15.000000, mu=84.000000, sigma=2.000000
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 25, 79, 3, 3
#
# amplitude=25.000000, x_0=79.000000, gamma=3.000000, alpha=3.000000
#
# Parameters of Moffat profile 2 : 5, 90, 3, 3
#
# amplitude=5.000000, x_0=90.000000, gamma=3.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.09737994)>
#
#     [1]: <Gaussian1D(amplitude=11.20099588, mean=84.16067182, stddev=2.62109048)>
#
#     [2]: <Moffat1D(amplitude=25.23916814, x_0=78.79058261, gamma=6.47941067, alpha=4.86139887)>
#
#     [3]: <Moffat1D(amplitude=4.75137907, x_0=89.71314043, gamma=5.17930637, alpha=4.3332163)>
# Parameters:
#             c0_0            amplitude_1     ...     gamma_3           alpha_3
#     -------------------- ------------------ ... ---------------- -----------------
#     -0.09737994405985942 11.200995879051243 ... 5.17930637267121 4.333216295111969
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no

# %%
def tie_pos1_moffat_1(model):
    return model.x_0_2 + (0.87 / spec.ordinfo[0]['pixscale']) #(0.886 / pixscale)

def tie_pos2_moffat_1(model):
    return model.x_0_2 + (1.81 / spec.ordinfo[0]['pixscale'])  #(1.87 / pixscale) 

def tie_pos1_moffat_2(model):
    return model.x_0_2 + (0.87 / spec.ordinfo[1]['pixscale']) #(0.886 / pixscale)

def tie_pos2_moffat_2(model):
    return model.x_0_2 + (1.81 / spec.ordinfo[1]['pixscale'])  #(1.87 / pixscale) 

def tie_pos1_moffat_3(model):
    return model.x_0_2 + (0.87 / spec.ordinfo[2]['pixscale']) #(0.886 / pixscale)

def tie_pos2_moffat_3(model):
    return model.x_0_2 + (1.81 / spec.ordinfo[2]['pixscale'])  #(1.87 / pixscale) 

def tie_pos1_moffat_4(model):
    return model.x_0_2 + (0.87 / spec.ordinfo[3]['pixscale']) #(0.886 / pixscale)

def tie_pos2_moffat_4(model):
    return model.x_0_2 + (1.81 / spec.ordinfo[3]['pixscale'])  #(1.87 / pixscale) 

def tie_pos1_moffat_5(model):
    return model.x_0_2 + (0.87 / spec.ordinfo[4]['pixscale']) #(0.886 / pixscale)

def tie_pos2_moffat_5(model):
    return model.x_0_2 + (1.81 / spec.ordinfo[4]['pixscale'])  #(1.87 / pixscale) 

def tie_pos1_moffat_6(model):
    return model.x_0_2 + (0.87 / spec.ordinfo[5]['pixscale']) #(0.886 / pixscale)

def tie_pos2_moffat_6(model):
    return model.x_0_2 + (1.81 / spec.ordinfo[5]['pixscale'])  #(1.87 / pixscale) 

def tie_pos1_moffat_7(model):
    return model.x_0_2 + (0.87 / spec.ordinfo[6]['pixscale']) #(0.886 / pixscale)

def tie_pos2_moffat_7(model):
    return model.x_0_2 + (1.81 / spec.ordinfo[6]['pixscale'])  #(1.87 / pixscale) 

def tie_pos1_moffat_8(model):
    return model.x_0_2 + (0.87 / spec.ordinfo[7]['pixscale']) #(0.886 / pixscale)

def tie_pos2_moffat_8(model):
    return model.x_0_2 + (1.81 / spec.ordinfo[7]['pixscale'])  #(1.87 / pixscale) 

def tie_pos1_moffat_9(model):
    return model.x_0_2 + (0.87 / spec.ordinfo[8]['pixscale']) #(0.886 / pixscale)

def tie_pos2_moffat_9(model):
    return model.x_0_2 + (1.81 / spec.ordinfo[8]['pixscale'])  #(1.87 / pixscale) 

def tie_pos1_moffat_10(model):
    return model.x_0_2 + (0.87 / spec.ordinfo[9]['pixscale']) #(0.886 / pixscale)

def tie_pos2_moffat_10(model):
    return model.x_0_2 + (1.81 / spec.ordinfo[9]['pixscale'])  #(1.87 / pixscale) 

def tie_gamma_moffat(model):
    return model.gamma_2

def tie_alpha_moffat(model):
    return model.alpha_2

func_dict = {'1_1' : tie_pos1_moffat_1, '1_2' : tie_pos2_moffat_1,
             '2_1' : tie_pos1_moffat_2, '2_2' : tie_pos2_moffat_2,
             '3_1' : tie_pos1_moffat_3, '3_2' : tie_pos2_moffat_3,
             '4_1' : tie_pos1_moffat_4, '4_2' : tie_pos2_moffat_4,
             '5_1' : tie_pos1_moffat_5, '5_2' : tie_pos2_moffat_5,
             '6_1' : tie_pos1_moffat_6, '6_2' : tie_pos2_moffat_6,
             '7_1' : tie_pos1_moffat_7, '7_2' : tie_pos2_moffat_7,
             '8_1' : tie_pos1_moffat_8, '8_2' : tie_pos2_moffat_8,
             '9_1' : tie_pos1_moffat_9, '9_2' : tie_pos2_moffat_9,
             '10_1' : tie_pos1_moffat_10, '10_2' : tie_pos2_moffat_10
            }

for sp, info in zip(spec, spec.ordinfo):
    if sp.mod0 is not None:
        print(info['pixscale'])
        sp.mod0[1].mean.tied = func_dict['%d_%d' %(info['order'], 1)] #tie_pos1_moffat
        sp.mod0[3].x_0.tied = func_dict['%d_%d' %(info['order'], 2)] #tie_pos2_moffat
        sp.mod0[3].gamma.tied = tie_gamma_moffat
        sp.mod0[3].alpha.tied = tie_alpha_moffat
        sp.refined_model(sp.mod0)
# Out:
# 0.12
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.18092902)>
#
#     [1]: <Gaussian1D(amplitude=23.68695468, mean=112.84046547, stddev=2.99344284)>
#
#     [2]: <Moffat1D(amplitude=56.43220875, x_0=110.28349462, gamma=5.38900754, alpha=2.11492097)>
#
#     [3]: <Moffat1D(amplitude=9.72729947, x_0=124.7014312, gamma=8.98248787, alpha=3.0857642)>
# Parameters:
#             c0_0          amplitude_1   ...      gamma_3           alpha_3
#     -------------------- -------------- ... ----------------- ------------------
#     -0.18092901609149886 23.68695467922 ... 8.982487869410834 3.0857641954582897
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.12003895)>
#
#     [1]: <Gaussian1D(amplitude=4.71042432, mean=118.17835445, stddev=5.73060134)>
#
#     [2]: <Moffat1D(amplitude=72.06134664, x_0=110.92835445, gamma=8.0351855, alpha=3.72224424)>
#
#     [3]: <Moffat1D(amplitude=7.71305333, x_0=126.01168779, gamma=8.0351855, alpha=3.72224424)>
# Parameters:
#             c0_0            amplitude_1    ...     gamma_3           alpha_3
#     -------------------- ----------------- ... ---------------- -----------------
#     -0.12003894646558472 4.710424320531887 ... 8.03518549938144 3.722244244761665
#
# -------------------------------------------
# 0.127
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.16360698)>
#
#     [1]: <Gaussian1D(amplitude=20.9743497, mean=104.12154401, stddev=3.22553094)>
#
#     [2]: <Moffat1D(amplitude=86.26944011, x_0=101.65544904, gamma=5.44019922, alpha=2.46802561)>
#
#     [3]: <Moffat1D(amplitude=12.8192054, x_0=115.09833319, gamma=9.10131547, alpha=3.90882872)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_3          alpha_3
#     -------------------- ----------------- ... ----------------- ----------------
#     -0.16360697675153618 20.97434969998739 ... 9.101315472970542 3.90882871785597
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.13058756)>
#
#     [1]: <Gaussian1D(amplitude=7.47065049, mean=108.79375164, stddev=4.66433301)>
#
#     [2]: <Moffat1D(amplitude=99.63417159, x_0=101.94335794, gamma=6.83373434, alpha=3.34988217)>
#
#     [3]: <Moffat1D(amplitude=10.40893836, x_0=116.19532645, gamma=6.83373434, alpha=3.34988217)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_3           alpha_3
#     -------------------- ----------------- ... ----------------- -----------------
#     -0.13058755793479396 7.470650489901434 ... 6.833734339570091 3.349882165673408
#
# -------------------------------------------
# 0.134
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.10801664)>
#
#     [1]: <Gaussian1D(amplitude=18.71805845, mean=101.71022476, stddev=3.36302815)>
#
#     [2]: <Moffat1D(amplitude=143.52268351, x_0=98.63012621, gamma=5.2805252, alpha=2.63313699)>
#
#     [3]: <Moffat1D(amplitude=19.61765581, x_0=111.6796318, gamma=6.08670557, alpha=2.24520793)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_3           alpha_3
#     -------------------- ------------------ ... ----------------- ------------------
#     -0.10801663586589944 18.718058450691903 ... 6.086705571511379 2.2452079289335694
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.03594105)>
#
#     [1]: <Gaussian1D(amplitude=11.00857278, mean=105.26538018, stddev=3.44525762)>
#
#     [2]: <Moffat1D(amplitude=153.9706636, x_0=98.77284287, gamma=5.93317606, alpha=3.02915429)>
#
#     [3]: <Moffat1D(amplitude=18.61194237, x_0=112.28030555, gamma=5.93317606, alpha=3.02915429)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_3           alpha_3
#     ------------------- ------------------ ... ----------------- ------------------
#     -0.0359410478416889 11.008572776753924 ... 5.933176064044539 3.0291542873605963
#
# -------------------------------------------
# 0.137
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.1021745)>
#
#     [1]: <Gaussian1D(amplitude=21.26190853, mean=99.29064684, stddev=3.35981771)>
#
#     [2]: <Moffat1D(amplitude=178.10355272, x_0=95.78992219, gamma=5.0304964, alpha=2.65181409)>
#
#     [3]: <Moffat1D(amplitude=23.54455111, x_0=108.0853195, gamma=5.15458191, alpha=1.9414965)>
# Parameters:
#             c0_0            amplitude_1     ...     gamma_3           alpha_3
#     -------------------- ------------------ ... ---------------- ------------------
#     -0.10217449509701948 21.261908532457493 ... 5.15458190774051 1.9414964966976336
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.01397965)>
#
#     [1]: <Gaussian1D(amplitude=17.76916629, mean=102.23014002, stddev=4.70625947)>
#
#     [2]: <Moffat1D(amplitude=183.17405326, x_0=95.87977506, gamma=5.73096578, alpha=3.20652322)>
#
#     [3]: <Moffat1D(amplitude=16.44872835, x_0=109.09145389, gamma=5.73096578, alpha=3.20652322)>
# Parameters:
#              c0_0            amplitude_1    ...      gamma_3           alpha_3
#     --------------------- ----------------- ... ----------------- -----------------
#     -0.013979648667698711 17.76916629106761 ... 5.730965777297893 3.206523223039457
#
# -------------------------------------------
# 0.144
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.05263196)>
#
#     [1]: <Gaussian1D(amplitude=20.67435033, mean=96.51608453, stddev=3.48850266)>
#
#     [2]: <Moffat1D(amplitude=214.29936143, x_0=92.35602281, gamma=4.91386476, alpha=2.59581749)>
#
#     [3]: <Moffat1D(amplitude=27.12793368, x_0=104.16961144, gamma=5.59561345, alpha=2.42602004)>
# Parameters:
#             c0_0            amplitude_1     ...     gamma_3           alpha_3
#     -------------------- ------------------ ... ---------------- ------------------
#     -0.05263196422487639 20.674350334666435 ... 5.59561345369832 2.4260200351886008
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.00535115)>
#
#     [1]: <Gaussian1D(amplitude=21.48366528, mean=98.43521676, stddev=4.80238)>
#
#     [2]: <Moffat1D(amplitude=214.90681543, x_0=92.39355009, gamma=5.13234852, alpha=2.77068017)>
#
#     [3]: <Moffat1D(amplitude=18.79627625, x_0=104.96299454, gamma=5.13234852, alpha=2.77068017)>
# Parameters:
#              c0_0            amplitude_1    ...      gamma_3           alpha_3
#     --------------------- ----------------- ... ----------------- ------------------
#     -0.005351146571761828 21.48366527999195 ... 5.132348516712331 2.7706801681579973
#
# -------------------------------------------
# 0.149
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.12431574)>
#
#     [1]: <Gaussian1D(amplitude=49.81911974, mean=89.09168743, stddev=3.18186106)>
#
#     [2]: <Moffat1D(amplitude=252.38714897, x_0=85.59620501, gamma=4.62633536, alpha=2.61676661)>
#
#     [3]: <Moffat1D(amplitude=39.06017317, x_0=97.04165788, gamma=5.92445854, alpha=2.34745224)>
# Parameters:
#             c0_0            amplitude_1     ...      alpha_3
#     -------------------- ------------------ ... ------------------
#     -0.12431573958967715 49.819119736557525 ... 2.3474522372660664
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.04960192)>
#
#     [1]: <Gaussian1D(amplitude=39.76025951, mean=91.59106113, stddev=3.13821156)>
#
#     [2]: <Moffat1D(amplitude=272.75572252, x_0=85.75213496, gamma=5.41529416, alpha=3.16983841)>
#
#     [3]: <Moffat1D(amplitude=34.66187763, x_0=97.89978597, gamma=5.41529416, alpha=3.16983841)>
# Parameters:
#             c0_0           amplitude_1    ...     gamma_3           alpha_3
#     ------------------- ----------------- ... ---------------- -----------------
#     0.04960191796225214 39.76025950940084 ... 5.41529415779805 3.169838407844971
#
# -------------------------------------------
# 0.153
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.10249643)>
#
#     [1]: <Gaussian1D(amplitude=77.74834244, mean=87.96775725, stddev=3.1570265)>
#
#     [2]: <Moffat1D(amplitude=244.12716619, x_0=84.62894977, gamma=4.57631229, alpha=2.6727283)>
#
#     [3]: <Moffat1D(amplitude=44.08709476, x_0=95.51172969, gamma=6.80491694, alpha=2.5803178)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_3           alpha_3
#     -------------------- ----------------- ... ----------------- ------------------
#     -0.10249643028960977 77.74834243851173 ... 6.804916942047589 2.5803177957055725
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.13977537)>
#
#     [1]: <Gaussian1D(amplitude=60.77605157, mean=90.56623541, stddev=2.91180302)>
#
#     [2]: <Moffat1D(amplitude=281.21154092, x_0=84.8799609, gamma=5.9841132, alpha=3.74136071)>
#
#     [3]: <Moffat1D(amplitude=38.00565486, x_0=96.71002626, gamma=5.9841132, alpha=3.74136071)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_3           alpha_3
#     ------------------- ----------------- ... ----------------- -----------------
#     0.13977536629016418 60.77605157382486 ... 5.984113202750233 3.741360707357153
#
# -------------------------------------------
# 0.158
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.03505375)>
#
#     [1]: <Gaussian1D(amplitude=93.34262173, mean=86.55776437, stddev=2.82384536)>
#
#     [2]: <Moffat1D(amplitude=241.50034532, x_0=83.23962516, gamma=4.48227995, alpha=2.79871175)>
#
#     [3]: <Moffat1D(amplitude=45.68836584, x_0=93.33619235, gamma=9.39031002, alpha=4.69959577)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_3          alpha_3
#     -------------------- ----------------- ... ----------------- ----------------
#     -0.03505374651019603 93.34262173138364 ... 9.390310015210247 4.69959576978031
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.10363416)>
#
#     [1]: <Gaussian1D(amplitude=72.50592806, mean=89.07263083, stddev=2.81082418)>
#
#     [2]: <Moffat1D(amplitude=279.93267259, x_0=83.56630172, gamma=6.62248723, alpha=4.7109292)>
#
#     [3]: <Moffat1D(amplitude=34.07197802, x_0=95.02199792, gamma=6.62248723, alpha=4.7109292)>
# Parameters:
#            c0_0           amplitude_1    ...      gamma_3            alpha_3
#     ------------------ ----------------- ... ------------------ ------------------
#     0.1036341600951349 72.50592806465961 ... 6.6224872346492125 4.7109291953311665
#
# -------------------------------------------
# 0.163
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.14871235)>
#
#     [1]: <Gaussian1D(amplitude=99.63391664, mean=83.82652922, stddev=2.7141478)>
#
#     [2]: <Moffat1D(amplitude=251.7974517, x_0=80.09199648, gamma=4.5304893, alpha=2.92129415)>
#
#     [3]: <Moffat1D(amplitude=49.92250997, x_0=90.05344404, gamma=8.27915846, alpha=4.00379186)>
# Parameters:
#             c0_0           amplitude_1   ...      gamma_3           alpha_3
#     -------------------- --------------- ... ----------------- -----------------
#     -0.14871235022153567 99.633916637489 ... 8.279158464709024 4.003791863167999
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.02581475)>
#
#     [1]: <Gaussian1D(amplitude=87.36416977, mean=85.72898176, stddev=2.64629979)>
#
#     [2]: <Moffat1D(amplitude=281.40592318, x_0=80.39155845, gamma=6.51402834, alpha=4.76362277)>
#
#     [3]: <Moffat1D(amplitude=39.53224381, x_0=91.49585293, gamma=6.51402834, alpha=4.76362277)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_3            alpha_3
#     -------------------- ----------------- ... ------------------ ------------------
#     0.025814752825696816 87.36416976717953 ... 6.5140283379530635 4.7636227720817095
#
# -------------------------------------------
# 0.168
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.09737994)>
#
#     [1]: <Gaussian1D(amplitude=11.20099588, mean=84.16067182, stddev=2.62109048)>
#
#     [2]: <Moffat1D(amplitude=25.23916814, x_0=78.79058261, gamma=6.47941067, alpha=4.86139887)>
#
#     [3]: <Moffat1D(amplitude=4.75137907, x_0=89.71314043, gamma=5.17930637, alpha=4.3332163)>
# Parameters:
#             c0_0            amplitude_1     ...     gamma_3           alpha_3
#     -------------------- ------------------ ... ---------------- -----------------
#     -0.09737994405985942 11.200995879051243 ... 5.17930637267121 4.333216295111969
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.1038742)>
#
#     [1]: <Gaussian1D(amplitude=11.17827026, mean=83.92275614, stddev=2.63300851)>
#
#     [2]: <Moffat1D(amplitude=25.00180243, x_0=78.74418471, gamma=6.14685546, alpha=4.54382092)>
#
#     [3]: <Moffat1D(amplitude=4.76448887, x_0=89.51799423, gamma=6.14685546, alpha=4.54382092)>
# Parameters:
#             c0_0            amplitude_1     ...     gamma_3           alpha_3
#     -------------------- ------------------ ... ---------------- -----------------
#     -0.10387419759610964 11.178270260531015 ... 6.14685546158122 4.543820915610064
#
# -------------------------------------------

# %%
outspec = spec.extract_all(method='cdf', plot_profiles=False, plot_traces=True, plot_extracted=False,
                           stepsize=25, pixrange=[0, -1, 2200, -1], level=-20, fit_dict={10 : [0, 2000]}, 
                           extrange_dict={10 : [0, 2000]}, 
                           fitorder_dict={'common':{'mean_1': 4, 'x_0_2':4, 'x_0_3':4}})
# Out:
# Extracting spectra
# ------------------
# Order_01
#
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 138 segments
#   of the 2D spectrum with stepsize=25 pix ...
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1500 - 3000
# Fitting to the trace at 3461 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  4071.46
#  Spectrum End:     4310.06
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.16
#
#  Spectrum Start:  4071.46
#  Spectrum End:     4310.06
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.16
#
#  Spectrum Start:  4071.46
#  Spectrum End:     4310.06
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.16
#
#
# Plotting the spectrum
# Order_02
#
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1400 - 3400
# Fitting to the trace at 4093 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  4240.70
#  Spectrum End:     4575.32
#  Dispersion (1st pixel):   0.16
#  Dispersion (average):      0.17
#
#  Spectrum Start:  4240.70
#  Spectrum End:     4575.32
#  Dispersion (1st pixel):   0.16
#  Dispersion (average):      0.17
#
#  Spectrum Start:  4240.70
#  Spectrum End:     4575.32
#  Dispersion (1st pixel):   0.16
#  Dispersion (average):      0.17
#
#
# Plotting the spectrum
# Order_03
#
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1300 - 3700
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  4546.04
#  Spectrum End:     4979.85
#  Dispersion (1st pixel):   0.17
#  Dispersion (average):      0.18
#
#  Spectrum Start:  4546.04
#  Spectrum End:     4979.85
#  Dispersion (1st pixel):   0.17
#  Dispersion (average):      0.18
#
#  Spectrum Start:  4546.04
#  Spectrum End:     4979.85
#  Dispersion (1st pixel):   0.17
#  Dispersion (average):      0.18
#
#
# Plotting the spectrum
# Order_04
#
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1200 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#
# Plotting the spectrum
# Order_05
#
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1100 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  5325.24
#  Spectrum End:     5967.01
#  Dispersion (1st pixel):   0.20
#  Dispersion (average):      0.21
#
#  Spectrum Start:  5325.24
#  Spectrum End:     5967.01
#  Dispersion (1st pixel):   0.20
#  Dispersion (average):      0.21
#
#  Spectrum Start:  5325.24
#  Spectrum End:     5967.01
#  Dispersion (1st pixel):   0.20
#  Dispersion (average):      0.21
#
#
# Plotting the spectrum
# Order_06
#
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 900 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  5810.63
#  Spectrum End:     6560.55
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#  Spectrum Start:  5810.63
#  Spectrum End:     6560.55
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#  Spectrum Start:  5810.63
#  Spectrum End:     6560.55
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#
# Plotting the spectrum
# Order_07
#
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 600 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  6380.37
#  Spectrum End:     7286.41
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#  Spectrum Start:  6380.37
#  Spectrum End:     7286.41
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#  Spectrum Start:  6380.37
#  Spectrum End:     7286.41
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#
# Plotting the spectrum
# Order_08
#
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 200 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  7066.66
#  Spectrum End:     8193.74
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29
#
#  Spectrum Start:  7066.66
#  Spectrum End:     8193.74
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29
#
#  Spectrum Start:  7066.66
#  Spectrum End:     8193.74
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29
#
#
# Plotting the spectrum
# Order_09
#
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 0 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  8012.11
#  Spectrum End:     9360.83
#  Dispersion (1st pixel):   0.30
#  Dispersion (average):      0.33
#
#  Spectrum Start:  8012.11
#  Spectrum End:     9360.83
#  Dispersion (1st pixel):   0.30
#  Dispersion (average):      0.33
#
#  Spectrum Start:  8012.11
#  Spectrum End:     9360.83
#  Dispersion (1st pixel):   0.30
#  Dispersion (average):      0.33
#
#
# Plotting the spectrum
# Order_10
#
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: mean_1
# Fitting polynomial of degree 3 to parameter: stddev_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 0 - 2000
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  9337.74
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.35
#  Dispersion (average):      0.37
#
#  Spectrum Start:  9337.74
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.35
#  Dispersion (average):      0.37
#
#  Spectrum Start:  9337.74
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.35
#  Dispersion (average):      0.37
#
#
# Plotting the spectrum
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   1  1500   4071.46  4310.06   0.16
#   2  2000   4240.70  4575.32   0.17
#   3  2400   4546.04  4979.85   0.18
#   4  2896   4902.88  5472.92   0.20
#   5  2996   5325.24  5967.01   0.21
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.66  8193.74   0.29
#   9  4096   8012.11  9360.83   0.33
#  10  2000   9337.74 10074.55   0.37
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   1  1500   4071.46  4310.06   0.16
#   2  2000   4240.70  4575.32   0.17
#   3  2400   4546.04  4979.85   0.18
#   4  2896   4902.88  5472.92   0.20
#   5  2996   5325.24  5967.01   0.21
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.66  8193.74   0.29
#   9  4096   8012.11  9360.83   0.33
#  10  2000   9337.74 10074.55   0.37
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   1  1500   4071.46  4310.06   0.16
#   2  2000   4240.70  4575.32   0.17
#   3  2400   4546.04  4979.85   0.18
#   4  2896   4902.88  5472.92   0.20
#   5  2996   5325.24  5967.01   0.21
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.66  8193.74   0.29
#   9  4096   8012.11  9360.83   0.33
#  10  2000   9337.74 10074.55   0.37

# %%
for sp, info in zip(spec, spec.ordinfo):
    if sp.mod0 is not None:
        a = 1.81/(sp.fitpars['x_0_3'] - sp.fitpars['x_0_2'])
        b = 0.87/(sp.fitpars['mean_1'] - sp.fitpars['x_0_2'])
        print('order: %d' %info['order'])
        print(np.max(a), np.min(a))
        print(np.max(b), np.min(b))
# Out:
# order: 1
# 0.12000000000000118 0.11999999999999619
# 0.12000000000000706 0.11999999999999883
# order: 2
# 0.1270000000000004 0.12699999999998315
# 0.12700000000000147 0.12699999999999753
# order: 3
# 0.13399999999999998 0.13399999999998646
# 0.1340000000000018 0.13400000000000004
# order: 4
# 0.1370000000000075 0.13699999999999984
# 0.13700000000001408 0.13699999999999812
# order: 5
# 0.14400000000000002 0.14399999999999905
# 0.14400000000000193 0.14399999999999583
# order: 6
# 0.14900000000000221 0.14899999999999924
# 0.14900000000000024 0.14899999999998756
# order: 7
# 0.15300000000000064 0.15299999999999936
# 0.1530000000000015 0.1529999999999946
# order: 8
# 0.15800000000000164 0.15799999999999967
# 0.15800000000000564 0.15799999999999828
# order: 9
# 0.16300000000000087 0.1629999999999996
# 0.16300000000000361 0.16300000000000103
# order: 10
# 0.16799999999999987 0.16799999999991322
# 0.16800000000000131 0.1679999999997353

# %%
outspec[1].save_multi('esi1d_J0924_41_moffat_primary')
outspec[0].save_multi('esi1d_J0924_41_moffat_secondary')
outspec[2].save_multi('esi1d_J0924_41_moffat_tertiary')
# Out:
# Spectrum saved in mode multitab to file esi1d_J0924_41_moffat_primary.fits
# Spectrum saved in mode multitab to file esi1d_J0924_41_moffat_secondary.fits
# Spectrum saved in mode multitab to file esi1d_J0924_41_moffat_tertiary.fits

# %%
outspec[0].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt')
# Out:
#  Spectrum Start:  4071.46
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.25

# %%
outspec[1].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt')
# Out:
#  Spectrum Start:  4071.46
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.25

# %%
outspec[2].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt')
# Out:
#  Spectrum Start:  4071.46
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.25

# %%
outspec[0].spec1d.save('spec1d_J0924_41_moffat_secondary.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0924_41_moffat_secondary.fits in format fits

# %%
outspec[1].spec1d.save('spec1d_J0924_41_moffat_primary.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0924_41_moffat_primary.fits in format fits

# %%
outspec[2].spec1d.save('spec1d_J0924_41_moffat_tertiary.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0924_41_moffat_tertiary.fits in format fits

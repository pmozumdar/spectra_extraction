# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from astropy.io import fits
from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, spec1d, echelle1d
from scipy.ndimage import shift

# %%
file_loc = '../galaxy_spectra/ESI_data/2018/*'

# %%
spec2d_file_list = []
var2d_file_list = []
#out_file = []
for i,p in enumerate(glob.glob(file_loc)):
    if 'J0630' in p:
        if 'bgsub.fits' in p:
            spec2d_file_list.append(p)
        elif 'var.fits' in p:
            var2d_file_list.append(p)

# %%
spec2d_file_list, var2d_file_list
# Out:
# (['../galaxy_spectra/ESI_data/2018/J0630-1201_0038_bgsub.fits',
#   '../galaxy_spectra/ESI_data/2018/J0630-1201_0037_bgsub.fits',
#   '../galaxy_spectra/ESI_data/2018/J0630-1201_0039_bgsub.fits'],
#  ['../galaxy_spectra/ESI_data/2018/J0630-1201_0038_var.fits',
#   '../galaxy_spectra/ESI_data/2018/J0630-1201_0039_var.fits',
#   '../galaxy_spectra/ESI_data/2018/J0630-1201_0037_var.fits'])

# %%
spec1 = esi2d.Esi2d(spec2d_file_list[1], varfile=var2d_file_list[2])
spec2 = esi2d.Esi2d(spec2d_file_list[0], varfile=var2d_file_list[0])
spec3 = esi2d.Esi2d(spec2d_file_list[2], varfile=var2d_file_list[1])
# Out:
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3461x165     x
#   2   4093x145     x
#   3   4096x146     x
#   4   4096x141     x
#   5   4096x130     x
#   6   4096x127     x
#   7   4096x124     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x111     x
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3461x165     x
#   2   4093x145     x
#   3   4096x146     x
#   4   4096x141     x
#   5   4096x130     x
#   6   4096x127     x
#   7   4096x124     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x111     x
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3461x165     x
#   2   4093x145     x
#   3   4096x146     x
#   4   4096x141     x
#   5   4096x130     x
#   6   4096x127     x
#   7   4096x124     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x111     x

# %%
pixrange = [[2850, 3250], [2400, 2800], [2200, 2600], [2000, 2400], [1600, 2000], [1600, 1900], [1150, 1550]]
spec_list = [spec1, spec2, spec3]
order_list = spec1.ordinfo

for order, pix in zip(order_list[3:], pixrange):
    print(order['name'], 'pixscale:', order['pixscale'])
    for sp in spec_list:
        profile = sp[order['order']-1].spatial_profile(pixrange=pix)
        plt.show()
        sp[order['order']-1].initial_model()
# Out:
# Order_04 pixscale: 0.137
# Profile max value (before normalization) 136.705194
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 136, 61, 3, 4
#
# amplitude=136.000000, x_0=61.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 15, 40, 2, 3
#
# amplitude=15.000000, x_0=40.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.59048909)>
#
#     [1]: <Moffat1D(amplitude=137.12873195, x_0=61.27224951, gamma=4.56831719, alpha=2.23490224)>
#
#     [2]: <Moffat1D(amplitude=5.49722164, x_0=41.82110722, gamma=9.77811263, alpha=3.32413567)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2           alpha_2
#     ------------------- ------------------ ... ----------------- -----------------
#     -0.5904890940992331 137.12873195034152 ... 9.778112634576836 3.324135666878713
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 141.791181
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 141, 87, 3, 4
#
# amplitude=141.000000, x_0=87.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 10, 67, 2, 3
#
# amplitude=10.000000, x_0=67.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.6720547)>
#
#     [1]: <Moffat1D(amplitude=144.44342367, x_0=87.77989577, gamma=4.25546846, alpha=2.16726214)>
#
#     [2]: <Moffat1D(amplitude=6.35621651, x_0=68.37373197, gamma=4.68074535, alpha=1.24256219)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_2           alpha_2
#     ------------------ ------------------ ... ----------------- -----------------
#     -0.672054703638087 144.44342367450642 ... 4.680745345446068 1.242562189877411
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 139.469739
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 139, 32, 3, 4
#
# amplitude=139.000000, x_0=32.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 10, 11, 2, 3
#
# amplitude=10.000000, x_0=11.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.391987)>
#
#     [1]: <Moffat1D(amplitude=139.40691087, x_0=31.78282477, gamma=4.94168097, alpha=2.67201927)>
#
#     [2]: <Moffat1D(amplitude=4.50993097, x_0=12.9263145, gamma=42.60434019, alpha=67.45770089)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_2           alpha_2
#     -------------------- ------------------ ... ------------------ ----------------
#     -0.39198700033678574 139.40691086696341 ... 42.604340192336586 67.4577008902725
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_05 pixscale: 0.144
# Profile max value (before normalization) 76.014526
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 76, 59, 3, 4
#
# amplitude=76.000000, x_0=59.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 9, 38, 2, 3
#
# amplitude=9.000000, x_0=38.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.6483514)>
#
#     [1]: <Moffat1D(amplitude=77.31649231, x_0=58.75048412, gamma=4.03755298, alpha=1.89729112)>
#
#     [2]: <Moffat1D(amplitude=7.28023152, x_0=39.49831703, gamma=3.31734452, alpha=1.21971863)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2            alpha_2
#     ------------------- ----------------- ... ------------------ ------------------
#     -0.6483514040519135 77.31649231488662 ... 3.3173445179904264 1.2197186335613928
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 80.078235
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 80, 84, 3, 4
#
# amplitude=80.000000, x_0=84.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 10, 63, 2, 3
#
# amplitude=10.000000, x_0=63.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.32781433)>
#
#     [1]: <Moffat1D(amplitude=81.33792716, x_0=84.36674085, gamma=4.02301173, alpha=2.01298848)>
#
#     [2]: <Moffat1D(amplitude=8.77824232, x_0=64.86262406, gamma=2.23475582, alpha=0.70366324)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2           alpha_2
#     ------------------- ----------------- ... ----------------- ------------------
#     -0.3278143262927165 81.33792716256552 ... 2.234755822478562 0.7036632391562221
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 79.176354
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 79, 30, 3, 4
#
# amplitude=79.000000, x_0=30.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 10, 10, 2, 3
#
# amplitude=10.000000, x_0=10.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.14272247)>
#
#     [1]: <Moffat1D(amplitude=81.0968978, x_0=30.20682026, gamma=4.51345676, alpha=2.3968309)>
#
#     [2]: <Moffat1D(amplitude=8.8762989, x_0=11.06905761, gamma=1.55816107, alpha=0.71429552)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_2            alpha_2
#     -------------------- ----------------- ... ------------------ -----------------
#     -0.14272246505078195 81.09689779815122 ... 1.5581610661519125 0.714295523434195
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Order_06 pixscale: 0.149
# Profile max value (before normalization) 97.246020
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 97, 52, 3, 4
#
# amplitude=97.000000, x_0=52.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 10, 34, 2, 3
#
# amplitude=10.000000, x_0=34.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.24018764)>
#
#     [1]: <Moffat1D(amplitude=97.19625435, x_0=53.92752581, gamma=4.10477228, alpha=2.18929134)>
#
#     [2]: <Moffat1D(amplitude=8.90193642, x_0=35.68390802, gamma=2.59895478, alpha=0.9186457)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2            alpha_2
#     ------------------- ----------------- ... ------------------ ------------------
#     -0.2401876385467894 97.19625434718847 ... 2.5989547753192723 0.9186457014348486
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 104.153973
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 104, 77, 3, 4
#
# amplitude=104.000000, x_0=77.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 10, 58, 2, 3
#
# amplitude=10.000000, x_0=58.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.13485765)>
#
#     [1]: <Moffat1D(amplitude=103.90267553, x_0=78.10268586, gamma=3.49673775, alpha=1.8498764)>
#
#     [2]: <Moffat1D(amplitude=8.95363763, x_0=59.79339406, gamma=3.35360982, alpha=1.54858187)>
# Parameters:
#             c0_0            amplitude_1     ...      alpha_2
#     -------------------- ------------------ ... ------------------
#     -0.13485765212758713 103.90267553221405 ... 1.5485818724484304
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 100.435099
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.2
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 100, 26, 3, 4
#
# amplitude=100.000000, x_0=26.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 15, 6, 2, 3
#
# amplitude=15.000000, x_0=6.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.54117887)>
#
#     [1]: <Moffat1D(amplitude=102.47172111, x_0=26.38531625, gamma=3.9380327, alpha=2.08141774)>
#
#     [2]: <Moffat1D(amplitude=11.55473752, x_0=7.41663186, gamma=2.62290604, alpha=0.5257373)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2            alpha_2
#     ------------------- ----------------- ... ------------------ ------------------
#     -0.5411788701692147 102.4717211114034 ... 2.6229060383864615 0.5257372954973895
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_07 pixscale: 0.153
# Profile max value (before normalization) 225.871039
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 225, 54, 3, 4
#
# amplitude=225.000000, x_0=54.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 20, 34, 2, 3
#
# amplitude=20.000000, x_0=34.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.54119955)>
#
#     [1]: <Moffat1D(amplitude=227.48815095, x_0=53.72560142, gamma=3.75930932, alpha=1.96476169)>
#
#     [2]: <Moffat1D(amplitude=16.70024262, x_0=35.83671575, gamma=2.56737704, alpha=0.81856488)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2           alpha_2
#     ------------------- ------------------ ... ----------------- ------------------
#     -0.5411995452392911 227.48815094832963 ... 2.567377042712488 0.8185648778053252
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 234.775683
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 234, 77, 3, 4
#
# amplitude=234.000000, x_0=77.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 10, 59, 2, 3
#
# amplitude=10.000000, x_0=59.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.42374998)>
#
#     [1]: <Moffat1D(amplitude=241.78034967, x_0=77.50686642, gamma=3.41798877, alpha=1.85191184)>
#
#     [2]: <Moffat1D(amplitude=17.63269584, x_0=59.43076755, gamma=2.11916995, alpha=0.83053123)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ ------------------
#     -0.4237499847835456 241.78034966763502 ... 2.1191699469727125 0.8305312314962475
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 233.305278
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 233, 26, 3, 4
#
# amplitude=233.000000, x_0=26.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 10, 7, 2, 3
#
# amplitude=10.000000, x_0=7.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.14230554)>
#
#     [1]: <Moffat1D(amplitude=236.53636478, x_0=26.59626263, gamma=3.97596504, alpha=2.27624131)>
#
#     [2]: <Moffat1D(amplitude=15.77129876, x_0=8.80221462, gamma=3.24952369, alpha=0.79183256)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_2            alpha_2
#     -------------------- ----------------- ... ------------------ ------------------
#     -0.14230554075929314 236.5363647762246 ... 3.2495236860685335 0.7918325581080621
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_08 pixscale: 0.158
# Profile max value (before normalization) 128.423022
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.2
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 128, 53, 3, 4
#
# amplitude=128.000000, x_0=53.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 15, 34, 2, 3
#
# amplitude=15.000000, x_0=34.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.16577287)>
#
#     [1]: <Moffat1D(amplitude=132.97454804, x_0=53.24284186, gamma=3.37000314, alpha=1.6885036)>
#
#     [2]: <Moffat1D(amplitude=13.76353847, x_0=35.72722507, gamma=3.28419817, alpha=1.27109294)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ -----------------
#     -1.1657728679845776 132.97454803674896 ... 3.2841981713824233 1.271092938037813
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 137.536571
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 137, 77, 3, 4
#
# amplitude=137.000000, x_0=77.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 14, 58, 2, 3
#
# amplitude=14.000000, x_0=58.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.42022698)>
#
#     [1]: <Moffat1D(amplitude=140.88281152, x_0=76.42473908, gamma=2.98404723, alpha=1.57966108)>
#
#     [2]: <Moffat1D(amplitude=15.00511017, x_0=58.95401082, gamma=2.77504567, alpha=1.04259217)>
# Parameters:
#             c0_0            amplitude_1     ...      gamma_2           alpha_2
#     -------------------- ------------------ ... ----------------- ------------------
#     -0.42022697659922886 140.88281152116753 ... 2.775045674070252 1.0425921675011802
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 135.107714
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 135, 26, 3, 4
#
# amplitude=135.000000, x_0=26.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 18, 9, 2, 3
#
# amplitude=18.000000, x_0=9.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.29430513)>
#
#     [1]: <Moffat1D(amplitude=138.87494606, x_0=26.35858822, gamma=3.4004946, alpha=1.82912789)>
#
#     [2]: <Moffat1D(amplitude=15.47254263, x_0=8.8166783, gamma=2.12059449, alpha=0.75091851)>
# Parameters:
#             c0_0           amplitude_1     ...     gamma_2           alpha_2
#     ------------------- ------------------ ... ---------------- ------------------
#     -0.2943051250535057 138.87494605891544 ... 2.12059448839914 0.7509185058425341
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_09 pixscale: 0.163
# Profile max value (before normalization) 163.378247
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 160, 50, 3, 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-6cffc65be303> in <module>
#       8         profile = sp[order['order']-1].spatial_profile(pixrange=pix)
#       9         plt.show()
# ---> 10         sp[order['order']-1].initial_model()
#
# ~/Project/new_project/spectra_extraction/specim_test/specim/specfuncs/spec2d.py in initial_model(self, profile, verbose)
#    1210             background_order = int(input('Order of background polynomial : '))
#    1211             num_gauss = int(input('Number of Gaussian profile : '))
# -> 1212             num_moffat = int(input('Number of Moffat profile : '))
#    1213
#    1214             bg_const = []
#
# ValueError: invalid literal for int() with base 10: '160, 50, 3, 4'

# %%
pixrange = [[2850, 3250], [2400, 2800], [2200, 2600], [2000, 2400], [1600, 2000], [1600, 1900], [1150, 1550]]
spec_list = [spec1, spec2, spec3]
order_list = spec1.ordinfo

for order, pix in zip(order_list[8:], pixrange):
    print(order['name'], 'pixscale:', order['pixscale'])
    for sp in spec_list:
        profile = sp[order['order']-1].spatial_profile(pixrange=pix)
        plt.show()
        sp[order['order']-1].initial_model()
# Out:
# Order_09 pixscale: 0.163
# Profile max value (before normalization) 156.593822
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 156, 50, 3, 4
#
# amplitude=156.000000, x_0=50.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 18, 34, 2, 3
#
# amplitude=18.000000, x_0=34.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.52206163)>
#
#     [1]: <Moffat1D(amplitude=157.36700649, x_0=51.80898658, gamma=3.19526087, alpha=1.77470618)>
#
#     [2]: <Moffat1D(amplitude=14.72711774, x_0=37.40574226, gamma=54.12668568, alpha=56.87942361)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_2           alpha_2
#     ------------------ ------------------ ... ----------------- ------------------
#     -1.522061630466038 157.36700648510242 ... 54.12668567945632 56.879423607795815
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 159.087179
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.2
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 158, 73, 3, 4
#
# amplitude=158.000000, x_0=73.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 18, 55, 2, 3
#
# amplitude=18.000000, x_0=55.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-2.17590975)>
#
#     [1]: <Moffat1D(amplitude=160.0561515, x_0=73.82566078, gamma=2.72256198, alpha=1.55297739)>
#
#     [2]: <Moffat1D(amplitude=18.71052477, x_0=57.79758623, gamma=2.66353249, alpha=0.68623268)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_2            alpha_2
#     ------------------- ------------------ ... ------------------ -----------------
#     -2.1759097532692393 160.05615149697292 ... 2.6635324860010794 0.686232680953256
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 145.745475
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -0.3
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 145, 26, 3, 4
#
# amplitude=145.000000, x_0=26.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 17, 9, 2, 3
#
# amplitude=17.000000, x_0=9.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.73047004)>
#
#     [1]: <Moffat1D(amplitude=148.60137559, x_0=25.68823816, gamma=3.59802076, alpha=2.17091933)>
#
#     [2]: <Moffat1D(amplitude=12.65450285, x_0=9.12714271, gamma=6.51653017, alpha=5.19205272)>
# Parameters:
#             c0_0           amplitude_1     ...     gamma_2           alpha_2
#     ------------------- ------------------ ... ---------------- -----------------
#     -0.7304700439308147 148.60137559411598 ... 6.51653017060239 5.192052723249681
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Order_10 pixscale: 0.168
# Profile max value (before normalization) 6.701262
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 2
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -0.3
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 7, 48, 3, 4
#
# amplitude=7.000000, x_0=48.000000, gamma=3.000000, alpha=4.000000
#
# Parameters of Moffat profile 2 : 1, 21, 2, 3
#
# amplitude=1.000000, x_0=21.000000, gamma=2.000000, alpha=3.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.18857498)>
#
#     [1]: <Moffat1D(amplitude=6.86063486, x_0=50.2031259, gamma=3.17639448, alpha=1.581483)>
#
#     [2]: <Moffat1D(amplitude=0.28851547, x_0=29.87247263, gamma=12.0851872, alpha=0.73629393)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_2           alpha_2
#     ------------------- ----------------- ... ----------------- ------------------
#     -0.1885749775471308 6.860634855286557 ... 12.08518720369442 0.7362939250633356
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# yes
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : -0.3
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 7, 48, 3, 4
#
# amplitude=7.000000, x_0=48.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.1699778)>
#
#     [1]: <Moffat1D(amplitude=6.79547292, x_0=50.18494828, gamma=3.4617161, alpha=1.79396831)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_1           alpha_1
#     -------------------- ----------------- ... ----------------- ------------------
#     -0.16997779517793954 6.795472919498441 ... 3.461716098045477 1.7939683125943908
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 6.300107
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.5
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 6.3, 70, 3, 4
#
# amplitude=6.300000, x_0=70.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.10271587)>
#
#     [1]: <Moffat1D(amplitude=6.61025329, x_0=72.01537898, gamma=3.11985884, alpha=2.2525631)>
# Parameters:
#             c0_0            amplitude_1    ...      gamma_1           alpha_1
#     -------------------- ----------------- ... ----------------- ------------------
#     -0.10271587492552763 6.610253288072149 ... 3.119858839563723 2.2525631033719407
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 7.310368
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 1
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 0.3
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 7, 23, 3, 4
#
# amplitude=7.000000, x_0=23.000000, gamma=3.000000, alpha=4.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1]
# Components:
#     [0]: <Polynomial1D(0, c0=-0.08416501)>
#
#     [1]: <Moffat1D(amplitude=7.47010329, x_0=24.73820388, gamma=2.44562671, alpha=1.25067585)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_1            alpha_1
#     -------------------- ---------------- ... ------------------ ------------------
#     -0.08416501205579162 7.47010329118459 ... 2.4456267087018886 1.2506758500830222
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no

# %%
for od in order_list[3:]:
    for i, sp in enumerate(spec_list):
        if i==0:
            print(od['name']+':')
            print(sp[od['order']-1].mod0.x_0_1.value)
            center1 = sp[od['order']-1].mod0.x_0_1.value
            if od['order']!=10:
                center2 = sp[od['order']-1].mod0.x_0_2.value

        else:
            print(center1 - sp[od['order']-1].mod0.x_0_1.value)
            if od['order']!=10:
                print(center2 - sp[od['order']-1].mod0.x_0_2.value)
# Out:
# Order_04:
# 61.272249511225965
# -26.50764625691818
# -26.55262474451657
# 29.489424743129135
# 28.894792718522673
# Order_05:
# 58.750484116679665
# -25.616256734689266
# -25.364307030572647
# 28.543663858448625
# 28.429259424443885
# Order_06:
# 53.927525805597504
# -24.175160051211996
# -24.10948604189683
# 27.542209553691734
# 28.2672761542081
# Order_07:
# 53.72560141886261
# -23.781264997055644
# -23.594051799116883
# 27.129338784752964
# 27.034501130859695
# Order_08:
# 53.242841861364404
# -23.181897219972434
# -23.226785753344345
# 26.884253639277794
# 26.91054676607201
# Order_09:
# 51.80898658072395
# -22.016674197593332
# -20.391843968661135
# 26.12074842480377
# 28.278599547085737
# Order_10:
# 50.18494827540104
# -21.83043070422255
# 25.446744394622254

# %%
order_list = [4, 5, 6, 7, 8, 9, 10]
spec_list = [spec1, spec2, spec3]
shifted_sp = []
shifted_var = []
shift_pixel = np.array([[0.0, -26.51, 29.49], [0.0, -25.62, 28.54], [0.0, -24.18, 27.54], 
                        [0.0, -23.78, 27.13], [0.0, -23.18, 26.88], [0.0, -22.02, 26.12],
                        [0.0, -21.83, 25.45]])
for shft, order in zip(shift_pixel, order_list):
    new_sp = []
    new_var = []
    for i, sp in enumerate(spec_list):
        #print(sp[order-1].mod0, shift[i])
        nanmask = (sp[order-1].vardata <= 0) | (np.isnan(sp[order-1].vardata)) 
        nnan = nanmask.sum()
        if nnan > 0:
            print('Found %d NaNs in the two-dimensional variance '\
                  'spectrum' % nnan)

            """ Replace the NaNs with a big value """
            sp[order-1].vardata[nanmask] = 1.e9
        new_sp.append(shift(sp[order-1].data, [shft[i], 0], order=1))
        new_var.append(shift(sp[order-1].vardata, [shft[i], 0], order=1))
    shifted_sp.append(new_sp)
    shifted_var.append(new_var)
# Out:
# Found 1601 NaNs in the two-dimensional variance spectrum
# Found 1578 NaNs in the two-dimensional variance spectrum
# Found 1895 NaNs in the two-dimensional variance spectrum
# Found 2081 NaNs in the two-dimensional variance spectrum
# Found 1852 NaNs in the two-dimensional variance spectrum
# Found 1552 NaNs in the two-dimensional variance spectrum
# Found 1177 NaNs in the two-dimensional variance spectrum
# Found 1525 NaNs in the two-dimensional variance spectrum
# Found 1740 NaNs in the two-dimensional variance spectrum
# Found 1407 NaNs in the two-dimensional variance spectrum
# Found 1444 NaNs in the two-dimensional variance spectrum
# Found 1133 NaNs in the two-dimensional variance spectrum
# Found 1510 NaNs in the two-dimensional variance spectrum
# Found 1790 NaNs in the two-dimensional variance spectrum
# Found 1326 NaNs in the two-dimensional variance spectrum
# Found 1054 NaNs in the two-dimensional variance spectrum
# Found 1839 NaNs in the two-dimensional variance spectrum
# Found 1631 NaNs in the two-dimensional variance spectrum
# Found 877 NaNs in the two-dimensional variance spectrum
# Found 1095 NaNs in the two-dimensional variance spectrum
# Found 1062 NaNs in the two-dimensional variance spectrum

# %%
#%matplotlib notebook
pixrange = [[2850, 3250], [2400, 2800], [2200, 2600], [2000, 2400], [1600, 2000], [1600, 1900], [1150, 1550]]
for od, sp_list, pix in zip(order_list, shifted_sp, pixrange):
    plt.figure(figsize=(8, 6))
    color = ['b', 'r', 'k']
    label = ['frame_37', 'frame_38', 'frame_39']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pix[0]:pix[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    plt.legend()
    plt.title('order %d' %od)

# %%
outsp = []
outvar = []

for sp_list, var_list in zip(shifted_sp, shifted_var):
    wtsp = np.zeros(sp_list[0].shape)
    wtsum = np.zeros(sp_list[0].shape)
    for s, v in zip(sp_list, var_list):
        wt = np.zeros(wtsp.shape)
        mask = np.isnan(v) | (v<=0)
        wt[~mask] = 1.0 / v[~mask]
        #print(sum(sum(np.isnan(wt) | (wt<=0))))
        wtsp += wt * s
        #print(sum(sum(wtsp==0)))
        wtsum += wt
        #print(sum(sum(wtsum==0)))

    wtsp[wtsum == 0] = 0
    wtsum[wtsum == 0] = 1
    outsp.append(wtsp / wtsum)
    outvar.append(1.0 / wtsum)

# %%
for od, sp_list, cd_sp, pix in zip(order_list, shifted_sp, outsp, pixrange):
    plt.figure(figsize=(8, 6))
    color = ['b', 'r', 'k']
    label = ['frame_37', 'frame_38', 'frame_39']
    for i, p in enumerate(sp_list):
        tmpdata = p[:, pix[0]:pix[1]]
        pflux = np.median(tmpdata, axis=1)
        x = np.arange(p.shape[0])
        plt.plot(x, pflux, color=color[i], drawstyle='steps', label=label[i])
    
    tmpdata = cd_sp[:, pix[0]:pix[1]]
    pflux = np.median(tmpdata, axis=1)
    x = np.arange(cd_sp.shape[0])
    plt.plot(x, pflux, color='g', drawstyle='steps', label='coadded')
    plt.legend()
    plt.title('order %d' %od)

# %%
s = fits.open('../galaxy_spectra/ESI_data/2018/J0630-1201_0037_bgsub.fits')
for od, cd_sp, cd_var in zip(order_list, outsp, outvar):
    file_name1 = 'J0630_ESI_spectra/J0630_coadd2d_sp_order_' + str(od) + '.fits'
    file_name2 = 'J0630_ESI_spectra/J0630_coadd2d_var_order_' + str(od) + '.fits'
    fits.writeto(file_name1, cd_sp, header=s[od].header)
    fits.writeto(file_name2, cd_var, header=s[od].header)

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from astropy.table import Table
from astropy.modeling import models
from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, echelle1d, spec1d
#from specim.specfuncs import spec1d, specset1d

# %%
file_loc = '../galaxy_spectra/ESI_data/*'

# %%
spec2d_file_list = []
var2d_file_list = []
#out_file = []
for i,p in enumerate(glob.glob(file_loc)):
    if 'J0147' in p:
        if 'bgsub.fits' in p:
            spec2d_file_list.append(p)
        elif 'var.fits' in p:
            var2d_file_list.append(p)
            #frame = p.split('_')[-3][:4]
            #out_file.append('0053m1_r'+ frame + '_cleaned.fits')
        #print(p)

# %%
spec = esi2d.Esi2d(spec2d_file_list[0], varfile=var2d_file_list[1])
print(spec2d_file_list[0])
print(var2d_file_list[1])
# Out:
# Order  Shape    Dispaxis
# ----- --------- --------
#   1   3461x165     x
#   2   4093x145     x
#   3   4096x146     x
#   4   4096x141     x
#   5   4096x130     x
#   6   4096x127     x
#   7   4096x124     x
#   8   4096x121     x
#   9   4096x117     x
#  10   4096x111     x
# ../galaxy_spectra/ESI_data/J0147+4630_0031_bgsub.fits
# ../galaxy_spectra/ESI_data/J0147+4630_0031_var.fits

# %%
spec.plot_2d()
# Out:
# No valid WCS information in image header
#  CTYPE keys are not RA/DEC
#    Cutout data in section [xrange,yrange]:  [0:4096,0:1777]
#    Cutout image center (x, y): (2048, 888)
#    Cutout image size (x y): 4096x1777
#
# Calculating display limits
# --------------------------
#  Clipped mean: 0.576192
#  Clipped rms:  5.981041
#  fmin (mean -   1 sigma):  -5.404849
#  fmax (mean +  10 sigma):  60.386607

# %%
spec.plot_profiles()

# %%
pixrange = [(1900, 2400)] #(1900, 2400)
sp_list = [spec[1], spec[2], spec[5],spec[6], spec[8], spec[9]]
sp_info = [spec.ordinfo[1], spec.ordinfo[2], spec.ordinfo[5], spec.ordinfo[6], spec.ordinfo[8],
          spec.ordinfo[9]]
for sp, info in zip(spec, spec.ordinfo):
    title = 'Spatial profile for ' + str(info['name'])
    sp.spatial_profile(pixrange=pixrange[0], title=title)
    plt.show()
    sp.initial_model()
# Out:
# Profile max value (before normalization) 858.924703
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 3
# Number of Moffat profile : 0
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 3
#
# Enter parameter values for a Gaussian profile in following format...
# amplitude_value, mu_value, sigma_value
#
# Parameters of Gaussian profile 1 : 800, 75, 2
#
# amplitude=800.000000, mu=75.000000, sigma=2.000000
#
# Parameters of Gaussian profile 2 : 160, 81, 2
#
# amplitude=160.000000, mu=81.000000, sigma=2.000000
#
# Parameters of Gaussian profile 3 : 100, 101, 2
#
# amplitude=100.000000, mu=101.000000, sigma=2.000000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
# ...

# %%
def tie_pos1_moffat(model):
    print(pixscale)
    return model.x_0_2 + 0.886 / pixscale

def tie_pos1_gauss(model):
    print(pixscale)
    return model.mean_1 + (0.886 / pixscale)

def tie_pos2_gauss(model):
    #print(pixscale)
    return model.mean_1 + (1.87 / pixscale)

def tie_stddev_gauss(model):
    return model.stddev_3
    
for sp, info in zip(spec, spec.ordinfo):
    if sp.mod0 is not None:
        pixscale = info['pixscale']
        #sp.mod0[2].mean.tied = tie_pos1_gauss
        #sp.mod0[3].mean.tied = tie_pos2_gauss
        sp.mod0[1].stddev.tied = tie_stddev_gauss
        sp.refined_model(sp.mod0)
# Out:
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=1.55202874)>
#
#     [1]: <Gaussian1D(amplitude=839.27641026, mean=74.44931775, stddev=3.43669319)>
#
#     [2]: <Gaussian1D(amplitude=94.49904926, mean=81.7887852, stddev=3.71385331)>
#
#     [3]: <Gaussian1D(amplitude=78.51233219, mean=101.1816703, stddev=3.70448585)>
# Parameters:
#            c0_0           amplitude_1    ...       mean_3            stddev_3
#     ------------------ ----------------- ... ------------------ -----------------
#     1.5520287420861094 839.2764102587606 ... 101.18167030062425 3.704485854019757
#
# -------------------------------------------
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# ...

# %%
outspec = spec.extract_all(method='cdf', plot_profiles=False, plot_traces=True, plot_extracted=False,
                          stepsize=25) #, fit_dict = {2 : [1400, 2700]})
# Out:
# Extracting spectra
# ------------------
# Order_01
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fitting polynomial of degree 2 to parameter: c0_0
# Fitting polynomial of degree 2 to parameter: mean_1
# Fitting polynomial of degree 2 to parameter: stddev_1
# Fitting polynomial of degree 2 to parameter: mean_2
# Fitting polynomial of degree 2 to parameter: stddev_2
# Fitting polynomial of degree 2 to parameter: mean_3
# Fitting polynomial of degree 2 to parameter: stddev_3
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1500 - 3000
# Fitting to the trace at 3461 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  4071.46
#  Spectrum End:     4310.06
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.16
#
#  Spectrum Start:  4071.46
#  Spectrum End:     4310.06
#  Dispersion (1st pixel):   0.15
# ...

# %%
#%matplotlib qt
outspec[0].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))
outspec[1].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))
outspec[2].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))

# %%
#outspec[0].save_multi('spec1d_J0147_31_primary.fits')
#outspec[1].save_multi('spec1d_J0147_31_secondary.fits')
#outspec[2].save_multi('spec1d_J0147_31_tertiary.fits')
# Out:
# Spectrum saved in mode multitab to file spec1d_J0147_31_primary.fits.fits
# Spectrum saved in mode multitab to file spec1d_J0147_31_secondary.fits.fits
# Spectrum saved in mode multitab to file spec1d_J0147_31_tertiary.fits.fits

# %%
#pr_spec = echelle1d.Ech1d('spec1d_J0147_31_primary.fits.fits')
#se_spec = echelle1d.Ech1d('spec1d_J0147_31_secondary.fits.fits')
tr_spec = echelle1d.Ech1d('spec1d_J0147_31_tertiary.fits.fits')
# Out:
# Opening echelle spectrum file: spec1d_J0147_31_tertiary.fits.fits
#
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   0  1500   4071.46  4310.06   0.16
#   1  2000   4240.70  4575.32   0.17
#   2  2400   4546.04  4979.85   0.18
#   3  2896   4902.88  5472.92   0.20
#   4  2996   5325.24  5967.01   0.21
#   5  3196   5810.63  6560.55   0.23
#   6  3496   6380.37  7286.41   0.26
#   7  3896   7066.66  8193.74   0.29
#   8  4096   8012.11  9360.83   0.33
#   9  4096   9337.74 10909.62   0.38

# %%
#pr_spec.plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))
tr_spec.plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
#pr_spec.stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth.txt')
tr_spec.stitch_to_spec1d(respfile='response_curve_ESI_optimal_10_4.txt')
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">
#  Spectrum Start:  4071.46
#  Spectrum End:    10909.62
#  Dispersion (1st pixel):   0.15
#  Dispersion (average):      0.26

# %%
# %matplotlib notebook
plt.plot(pr_spec.spec1d['wav'][0:17500], pr_spec.spec1d['flux'][0:17500])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
#pr_spec.spec1d.plot()
tr_spec.spec1d.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
resp_corr = np.loadtxt('response_curve_ESI_optimal.txt')
r = []
order = [4, 5] #, 9, 10]
for i, p in enumerate(order):
    r.append(resp_corr[p-1])
#r.append(resp_corr[5:7])
#r.append(resp_corr[8:])
np.savetxt('resp_file_for_testing.txt', r)

# %%
outspec[0].stitch_to_spec1d(respfile='resp_file_for_testing.txt', resp_corr=True)

# %%
# %matplotlib notebook
outspec[0].spec1d.plot()

# %%
new_outspec = outspec[2]
new_outspec= new_outspec.esi_resp_corr(new_outspec, respfile='resp_file_for_testing.txt')
outspec[2].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))

# %%
new_spec1d = new_outspec.stitch_to_spec1d(new_outspec)

# %%
# %matplotlib notebook
new_spec1d.plot()

# %%
spec.stitch(outspec=outspec, respfile='resp_file_for_testing.txt')

# %%
# %matplotlib notebook
spec.outspec[0].spec1d.plot()

# %%
spec.outspec[2].spec1d.plot()

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

from keckcode_test.keckcode.esiredux import esi2d, esi1d
from specim_test.specim.specfuncs import spec2d, echelle1d, spec1d, echelle2d

# %%
file_loc = 'J0147_spectra/*'

# %%
spec2d_file_list = []
var2d_file_list = []
#out_file = []
for i, p in enumerate(glob.glob(file_loc)):
    file_name = p.split('/')[-1]
    if 'sp' in file_name and 'order' in file_name:
        spec2d_file_list.append(p)
    elif 'var' in file_name:
        var2d_file_list.append(p)

# %%
print(spec2d_file_list, var2d_file_list)
# Out:
# ['J0147_spectra/J0147_coadd2d_sp_order_6.fits', 'J0147_spectra/J0147_coadd2d_sp_order_8.fits', 'J0147_spectra/J0147_coadd2d_sp_order_5.fits', 'J0147_spectra/J0147_coadd2d_sp_order_7.fits', 'J0147_spectra/J0147_coadd2d_sp_order_4.fits', 'J0147_spectra/J0147_coadd2d_sp_order_9.fits', 'J0147_spectra/J0147_coadd2d_sp_order_10.fits'] ['J0147_spectra/J0147_coadd2d_var_order_10.fits', 'J0147_spectra/J0147_coadd2d_var_order_7.fits', 'J0147_spectra/J0147_coadd2d_var_order_5.fits', 'J0147_spectra/J0147_coadd2d_var_order_8.fits', 'J0147_spectra/J0147_coadd2d_var_order_9.fits', 'J0147_spectra/J0147_coadd2d_var_order_6.fits', 'J0147_spectra/J0147_coadd2d_var_order_4.fits']

# %%
spec_ord_4 = spec2d.Spec2d(inspec=spec2d_file_list[4], invar=var2d_file_list[6], logwav=True)
spec_ord_5 = spec2d.Spec2d(inspec=spec2d_file_list[2], invar=var2d_file_list[2], logwav=True)
spec_ord_6 = spec2d.Spec2d(inspec=spec2d_file_list[0], invar=var2d_file_list[5], logwav=True)
spec_ord_7 = spec2d.Spec2d(inspec=spec2d_file_list[3], invar=var2d_file_list[1], logwav=True)
spec_ord_8 = spec2d.Spec2d(inspec=spec2d_file_list[1], invar=var2d_file_list[3], logwav=True)
spec_ord_9 = spec2d.Spec2d(inspec=spec2d_file_list[5], invar=var2d_file_list[4], logwav=True)
spec_ord_10 = spec2d.Spec2d(inspec=spec2d_file_list[6], invar=var2d_file_list[0], logwav=True)
# Out:
# Loading file J0147_spectra/J0147_coadd2d_sp_order_4.fits
# -----------------------------------------------
#
# Loading file J0147_spectra/J0147_coadd2d_var_order_4.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from J0147_spectra/J0147_coadd2d_sp_order_4.fits (HDU=0)
# Final data dimensions (x y): 4096 x 141
#
# Dispersion axis:              x
# N_pixels along dispersion axis: 4096
#
#
# Loading file J0147_spectra/J0147_coadd2d_sp_order_5.fits
# -----------------------------------------------
#
# Loading file J0147_spectra/J0147_coadd2d_var_order_5.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from J0147_spectra/J0147_coadd2d_sp_order_5.fits (HDU=0)
# Final data dimensions (x y): 4096 x 130
#
# Dispersion axis:              x
# N_pixels along dispersion axis: 4096
#
#
# Loading file J0147_spectra/J0147_coadd2d_sp_order_6.fits
# -----------------------------------------------
#
# Loading file J0147_spectra/J0147_coadd2d_var_order_6.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from J0147_spectra/J0147_coadd2d_sp_order_6.fits (HDU=0)
# Final data dimensions (x y): 4096 x 127
#
# Dispersion axis:              x
# N_pixels along dispersion axis: 4096
#
#
# Loading file J0147_spectra/J0147_coadd2d_sp_order_7.fits
# -----------------------------------------------
#
# Loading file J0147_spectra/J0147_coadd2d_var_order_7.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from J0147_spectra/J0147_coadd2d_sp_order_7.fits (HDU=0)
# Final data dimensions (x y): 4096 x 124
#
# Dispersion axis:              x
# N_pixels along dispersion axis: 4096
#
#
# Loading file J0147_spectra/J0147_coadd2d_sp_order_8.fits
# -----------------------------------------------
#
# Loading file J0147_spectra/J0147_coadd2d_var_order_8.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from J0147_spectra/J0147_coadd2d_sp_order_8.fits (HDU=0)
# Final data dimensions (x y): 4096 x 121
#
# Dispersion axis:              x
# N_pixels along dispersion axis: 4096
#
#
# Loading file J0147_spectra/J0147_coadd2d_sp_order_9.fits
# -----------------------------------------------
#
# Loading file J0147_spectra/J0147_coadd2d_var_order_9.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from J0147_spectra/J0147_coadd2d_sp_order_9.fits (HDU=0)
# Final data dimensions (x y): 4096 x 117
#
# Dispersion axis:              x
# N_pixels along dispersion axis: 4096
#
#
# Loading file J0147_spectra/J0147_coadd2d_sp_order_10.fits
# -----------------------------------------------
#
# Loading file J0147_spectra/J0147_coadd2d_var_order_10.fits
# -----------------------------------------------
# Read in 2-dimensional spectrum from J0147_spectra/J0147_coadd2d_sp_order_10.fits (HDU=0)
# Final data dimensions (x y): 4096 x 111
#
# Dispersion axis:              x
# N_pixels along dispersion axis: 4096

# %%
spec_list= [spec_ord_4, spec_ord_5, spec_ord_6, spec_ord_7, spec_ord_8, 
            spec_ord_9, spec_ord_10]
pixrange_list = np.array([[2700, 3000], [2700, 3000], [2700, 3000], [1800, 2200],
                          [1800, 2200], [1500, 1800], [1500, 1800]])
for i, sp in enumerate(spec_list):
    sp.spatial_profile(pixrange=pixrange_list[i])
    plt.show()
    sp.initial_model()
# Out:
# Profile max value (before normalization) 2778.142952
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 3
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 2700, 62.5, 3, 4.765
#
# amplitude=2700.000000, x_0=62.500000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 150, 76.5, 3, 4.765
#
# amplitude=150.000000, x_0=76.500000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 3 : 300, 85, 3, 4.765
#
# amplitude=300.000000, x_0=85.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-4.48258581)>
#
#     [1]: <Moffat1D(amplitude=2794.49063321, x_0=62.30429106, gamma=6.13338494, alpha=2.57294312)>
#
#     [2]: <Moffat1D(amplitude=-21.48225613, x_0=71.89447709, gamma=84.07718783, alpha=28.76786127)>
#
#     [3]: <Moffat1D(amplitude=286.38262658, x_0=84.94239422, gamma=3.39451042, alpha=1.03130407)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_3           alpha_3
#     ------------------ ------------------ ... ----------------- ------------------
#     -4.482585814966173 2794.4906332106634 ... 3.394510420031827 1.0313040737540682
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 2255.623013
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 3
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 2200, 59, 3, 4.765
#
# amplitude=2200.000000, x_0=59.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 150, 72.5, 3,4.765
#
# amplitude=150.000000, x_0=72.500000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 3 : 250, 81, 3, 4.765
#
# amplitude=250.000000, x_0=81.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-2.59151366)>
#
#     [1]: <Moffat1D(amplitude=2309.96143219, x_0=59.63470834, gamma=5.37949984, alpha=2.19640431)>
#
#     [2]: <Moffat1D(amplitude=3.07476163, x_0=72.60560829, gamma=2.1208897, alpha=6.19927866)>
#
#     [3]: <Moffat1D(amplitude=265.52522383, x_0=81.45497768, gamma=4.13806746, alpha=1.51345422)>
# Parameters:
#            c0_0           amplitude_1    ...      gamma_3           alpha_3
#     ------------------ ----------------- ... ----------------- ------------------
#     -2.591513657448093 2309.961432192478 ... 4.138067458035958 1.5134542207011457
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 3062.197787
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 3
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 3000, 54, 3, 4.765
#
# amplitude=3000.000000, x_0=54.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 150, 67, 3, 4.765
#
# amplitude=150.000000, x_0=67.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 3 : 280, 74.5, 3, 4.765
#
# amplitude=280.000000, x_0=74.500000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-4.52266377)>
#
#     [1]: <Moffat1D(amplitude=3105.77755411, x_0=53.84309016, gamma=6.18804427, alpha=2.84466177)>
#
#     [2]: <Moffat1D(amplitude=-5.35667043, x_0=61.6389759, gamma=-2.22022696, alpha=13.5259195)>
#
#     [3]: <Moffat1D(amplitude=332.22915154, x_0=74.73015968, gamma=3.11046466, alpha=1.0282046)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_3            alpha_3
#     ------------------ ------------------ ... ------------------ ------------------
#     -4.522663769424521 3105.7775541138576 ... 3.1104646550695274 1.0282045952087524
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 2548.956037
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 3
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 2600, 51.5, 3, 4.765
#
# amplitude=2600.000000, x_0=51.500000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 150, 64, 3, 4.765
#
# amplitude=150.000000, x_0=64.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 3 : 300, 72, 3, 4.765
#
# amplitude=300.000000, x_0=72.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.21084014)>
#
#     [1]: <Moffat1D(amplitude=2542.85233161, x_0=52.43505903, gamma=4.64572711, alpha=1.98148818)>
#
#     [2]: <Moffat1D(amplitude=118.57542418, x_0=60.78306089, gamma=8.20815133, alpha=1.05215408)>
#
#     [3]: <Moffat1D(amplitude=250.42764327, x_0=73.04770569, gamma=4.35352657, alpha=2.10809335)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_3           alpha_3
#     ------------------ ------------------ ... ----------------- ------------------
#     0.2108401414375507 2542.8523316101137 ... 4.353526565878251 2.1080933505696793
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 2878.403057
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 3
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 2800, 50.5, 3, 4.76
#
# amplitude=2800.000000, x_0=50.500000, gamma=3.000000, alpha=4.760000
#
# Parameters of Moffat profile 2 : 150, 63, 3, 4.765
#
# amplitude=150.000000, x_0=63.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 3 : 300, 70.5, 3, 4.765
#
# amplitude=300.000000, x_0=70.500000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-5.46696163)>
#
#     [1]: <Moffat1D(amplitude=2850.82855063, x_0=51.49217056, gamma=4.65892627, alpha=1.98470759)>
#
#     [2]: <Moffat1D(amplitude=143.66919288, x_0=59.36916508, gamma=6.41394463, alpha=0.75989757)>
#
#     [3]: <Moffat1D(amplitude=266.6590207, x_0=71.56747484, gamma=4.39304198, alpha=2.12195393)>
# Parameters:
#             c0_0           amplitude_1    ...     gamma_3           alpha_3
#     ------------------- ----------------- ... ---------------- ------------------
#     -5.4669616346836385 2850.828550633148 ... 4.39304198324723 2.1219539275586587
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 3147.126035
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 3
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 :  3100, 50, 3, 4.765
#
# amplitude=3100.000000, x_0=50.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 150, 61.5, 3, 4.765
#
# amplitude=150.000000, x_0=61.500000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 3 : 300, 69.5, 3, 4.765
#
# amplitude=300.000000, x_0=69.500000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.1496237)>
#
#     [1]: <Moffat1D(amplitude=3128.04196689, x_0=49.4661409, gamma=6.62523908, alpha=3.71984633)>
#
#     [2]: <Moffat1D(amplitude=179.62982979, x_0=55.00771048, gamma=-2.99299724, alpha=1.67192573)>
#
#     [3]: <Moffat1D(amplitude=319.56040671, x_0=68.8232912, gamma=6.49420913, alpha=3.11757134)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_3           alpha_3
#     ------------------- ----------------- ... ----------------- -----------------
#     -1.1496236963596873 3128.041966891099 ... 6.494209130427684 3.117571341567012
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no
# Profile max value (before normalization) 896.459857
# To create an initial model you first need to enter degree of background polynomial(<3) and number of Gaussian and Moffat profile as integers.
# Order of background polynomial : 0
# Number of Gaussian profile : 0
# Number of Moffat profile : 3
#
# Now enter constants of the background polynomial upto degree 0
# c0 : 1
#
# Enter parameter values for a Moffat profile in following format...
# amplitude_value, x_0_value, gamma_value, alpha_value
#
# Parameters of Moffat profile 1 : 870, 47, 3, 4.765
#
# amplitude=870.000000, x_0=47.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 2 : 50, 59, 3, 4.765
#
# amplitude=50.000000, x_0=59.000000, gamma=3.000000, alpha=4.765000
#
# Parameters of Moffat profile 3 : 70, 66, 3, 4.765
#
# amplitude=70.000000, x_0=66.000000, gamma=3.000000, alpha=4.765000
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-3.39245385)>
#
#     [1]: <Moffat1D(amplitude=854.73860246, x_0=47.94222462, gamma=5.0856469, alpha=2.70136195)>
#
#     [2]: <Moffat1D(amplitude=38.88566189, x_0=53.28765971, gamma=15.47875721, alpha=1.38182588)>
#
#     [3]: <Moffat1D(amplitude=70.66729035, x_0=66.99759603, gamma=3.98369508, alpha=1.66261364)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_3           alpha_3
#     ------------------- ----------------- ... ----------------- ------------------
#     -3.3924538471820433 854.7386024577354 ... 3.983695080113781 1.6626136383996615
#
# -------------------------------------------
# Do you want to start over ? : type yes/no
# no

# %%
def tie_pos1_moffat_4(model):
    return model.x_0_1 + (1.95 / pixscale[0]) #(0.886 / pixscale)

def tie_pos2_moffat_4(model):
    return model.x_0_1 + (3.15 / pixscale[0])  #(1.87 / pixscale) 

def tie_pos1_moffat_5(model):
    return model.x_0_1 + (1.95 / pixscale[1]) #(0.886 / pixscale)

def tie_pos2_moffat_5(model):
    return model.x_0_1 + (3.15 / pixscale[1])  #(1.87 / pixscale) 

def tie_pos1_moffat_6(model):
    return model.x_0_1 + (1.95 / pixscale[2]) #(0.886 / pixscale)

def tie_pos2_moffat_6(model):
    return model.x_0_1 + (3.15 / pixscale[2])

def tie_pos1_moffat_7(model):
    return model.x_0_1 + (1.95 / pixscale[3]) #(0.886 / pixscale)

def tie_pos2_moffat_7(model):
    return model.x_0_1 + (3.15 / pixscale[3])  #(1.87 / pixscale) 

def tie_pos1_moffat_8(model):
    return model.x_0_1 + (1.95 /  pixscale[4]) #(0.886 / pixscale)

def tie_pos2_moffat_8(model):
    return model.x_0_1 + (3.15 /  pixscale[4])  #(1.87 / pixscale) 

def tie_pos1_moffat_9(model):
    return model.x_0_1 + (1.95 /  pixscale[5]) #(0.886 / pixscale)

def tie_pos2_moffat_9(model):
    return model.x_0_1 + (3.15 /  pixscale[5])  #(1.87 / pixscale) 

def tie_pos1_moffat_10(model):
    return model.x_0_1 + (1.95 /  pixscale[6]) #(0.886 / pixscale)

def tie_pos2_moffat_10(model):
    return model.x_0_1 + (3.15 /  pixscale[6])  #(1.87 / pixscale) 

def tie_gamma_moffat(model):
    return model.gamma_3

def tie_alpha_moffat(model):
    return model.alpha_3

func_dict = {'4_1' : tie_pos1_moffat_4, '4_2' : tie_pos2_moffat_4,
             '5_1' : tie_pos1_moffat_5, '5_2' : tie_pos2_moffat_5,
             '6_1' : tie_pos1_moffat_6, '6_2' : tie_pos2_moffat_6,
             '7_1' : tie_pos1_moffat_7, '7_2' : tie_pos2_moffat_7,
             '8_1' : tie_pos1_moffat_8, '8_2' : tie_pos2_moffat_8,
             '9_1' : tie_pos1_moffat_9, '9_2' : tie_pos2_moffat_9,
             '10_1' : tie_pos1_moffat_10, '10_2' : tie_pos2_moffat_10
            }
pixscale = [0.137, 0.144, 0.149, 0.153, 0.158, 0.163, 0.168]
ord_list = [4, 5, 6, 7, 8, 9, 10]
for i, sp in enumerate(spec_list):
    if sp.mod0 is not None:
        print(pixscale[i])
        sp.mod0[2].x_0.tied = func_dict['%d_%d' %(ord_list[i], 1)] #tie_pos1_moffat
        sp.mod0[3].x_0.tied = func_dict['%d_%d' %(ord_list[i], 2)] #tie_pos2_moffat
        sp.mod0[1].gamma.tied = tie_gamma_moffat
        sp.mod0[1].alpha.tied = tie_alpha_moffat
        sp.mod0[2].gamma.tied = tie_gamma_moffat
        sp.mod0[2].alpha.tied = tie_alpha_moffat
        sp.refined_model(sp.mod0)
# Out:
# 0.137
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-4.48258581)>
#
#     [1]: <Moffat1D(amplitude=2794.49063321, x_0=62.30429106, gamma=6.13338494, alpha=2.57294312)>
#
#     [2]: <Moffat1D(amplitude=-21.48225613, x_0=71.89447709, gamma=84.07718783, alpha=28.76786127)>
#
#     [3]: <Moffat1D(amplitude=286.38262658, x_0=84.94239422, gamma=3.39451042, alpha=1.03130407)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_3           alpha_3
#     ------------------ ------------------ ... ----------------- ------------------
#     -4.482585814966173 2794.4906332106634 ... 3.394510420031827 1.0313040737540682
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-2.16241805)>
#
#     [1]: <Moffat1D(amplitude=2795.5479311, x_0=62.30531179, gamma=6.25601564, alpha=2.67271446)>
#
#     [2]: <Moffat1D(amplitude=27.15190802, x_0=76.53888843, gamma=6.25601564, alpha=2.67271446)>
#
#     [3]: <Moffat1D(amplitude=270.47184267, x_0=85.29801252, gamma=6.25601564, alpha=2.67271446)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_3           alpha_3
#     ------------------- ------------------ ... ----------------- ------------------
#     -2.1624180493034486 2795.5479310972646 ... 6.256015638253954 2.6727144563207785
#
# -------------------------------------------
# 0.144
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-2.59151366)>
#
#     [1]: <Moffat1D(amplitude=2309.96143219, x_0=59.63470834, gamma=5.37949984, alpha=2.19640431)>
#
#     [2]: <Moffat1D(amplitude=3.07476163, x_0=72.60560829, gamma=2.1208897, alpha=6.19927866)>
#
#     [3]: <Moffat1D(amplitude=265.52522383, x_0=81.45497768, gamma=4.13806746, alpha=1.51345422)>
# Parameters:
#            c0_0           amplitude_1    ...      gamma_3           alpha_3
#     ------------------ ----------------- ... ----------------- ------------------
#     -2.591513657448093 2309.961432192478 ... 4.138067458035958 1.5134542207011457
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.39214091)>
#
#     [1]: <Moffat1D(amplitude=2295.45623729, x_0=59.64731058, gamma=6.2067142, alpha=2.76109474)>
#
#     [2]: <Moffat1D(amplitude=20.43767078, x_0=73.18897724, gamma=6.2067142, alpha=2.76109474)>
#
#     [3]: <Moffat1D(amplitude=253.55616522, x_0=81.52231058, gamma=6.2067142, alpha=2.76109474)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_3           alpha_3
#     ------------------- ----------------- ... ----------------- ------------------
#     -1.3921409091817585 2295.456237294534 ... 6.206714196714998 2.7610947362378906
#
# -------------------------------------------
# 0.149
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-4.52266377)>
#
#     [1]: <Moffat1D(amplitude=3105.77755411, x_0=53.84309016, gamma=6.18804427, alpha=2.84466177)>
#
#     [2]: <Moffat1D(amplitude=-5.35667043, x_0=61.6389759, gamma=-2.22022696, alpha=13.5259195)>
#
#     [3]: <Moffat1D(amplitude=332.22915154, x_0=74.73015968, gamma=3.11046466, alpha=1.0282046)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_3            alpha_3
#     ------------------ ------------------ ... ------------------ ------------------
#     -4.522663769424521 3105.7775541138576 ... 3.1104646550695274 1.0282045952087524
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.6867979)>
#
#     [1]: <Moffat1D(amplitude=3107.13351426, x_0=53.84751028, gamma=6.35847194, alpha=2.99249774)>
#
#     [2]: <Moffat1D(amplitude=36.51823491, x_0=66.93475861, gamma=6.35847194, alpha=2.99249774)>
#
#     [3]: <Moffat1D(amplitude=311.84410926, x_0=74.98844988, gamma=6.35847194, alpha=2.99249774)>
# Parameters:
#             c0_0           amplitude_1     ...      gamma_3           alpha_3
#     ------------------- ------------------ ... ----------------- -----------------
#     -1.6867978993124921 3107.1335142579896 ... 6.358471938212655 2.992497738636706
#
# -------------------------------------------
# 0.153
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=0.21084014)>
#
#     [1]: <Moffat1D(amplitude=2542.85233161, x_0=52.43505903, gamma=4.64572711, alpha=1.98148818)>
#
#     [2]: <Moffat1D(amplitude=118.57542418, x_0=60.78306089, gamma=8.20815133, alpha=1.05215408)>
#
#     [3]: <Moffat1D(amplitude=250.42764327, x_0=73.04770569, gamma=4.35352657, alpha=2.10809335)>
# Parameters:
#            c0_0           amplitude_1     ...      gamma_3           alpha_3
#     ------------------ ------------------ ... ----------------- ------------------
#     0.2108401414375507 2542.8523316101137 ... 4.353526565878251 2.1080933505696793
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.41888981)>
#
#     [1]: <Moffat1D(amplitude=2589.49560428, x_0=52.86670846, gamma=6.56736599, alpha=3.15422838)>
#
#     [2]: <Moffat1D(amplitude=40.84219363, x_0=65.6118065, gamma=6.56736599, alpha=3.15422838)>
#
#     [3]: <Moffat1D(amplitude=283.66555859, x_0=73.45494376, gamma=6.56736599, alpha=3.15422838)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_3           alpha_3
#     ------------------- ----------------- ... ----------------- ------------------
#     -1.4188898077406982 2589.495604280973 ... 6.567365990106266 3.1542283767782604
#
# -------------------------------------------
# 0.158
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-5.46696163)>
#
#     [1]: <Moffat1D(amplitude=2850.82855063, x_0=51.49217056, gamma=4.65892627, alpha=1.98470759)>
#
#     [2]: <Moffat1D(amplitude=143.66919288, x_0=59.36916508, gamma=6.41394463, alpha=0.75989757)>
#
#     [3]: <Moffat1D(amplitude=266.6590207, x_0=71.56747484, gamma=4.39304198, alpha=2.12195393)>
# Parameters:
#             c0_0           amplitude_1    ...     gamma_3           alpha_3
#     ------------------- ----------------- ... ---------------- ------------------
#     -5.4669616346836385 2850.828550633148 ... 4.39304198324723 2.1219539275586587
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-2.22852517)>
#
#     [1]: <Moffat1D(amplitude=2913.19496076, x_0=51.96018832, gamma=7.18064769, alpha=3.64440264)>
#
#     [2]: <Moffat1D(amplitude=59.96644167, x_0=64.30196047, gamma=7.18064769, alpha=3.64440264)>
#
#     [3]: <Moffat1D(amplitude=308.59362705, x_0=71.89689718, gamma=7.18064769, alpha=3.64440264)>
# Parameters:
#            c0_0           amplitude_1     ...     gamma_3           alpha_3
#     ------------------ ------------------ ... ---------------- ------------------
#     -2.228525166541304 2913.1949607629413 ... 7.18064768779382 3.6444026385302903
#
# -------------------------------------------
# 0.163
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.1496237)>
#
#     [1]: <Moffat1D(amplitude=3128.04196689, x_0=49.4661409, gamma=6.62523908, alpha=3.71984633)>
#
#     [2]: <Moffat1D(amplitude=179.62982979, x_0=55.00771048, gamma=-2.99299724, alpha=1.67192573)>
#
#     [3]: <Moffat1D(amplitude=319.56040671, x_0=68.8232912, gamma=6.49420913, alpha=3.11757134)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_3           alpha_3
#     ------------------- ----------------- ... ----------------- -----------------
#     -1.1496236963596873 3128.041966891099 ... 6.494209130427684 3.117571341567012
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-2.001481)>
#
#     [1]: <Moffat1D(amplitude=3168.57698853, x_0=49.5988388, gamma=7.17339008, alpha=3.92490647)>
#
#     [2]: <Moffat1D(amplitude=71.92419654, x_0=61.56202899, gamma=7.17339008, alpha=3.92490647)>
#
#     [3]: <Moffat1D(amplitude=310.93735754, x_0=68.92399218, gamma=7.17339008, alpha=3.92490647)>
# Parameters:
#             c0_0           amplitude_1     ...     gamma_3           alpha_3
#     ------------------- ------------------ ... ---------------- -----------------
#     -2.0014810012654527 3168.5769885269424 ... 7.17339008229631 3.924906471610258
#
# -------------------------------------------
# 0.168
#
# Initial model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-3.39245385)>
#
#     [1]: <Moffat1D(amplitude=854.73860246, x_0=47.94222462, gamma=5.0856469, alpha=2.70136195)>
#
#     [2]: <Moffat1D(amplitude=38.88566189, x_0=53.28765971, gamma=15.47875721, alpha=1.38182588)>
#
#     [3]: <Moffat1D(amplitude=70.66729035, x_0=66.99759603, gamma=3.98369508, alpha=1.66261364)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_3           alpha_3
#     ------------------- ----------------- ... ----------------- ------------------
#     -3.3924538471820433 854.7386024577354 ... 3.983695080113781 1.6626136383996615
#
# -------------------------------------------
#
#
# Fitted model
# -------------
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] + [1] + [2] + [3]
# Components:
#     [0]: <Polynomial1D(0, c0=-1.79089337)>
#
#     [1]: <Moffat1D(amplitude=904.27315969, x_0=48.07579882, gamma=4.75588009, alpha=2.20496813)>
#
#     [2]: <Moffat1D(amplitude=26.63800331, x_0=59.68294168, gamma=4.75588009, alpha=2.20496813)>
#
#     [3]: <Moffat1D(amplitude=91.29406749, x_0=66.82579882, gamma=4.75588009, alpha=2.20496813)>
# Parameters:
#             c0_0           amplitude_1    ...      gamma_3           alpha_3
#     ------------------- ----------------- ... ----------------- ------------------
#     -1.7908933694234432 904.2731596891579 ... 4.755880093871405 2.2049681304422624
#
# -------------------------------------------

# %%
fitrange_list = np.array([[1000, 4100], [1000, 4100], [1000, 4100], [0, 4100],
                          [0, 4100], [0, 4100], [0, 4100]])
for i, sp in enumerate(spec_list):
    sp.find_and_trace(sp.mod0, stepsize=25, fitorder={'x_0_1':4, 'mean_1':4, 'x_0_2':4, 'x_0_3':4},
                    fitrange=fitrange_list[i], polyorder=3)
    plt.show()
# Out:
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: x_0_1
# Fitting polynomial of degree 3 to parameter: gamma_1
# Fitting polynomial of degree 3 to parameter: alpha_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: x_0_1
# Fitting polynomial of degree 3 to parameter: gamma_1
# Fitting polynomial of degree 3 to parameter: alpha_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: x_0_1
# Fitting polynomial of degree 3 to parameter: gamma_1
# Fitting polynomial of degree 3 to parameter: alpha_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: x_0_1
# Fitting polynomial of degree 3 to parameter: gamma_1
# Fitting polynomial of degree 3 to parameter: alpha_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: x_0_1
# Fitting polynomial of degree 3 to parameter: gamma_1
# Fitting polynomial of degree 3 to parameter: alpha_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: x_0_1
# Fitting polynomial of degree 3 to parameter: gamma_1
# Fitting polynomial of degree 3 to parameter: alpha_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3
# Running fit_trace
# ---------------------------------------------------------
# Fitting to the trace at 163 segments
#   of the 2D spectrum with stepsize=25 pix ...
#     Done
# Fitting polynomial of degree 3 to parameter: c0_0
# Fitting polynomial of degree 4 to parameter: x_0_1
# Fitting polynomial of degree 3 to parameter: gamma_1
# Fitting polynomial of degree 3 to parameter: alpha_1
# Fitting polynomial of degree 4 to parameter: x_0_2
# Fitting polynomial of degree 3 to parameter: gamma_2
# Fitting polynomial of degree 3 to parameter: alpha_2
# Fitting polynomial of degree 4 to parameter: x_0_3
# Fitting polynomial of degree 3 to parameter: gamma_3
# Fitting polynomial of degree 3 to parameter: alpha_3

# %%
extrange_list = np.array([[1200, -1], [1100, -1], [900, -1], [600, -1], 
                          [200, -1], [0, -1], [0, 2000]])
for sp, ext in zip(spec_list, extrange_list):
    sp.extract(method='modelfit', extrange=ext)
    plt.show()
# Out:
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1200 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#  Spectrum Start:  4902.88
#  Spectrum End:     5472.92
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.20
#
#
# Plotting the spectrum
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 1100 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  5325.24
#  Spectrum End:     5967.01
#  Dispersion (1st pixel):   0.20
#  Dispersion (average):      0.21
#
#  Spectrum Start:  5325.24
#  Spectrum End:     5967.01
#  Dispersion (1st pixel):   0.20
#  Dispersion (average):      0.21
#
#  Spectrum Start:  5325.24
#  Spectrum End:     5967.01
#  Dispersion (1st pixel):   0.20
#  Dispersion (average):      0.21
#
#
# Plotting the spectrum
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 900 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  5810.63
#  Spectrum End:     6560.55
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#  Spectrum Start:  5810.63
#  Spectrum End:     6560.55
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#  Spectrum Start:  5810.63
#  Spectrum End:     6560.55
#  Dispersion (1st pixel):   0.22
#  Dispersion (average):      0.23
#
#
# Plotting the spectrum
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 600 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  6380.37
#  Spectrum End:     7286.41
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#  Spectrum Start:  6380.37
#  Spectrum End:     7286.41
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#  Spectrum Start:  6380.37
#  Spectrum End:     7286.41
#  Dispersion (1st pixel):   0.24
#  Dispersion (average):      0.26
#
#
# Plotting the spectrum
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 200 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  7066.66
#  Spectrum End:     8193.74
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29
#
#  Spectrum Start:  7066.66
#  Spectrum End:     8193.74
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29
#
#  Spectrum Start:  7066.66
#  Spectrum End:     8193.74
#  Dispersion (1st pixel):   0.27
#  Dispersion (average):      0.29
#
#
# Plotting the spectrum
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 0 - 4096
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  8012.11
#  Spectrum End:     9360.83
#  Dispersion (1st pixel):   0.30
#  Dispersion (average):      0.33
#
#  Spectrum Start:  8012.11
#  Spectrum End:     9360.83
#  Dispersion (1st pixel):   0.30
#  Dispersion (average):      0.33
#
#  Spectrum Start:  8012.11
#  Spectrum End:     9360.83
#  Dispersion (1st pixel):   0.30
#  Dispersion (average):      0.33
#
#
# Plotting the spectrum
# Fitting to 3 components, plus a background
# Extracting the spectrum.  Please be patient
#  Extraction range (pixels): 0 - 2000
# Fitting to the trace at 4096 segments
#   of the 2D spectrum with stepsize=1 pix ...
#  Spectrum Start:  9337.74
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.35
#  Dispersion (average):      0.37
#
#  Spectrum Start:  9337.74
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.35
#  Dispersion (average):      0.37
#
#  Spectrum Start:  9337.74
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.35
#  Dispersion (average):      0.37
#
#
# Plotting the spectrum

# %%
outspec = []
orderinfo = np.array([4, 5, 6, 7, 8, 9, 10], dtype=[('order', int)])

# %%
for i, spp in enumerate(spec_ord_4.spectra):
    s = []
    for sp in spec_list:
        s.append(sp.spectra[i][1])
    outspec.append(echelle1d.Ech1d(s, ordinfo=orderinfo))
# Out:
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   4  2896   4902.88  5472.92   0.20
#   5  2996   5325.24  5967.01   0.21
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.66  8193.74   0.29
#   9  4096   8012.11  9360.83   0.33
#  10  2000   9337.74 10074.55   0.37
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   4  2896   4902.88  5472.92   0.20
#   5  2996   5325.24  5967.01   0.21
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.66  8193.74   0.29
#   9  4096   8012.11  9360.83   0.33
#  10  2000   9337.74 10074.55   0.37
# Ord N_pix lam_start lam_end  dispave
# --- ----- --------- -------- -------
#   4  2896   4902.88  5472.92   0.20
#   5  2996   5325.24  5967.01   0.21
#   6  3196   5810.63  6560.55   0.23
#   7  3496   6380.37  7286.41   0.26
#   8  3896   7066.66  8193.74   0.29
#   9  4096   8012.11  9360.83   0.33
#  10  2000   9337.74 10074.55   0.37

# %%
outspec[0].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))
outspec[1].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))
outspec[2].plot_all(fig=plt.figure(figsize=(10,7)), ax=plt.subplot(111))

# %%
outspec[0].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt', order=[4, 10])
# Out:
#  Spectrum Start:     3.69
#  Spectrum End:        4.00
#  Dispersion (1st pixel): 1.65e-05
#  Dispersion (average):    1.65e-05

# %%
outspec[1].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt', order=[4, 10])
# Out:
#  Spectrum Start:     3.69
#  Spectrum End:        4.00
#  Dispersion (1st pixel): 1.65e-05
#  Dispersion (average):    1.65e-05

# %%
outspec[2].stitch_to_spec1d(respfile='response_curve_ESI_optimal_smooth_new.txt', order=[4, 10])
# Out:
#  Spectrum Start:     3.69
#  Spectrum End:        4.00
#  Dispersion (1st pixel): 1.65e-05
#  Dispersion (average):    1.65e-05

# %%
outspec[1].save_multi('esi1d_J0147_coadd2d_three_moffat_deflector')
outspec[0].save_multi('esi1d_J0147_coadd2d_three_moffat_primary')
outspec[2].save_multi('esi1d_J0147_coadd2d_three_moffat_secondary')
# Out:
# Spectrum saved in mode multitab to file esi1d_J0147_coadd2d_three_moffat_deflector.fits
# Spectrum saved in mode multitab to file esi1d_J0147_coadd2d_three_moffat_primary.fits
# Spectrum saved in mode multitab to file esi1d_J0147_coadd2d_three_moffat_secondary.fits

# %%
outspec[1].spec1d.save('spec1d_J0147_coadd2d_three_moffat_deflector.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0147_coadd2d_three_moffat_deflector.fits in format fits

# %%
outspec[0].spec1d.save('spec1d_J0147_coadd2d_three_moffat_primary.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0147_coadd2d_three_moffat_primary.fits in format fits

# %%
outspec[2].spec1d.save('spec1d_J0147_coadd2d_three_moffat_secondary.fits', outformat='fits')
# Out:
# Saved spectrum to file spec1d_J0147_coadd2d_three_moffat_secondary.fits in format fits

# %%
sp1d = spec1d.Spec1d('spec1d_J0147_coadd2d_three_moffat_deflector.fits', informat='fits', 
                     logwav=True, trimsec=[5300, -1])
# Out:
# Reading spectrum from spec1d_J0147_coadd2d_three_moffat_deflector.fits
# Expected file format: fits
#  Spectrum Start:  5996.55
#  Spectrum End:    10074.16
#  Dispersion (1st pixel):   0.23
#  Dispersion (average):      0.30

# %%
# %matplotlib notebook
sp1d.smooth(9)
sp1d.mark_lines('abs', z=0.678, usesmooth=True)
# Out:
# <img src="data:image/png;base64,..." width="944.5454340729837">
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# H-kappa       3750.00       6292.50
# [Fe VII]      3761.40       6311.63
# H-iota        3770.00       6326.06
# H-theta       3797.00       6371.37
# H-eta         3835.00       6435.13
# CN bandhd     3883.00       6515.67
# CaII K        3933.67       6600.70
# CaII H        3968.47       6659.09
# H-delta       4101.00       6881.48
# G-band        4305.00       7223.79
# H-gamma       4340.00       7282.52
# Fe4383        4383.00       7354.67
# Ca4455        4455.00       7475.49
# Fe4531        4531.00       7603.02
# H-beta        4861.00       8156.76
# Mg I (b)      5176.00       8685.33
# Na I (D)      5889.95       9883.34
# Na I (D)      5895.92       9893.35

# %%
qim1 = spec1d.Spec1d('spec1d_J0147_coadd2d_three_moffat_primary.fits', informat='fits',
                     logwav=True)
# Out:
# Reading spectrum from spec1d_J0147_coadd2d_three_moffat_primary.fits
# Expected file format: fits
#  Spectrum Start:  4902.88
#  Spectrum End:    10074.55
#  Dispersion (1st pixel):   0.19
#  Dispersion (average):      0.27

# %%
qim1.plot()
qim1.mark_lines('abs', z=2.341)
qim1.mark_lines('em', z=2.341)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# Fe III        2075.00       6932.58
# Fe II         2375.00       7934.88
# Fe II         2383.00       7961.60
# Fe II         2587.00       8643.17
# Fe II         2600.00       8686.60
# Fe II         2750.30       9188.75
# Mg II         2795.53       9339.87
# Mg II         2802.71       9363.85
# Mg I          2852.00       9528.53
#
#
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# N IV]         1486.50       4966.40
# C IV          1549.10       5175.54
# He II         1640.50       5480.91
# O III]        1663.00       5556.08
# N III]        1750.40       5848.09
# Al III        1858.70       6209.92
# Si III]       1892.00       6321.17
# C III]        1908.70       6376.97
# C II]         2326.00       7771.17
# [Ne IV]       2423.00       8095.24
# Mg II         2799.80       9354.13
